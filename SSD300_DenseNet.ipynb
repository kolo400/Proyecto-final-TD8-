# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]




def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)




def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())


train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        img = read_image(path_base + '/Imagenes/' + item['image_filename'])


        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])


        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])




        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)


        if self.transform:
            img, target = self.transform(img, target)
        return img, target



train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))


print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import  ssd300_DenseNet


model = ssd300_DenseNet(pretrained=False)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 105MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background


in_channels = [128, 1024, 512, 256, 256, 256]
num_anchors = [4, 6, 6, 6, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:

        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()


        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-18 12:46:31--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-18 12:46:31 (74.2 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-18 12:46:31--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-18 12:46:31 (98.0 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-18 12:46:31--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-18 12:46:31 (116 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-18 12:46:31--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-18 12:46:32 (109 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-18 12:46:32--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.002s
#
# 2024-11-18 12:46:32 (14.3 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# Epoch: [0]  [ 0/22]  eta: 0:04:30  lr: 0.000146  time: 12.2796  data: 9.0502  max mem: 3892
# Epoch: [0]  [20/22]  eta: 0:00:13  lr: 0.003000  time: 6.5892  data: 6.3062  max mem: 3892
# Epoch: [0]  [21/22]  eta: 0:00:06  lr: 0.003000  time: 6.5395  data: 6.2656  max mem: 3892
# Epoch: [0] Total time: 0:02:30 (6.8392 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:11  model_time: 0.1863 (0.1863)  evaluator_time: 0.0239 (0.0239)  time: 0.2757  data: 0.0617  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0149)  evaluator_time: 0.0126 (0.0337)  time: 0.1004  data: 0.0564  max mem: 3892
# Test: Total time: 0:00:04 (0.1108 s / it)
# Averaged stats: model_time: 0.0106 (0.0149)  evaluator_time: 0.0126 (0.0337)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.042
# Epoch: [1]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4451  data: 1.9472  max mem: 3892
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1782  data: 1.8744  max mem: 3892
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1777  data: 1.8665  max mem: 3892
# Epoch: [1] Total time: 0:00:48 (2.2035 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0270 (0.0270)  time: 0.1035  data: 0.0618  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0103 (0.0104)  evaluator_time: 0.0164 (0.0374)  time: 0.1011  data: 0.0569  max mem: 3892
# Test: Total time: 0:00:04 (0.1103 s / it)
# Averaged stats: model_time: 0.0103 (0.0104)  evaluator_time: 0.0164 (0.0374)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.053
# Epoch: [2]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2506  data: 1.8592  max mem: 3892
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0897  data: 1.8016  max mem: 3892
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0762  data: 1.7855  max mem: 3892
# Epoch: [2] Total time: 0:00:46 (2.0994 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0109 (0.0109)  evaluator_time: 0.0262 (0.0262)  time: 0.1020  data: 0.0612  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0102)  evaluator_time: 0.0224 (0.0347)  time: 0.1033  data: 0.0571  max mem: 3892
# Test: Total time: 0:00:04 (0.1074 s / it)
# Averaged stats: model_time: 0.0101 (0.0102)  evaluator_time: 0.0224 (0.0347)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.164
# Epoch: [3]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5488  data: 2.3080  max mem: 3892
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0536  data: 1.7631  max mem: 3892
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0785  data: 1.7779  max mem: 3892
# Epoch: [3] Total time: 0:00:45 (2.0909 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0248 (0.0248)  time: 0.1016  data: 0.0620  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0103)  evaluator_time: 0.0221 (0.0331)  time: 0.1027  data: 0.0566  max mem: 3892
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0100 (0.0103)  evaluator_time: 0.0221 (0.0331)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
# Epoch: [4]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8697  data: 1.5496  max mem: 3892
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0579  data: 1.7855  max mem: 3892
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0602  data: 1.7822  max mem: 3892
# Epoch: [4] Total time: 0:00:45 (2.0592 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0265 (0.0265)  time: 0.1023  data: 0.0612  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0103)  evaluator_time: 0.0237 (0.0337)  time: 0.1035  data: 0.0560  max mem: 3892
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0102 (0.0103)  evaluator_time: 0.0237 (0.0337)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
# Epoch: [5]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0378  data: 1.8494  max mem: 3892
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1193  data: 1.8072  max mem: 3892
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1163  data: 1.8031  max mem: 3892
# Epoch: [5] Total time: 0:00:46 (2.1183 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0262 (0.0262)  time: 0.1020  data: 0.0612  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0229 (0.0330)  time: 0.1012  data: 0.0560  max mem: 3892
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0229 (0.0330)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.266
# Epoch: [6]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2529  data: 1.9434  max mem: 3892
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1838  data: 1.8897  max mem: 3892
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1486  data: 1.8667  max mem: 3892
# Epoch: [6] Total time: 0:00:47 (2.1682 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0279 (0.0279)  time: 0.1044  data: 0.0617  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0103)  evaluator_time: 0.0221 (0.0334)  time: 0.1028  data: 0.0559  max mem: 3892
# Test: Total time: 0:00:04 (0.1062 s / it)
# Averaged stats: model_time: 0.0101 (0.0103)  evaluator_time: 0.0221 (0.0334)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.302
# Epoch: [7]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0904  data: 1.7356  max mem: 3892
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0699  data: 1.7707  max mem: 3892
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0711  data: 1.7756  max mem: 3892
# Epoch: [7] Total time: 0:00:45 (2.0787 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0108 (0.0108)  evaluator_time: 0.0279 (0.0279)  time: 0.1034  data: 0.0610  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0102)  evaluator_time: 0.0240 (0.0337)  time: 0.1047  data: 0.0560  max mem: 3892
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0101 (0.0102)  evaluator_time: 0.0240 (0.0337)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.318
# Epoch: [8]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7857  data: 1.5095  max mem: 3892
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0392  data: 1.7629  max mem: 3892
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0498  data: 1.7714  max mem: 3892
# Epoch: [8] Total time: 0:00:44 (2.0334 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:09  model_time: 0.0108 (0.0108)  evaluator_time: 0.1615 (0.1615)  time: 0.2385  data: 0.0626  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0239 (0.0365)  time: 0.1036  data: 0.0559  max mem: 3892
# Test: Total time: 0:00:04 (0.1085 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0239 (0.0365)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.338
# Epoch: [9]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.9063  data: 1.6127  max mem: 3892
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1593  data: 1.8550  max mem: 3892
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1068  data: 1.8112  max mem: 3892
# Epoch: [9] Total time: 0:00:46 (2.1240 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0253 (0.0253)  time: 0.1014  data: 0.0618  max mem: 3892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0103)  evaluator_time: 0.0217 (0.0321)  time: 0.1054  data: 0.0591  max mem: 3892
# Test: Total time: 0:00:04 (0.1062 s / it)
# Averaged stats: model_time: 0.0102 (0.0103)  evaluator_time: 0.0217 (0.0321)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.345
# Epoch: [10]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6409  data: 1.4723  max mem: 3892
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0274  data: 1.7567  max mem: 3990
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0345  data: 1.7630  max mem: 3990
# Epoch: [10] Total time: 0:00:44 (2.0172 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0120 (0.0120)  evaluator_time: 0.0291 (0.0291)  time: 0.1096  data: 0.0647  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0104)  evaluator_time: 0.0239 (0.0336)  time: 0.1044  data: 0.0564  max mem: 3990
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0102 (0.0104)  evaluator_time: 0.0239 (0.0336)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.347
# Epoch: [11]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7215  data: 1.5681  max mem: 3990
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0456  data: 1.7599  max mem: 3990
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0239  data: 1.7405  max mem: 3990
# Epoch: [11] Total time: 0:00:44 (2.0170 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0269 (0.0269)  time: 0.1030  data: 0.0619  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0101)  evaluator_time: 0.0247 (0.0338)  time: 0.1031  data: 0.0561  max mem: 3990
# Test: Total time: 0:00:04 (0.1060 s / it)
# Averaged stats: model_time: 0.0099 (0.0101)  evaluator_time: 0.0247 (0.0338)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [12]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8737  data: 1.5912  max mem: 3990
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0120  data: 1.7397  max mem: 3990
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0317  data: 1.7559  max mem: 3990
# Epoch: [12] Total time: 0:00:44 (2.0256 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0109 (0.0109)  evaluator_time: 0.0267 (0.0267)  time: 0.1026  data: 0.0613  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0097 (0.0101)  evaluator_time: 0.0214 (0.0324)  time: 0.1019  data: 0.0558  max mem: 3990
# Test: Total time: 0:00:04 (0.1044 s / it)
# Averaged stats: model_time: 0.0097 (0.0101)  evaluator_time: 0.0214 (0.0324)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.366
# Epoch: [13]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7192  data: 1.4571  max mem: 3990
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0346  data: 1.7472  max mem: 3990
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0192  data: 1.7342  max mem: 3990
# Epoch: [13] Total time: 0:00:44 (2.0168 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0267 (0.0267)  time: 0.1030  data: 0.0616  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0100)  evaluator_time: 0.0235 (0.0330)  time: 0.1042  data: 0.0561  max mem: 3990
# Test: Total time: 0:00:04 (0.1052 s / it)
# Averaged stats: model_time: 0.0099 (0.0100)  evaluator_time: 0.0235 (0.0330)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.383
# Epoch: [14]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7255  data: 1.5152  max mem: 3990
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2039  data: 1.9047  max mem: 3990
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1803  data: 1.8841  max mem: 3990
# Epoch: [14] Total time: 0:00:47 (2.1729 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0114 (0.0114)  evaluator_time: 0.0274 (0.0274)  time: 0.1040  data: 0.0615  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0103)  evaluator_time: 0.0227 (0.0323)  time: 0.1026  data: 0.0563  max mem: 3990
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0100 (0.0103)  evaluator_time: 0.0227 (0.0323)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# Epoch: [15]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0904  data: 1.8069  max mem: 3990
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0746  data: 1.7729  max mem: 3990
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0771  data: 1.7794  max mem: 3990
# Epoch: [15] Total time: 0:00:45 (2.0844 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:09  model_time: 0.0121 (0.0121)  evaluator_time: 0.1577 (0.1577)  time: 0.2351  data: 0.0616  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0101)  evaluator_time: 0.0217 (0.0358)  time: 0.1020  data: 0.0559  max mem: 3990
# Test: Total time: 0:00:04 (0.1077 s / it)
# Averaged stats: model_time: 0.0099 (0.0101)  evaluator_time: 0.0217 (0.0358)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.360
# Epoch: [16]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1505  data: 1.7923  max mem: 3990
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1098  data: 1.8258  max mem: 3990
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1282  data: 1.8384  max mem: 3990
# Epoch: [16] Total time: 0:00:46 (2.1254 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0108 (0.0108)  evaluator_time: 0.0265 (0.0265)  time: 0.1031  data: 0.0621  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0233 (0.0328)  time: 0.1053  data: 0.0570  max mem: 3990
# Test: Total time: 0:00:04 (0.1053 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0233 (0.0328)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.385
# Epoch: [17]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0088  data: 1.6886  max mem: 3990
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1560  data: 1.8615  max mem: 3990
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1270  data: 1.8381  max mem: 3990
# Epoch: [17] Total time: 0:00:46 (2.1330 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0255 (0.0255)  time: 0.1024  data: 0.0622  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0225 (0.0344)  time: 0.1048  data: 0.0566  max mem: 3990
# Test: Total time: 0:00:04 (0.1071 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0225 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.401
# Epoch: [18]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.8122  data: 1.4476  max mem: 3990
# Epoch: [18]  [20/22]  eta: 0:00:03  lr: 0.003000  time: 1.9865  data: 1.7072  max mem: 3990
# Epoch: [18]  [21/22]  eta: 0:00:01  lr: 0.003000  time: 1.9887  data: 1.7034  max mem: 3990
# Epoch: [18] Total time: 0:00:43 (1.9847 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0107 (0.0107)  evaluator_time: 0.0265 (0.0265)  time: 0.1035  data: 0.0625  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0252 (0.0344)  time: 0.1081  data: 0.0572  max mem: 3990
# Test: Total time: 0:00:04 (0.1075 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0252 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
# Epoch: [19]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9362  data: 1.6210  max mem: 3990
# Epoch: [19]  [20/22]  eta: 0:00:03  lr: 0.003000  time: 1.9916  data: 1.6904  max mem: 3990
# Epoch: [19]  [21/22]  eta: 0:00:01  lr: 0.003000  time: 1.9912  data: 1.6862  max mem: 3990
# Epoch: [19] Total time: 0:00:43 (1.9987 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0107 (0.0107)  evaluator_time: 0.0280 (0.0280)  time: 0.1035  data: 0.0611  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0102)  evaluator_time: 0.0249 (0.0347)  time: 0.1069  data: 0.0562  max mem: 3990
# Test: Total time: 0:00:04 (0.1073 s / it)
# Averaged stats: model_time: 0.0102 (0.0102)  evaluator_time: 0.0249 (0.0347)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.412
# Epoch: [20]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9750  data: 1.6701  max mem: 3990
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1688  data: 1.8741  max mem: 3990
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1462  data: 1.8554  max mem: 3990
# Epoch: [20] Total time: 0:00:47 (2.1482 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0105 (0.0105)  evaluator_time: 0.0260 (0.0260)  time: 0.1013  data: 0.0613  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0100)  evaluator_time: 0.0221 (0.0325)  time: 0.1038  data: 0.0560  max mem: 3990
# Test: Total time: 0:00:04 (0.1048 s / it)
# Averaged stats: model_time: 0.0099 (0.0100)  evaluator_time: 0.0221 (0.0325)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
# Epoch: [21]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1690  data: 1.9477  max mem: 3990
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0328  data: 1.7478  max mem: 3990
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0465  data: 1.7604  max mem: 3990
# Epoch: [21] Total time: 0:00:45 (2.0458 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0105 (0.0105)  evaluator_time: 0.0273 (0.0273)  time: 0.1042  data: 0.0627  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0238 (0.0345)  time: 0.1063  data: 0.0565  max mem: 3990
# Test: Total time: 0:00:04 (0.1079 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0238 (0.0345)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.365
# Epoch: [22]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1048  data: 1.8892  max mem: 3990
# Epoch: [22]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0928  data: 1.7965  max mem: 3990
# Epoch: [22]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0985  data: 1.8008  max mem: 3990
# Epoch: [22] Total time: 0:00:45 (2.0865 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0267 (0.0267)  time: 0.1029  data: 0.0621  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0236 (0.0377)  time: 0.1044  data: 0.0563  max mem: 3990
# Test: Total time: 0:00:04 (0.1100 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0236 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.308
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.394
# Epoch: [23]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7891  data: 1.5689  max mem: 3990
# Epoch: [23]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1072  data: 1.8067  max mem: 3990
# Epoch: [23]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0824  data: 1.7801  max mem: 3990
# Epoch: [23] Total time: 0:00:46 (2.0912 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0105 (0.0105)  evaluator_time: 0.0263 (0.0263)  time: 0.1017  data: 0.0613  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0100)  evaluator_time: 0.0205 (0.0326)  time: 0.1034  data: 0.0561  max mem: 3990
# Test: Total time: 0:00:04 (0.1046 s / it)
# Averaged stats: model_time: 0.0099 (0.0100)  evaluator_time: 0.0205 (0.0326)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.169
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.424
# Epoch: [24]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7782  data: 1.4993  max mem: 3990
# Epoch: [24]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0824  data: 1.8031  max mem: 3990
# Epoch: [24]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0554  data: 1.7820  max mem: 3990
# Epoch: [24] Total time: 0:00:45 (2.0561 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0247 (0.0247)  time: 0.1002  data: 0.0613  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0101)  evaluator_time: 0.0204 (0.0312)  time: 0.1029  data: 0.0564  max mem: 3990
# Test: Total time: 0:00:04 (0.1033 s / it)
# Averaged stats: model_time: 0.0101 (0.0101)  evaluator_time: 0.0204 (0.0312)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.451
# Epoch: [25]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2006  data: 1.8968  max mem: 3990
# Epoch: [25]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0149  data: 1.7280  max mem: 3990
# Epoch: [25]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0226  data: 1.7290  max mem: 3990
# Epoch: [25] Total time: 0:00:44 (2.0263 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0107 (0.0107)  evaluator_time: 0.0258 (0.0258)  time: 0.1014  data: 0.0613  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0227 (0.0335)  time: 0.1043  data: 0.0563  max mem: 3990
# Test: Total time: 0:00:04 (0.1061 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0227 (0.0335)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.403
# Epoch: [26]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9683  data: 1.6621  max mem: 3990
# Epoch: [26]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0886  data: 1.8039  max mem: 3990
# Epoch: [26]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0904  data: 1.8037  max mem: 3990
# Epoch: [26] Total time: 0:00:45 (2.0730 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0271 (0.0271)  time: 0.1025  data: 0.0612  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0100)  evaluator_time: 0.0241 (0.0338)  time: 0.1043  data: 0.0560  max mem: 3990
# Test: Total time: 0:00:04 (0.1057 s / it)
# Averaged stats: model_time: 0.0099 (0.0100)  evaluator_time: 0.0241 (0.0338)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.315
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.397
# ...
# Epoch: [41]  [20/22]  eta: 0:00:03  lr: 0.003000  time: 1.9808  data: 1.7022  max mem: 3990
# Epoch: [41]  [21/22]  eta: 0:00:01  lr: 0.003000  time: 1.9871  data: 1.7112  max mem: 3990
# Epoch: [41] Total time: 0:00:43 (1.9749 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0107 (0.0107)  evaluator_time: 0.0267 (0.0267)  time: 0.1025  data: 0.0615  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0235 (0.0362)  time: 0.1073  data: 0.0571  max mem: 3990
# Test: Total time: 0:00:04 (0.1089 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0235 (0.0362)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.412
# Epoch: [42]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6475  data: 1.3827  max mem: 3990
# Epoch: [42]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0905  data: 1.7818  max mem: 3990
# Epoch: [42]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0915  data: 1.7833  max mem: 3990
# Epoch: [42] Total time: 0:00:45 (2.0603 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0251 (0.0251)  time: 0.1013  data: 0.0622  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0242 (0.0330)  time: 0.1055  data: 0.0573  max mem: 3990
# Test: Total time: 0:00:04 (0.1061 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0242 (0.0330)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
# Epoch: [43]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0383  data: 1.8127  max mem: 3990
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0263  data: 1.7250  max mem: 3990
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0114  data: 1.7129  max mem: 3990
# Epoch: [43] Total time: 0:00:44 (2.0239 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0275 (0.0275)  time: 0.1030  data: 0.0612  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0100)  evaluator_time: 0.0243 (0.0339)  time: 0.1065  data: 0.0570  max mem: 3990
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0099 (0.0100)  evaluator_time: 0.0243 (0.0339)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.437
# Epoch: [44]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9218  data: 1.6726  max mem: 3990
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1375  data: 1.8387  max mem: 3990
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1117  data: 1.8121  max mem: 3990
# Epoch: [44] Total time: 0:00:46 (2.1175 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0107 (0.0107)  evaluator_time: 0.0258 (0.0258)  time: 0.1023  data: 0.0622  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0102)  evaluator_time: 0.0234 (0.0343)  time: 0.1054  data: 0.0570  max mem: 3990
# Test: Total time: 0:00:04 (0.1073 s / it)
# Averaged stats: model_time: 0.0099 (0.0102)  evaluator_time: 0.0234 (0.0343)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# Epoch: [45]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9619  data: 1.6746  max mem: 3990
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0506  data: 1.7620  max mem: 3990
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0631  data: 1.7761  max mem: 3990
# Epoch: [45] Total time: 0:00:45 (2.0611 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0279 (0.0279)  time: 0.1032  data: 0.0611  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0101)  evaluator_time: 0.0227 (0.0319)  time: 0.1035  data: 0.0565  max mem: 3990
# Test: Total time: 0:00:04 (0.1047 s / it)
# Averaged stats: model_time: 0.0099 (0.0101)  evaluator_time: 0.0227 (0.0319)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# Epoch: [46]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2236  data: 1.8302  max mem: 3990
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0152  data: 1.7522  max mem: 3990
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0220  data: 1.7527  max mem: 3990
# Epoch: [46] Total time: 0:00:44 (2.0319 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0105 (0.0105)  evaluator_time: 0.0252 (0.0252)  time: 0.1021  data: 0.0627  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0097 (0.0099)  evaluator_time: 0.0188 (0.0303)  time: 0.1014  data: 0.0559  max mem: 3990
# Test: Total time: 0:00:04 (0.1026 s / it)
# Averaged stats: model_time: 0.0097 (0.0099)  evaluator_time: 0.0188 (0.0303)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.346
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
# Epoch: [47]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6808  data: 1.4719  max mem: 3990
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0752  data: 1.7703  max mem: 3990
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0481  data: 1.7461  max mem: 3990
# Epoch: [47] Total time: 0:00:45 (2.0566 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0266 (0.0266)  time: 0.1030  data: 0.0615  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0104)  evaluator_time: 0.0230 (0.0380)  time: 0.1070  data: 0.0567  max mem: 3990
# Test: Total time: 0:00:04 (0.1112 s / it)
# Averaged stats: model_time: 0.0100 (0.0104)  evaluator_time: 0.0230 (0.0380)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.453
# Epoch: [48]  [ 0/22]  eta: 0:00:34  lr: 0.003000  time: 1.5726  data: 1.3770  max mem: 3990
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0821  data: 1.7920  max mem: 3990
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0715  data: 1.7832  max mem: 3990
# Epoch: [48] Total time: 0:00:45 (2.0528 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0116 (0.0116)  evaluator_time: 0.0256 (0.0256)  time: 0.1023  data: 0.0614  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0104)  evaluator_time: 0.0235 (0.0308)  time: 0.1023  data: 0.0565  max mem: 3990
# Test: Total time: 0:00:04 (0.1045 s / it)
# Averaged stats: model_time: 0.0100 (0.0104)  evaluator_time: 0.0235 (0.0308)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.423
# Epoch: [49]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8815  data: 1.6120  max mem: 3990
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0754  data: 1.7583  max mem: 3990
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0976  data: 1.7769  max mem: 3990
# Epoch: [49] Total time: 0:00:45 (2.0833 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0264 (0.0264)  time: 0.1041  data: 0.0636  max mem: 3990
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0098 (0.0099)  evaluator_time: 0.0232 (0.0322)  time: 0.1022  data: 0.0560  max mem: 3990
# Test: Total time: 0:00:04 (0.1041 s / it)
# Averaged stats: model_time: 0.0098 (0.0099)  evaluator_time: 0.0232 (0.0322)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.475
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.475
# Training time 0:45:35

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_DenseNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.20146278778798812

# %%
start_time = time.time()

# Continuar el entrenamiento por otras 50 épocas
for epoch in range(50, 100):  # Cambiar el rango para empezar en la época 50
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()  # El scheduler seguirá ajustando la tasa en las épocas definidas
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Epoch: [50]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4363  data: 1.9911  max mem: 4547
# Epoch: [50]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2483  data: 1.9389  max mem: 4547
# Epoch: [50]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2235  data: 1.9173  max mem: 4547
# Epoch: [50] Total time: 0:00:49 (2.2460 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0272 (0.0272)  time: 0.1044  data: 0.0624  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0261 (0.0309)  time: 0.1056  data: 0.0578  max mem: 4547
# Test: Total time: 0:00:04 (0.1050 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0261 (0.0309)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# Epoch: [51]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8846  data: 1.7044  max mem: 4547
# Epoch: [51]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0922  data: 1.8004  max mem: 4547
# Epoch: [51]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0956  data: 1.8025  max mem: 4547
# Epoch: [51] Total time: 0:00:45 (2.0799 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0289 (0.0289)  time: 0.1066  data: 0.0628  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0110)  evaluator_time: 0.0253 (0.0339)  time: 0.1070  data: 0.0569  max mem: 4547
# Test: Total time: 0:00:04 (0.1085 s / it)
# Averaged stats: model_time: 0.0107 (0.0110)  evaluator_time: 0.0253 (0.0339)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# Epoch: [52]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.0909  data: 1.7563  max mem: 4547
# Epoch: [52]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1315  data: 1.8434  max mem: 4547
# Epoch: [52]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1322  data: 1.8433  max mem: 4547
# Epoch: [52] Total time: 0:00:46 (2.1292 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0230 (0.0230)  time: 0.0993  data: 0.0613  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0243 (0.0305)  time: 0.1056  data: 0.0575  max mem: 4547
# Test: Total time: 0:00:04 (0.1047 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0243 (0.0305)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.485
# Epoch: [53]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0497  data: 1.7445  max mem: 4547
# Epoch: [53]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1635  data: 1.8645  max mem: 4547
# Epoch: [53]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1274  data: 1.8358  max mem: 4547
# Epoch: [53] Total time: 0:00:47 (2.1546 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0108 (0.0108)  evaluator_time: 0.0273 (0.0273)  time: 0.1035  data: 0.0617  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0240 (0.0316)  time: 0.1060  data: 0.0578  max mem: 4547
# Test: Total time: 0:00:04 (0.1076 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0240 (0.0316)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.491
# Epoch: [54]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8643  data: 1.6057  max mem: 4547
# Epoch: [54]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0573  data: 1.7739  max mem: 4547
# Epoch: [54]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0541  data: 1.7667  max mem: 4547
# Epoch: [54] Total time: 0:00:45 (2.0492 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0249 (0.0249)  time: 0.1037  data: 0.0639  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0208 (0.0302)  time: 0.1041  data: 0.0565  max mem: 4547
# Test: Total time: 0:00:04 (0.1039 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0208 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.485
# Epoch: [55]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9909  data: 1.7236  max mem: 4547
# Epoch: [55]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0849  data: 1.8128  max mem: 4547
# Epoch: [55]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0799  data: 1.8066  max mem: 4547
# Epoch: [55] Total time: 0:00:45 (2.0815 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0264 (0.0264)  time: 0.1034  data: 0.0620  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0228 (0.0312)  time: 0.1059  data: 0.0568  max mem: 4547
# Test: Total time: 0:00:04 (0.1048 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0228 (0.0312)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.500
# Epoch: [56]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9721  data: 1.6728  max mem: 4547
# Epoch: [56]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0724  data: 1.7659  max mem: 4547
# Epoch: [56]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0866  data: 1.7728  max mem: 4547
# Epoch: [56] Total time: 0:00:45 (2.0842 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0276 (0.0276)  time: 0.1042  data: 0.0617  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0108)  evaluator_time: 0.0242 (0.0305)  time: 0.1044  data: 0.0570  max mem: 4547
# Test: Total time: 0:00:04 (0.1041 s / it)
# Averaged stats: model_time: 0.0108 (0.0108)  evaluator_time: 0.0242 (0.0305)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# Epoch: [57]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2477  data: 1.8896  max mem: 4547
# Epoch: [57]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1194  data: 1.8073  max mem: 4547
# Epoch: [57]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1028  data: 1.7999  max mem: 4547
# Epoch: [57] Total time: 0:00:46 (2.1114 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0284 (0.0284)  time: 0.1075  data: 0.0643  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0207 (0.0351)  time: 0.1055  data: 0.0568  max mem: 4547
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0207 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
# Epoch: [58]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1947  data: 1.7440  max mem: 4547
# Epoch: [58]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0952  data: 1.8167  max mem: 4547
# Epoch: [58]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1186  data: 1.8355  max mem: 4547
# Epoch: [58] Total time: 0:00:46 (2.1191 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0116 (0.0116)  evaluator_time: 0.0295 (0.0295)  time: 0.1087  data: 0.0637  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0109)  evaluator_time: 0.0254 (0.0322)  time: 0.1057  data: 0.0566  max mem: 4547
# Test: Total time: 0:00:04 (0.1058 s / it)
# Averaged stats: model_time: 0.0106 (0.0109)  evaluator_time: 0.0254 (0.0322)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.488
# Epoch: [59]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7277  data: 1.5120  max mem: 4547
# Epoch: [59]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0684  data: 1.7829  max mem: 4547
# Epoch: [59]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0620  data: 1.7712  max mem: 4547
# Epoch: [59] Total time: 0:00:45 (2.0503 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0112 (0.0112)  evaluator_time: 0.0238 (0.0238)  time: 0.1014  data: 0.0628  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0227 (0.0313)  time: 0.1054  data: 0.0565  max mem: 4547
# Test: Total time: 0:00:04 (0.1050 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0227 (0.0313)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
# Epoch: [60]  [ 0/22]  eta: 0:00:55  lr: 0.003000  time: 2.5097  data: 2.1866  max mem: 4547
# Epoch: [60]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0942  data: 1.7919  max mem: 4547
# Epoch: [60]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1051  data: 1.8051  max mem: 4547
# Epoch: [60] Total time: 0:00:46 (2.1135 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0122 (0.0122)  evaluator_time: 0.0275 (0.0275)  time: 0.1069  data: 0.0631  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0212 (0.0318)  time: 0.1047  data: 0.0566  max mem: 4547
# Test: Total time: 0:00:04 (0.1058 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0212 (0.0318)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.505
# Epoch: [61]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7556  data: 1.5003  max mem: 4547
# Epoch: [61]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0576  data: 1.7761  max mem: 4547
# Epoch: [61]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0596  data: 1.7775  max mem: 4547
# Epoch: [61] Total time: 0:00:45 (2.0667 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0108 (0.0108)  evaluator_time: 0.0275 (0.0275)  time: 0.1038  data: 0.0618  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0108)  evaluator_time: 0.0241 (0.0333)  time: 0.1072  data: 0.0579  max mem: 4547
# Test: Total time: 0:00:04 (0.1075 s / it)
# Averaged stats: model_time: 0.0108 (0.0108)  evaluator_time: 0.0241 (0.0333)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.477
# Epoch: [62]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2806  data: 1.8945  max mem: 4547
# Epoch: [62]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1679  data: 1.8502  max mem: 4547
# Epoch: [62]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1730  data: 1.8525  max mem: 4547
# Epoch: [62] Total time: 0:00:47 (2.1727 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0112 (0.0112)  evaluator_time: 0.0278 (0.0278)  time: 0.1052  data: 0.0625  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0108)  evaluator_time: 0.0250 (0.0333)  time: 0.1089  data: 0.0582  max mem: 4547
# Test: Total time: 0:00:04 (0.1077 s / it)
# Averaged stats: model_time: 0.0109 (0.0108)  evaluator_time: 0.0250 (0.0333)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.461
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.461
# Epoch: [63]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1835  data: 1.8909  max mem: 4547
# Epoch: [63]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0180  data: 1.7361  max mem: 4547
# Epoch: [63]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0157  data: 1.7304  max mem: 4547
# Epoch: [63] Total time: 0:00:44 (2.0194 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0119 (0.0119)  evaluator_time: 0.0266 (0.0266)  time: 0.1049  data: 0.0626  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0238 (0.0349)  time: 0.1090  data: 0.0587  max mem: 4547
# Test: Total time: 0:00:04 (0.1097 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0238 (0.0349)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
# Epoch: [64]  [ 0/22]  eta: 0:00:34  lr: 0.003000  time: 1.5538  data: 1.4221  max mem: 4547
# Epoch: [64]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2605  data: 1.9337  max mem: 4547
# Epoch: [64]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2682  data: 1.9408  max mem: 4547
# Epoch: [64] Total time: 0:00:49 (2.2383 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0123 (0.0123)  evaluator_time: 0.0222 (0.0222)  time: 0.1013  data: 0.0627  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0109)  evaluator_time: 0.0255 (0.0293)  time: 0.1056  data: 0.0582  max mem: 4547
# Test: Total time: 0:00:04 (0.1037 s / it)
# Averaged stats: model_time: 0.0107 (0.0109)  evaluator_time: 0.0255 (0.0293)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
# Epoch: [65]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0882  data: 1.8032  max mem: 4547
# Epoch: [65]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1122  data: 1.8274  max mem: 4547
# Epoch: [65]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0771  data: 1.7868  max mem: 4547
# Epoch: [65] Total time: 0:00:46 (2.1072 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0139 (0.0139)  evaluator_time: 0.0242 (0.0242)  time: 0.1046  data: 0.0626  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0109)  evaluator_time: 0.0247 (0.0349)  time: 0.1149  data: 0.0582  max mem: 4547
# Test: Total time: 0:00:04 (0.1094 s / it)
# Averaged stats: model_time: 0.0106 (0.0109)  evaluator_time: 0.0247 (0.0349)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
# Epoch: [66]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2630  data: 1.9130  max mem: 4547
# Epoch: [66]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0732  data: 1.8000  max mem: 4547
# Epoch: [66]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0528  data: 1.7836  max mem: 4547
# Epoch: [66] Total time: 0:00:45 (2.0666 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0112 (0.0112)  evaluator_time: 0.0268 (0.0268)  time: 0.1044  data: 0.0628  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0239 (0.0319)  time: 0.1072  data: 0.0578  max mem: 4547
# Test: Total time: 0:00:04 (0.1062 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0239 (0.0319)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.367
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.479
# Epoch: [67]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1583  data: 1.8345  max mem: 4547
# Epoch: [67]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0935  data: 1.8089  max mem: 4547
# Epoch: [67]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1089  data: 1.8271  max mem: 4547
# Epoch: [67] Total time: 0:00:46 (2.1130 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0241 (0.0241)  time: 0.1013  data: 0.0622  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0109)  evaluator_time: 0.0222 (0.0308)  time: 0.1051  data: 0.0563  max mem: 4547
# Test: Total time: 0:00:04 (0.1046 s / it)
# Averaged stats: model_time: 0.0106 (0.0109)  evaluator_time: 0.0222 (0.0308)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
# Epoch: [68]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1828  data: 1.8485  max mem: 4547
# Epoch: [68]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1259  data: 1.8538  max mem: 4547
# Epoch: [68]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1021  data: 1.8276  max mem: 4547
# Epoch: [68] Total time: 0:00:46 (2.1181 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0109 (0.0109)  evaluator_time: 0.0218 (0.0218)  time: 0.0998  data: 0.0634  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0108)  evaluator_time: 0.0242 (0.0309)  time: 0.1081  data: 0.0594  max mem: 4547
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0108 (0.0108)  evaluator_time: 0.0242 (0.0309)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.486
# Epoch: [69]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9104  data: 1.7211  max mem: 4547
# Epoch: [69]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1773  data: 1.8846  max mem: 4547
# Epoch: [69]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1663  data: 1.8730  max mem: 4547
# Epoch: [69] Total time: 0:00:47 (2.1556 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0277 (0.0277)  time: 0.1074  data: 0.0644  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0108)  evaluator_time: 0.0263 (0.0317)  time: 0.1049  data: 0.0567  max mem: 4547
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0108 (0.0108)  evaluator_time: 0.0263 (0.0317)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.472
# Epoch: [70]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7928  data: 1.5730  max mem: 4547
# Epoch: [70]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1737  data: 1.8692  max mem: 4547
# Epoch: [70]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1662  data: 1.8620  max mem: 4547
# Epoch: [70] Total time: 0:00:47 (2.1522 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0112 (0.0112)  evaluator_time: 0.0250 (0.0250)  time: 0.1055  data: 0.0655  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0199 (0.0300)  time: 0.1047  data: 0.0567  max mem: 4547
# Test: Total time: 0:00:04 (0.1039 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0199 (0.0300)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
# Epoch: [71]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1111  data: 1.7479  max mem: 4547
# Epoch: [71]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1873  data: 1.8652  max mem: 4547
# Epoch: [71]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1677  data: 1.8450  max mem: 4547
# Epoch: [71] Total time: 0:00:47 (2.1707 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0252 (0.0252)  time: 0.1023  data: 0.0623  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0109)  evaluator_time: 0.0208 (0.0312)  time: 0.1065  data: 0.0579  max mem: 4547
# Test: Total time: 0:00:04 (0.1056 s / it)
# Averaged stats: model_time: 0.0107 (0.0109)  evaluator_time: 0.0208 (0.0312)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.498
# Epoch: [72]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9693  data: 1.7246  max mem: 4547
# Epoch: [72]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1460  data: 1.8646  max mem: 4547
# Epoch: [72]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1443  data: 1.8555  max mem: 4547
# Epoch: [72] Total time: 0:00:47 (2.1418 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0270 (0.0270)  time: 0.1045  data: 0.0627  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0226 (0.0308)  time: 0.1052  data: 0.0565  max mem: 4547
# Test: Total time: 0:00:04 (0.1043 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0226 (0.0308)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.487
# Epoch: [73]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0193  data: 1.6716  max mem: 4547
# Epoch: [73]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1847  data: 1.8906  max mem: 4547
# Epoch: [73]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1934  data: 1.8932  max mem: 4547
# Epoch: [73] Total time: 0:00:48 (2.1847 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0120 (0.0120)  evaluator_time: 0.0236 (0.0236)  time: 0.1012  data: 0.0619  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0243 (0.0318)  time: 0.1067  data: 0.0569  max mem: 4547
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0243 (0.0318)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.496
# Epoch: [74]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8548  data: 1.5895  max mem: 4547
# Epoch: [74]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0662  data: 1.7761  max mem: 4547
# Epoch: [74]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0706  data: 1.7763  max mem: 4547
# Epoch: [74] Total time: 0:00:45 (2.0635 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0114 (0.0114)  evaluator_time: 0.0281 (0.0281)  time: 0.1059  data: 0.0625  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0109)  evaluator_time: 0.0221 (0.0341)  time: 0.1120  data: 0.0568  max mem: 4547
# Test: Total time: 0:00:04 (0.1081 s / it)
# Averaged stats: model_time: 0.0107 (0.0109)  evaluator_time: 0.0221 (0.0341)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.491
# Epoch: [75]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0757  data: 1.7200  max mem: 4547
# Epoch: [75]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1331  data: 1.8412  max mem: 4547
# Epoch: [75]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1183  data: 1.8313  max mem: 4547
# Epoch: [75] Total time: 0:00:46 (2.1275 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0115 (0.0115)  evaluator_time: 0.0253 (0.0253)  time: 0.1032  data: 0.0625  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0222 (0.0304)  time: 0.1056  data: 0.0570  max mem: 4547
# Test: Total time: 0:00:04 (0.1042 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0222 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.523
# Epoch: [76]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7827  data: 1.5224  max mem: 4547
# Epoch: [76]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1463  data: 1.8526  max mem: 4547
# Epoch: [76]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1176  data: 1.8278  max mem: 4547
# Epoch: [76] Total time: 0:00:46 (2.1339 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0117 (0.0117)  evaluator_time: 0.0269 (0.0269)  time: 0.1044  data: 0.0620  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0108)  evaluator_time: 0.0286 (0.0335)  time: 0.1093  data: 0.0574  max mem: 4547
# Test: Total time: 0:00:04 (0.1074 s / it)
# Averaged stats: model_time: 0.0108 (0.0108)  evaluator_time: 0.0286 (0.0335)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.473
# ...
# Epoch: [91]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1641  data: 1.8656  max mem: 4547
# Epoch: [91]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1684  data: 1.8662  max mem: 4547
# Epoch: [91] Total time: 0:00:47 (2.1539 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0263 (0.0263)  time: 0.1034  data: 0.0622  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0223 (0.0305)  time: 0.1047  data: 0.0565  max mem: 4547
# Test: Total time: 0:00:04 (0.1038 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0223 (0.0305)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
# Epoch: [92]  [ 0/22]  eta: 0:00:36  lr: 0.000300  time: 1.6617  data: 1.4026  max mem: 4547
# Epoch: [92]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1021  data: 1.8151  max mem: 4547
# Epoch: [92]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0876  data: 1.8016  max mem: 4547
# Epoch: [92] Total time: 0:00:45 (2.0847 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0109 (0.0109)  evaluator_time: 0.0254 (0.0254)  time: 0.1016  data: 0.0616  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0109)  evaluator_time: 0.0215 (0.0303)  time: 0.1051  data: 0.0568  max mem: 4547
# Test: Total time: 0:00:04 (0.1041 s / it)
# Averaged stats: model_time: 0.0106 (0.0109)  evaluator_time: 0.0215 (0.0303)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.525
# Epoch: [93]  [ 0/22]  eta: 0:00:37  lr: 0.000300  time: 1.7250  data: 1.4866  max mem: 4547
# Epoch: [93]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1185  data: 1.8404  max mem: 4547
# Epoch: [93]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1049  data: 1.8304  max mem: 4547
# Epoch: [93] Total time: 0:00:46 (2.0943 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0112 (0.0112)  evaluator_time: 0.0264 (0.0264)  time: 0.1039  data: 0.0625  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0109)  evaluator_time: 0.0276 (0.0340)  time: 0.1120  data: 0.0567  max mem: 4547
# Test: Total time: 0:00:04 (0.1078 s / it)
# Averaged stats: model_time: 0.0107 (0.0109)  evaluator_time: 0.0276 (0.0340)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.520
# Epoch: [94]  [ 0/22]  eta: 0:00:41  lr: 0.000300  time: 1.8971  data: 1.6209  max mem: 4547
# Epoch: [94]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.0816  data: 1.8022  max mem: 4547
# Epoch: [94]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0750  data: 1.8019  max mem: 4547
# Epoch: [94] Total time: 0:00:45 (2.0743 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0114 (0.0114)  evaluator_time: 0.0262 (0.0262)  time: 0.1032  data: 0.0619  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0231 (0.0310)  time: 0.1056  data: 0.0567  max mem: 4547
# Test: Total time: 0:00:04 (0.1045 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0231 (0.0310)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# Epoch: [95]  [ 0/22]  eta: 0:00:44  lr: 0.000300  time: 2.0390  data: 1.6769  max mem: 4547
# Epoch: [95]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1225  data: 1.8336  max mem: 4547
# Epoch: [95]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0977  data: 1.8129  max mem: 4547
# Epoch: [95] Total time: 0:00:46 (2.1023 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0111 (0.0111)  evaluator_time: 0.0257 (0.0257)  time: 0.1030  data: 0.0626  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0222 (0.0309)  time: 0.1058  data: 0.0568  max mem: 4547
# Test: Total time: 0:00:04 (0.1046 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0222 (0.0309)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.535
# Epoch: [96]  [ 0/22]  eta: 0:00:51  lr: 0.000300  time: 2.3436  data: 2.0357  max mem: 4547
# Epoch: [96]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1647  data: 1.8616  max mem: 4547
# Epoch: [96]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1732  data: 1.8732  max mem: 4547
# Epoch: [96] Total time: 0:00:48 (2.1859 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0113 (0.0113)  evaluator_time: 0.0255 (0.0255)  time: 0.1037  data: 0.0630  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0106 (0.0108)  evaluator_time: 0.0233 (0.0306)  time: 0.1056  data: 0.0569  max mem: 4547
# Test: Total time: 0:00:04 (0.1042 s / it)
# Averaged stats: model_time: 0.0106 (0.0108)  evaluator_time: 0.0233 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.526
# Epoch: [97]  [ 0/22]  eta: 0:00:44  lr: 0.000300  time: 2.0205  data: 1.7191  max mem: 4547
# Epoch: [97]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1444  data: 1.8552  max mem: 4547
# Epoch: [97]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1436  data: 1.8532  max mem: 4547
# Epoch: [97] Total time: 0:00:46 (2.1328 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0114 (0.0114)  evaluator_time: 0.0266 (0.0266)  time: 0.1053  data: 0.0635  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0214 (0.0306)  time: 0.1065  data: 0.0576  max mem: 4547
# Test: Total time: 0:00:04 (0.1047 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0214 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.528
# Epoch: [98]  [ 0/22]  eta: 0:00:48  lr: 0.000300  time: 2.1905  data: 1.8537  max mem: 4547
# Epoch: [98]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1782  data: 1.8689  max mem: 4547
# Epoch: [98]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1340  data: 1.8223  max mem: 4547
# Epoch: [98] Total time: 0:00:47 (2.1650 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0110 (0.0110)  evaluator_time: 0.0262 (0.0262)  time: 0.1028  data: 0.0618  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0235 (0.0306)  time: 0.1061  data: 0.0576  max mem: 4547
# Test: Total time: 0:00:04 (0.1048 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0235 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# Epoch: [99]  [ 0/22]  eta: 0:00:42  lr: 0.000300  time: 1.9393  data: 1.7400  max mem: 4547
# Epoch: [99]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1326  data: 1.8484  max mem: 4547
# Epoch: [99]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1143  data: 1.8337  max mem: 4547
# Epoch: [99] Total time: 0:00:46 (2.1195 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0125 (0.0125)  evaluator_time: 0.0265 (0.0265)  time: 0.1062  data: 0.0631  max mem: 4547
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0107 (0.0108)  evaluator_time: 0.0223 (0.0307)  time: 0.1058  data: 0.0576  max mem: 4547
# Test: Total time: 0:00:04 (0.1047 s / it)
# Averaged stats: model_time: 0.0107 (0.0108)  evaluator_time: 0.0223 (0.0307)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.217
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
# Training time 0:44:35

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_DenseNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.23242612293958803
