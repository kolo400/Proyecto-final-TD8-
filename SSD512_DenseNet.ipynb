# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]




def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)


def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())


train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)

train_counts = defaultdict(int)
test_counts = defaultdict(int)

for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1

for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        img = read_image(path_base + '/Imagenes/' + item['image_filename'])

        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)

        if self.transform:
            img, target = self.transform(img, target)
        return img, target

train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))

print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import  ssd512_DenseNet


model = ssd512_DenseNet(pretrained=False)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 144MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background


in_channels = [128, 1024, 512, 256, 256, 256, 256]
num_anchors = [4, 6, 6, 6, 4, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)

        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)


        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()
        print(loss_value)

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-18 15:40:54--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-18 15:40:55 (96.6 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-18 15:40:55--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-18 15:40:55 (105 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-18 15:40:55--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-18 15:40:55 (69.7 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-18 15:40:55--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-18 15:40:55 (102 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-18 15:40:55--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.002s
#
# 2024-11-18 15:40:56 (13.3 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)

model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# 13.56871223449707
# Epoch: [0]  [ 0/22]  eta: 0:04:22  lr: 0.000146  time: 11.9522  data: 8.7073  max mem: 6448
# 12.663093566894531
# 14.06663990020752
# 13.289907455444336
# 12.27734375
# 11.858440399169922
# 11.347018241882324
# 10.948929786682129
# 10.63290786743164
# 10.417991638183594
# 10.29688549041748
# 10.489461898803711
# 10.583375930786133
# 10.674946784973145
# 9.999801635742188
# 10.064798355102539
# 9.721334457397461
# 10.208354949951172
# 9.895685195922852
# 9.359992980957031
# 8.841989517211914
# Epoch: [0]  [20/22]  eta: 0:00:16  lr: 0.003000  time: 7.8494  data: 7.4879  max mem: 6523
# 8.839605331420898
# Epoch: [0]  [21/22]  eta: 0:00:08  lr: 0.003000  time: 7.7342  data: 7.3805  max mem: 6523
# Epoch: [0] Total time: 0:02:56 (8.0036 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.2348 (0.2348)  evaluator_time: 0.0273 (0.0273)  time: 0.3276  data: 0.0619  max mem: 6523
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0117 (0.0174)  evaluator_time: 0.0164 (0.0347)  time: 0.1018  data: 0.0559  max mem: 6523
# Test: Total time: 0:00:04 (0.1142 s / it)
# Averaged stats: model_time: 0.0117 (0.0174)  evaluator_time: 0.0164 (0.0347)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# 10.161524772644043
# Epoch: [1]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0176  data: 1.5955  max mem: 6523
# 9.511224746704102
# 9.089500427246094
# 8.764877319335938
# 8.471879959106445
# 8.43448257446289
# 7.895627975463867
# 8.144488334655762
# 7.59376335144043
# 7.885030746459961
# 7.6621575355529785
# 7.748979568481445
# 8.154054641723633
# 7.4314351081848145
# 7.332804203033447
# 7.048175811767578
# 6.680738925933838
# 6.3167290687561035
# 6.747425079345703
# 5.79697322845459
# 6.0850114822387695
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4693  data: 2.0724  max mem: 6932
# 6.026665687561035
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4548  data: 2.0617  max mem: 6932
# Epoch: [1] Total time: 0:00:53 (2.4306 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0126 (0.0126)  evaluator_time: 0.0293 (0.0293)  time: 0.1075  data: 0.0619  max mem: 6932
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0113 (0.0114)  evaluator_time: 0.0202 (0.0378)  time: 0.1088  data: 0.0560  max mem: 6932
# Test: Total time: 0:00:04 (0.1112 s / it)
# Averaged stats: model_time: 0.0113 (0.0114)  evaluator_time: 0.0202 (0.0378)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.093
# 5.534307479858398
# Epoch: [2]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9680  data: 1.6206  max mem: 6932
# 4.965546131134033
# 5.401648044586182
# 4.850554943084717
# 5.2782769203186035
# 4.932345867156982
# 5.244197368621826
# 5.323365688323975
# 4.716208457946777
# 5.065199851989746
# 4.682718276977539
# 4.5555925369262695
# 5.000490188598633
# 4.3593645095825195
# 4.521885871887207
# 3.9910614490509033
# 6.363081932067871
# 5.936088562011719
# 5.4379730224609375
# 4.975834846496582
# 4.117351055145264
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1428  data: 1.7561  max mem: 6932
# 4.612419128417969
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1649  data: 1.7698  max mem: 6932
# Epoch: [2] Total time: 0:00:47 (2.1483 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0115 (0.0115)  evaluator_time: 0.0256 (0.0256)  time: 0.1021  data: 0.0614  max mem: 6932
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0201 (0.0304)  time: 0.1021  data: 0.0564  max mem: 6932
# Test: Total time: 0:00:04 (0.1036 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0201 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.250
# 4.140678405761719
# Epoch: [3]  [ 0/22]  eta: 0:00:34  lr: 0.003000  time: 1.5588  data: 1.3106  max mem: 6932
# 4.97526741027832
# 4.538116455078125
# 4.195580959320068
# 4.5667595863342285
# 4.199757099151611
# 4.056739807128906
# 4.104942321777344
# 5.129234313964844
# 5.053879737854004
# 4.773385524749756
# 4.586705684661865
# 4.033675193786621
# 4.301553726196289
# 5.746230125427246
# 3.911979913711548
# 4.945372581481934
# 4.232194900512695
# 4.1991658210754395
# 4.378325462341309
# 4.512455940246582
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1606  data: 1.7858  max mem: 6932
# 3.98960542678833
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1282  data: 1.7611  max mem: 6932
# Epoch: [3] Total time: 0:00:46 (2.1245 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0118 (0.0118)  evaluator_time: 0.0266 (0.0266)  time: 0.1037  data: 0.0616  max mem: 6932
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0112 (0.0113)  evaluator_time: 0.0181 (0.0274)  time: 0.1003  data: 0.0571  max mem: 6932
# Test: Total time: 0:00:04 (0.1013 s / it)
# Averaged stats: model_time: 0.0112 (0.0113)  evaluator_time: 0.0181 (0.0274)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.305
# 4.123406410217285
# Epoch: [4]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8404  data: 1.5097  max mem: 6932
# 3.4954938888549805
# 3.886033773422241
# 5.6026930809021
# 4.032057762145996
# 4.418793678283691
# 4.618515968322754
# 4.181219100952148
# 4.49451208114624
# 4.767834663391113
# 4.513789176940918
# 4.417141914367676
# 4.351032257080078
# 4.390933990478516
# 4.7889604568481445
# 3.944403648376465
# 4.262903213500977
# 4.888535499572754
# 4.220941066741943
# 4.519897937774658
# 4.352222442626953
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0992  data: 1.7156  max mem: 7038
# 4.026954174041748
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1096  data: 1.7202  max mem: 7038
# Epoch: [4] Total time: 0:00:45 (2.0863 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0224 (0.0224)  time: 0.0990  data: 0.0614  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0111)  evaluator_time: 0.0175 (0.0250)  time: 0.0978  data: 0.0569  max mem: 7038
# Test: Total time: 0:00:03 (0.0984 s / it)
# Averaged stats: model_time: 0.0111 (0.0111)  evaluator_time: 0.0175 (0.0250)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.343
# 4.005465030670166
# Epoch: [5]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1570  data: 1.7301  max mem: 7038
# 4.210424900054932
# 4.731330394744873
# 4.878352165222168
# 4.915145397186279
# 4.025280952453613
# 5.336185932159424
# 4.7450127601623535
# 4.424566745758057
# 4.384721755981445
# 3.905550479888916
# 4.209318161010742
# 4.257086753845215
# 4.0407867431640625
# 3.8558034896850586
# 4.306858539581299
# 4.043760299682617
# 4.446501731872559
# 4.512077331542969
# 3.869347333908081
# 5.211761474609375
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2356  data: 1.8296  max mem: 7038
# 3.9365742206573486
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2159  data: 1.8146  max mem: 7038
# Epoch: [5] Total time: 0:00:48 (2.2224 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0181 (0.0181)  time: 0.0947  data: 0.0613  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0171 (0.0235)  time: 0.0966  data: 0.0568  max mem: 7038
# Test: Total time: 0:00:03 (0.0972 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0171 (0.0235)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.375
# 4.4130072593688965
# Epoch: [6]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3649  data: 1.9524  max mem: 7038
# 4.800021171569824
# 3.461087226867676
# 4.322342395782471
# 4.140180587768555
# 4.544888496398926
# 4.561310291290283
# 3.9042859077453613
# 4.005560398101807
# 3.998037338256836
# 4.1994948387146
# 4.452038764953613
# 4.561976432800293
# 4.130709171295166
# 4.141315460205078
# 3.9367876052856445
# 3.7993807792663574
# 3.6285176277160645
# 4.4901275634765625
# 4.840856075286865
# 3.939875364303589
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1377  data: 1.7459  max mem: 7038
# 3.733957052230835
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1058  data: 1.7188  max mem: 7038
# Epoch: [6] Total time: 0:00:47 (2.1444 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0191 (0.0191)  time: 0.0963  data: 0.0618  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0177 (0.0236)  time: 0.0968  data: 0.0570  max mem: 7038
# Test: Total time: 0:00:03 (0.0975 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0177 (0.0236)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.374
# 3.5451667308807373
# Epoch: [7]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6727  data: 1.3527  max mem: 7038
# 4.113264560699463
# 4.607711315155029
# 3.878711223602295
# 3.5818331241607666
# 4.420680046081543
# 4.256226539611816
# 3.8809590339660645
# 4.2850341796875
# 3.5464658737182617
# 5.160446643829346
# 3.502166748046875
# 3.8486974239349365
# 3.6667332649230957
# 3.7634918689727783
# 3.570129156112671
# 4.042779922485352
# 4.011367321014404
# 3.6041741371154785
# 3.677992343902588
# 3.988665819168091
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1624  data: 1.7824  max mem: 7038
# 3.979836940765381
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1851  data: 1.7990  max mem: 7038
# Epoch: [7] Total time: 0:00:47 (2.1652 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0172 (0.0172)  time: 0.0934  data: 0.0611  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0110)  evaluator_time: 0.0180 (0.0229)  time: 0.0949  data: 0.0560  max mem: 7038
# Test: Total time: 0:00:03 (0.0962 s / it)
# Averaged stats: model_time: 0.0110 (0.0110)  evaluator_time: 0.0180 (0.0229)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.420
# 3.4773340225219727
# Epoch: [8]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1427  data: 1.7777  max mem: 7038
# 3.603867530822754
# 3.7392044067382812
# 4.661195278167725
# 3.8585205078125
# 3.7584068775177
# 4.065782070159912
# 3.461763620376587
# 4.452359199523926
# 4.146171569824219
# 3.506373882293701
# 3.9017434120178223
# 4.638476371765137
# 3.6814894676208496
# 3.9071643352508545
# 3.6961512565612793
# 3.966557025909424
# 3.7844581604003906
# 4.292571067810059
# 3.5772500038146973
# 3.6262664794921875
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2220  data: 1.8100  max mem: 7038
# 3.8049674034118652
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2032  data: 1.7844  max mem: 7038
# Epoch: [8] Total time: 0:00:48 (2.2174 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0132 (0.0132)  evaluator_time: 0.0190 (0.0190)  time: 0.0975  data: 0.0617  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0113)  evaluator_time: 0.0178 (0.0281)  time: 0.0982  data: 0.0559  max mem: 7038
# Test: Total time: 0:00:04 (0.1019 s / it)
# Averaged stats: model_time: 0.0110 (0.0113)  evaluator_time: 0.0178 (0.0281)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# 4.453666687011719
# Epoch: [9]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9915  data: 1.6165  max mem: 7038
# 3.515714645385742
# 3.86802077293396
# 3.571577310562134
# 4.170707702636719
# 4.183268070220947
# 4.008723735809326
# 3.602175235748291
# 3.195030689239502
# 3.5322673320770264
# 3.9368276596069336
# 4.034193515777588
# 4.405614376068115
# 3.485459327697754
# 3.7392303943634033
# 3.9979724884033203
# 3.5413146018981934
# 3.6317358016967773
# 3.706538438796997
# 4.0792741775512695
# 4.007116317749023
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1424  data: 1.7588  max mem: 7038
# 3.8672471046447754
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1689  data: 1.7851  max mem: 7038
# Epoch: [9] Total time: 0:00:47 (2.1622 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0190 (0.0190)  time: 0.0953  data: 0.0613  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0178 (0.0240)  time: 0.0971  data: 0.0561  max mem: 7038
# Test: Total time: 0:00:03 (0.0978 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0178 (0.0240)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# 3.183445453643799
# Epoch: [10]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9563  data: 1.5846  max mem: 7038
# 3.1854352951049805
# 5.154461860656738
# 3.647385358810425
# 3.6401047706604004
# 3.2384090423583984
# 3.249958038330078
# 3.388648748397827
# 3.8485960960388184
# 4.3392720222473145
# 4.08563756942749
# 3.774505376815796
# 3.902578353881836
# 3.8155736923217773
# 3.1922597885131836
# 3.797382354736328
# 4.106096267700195
# 4.192687034606934
# 3.6579298973083496
# 4.002026557922363
# 4.277956485748291
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1665  data: 1.7989  max mem: 7038
# 3.548593521118164
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1498  data: 1.7821  max mem: 7038
# Epoch: [10] Total time: 0:00:47 (2.1517 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0205 (0.0205)  time: 0.0974  data: 0.0614  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0114 (0.0114)  evaluator_time: 0.0185 (0.0249)  time: 0.0984  data: 0.0572  max mem: 7038
# Test: Total time: 0:00:03 (0.0988 s / it)
# Averaged stats: model_time: 0.0114 (0.0114)  evaluator_time: 0.0185 (0.0249)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.348
# 3.8914904594421387
# Epoch: [11]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1803  data: 1.8224  max mem: 7038
# 3.908928632736206
# 4.08652400970459
# 3.9778366088867188
# 3.436540126800537
# 3.5573389530181885
# 3.920776844024658
# 3.2183728218078613
# 2.9432268142700195
# 3.425149440765381
# 3.5700268745422363
# 4.356344699859619
# 3.352066993713379
# 3.5202038288116455
# 3.6380457878112793
# 3.926313877105713
# 3.7918689250946045
# 3.4948439598083496
# 3.854356288909912
# 4.637813568115234
# 3.5073394775390625
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2109  data: 1.8317  max mem: 7038
# 3.330401659011841
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1967  data: 1.8193  max mem: 7038
# Epoch: [11] Total time: 0:00:48 (2.2056 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0119 (0.0119)  evaluator_time: 0.0157 (0.0157)  time: 0.0931  data: 0.0619  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0113)  evaluator_time: 0.0198 (0.0228)  time: 0.0963  data: 0.0569  max mem: 7038
# Test: Total time: 0:00:03 (0.0965 s / it)
# Averaged stats: model_time: 0.0111 (0.0113)  evaluator_time: 0.0198 (0.0228)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.273
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.405
# 3.2707152366638184
# Epoch: [12]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9269  data: 1.4924  max mem: 7038
# 4.091355800628662
# 3.3915059566497803
# 3.643866539001465
# 2.807318687438965
# 3.6859142780303955
# 4.004040241241455
# 3.2526304721832275
# 4.278367042541504
# 4.040403366088867
# 3.084620475769043
# 3.281482219696045
# 3.585810661315918
# 3.707137107849121
# 3.9879698753356934
# 3.3180856704711914
# 4.020313262939453
# 3.7506086826324463
# 3.9687299728393555
# 3.4287683963775635
# 3.3014073371887207
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1728  data: 1.7736  max mem: 7038
# 3.9681754112243652
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1652  data: 1.7696  max mem: 7038
# Epoch: [12] Total time: 0:00:47 (2.1524 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0173 (0.0173)  time: 0.0945  data: 0.0617  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0182 (0.0232)  time: 0.0971  data: 0.0568  max mem: 7038
# Test: Total time: 0:00:03 (0.0967 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0182 (0.0232)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.169
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# 3.3078925609588623
# Epoch: [13]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2257  data: 1.8163  max mem: 7038
# 4.20291805267334
# 3.7883858680725098
# 2.9964492321014404
# 3.758761405944824
# 3.671058177947998
# 3.4956214427948
# 3.2636871337890625
# 3.4509358406066895
# 4.076308727264404
# 3.8672337532043457
# 3.9141077995300293
# 4.4742560386657715
# 3.8632192611694336
# 3.129244804382324
# 3.383565902709961
# 3.5726284980773926
# 3.269634485244751
# 3.6020307540893555
# 3.4221343994140625
# 3.989255428314209
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2340  data: 1.8397  max mem: 7038
# 3.6000969409942627
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2093  data: 1.8203  max mem: 7038
# Epoch: [13] Total time: 0:00:48 (2.2246 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0121 (0.0121)  evaluator_time: 0.0175 (0.0175)  time: 0.0961  data: 0.0629  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0175 (0.0234)  time: 0.0982  data: 0.0573  max mem: 7038
# Test: Total time: 0:00:03 (0.0973 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0175 (0.0234)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.463
# 2.9082846641540527
# Epoch: [14]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2014  data: 1.8173  max mem: 7038
# 4.03660774230957
# 3.633521556854248
# 3.094050168991089
# 3.500859260559082
# 2.855534315109253
# 2.9854657649993896
# 4.4722137451171875
# 3.8217523097991943
# 3.3373279571533203
# 3.4581642150878906
# 3.1273725032806396
# 3.087273597717285
# 3.115074396133423
# 4.000919818878174
# 3.322380304336548
# 3.562561511993408
# 3.7514569759368896
# 3.4324488639831543
# 3.8402769565582275
# 3.2455687522888184
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2098  data: 1.8165  max mem: 7038
# 3.5445804595947266
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2162  data: 1.8257  max mem: 7038
# Epoch: [14] Total time: 0:00:48 (2.2188 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0181 (0.0181)  time: 0.0946  data: 0.0613  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0181 (0.0230)  time: 0.0974  data: 0.0573  max mem: 7038
# Test: Total time: 0:00:03 (0.0970 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0181 (0.0230)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.479
# 4.8463921546936035
# Epoch: [15]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4508  data: 1.9983  max mem: 7038
# 3.0636630058288574
# 3.4232683181762695
# 3.19258713722229
# 3.49920654296875
# 3.3872604370117188
# 4.397951602935791
# 3.223278045654297
# 3.5421690940856934
# 3.030714511871338
# 3.3018853664398193
# 3.414599895477295
# 4.618206024169922
# 3.013124942779541
# 4.027486324310303
# 3.1362521648406982
# 3.4738521575927734
# 3.183907985687256
# 3.979736804962158
# 3.1249260902404785
# 3.9866909980773926
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1781  data: 1.8002  max mem: 7038
# 3.299351692199707
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1724  data: 1.7980  max mem: 7038
# Epoch: [15] Total time: 0:00:48 (2.2005 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0181 (0.0181)  time: 0.0960  data: 0.0625  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0203 (0.0270)  time: 0.1037  data: 0.0561  max mem: 7038
# Test: Total time: 0:00:04 (0.1007 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0203 (0.0270)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.444
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.444
# 3.3988304138183594
# Epoch: [16]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0382  data: 1.6055  max mem: 7038
# 3.6543760299682617
# 4.005316257476807
# 3.606719493865967
# 3.119137763977051
# 2.814255714416504
# 3.3245723247528076
# 3.7257471084594727
# 3.447828531265259
# 3.2716124057769775
# 3.6087281703948975
# 2.848947048187256
# 3.0686771869659424
# 3.411789894104004
# 3.5472166538238525
# 3.457103729248047
# 4.416019439697266
# 4.290867328643799
# 2.640472650527954
# 4.010198593139648
# 3.0116450786590576
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1861  data: 1.8129  max mem: 7038
# 4.128406524658203
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1707  data: 1.7997  max mem: 7038
# Epoch: [16] Total time: 0:00:47 (2.1634 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0119 (0.0119)  evaluator_time: 0.0270 (0.0270)  time: 0.1037  data: 0.0612  max mem: 7038
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0201 (0.0254)  time: 0.0968  data: 0.0559  max mem: 7038
# Test: Total time: 0:00:03 (0.0988 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0201 (0.0254)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.326
# 3.343073606491089
# Epoch: [17]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9534  data: 1.6144  max mem: 7038
# 3.2720837593078613
# 3.7140145301818848
# 3.106931209564209
# 3.10141921043396
# 3.1250476837158203
# 4.456336498260498
# 3.2908759117126465
# 3.5664987564086914
# 2.812046527862549
# 3.491644859313965
# 3.7086381912231445
# 2.9602205753326416
# 3.0056469440460205
# 3.5730974674224854
# 4.0624470710754395
# 3.3041319847106934
# 3.7435896396636963
# 3.264138698577881
# 3.747164249420166
# 4.530007839202881
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2207  data: 1.8228  max mem: 7123
# 3.119950532913208
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2065  data: 1.8061  max mem: 7123
# Epoch: [17] Total time: 0:00:48 (2.2039 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0133 (0.0133)  evaluator_time: 0.0226 (0.0226)  time: 0.1021  data: 0.0624  max mem: 7123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0239 (0.0241)  time: 0.0966  data: 0.0559  max mem: 7123
# Test: Total time: 0:00:03 (0.0979 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0239 (0.0241)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.338
# 3.4206910133361816
# Epoch: [18]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0444  data: 1.6514  max mem: 7123
# 2.9597482681274414
# 3.72857666015625
# 3.581707239151001
# 3.1437032222747803
# 3.8736252784729004
# 3.061734437942505
# 3.2877659797668457
# 3.1551384925842285
# 3.972931385040283
# 5.021150588989258
# 3.134359359741211
# 3.3365368843078613
# 3.462599277496338
# 3.389622926712036
# 3.5791749954223633
# 3.1414272785186768
# 4.270807266235352
# 3.5525152683258057
# 3.2024118900299072
# 4.010603427886963
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1189  data: 1.7512  max mem: 7123
# 3.1358439922332764
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1142  data: 1.7470  max mem: 7123
# Epoch: [18] Total time: 0:00:46 (2.1183 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0144 (0.0144)  time: 0.0908  data: 0.0612  max mem: 7123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0110)  evaluator_time: 0.0177 (0.0220)  time: 0.0951  data: 0.0557  max mem: 7123
# Test: Total time: 0:00:03 (0.0949 s / it)
# Averaged stats: model_time: 0.0109 (0.0110)  evaluator_time: 0.0177 (0.0220)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.314
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.472
# 3.06280255317688
# Epoch: [19]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0659  data: 1.7072  max mem: 7123
# 3.659269332885742
# 3.632526397705078
# 3.972085475921631
# 3.211811065673828
# 3.3988044261932373
# 3.6476938724517822
# 3.4675824642181396
# 3.089996814727783
# 4.139620304107666
# 3.648397445678711
# 3.396207332611084
# 2.997387647628784
# 3.2316317558288574
# 3.0297963619232178
# 3.4381065368652344
# 3.4192824363708496
# 3.67093563079834
# 3.0885846614837646
# 3.028311252593994
# 4.169641971588135
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2250  data: 1.8220  max mem: 7123
# 3.5646588802337646
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2087  data: 1.8088  max mem: 7123
# Epoch: [19] Total time: 0:00:48 (2.2107 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0148 (0.0148)  time: 0.0913  data: 0.0611  max mem: 7123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0112 (0.0111)  evaluator_time: 0.0185 (0.0224)  time: 0.0964  data: 0.0564  max mem: 7123
# Test: Total time: 0:00:03 (0.0960 s / it)
# Averaged stats: model_time: 0.0112 (0.0111)  evaluator_time: 0.0185 (0.0224)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.477
# 3.6567201614379883
# Epoch: [20]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2505  data: 1.8625  max mem: 7123
# 2.969545841217041
# 4.023353099822998
# 3.4046614170074463
# 3.2973480224609375
# 3.2251052856445312
# 3.5100066661834717
# 3.2961316108703613
# 3.067610025405884
# 3.4293155670166016
# 3.436955451965332
# 2.5972414016723633
# 3.4292612075805664
# 3.385664939880371
# 3.0326380729675293
# 3.809358835220337
# 3.614534854888916
# 3.265192747116089
# 3.1958765983581543
# 3.493839740753174
# 2.689378499984741
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1074  data: 1.7502  max mem: 7123
# 4.419146537780762
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1143  data: 1.7449  max mem: 7123
# Epoch: [20] Total time: 0:00:46 (2.1141 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0165 (0.0165)  time: 0.0944  data: 0.0625  max mem: 7123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0114)  evaluator_time: 0.0197 (0.0241)  time: 0.0974  data: 0.0562  max mem: 7123
# Test: Total time: 0:00:03 (0.0984 s / it)
# Averaged stats: model_time: 0.0110 (0.0114)  evaluator_time: 0.0197 (0.0241)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# 3.9083027839660645
# Epoch: [21]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2257  data: 1.6989  max mem: 7123
# 2.7197442054748535
# 3.8546621799468994
# 3.557166814804077
# 2.850273609161377
# 3.5176053047180176
# 3.952683448791504
# 3.2580618858337402
# 2.9992034435272217
# 2.824639320373535
# 3.271209239959717
# 3.1395769119262695
# 3.4179577827453613
# 3.5568430423736572
# 2.94895076751709
# 2.9984006881713867
# 3.028463125228882
# 3.8158040046691895
# 3.1348958015441895
# 3.9076695442199707
# 3.2432148456573486
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2621  data: 1.8800  max mem: 7123
# 3.392432689666748
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2521  data: 1.8715  max mem: 7123
# Epoch: [21] Total time: 0:00:49 (2.2574 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0116 (0.0116)  evaluator_time: 0.0253 (0.0253)  time: 0.1018  data: 0.0613  max mem: 7123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0110)  evaluator_time: 0.0225 (0.0242)  time: 0.0987  data: 0.0564  max mem: 7123
# Test: Total time: 0:00:03 (0.0975 s / it)
# Averaged stats: model_time: 0.0110 (0.0110)  evaluator_time: 0.0225 (0.0242)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.442
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
# 2.7757091522216797
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.526
# 2.724853992462158
# Epoch: [43]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1328  data: 1.7653  max mem: 7228
# 2.9998204708099365
# 3.1119070053100586
# 3.057391881942749
# 3.2961082458496094
# 3.30041241645813
# 2.78964900970459
# 3.539457082748413
# 3.0328729152679443
# 3.6703131198883057
# 3.2953572273254395
# 3.2445333003997803
# 2.9686813354492188
# 3.164039134979248
# 2.9703896045684814
# 3.1148123741149902
# 3.1149561405181885
# 2.493536949157715
# 3.1989707946777344
# 2.244964599609375
# 3.2419707775115967
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1789  data: 1.8165  max mem: 7228
# 3.3359076976776123
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1620  data: 1.8066  max mem: 7228
# Epoch: [43] Total time: 0:00:47 (2.1687 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0152 (0.0152)  time: 0.0920  data: 0.0616  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0110)  evaluator_time: 0.0177 (0.0216)  time: 0.0966  data: 0.0573  max mem: 7228
# Test: Total time: 0:00:03 (0.0953 s / it)
# Averaged stats: model_time: 0.0110 (0.0110)  evaluator_time: 0.0177 (0.0216)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.501
# 2.992555618286133
# Epoch: [44]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2956  data: 1.9079  max mem: 7228
# 3.6543054580688477
# 3.1767992973327637
# 2.7326295375823975
# 3.0378313064575195
# 3.639155387878418
# 3.266713857650757
# 2.839136838912964
# 3.133962631225586
# 3.3239822387695312
# 2.9111838340759277
# 3.0348117351531982
# 3.1271729469299316
# 2.8809115886688232
# 3.4243240356445312
# 3.307673454284668
# 2.7297396659851074
# 3.572826862335205
# 3.0688655376434326
# 2.5952446460723877
# 3.138254165649414
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1213  data: 1.7452  max mem: 7228
# 2.9188156127929688
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1098  data: 1.7333  max mem: 7228
# Epoch: [44] Total time: 0:00:46 (2.1153 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0149 (0.0149)  time: 0.0919  data: 0.0618  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0111)  evaluator_time: 0.0185 (0.0216)  time: 0.0967  data: 0.0568  max mem: 7228
# Test: Total time: 0:00:03 (0.0955 s / it)
# Averaged stats: model_time: 0.0109 (0.0111)  evaluator_time: 0.0185 (0.0216)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# 3.2828543186187744
# Epoch: [45]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0129  data: 1.5485  max mem: 7228
# 2.8829469680786133
# 3.382554054260254
# 2.4845337867736816
# 2.603194236755371
# 3.2174313068389893
# 3.356032133102417
# 3.1256701946258545
# 3.293215036392212
# 3.331413745880127
# 3.3857853412628174
# 3.8986635208129883
# 2.7471466064453125
# 3.01715087890625
# 3.1115262508392334
# 2.939826250076294
# 2.8394367694854736
# 2.585810899734497
# 2.9637632369995117
# 3.1994736194610596
# 2.864459753036499
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1299  data: 1.7599  max mem: 7228
# 2.911116600036621
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1420  data: 1.7703  max mem: 7228
# Epoch: [45] Total time: 0:00:47 (2.1392 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0163 (0.0163)  time: 0.0928  data: 0.0612  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0110)  evaluator_time: 0.0172 (0.0215)  time: 0.0970  data: 0.0570  max mem: 7228
# Test: Total time: 0:00:03 (0.0949 s / it)
# Averaged stats: model_time: 0.0108 (0.0110)  evaluator_time: 0.0172 (0.0215)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
# 2.8312783241271973
# Epoch: [46]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9678  data: 1.6299  max mem: 7228
# 3.110095262527466
# 3.611144781112671
# 2.9282331466674805
# 2.9602675437927246
# 3.305420160293579
# 3.0951449871063232
# 2.576838493347168
# 2.692936897277832
# 3.6021535396575928
# 3.1080923080444336
# 2.9823074340820312
# 2.637316942214966
# 2.7412374019622803
# 3.0324926376342773
# 2.4925296306610107
# 3.302966356277466
# 2.8755393028259277
# 2.4466066360473633
# 3.0560765266418457
# 2.7409231662750244
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1760  data: 1.8010  max mem: 7228
# 3.514662265777588
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1429  data: 1.7746  max mem: 7228
# Epoch: [46] Total time: 0:00:47 (2.1529 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0144 (0.0144)  time: 0.0914  data: 0.0619  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0111)  evaluator_time: 0.0168 (0.0209)  time: 0.0961  data: 0.0573  max mem: 7228
# Test: Total time: 0:00:03 (0.0947 s / it)
# Averaged stats: model_time: 0.0111 (0.0111)  evaluator_time: 0.0168 (0.0209)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.514
# 2.977552652359009
# Epoch: [47]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1393  data: 1.7636  max mem: 7228
# 3.2212393283843994
# 3.283235549926758
# 2.629202365875244
# 2.8447988033294678
# 2.7486343383789062
# 2.984706163406372
# 3.082017421722412
# 2.722911834716797
# 2.531883955001831
# 3.014009952545166
# 2.7083709239959717
# 3.0140433311462402
# 2.832993984222412
# 2.723165988922119
# 3.953808307647705
# 3.011977195739746
# 3.2786285877227783
# 2.761772632598877
# 3.004950523376465
# 2.7687838077545166
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2233  data: 1.8157  max mem: 7228
# 3.0920891761779785
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2081  data: 1.8103  max mem: 7228
# Epoch: [47] Total time: 0:00:48 (2.2257 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0145 (0.0145)  time: 0.0918  data: 0.0619  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0110)  evaluator_time: 0.0174 (0.0207)  time: 0.0952  data: 0.0564  max mem: 7228
# Test: Total time: 0:00:03 (0.0945 s / it)
# Averaged stats: model_time: 0.0109 (0.0110)  evaluator_time: 0.0174 (0.0207)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.507
# 4.179689407348633
# Epoch: [48]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0868  data: 1.6410  max mem: 7228
# 3.3266186714172363
# 3.196279764175415
# 2.803065061569214
# 3.0911781787872314
# 3.020599126815796
# 3.7174763679504395
# 3.052234649658203
# 3.3375260829925537
# 3.5057921409606934
# 3.200443983078003
# 2.721649646759033
# 2.7986395359039307
# 3.481865406036377
# 3.547217845916748
# 2.6313114166259766
# 3.276768922805786
# 3.3866610527038574
# 2.449004650115967
# 3.015244960784912
# 2.812615394592285
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1799  data: 1.7981  max mem: 7228
# 2.6224255561828613
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1812  data: 1.7978  max mem: 7228
# Epoch: [48] Total time: 0:00:47 (2.1818 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0117 (0.0117)  evaluator_time: 0.0255 (0.0255)  time: 0.1020  data: 0.0613  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0110)  evaluator_time: 0.0181 (0.0227)  time: 0.0962  data: 0.0560  max mem: 7228
# Test: Total time: 0:00:03 (0.0960 s / it)
# Averaged stats: model_time: 0.0110 (0.0110)  evaluator_time: 0.0181 (0.0227)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.532
# 2.7731332778930664
# Epoch: [49]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4894  data: 2.0420  max mem: 7228
# 2.846853256225586
# 2.561138391494751
# 2.5467560291290283
# 2.5750718116760254
# 3.040419101715088
# 3.318373680114746
# 2.9845800399780273
# 3.1478848457336426
# 2.1936283111572266
# 2.931431531906128
# 2.8949289321899414
# 3.070863723754883
# 2.455548048019409
# 3.1851189136505127
# 2.7475366592407227
# 2.718395948410034
# 3.2801432609558105
# 3.1232266426086426
# 2.4533963203430176
# 3.3168997764587402
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2251  data: 1.8358  max mem: 7228
# 3.1098427772521973
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1996  data: 1.8148  max mem: 7228
# Epoch: [49] Total time: 0:00:48 (2.2265 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0116 (0.0116)  evaluator_time: 0.0159 (0.0159)  time: 0.1094  data: 0.0783  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0112 (0.0111)  evaluator_time: 0.0163 (0.0211)  time: 0.0955  data: 0.0562  max mem: 7228
# Test: Total time: 0:00:03 (0.0951 s / it)
# Averaged stats: model_time: 0.0112 (0.0111)  evaluator_time: 0.0163 (0.0211)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.504
# Training time 0:47:38

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_DenseNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.21887374106491583

# %%
start_time = time.time()


for epoch in range(50, 100):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# 3.4640636444091797
# Epoch: [50]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2750  data: 1.8622  max mem: 7228
# 2.881150484085083
# 2.902608871459961
# 3.042854070663452
# 3.2767627239227295
# 2.839421272277832
# 2.5862178802490234
# 3.3278541564941406
# 2.764930248260498
# 2.6714468002319336
# 2.3257031440734863
# 2.825709819793701
# 2.872647285461426
# 3.1588120460510254
# 3.4008216857910156
# 4.315618991851807
# 2.988476276397705
# 3.289238691329956
# 2.863274335861206
# 3.085440158843994
# 3.2863454818725586
# Epoch: [50]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1615  data: 1.7696  max mem: 7228
# 2.667698860168457
# Epoch: [50]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1474  data: 1.7592  max mem: 7228
# Epoch: [50] Total time: 0:00:47 (2.1614 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0150 (0.0150)  time: 0.0929  data: 0.0625  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0113)  evaluator_time: 0.0163 (0.0204)  time: 0.0945  data: 0.0563  max mem: 7228
# Test: Total time: 0:00:03 (0.0940 s / it)
# Averaged stats: model_time: 0.0111 (0.0113)  evaluator_time: 0.0163 (0.0204)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.512
# 3.2596654891967773
# Epoch: [51]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.8091  data: 1.4688  max mem: 7228
# 3.7298851013183594
# 2.8545854091644287
# 3.026934862136841
# 3.4011282920837402
# 2.9159274101257324
# 3.3152854442596436
# 2.964517593383789
# 3.2357497215270996
# 2.569450855255127
# 2.674302339553833
# 3.2402138710021973
# 3.3508424758911133
# 3.3196685314178467
# 2.96593976020813
# 2.7197611331939697
# 2.3735392093658447
# 2.135070562362671
# 3.5216288566589355
# 3.212141513824463
# 2.839401960372925
# Epoch: [51]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1858  data: 1.7942  max mem: 7228
# 3.9114151000976562
# Epoch: [51]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1703  data: 1.7787  max mem: 7228
# Epoch: [51] Total time: 0:00:47 (2.1576 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0120 (0.0120)  evaluator_time: 0.0252 (0.0252)  time: 0.1022  data: 0.0614  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0195 (0.0274)  time: 0.0968  data: 0.0563  max mem: 7228
# Test: Total time: 0:00:04 (0.1008 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0195 (0.0274)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.456
# 3.7539243698120117
# Epoch: [52]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1069  data: 1.6502  max mem: 7228
# 2.9149045944213867
# 2.9028830528259277
# 3.0468099117279053
# 2.6266579627990723
# 3.0934460163116455
# 3.0851776599884033
# 2.7887463569641113
# 3.231450319290161
# 2.4059603214263916
# 3.132736921310425
# 3.25313663482666
# 2.660295248031616
# 3.3228511810302734
# 2.6200897693634033
# 2.7863571643829346
# 2.7938170433044434
# 2.6226141452789307
# 3.2276692390441895
# 3.0070605278015137
# 3.093700408935547
# Epoch: [52]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1385  data: 1.7511  max mem: 7228
# 3.466639757156372
# Epoch: [52]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1345  data: 1.7459  max mem: 7228
# Epoch: [52] Total time: 0:00:46 (2.1292 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0145 (0.0145)  time: 0.0927  data: 0.0632  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0112)  evaluator_time: 0.0164 (0.0205)  time: 0.0940  data: 0.0561  max mem: 7228
# Test: Total time: 0:00:03 (0.0956 s / it)
# Averaged stats: model_time: 0.0109 (0.0112)  evaluator_time: 0.0164 (0.0205)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.493
# 3.729647159576416
# Epoch: [53]  [ 0/22]  eta: 0:00:55  lr: 0.003000  time: 2.5037  data: 1.9857  max mem: 7228
# 3.801769256591797
# 3.0802764892578125
# 2.821582317352295
# 2.628755569458008
# 2.9527535438537598
# 3.2474827766418457
# 2.3932881355285645
# 3.0150346755981445
# 2.886463165283203
# 3.590088129043579
# 3.5332388877868652
# 3.6592018604278564
# 2.638538360595703
# 3.3694825172424316
# 3.210670232772827
# 2.754596710205078
# 3.645162582397461
# 2.7963907718658447
# 3.0796287059783936
# 3.2104709148406982
# Epoch: [53]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2699  data: 1.8553  max mem: 7228
# 2.856462240219116
# Epoch: [53]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2305  data: 1.8342  max mem: 7228
# Epoch: [53] Total time: 0:00:49 (2.2619 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0158 (0.0158)  time: 0.0924  data: 0.0617  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0110)  evaluator_time: 0.0187 (0.0223)  time: 0.0980  data: 0.0571  max mem: 7228
# Test: Total time: 0:00:03 (0.0958 s / it)
# Averaged stats: model_time: 0.0111 (0.0110)  evaluator_time: 0.0187 (0.0223)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.541
# 3.3402092456817627
# Epoch: [54]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1983  data: 1.8022  max mem: 7228
# 3.1437649726867676
# 3.0459914207458496
# 3.187486171722412
# 3.7666726112365723
# 2.6886398792266846
# 2.6477885246276855
# 2.8714568614959717
# 3.449913740158081
# 2.8678927421569824
# 2.7226643562316895
# 3.400360345840454
# 3.643205404281616
# 2.850545644760132
# 3.057206392288208
# 3.187833309173584
# 3.3619582653045654
# 2.6466972827911377
# 2.687016725540161
# 3.0810465812683105
# 2.785752534866333
# Epoch: [54]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1410  data: 1.7626  max mem: 7228
# 3.349991798400879
# Epoch: [54]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1154  data: 1.7364  max mem: 7228
# Epoch: [54] Total time: 0:00:47 (2.1409 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0180 (0.0180)  time: 0.0953  data: 0.0617  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0175 (0.0221)  time: 0.0973  data: 0.0571  max mem: 7228
# Test: Total time: 0:00:03 (0.0962 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0175 (0.0221)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
# 2.567122220993042
# Epoch: [55]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0084  data: 1.6433  max mem: 7228
# 2.737607717514038
# 3.214737892150879
# 3.342623710632324
# 2.8710200786590576
# 2.7177278995513916
# 3.500270128250122
# 2.6545066833496094
# 3.5126070976257324
# 2.994859218597412
# 2.6749110221862793
# 3.05961275100708
# 2.7469329833984375
# 3.014838695526123
# 2.829582691192627
# 3.119208812713623
# 3.5877649784088135
# 3.522304058074951
# 3.017477035522461
# 3.801568031311035
# 2.604689121246338
# Epoch: [55]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1244  data: 1.7402  max mem: 7228
# 3.421300172805786
# Epoch: [55]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1258  data: 1.7436  max mem: 7228
# Epoch: [55] Total time: 0:00:46 (2.1260 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0185 (0.0185)  time: 0.0949  data: 0.0612  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0178 (0.0227)  time: 0.0978  data: 0.0568  max mem: 7228
# Test: Total time: 0:00:03 (0.0962 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0178 (0.0227)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
# 3.1885831356048584
# Epoch: [56]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0756  data: 1.7282  max mem: 7228
# 3.5119919776916504
# 2.3211190700531006
# 3.1587812900543213
# 3.0878612995147705
# 3.4350616931915283
# 3.8205766677856445
# 3.3058555126190186
# 3.0322012901306152
# 2.735800266265869
# 4.174249649047852
# 2.5767173767089844
# 2.9756476879119873
# 3.7296383380889893
# 3.328864097595215
# 2.730196952819824
# 2.944758892059326
# 2.9985857009887695
# 3.11588191986084
# 2.756340742111206
# 3.8057312965393066
# Epoch: [56]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2701  data: 1.8540  max mem: 7228
# 2.7125306129455566
# Epoch: [56]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2530  data: 1.8425  max mem: 7228
# Epoch: [56] Total time: 0:00:49 (2.2641 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0121 (0.0121)  evaluator_time: 0.0174 (0.0174)  time: 0.0957  data: 0.0625  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0112 (0.0113)  evaluator_time: 0.0161 (0.0218)  time: 0.0975  data: 0.0576  max mem: 7228
# Test: Total time: 0:00:03 (0.0962 s / it)
# Averaged stats: model_time: 0.0112 (0.0113)  evaluator_time: 0.0161 (0.0218)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.491
# 3.1774368286132812
# Epoch: [57]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0908  data: 1.6675  max mem: 7228
# 3.049163341522217
# 2.950131416320801
# 2.976292848587036
# 2.707303047180176
# 2.9014551639556885
# 3.1946558952331543
# 2.6828136444091797
# 2.8193979263305664
# 2.942288398742676
# 3.3031046390533447
# 3.00189208984375
# 2.3763341903686523
# 2.700390577316284
# 3.28926944732666
# 3.054762840270996
# 2.650144577026367
# 2.789485454559326
# 3.562476634979248
# 3.5041043758392334
# 2.9481163024902344
# Epoch: [57]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1520  data: 1.7706  max mem: 7228
# 2.281507968902588
# Epoch: [57]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1576  data: 1.7735  max mem: 7228
# Epoch: [57] Total time: 0:00:47 (2.1632 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0182 (0.0182)  time: 0.0949  data: 0.0615  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0110)  evaluator_time: 0.0174 (0.0220)  time: 0.0959  data: 0.0559  max mem: 7228
# Test: Total time: 0:00:03 (0.0952 s / it)
# Averaged stats: model_time: 0.0110 (0.0110)  evaluator_time: 0.0174 (0.0220)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.518
# 2.977041244506836
# Epoch: [58]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.9036  data: 1.5738  max mem: 7228
# 2.9621143341064453
# 3.06072735786438
# 2.611778736114502
# 2.5285568237304688
# 4.055377960205078
# 2.3987793922424316
# 2.8122286796569824
# 2.2886712551116943
# 3.0755555629730225
# 3.8734350204467773
# 3.2607345581054688
# 2.657278299331665
# 3.0898826122283936
# 3.2438669204711914
# 3.1274869441986084
# 3.461021900177002
# 2.7238097190856934
# 2.7936718463897705
# 2.5669610500335693
# 2.649610757827759
# Epoch: [58]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2222  data: 1.8400  max mem: 7228
# 3.0513176918029785
# Epoch: [58]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2353  data: 1.8492  max mem: 7228
# Epoch: [58] Total time: 0:00:48 (2.2063 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0117 (0.0117)  evaluator_time: 0.0242 (0.0242)  time: 0.1012  data: 0.0618  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0212 (0.0241)  time: 0.1000  data: 0.0572  max mem: 7228
# Test: Total time: 0:00:03 (0.0988 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0212 (0.0241)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.495
# 2.885603427886963
# Epoch: [59]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1277  data: 1.7317  max mem: 7228
# 2.243692398071289
# 2.8625149726867676
# 2.771404504776001
# 2.936627149581909
# 2.476456880569458
# 2.7412490844726562
# 2.6621651649475098
# 2.7033166885375977
# 2.7116267681121826
# 2.650977611541748
# 3.8763318061828613
# 2.81681752204895
# 3.370673418045044
# 2.5942001342773438
# 2.790281295776367
# 3.1648166179656982
# 3.051568031311035
# 3.0630228519439697
# 2.737370491027832
# 2.9442405700683594
# Epoch: [59]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1631  data: 1.7878  max mem: 7228
# 3.045865058898926
# Epoch: [59]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1532  data: 1.7733  max mem: 7228
# Epoch: [59] Total time: 0:00:47 (2.1586 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0138 (0.0138)  time: 0.0902  data: 0.0613  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0169 (0.0205)  time: 0.0944  data: 0.0561  max mem: 7228
# Test: Total time: 0:00:03 (0.0940 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0169 (0.0205)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.512
# 3.2331864833831787
# Epoch: [60]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1278  data: 1.6938  max mem: 7228
# 3.0748679637908936
# 2.6593708992004395
# 2.6616692543029785
# 2.7121875286102295
# 2.519300937652588
# 2.494305372238159
# 3.120168924331665
# 3.4987025260925293
# 3.0526742935180664
# 3.0368337631225586
# 3.513662576675415
# 3.6195170879364014
# 3.2999792098999023
# 3.010120391845703
# 3.0419106483459473
# 2.8416779041290283
# 2.982802629470825
# 2.9070773124694824
# 2.3242225646972656
# 2.7759809494018555
# Epoch: [60]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1079  data: 1.7489  max mem: 7228
# 2.810119390487671
# Epoch: [60]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1108  data: 1.7477  max mem: 7228
# Epoch: [60] Total time: 0:00:46 (2.1136 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0156 (0.0156)  time: 0.0925  data: 0.0615  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0110)  evaluator_time: 0.0167 (0.0211)  time: 0.0950  data: 0.0563  max mem: 7228
# Test: Total time: 0:00:03 (0.0948 s / it)
# Averaged stats: model_time: 0.0108 (0.0110)  evaluator_time: 0.0167 (0.0211)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# 3.2391064167022705
# Epoch: [61]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8731  data: 1.6052  max mem: 7228
# 2.3427982330322266
# 2.4835543632507324
# 3.8664748668670654
# 3.2349281311035156
# 2.889409065246582
# 2.8540804386138916
# 2.6440088748931885
# 2.5281219482421875
# 2.4939303398132324
# 2.4906466007232666
# 3.02339768409729
# 2.770442008972168
# 2.8302783966064453
# 2.903101921081543
# 3.573646306991577
# 3.5236120223999023
# 3.3660953044891357
# 2.899928092956543
# 3.0930933952331543
# 2.493596076965332
# Epoch: [61]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2010  data: 1.7944  max mem: 7228
# 2.974834680557251
# Epoch: [61]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1838  data: 1.7723  max mem: 7228
# Epoch: [61] Total time: 0:00:48 (2.1818 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0148 (0.0148)  time: 0.0926  data: 0.0627  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0111)  evaluator_time: 0.0184 (0.0247)  time: 0.1052  data: 0.0588  max mem: 7228
# Test: Total time: 0:00:03 (0.0998 s / it)
# Averaged stats: model_time: 0.0109 (0.0111)  evaluator_time: 0.0184 (0.0247)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.512
# 2.87638521194458
# Epoch: [62]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9154  data: 1.5241  max mem: 7228
# 2.326272487640381
# 2.832056999206543
# 3.478832721710205
# 2.8151276111602783
# 2.362095832824707
# 2.94671630859375
# 2.989830493927002
# 2.7546544075012207
# 2.880866527557373
# 2.8373677730560303
# 2.7581119537353516
# 2.461282968521118
# 2.9984517097473145
# 2.6600379943847656
# 3.203787088394165
# 2.921891927719116
# 2.285747528076172
# 3.136781692504883
# 2.811572790145874
# 3.2738277912139893
# Epoch: [62]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1171  data: 1.7419  max mem: 7228
# 2.9742705821990967
# Epoch: [62]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1382  data: 1.7552  max mem: 7228
# Epoch: [62] Total time: 0:00:46 (2.1263 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0150 (0.0150)  time: 0.0915  data: 0.0616  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0111)  evaluator_time: 0.0164 (0.0208)  time: 0.0953  data: 0.0565  max mem: 7228
# Test: Total time: 0:00:03 (0.0943 s / it)
# Averaged stats: model_time: 0.0111 (0.0111)  evaluator_time: 0.0164 (0.0208)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.507
# 2.6584417819976807
# Epoch: [63]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9796  data: 1.6278  max mem: 7228
# 2.9523487091064453
# 3.235640048980713
# 2.7386391162872314
# 2.7260735034942627
# 2.8551857471466064
# 2.9330949783325195
# 2.650618553161621
# 2.8981785774230957
# 2.7672677040100098
# 3.719208240509033
# 2.697789192199707
# 2.3362488746643066
# 2.918747901916504
# 3.2572529315948486
# 2.9820690155029297
# 2.8910903930664062
# 3.5067296028137207
# 3.185450553894043
# 3.069643259048462
# 2.731116533279419
# Epoch: [63]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1704  data: 1.7857  max mem: 7228
# 3.1010797023773193
# Epoch: [63]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1412  data: 1.7573  max mem: 7228
# Epoch: [63] Total time: 0:00:47 (2.1495 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0115 (0.0115)  evaluator_time: 0.0150 (0.0150)  time: 0.0920  data: 0.0618  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0171 (0.0214)  time: 0.0960  data: 0.0563  max mem: 7228
# Test: Total time: 0:00:03 (0.0947 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0171 (0.0214)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.511
# 3.0354063510894775
# Epoch: [64]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3649  data: 1.9664  max mem: 7228
# 3.3042900562286377
# 2.893000602722168
# 3.352263927459717
# 2.807126760482788
# 2.6144845485687256
# 2.892868757247925
# 3.0784575939178467
# 2.681279420852661
# 2.152017831802368
# 2.3365087509155273
# 2.316239833831787
# 3.011827230453491
# 4.119603157043457
# 2.7741312980651855
# 4.096658706665039
# 2.9417836666107178
# 3.417616128921509
# 3.328591823577881
# 3.2014458179473877
# 3.0331387519836426
# Epoch: [64]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2784  data: 1.8693  max mem: 7228
# 3.0815913677215576
# Epoch: [64]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2675  data: 1.8563  max mem: 7228
# Epoch: [64] Total time: 0:00:50 (2.2842 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0120 (0.0120)  evaluator_time: 0.0163 (0.0163)  time: 0.0940  data: 0.0620  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0112)  evaluator_time: 0.0200 (0.0221)  time: 0.0968  data: 0.0563  max mem: 7228
# Test: Total time: 0:00:03 (0.0959 s / it)
# Averaged stats: model_time: 0.0110 (0.0112)  evaluator_time: 0.0200 (0.0221)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# 3.2455568313598633
# Epoch: [65]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2293  data: 1.8781  max mem: 7228
# 2.6400012969970703
# 2.3995766639709473
# 2.642537832260132
# 3.3915493488311768
# 2.7156546115875244
# 3.3145549297332764
# 2.713898181915283
# 3.0955986976623535
# 3.675400495529175
# 2.988563299179077
# 3.0101699829101562
# 2.6074929237365723
# 2.961132049560547
# 3.112821102142334
# 2.639317274093628
# 2.8151121139526367
# 2.37555193901062
# 3.826016426086426
# 2.598308563232422
# 3.3160271644592285
# Epoch: [65]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1275  data: 1.7319  max mem: 7228
# 2.4520463943481445
# Epoch: [65]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1371  data: 1.7370  max mem: 7228
# Epoch: [65] Total time: 0:00:47 (2.1490 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0118 (0.0118)  evaluator_time: 0.0145 (0.0145)  time: 0.0919  data: 0.0619  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0207)  time: 0.0951  data: 0.0564  max mem: 7228
# Test: Total time: 0:00:03 (0.0940 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0207)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.507
# 2.9996092319488525
# Epoch: [66]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4788  data: 1.9910  max mem: 7228
# 2.465588331222534
# 3.2146685123443604
# 2.420844554901123
# 2.9271650314331055
# 3.344433307647705
# 3.1491730213165283
# 2.609839916229248
# 3.335635185241699
# 2.930162191390991
# 3.146477699279785
# 3.2824361324310303
# 2.666037082672119
# 3.177518844604492
# 2.953301429748535
# 2.6641464233398438
# 2.5469906330108643
# 2.526155710220337
# 3.1940696239471436
# 3.1776602268218994
# 2.612236738204956
# Epoch: [66]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1525  data: 1.7592  max mem: 7228
# 3.189349412918091
# Epoch: [66]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1733  data: 1.7748  max mem: 7228
# Epoch: [66] Total time: 0:00:47 (2.1800 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0169 (0.0169)  time: 0.0957  data: 0.0636  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0110)  evaluator_time: 0.0184 (0.0216)  time: 0.0965  data: 0.0568  max mem: 7228
# Test: Total time: 0:00:03 (0.0957 s / it)
# Averaged stats: model_time: 0.0109 (0.0110)  evaluator_time: 0.0184 (0.0216)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.521
# 3.0988409519195557
# Epoch: [67]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1826  data: 1.7005  max mem: 7228
# 2.6497981548309326
# 2.7738707065582275
# 2.9919068813323975
# 2.9063994884490967
# 2.7012054920196533
# 2.963648557662964
# 3.059091806411743
# 2.7705719470977783
# 3.228813409805298
# 2.6930017471313477
# 2.814847707748413
# 2.9758682250976562
# 2.5568642616271973
# 3.587519645690918
# 2.6901566982269287
# 2.900892734527588
# 2.9629406929016113
# 3.0994880199432373
# 2.5881905555725098
# 2.8544700145721436
# Epoch: [67]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1666  data: 1.7789  max mem: 7228
# 2.6345369815826416
# Epoch: [67]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1678  data: 1.7783  max mem: 7228
# Epoch: [67] Total time: 0:00:47 (2.1639 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0121 (0.0121)  evaluator_time: 0.0263 (0.0263)  time: 0.1043  data: 0.0622  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0185 (0.0229)  time: 0.0976  data: 0.0564  max mem: 7228
# Test: Total time: 0:00:03 (0.0964 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0185 (0.0229)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.346
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.532
# 2.7061362266540527
# Epoch: [68]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8371  data: 1.4984  max mem: 7228
# 2.8189470767974854
# 2.5334527492523193
# 2.6701431274414062
# 2.4974186420440674
# 1.825454831123352
# 2.7081832885742188
# 2.9330556392669678
# 2.965404510498047
# 3.0311930179595947
# 2.615227699279785
# 2.7070350646972656
# 2.6947145462036133
# 2.3554134368896484
# 3.165914535522461
# 2.526078224182129
# 2.3284518718719482
# 2.6340408325195312
# 2.388855457305908
# 3.6465675830841064
# 2.907442569732666
# Epoch: [68]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1636  data: 1.7903  max mem: 7228
# 3.1188619136810303
# Epoch: [68]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1359  data: 1.7598  max mem: 7228
# Epoch: [68] Total time: 0:00:47 (2.1415 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0141 (0.0141)  time: 0.0907  data: 0.0613  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0178 (0.0209)  time: 0.0958  data: 0.0565  max mem: 7228
# Test: Total time: 0:00:03 (0.0943 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0178 (0.0209)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# 3.5360677242279053
# Epoch: [69]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1384  data: 1.6415  max mem: 7228
# 2.4756064414978027
# 2.3950867652893066
# 2.566093921661377
# 3.161011219024658
# 2.908329963684082
# 2.665388584136963
# 3.36147403717041
# 2.645521640777588
# 2.277878999710083
# 2.4022164344787598
# 3.810081958770752
# 3.1832542419433594
# 2.6097288131713867
# 3.0967226028442383
# 2.5128579139709473
# 3.450914144515991
# 3.3997979164123535
# 2.9836857318878174
# 2.8666961193084717
# 3.231374740600586
# Epoch: [69]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1268  data: 1.7494  max mem: 7228
# 2.522733211517334
# Epoch: [69]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1456  data: 1.7648  max mem: 7228
# Epoch: [69] Total time: 0:00:46 (2.1339 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0114 (0.0114)  evaluator_time: 0.0157 (0.0157)  time: 0.0922  data: 0.0614  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0210)  time: 0.0986  data: 0.0595  max mem: 7228
# Test: Total time: 0:00:03 (0.0959 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0210)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.519
# 2.8709397315979004
# Epoch: [70]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8404  data: 1.5115  max mem: 7228
# 3.0283775329589844
# 3.0832014083862305
# 3.0484731197357178
# 3.2826955318450928
# 3.4124932289123535
# 3.4752535820007324
# 3.1715219020843506
# 3.401768684387207
# 3.29559326171875
# 3.4103691577911377
# 2.7216527462005615
# 3.2957725524902344
# 2.5130677223205566
# 3.6306257247924805
# 2.8375589847564697
# 2.711169719696045
# 2.8979287147521973
# 2.4517877101898193
# 3.1749684810638428
# 2.517608642578125
# Epoch: [70]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2369  data: 1.8170  max mem: 7228
# 3.465546131134033
# Epoch: [70]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2682  data: 1.8438  max mem: 7228
# Epoch: [70] Total time: 0:00:49 (2.2362 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0143 (0.0143)  time: 0.0909  data: 0.0617  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0111)  evaluator_time: 0.0163 (0.0203)  time: 0.0951  data: 0.0571  max mem: 7228
# Test: Total time: 0:00:03 (0.0939 s / it)
# Averaged stats: model_time: 0.0111 (0.0111)  evaluator_time: 0.0163 (0.0203)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.495
# 3.03497576713562
# Epoch: [71]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9171  data: 1.5326  max mem: 7228
# 2.727717399597168
# 2.5268986225128174
# 3.0379996299743652
# 2.7494349479675293
# 2.6590065956115723
# 3.0746374130249023
# 2.7969086170196533
# 3.1841444969177246
# 3.0542140007019043
# 2.751434803009033
# 2.649784564971924
# 2.382877826690674
# 3.497039556503296
# 2.8869407176971436
# 3.0338971614837646
# 3.2685790061950684
# 2.559755325317383
# 2.8302388191223145
# 2.5472960472106934
# 3.0754165649414062
# Epoch: [71]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2352  data: 1.8574  max mem: 7228
# 3.039874315261841
# Epoch: [71]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2095  data: 1.8364  max mem: 7228
# Epoch: [71] Total time: 0:00:48 (2.2148 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0116 (0.0116)  evaluator_time: 0.0238 (0.0238)  time: 0.1011  data: 0.0620  max mem: 7228
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0111)  evaluator_time: 0.0187 (0.0260)  time: 0.1046  data: 0.0570  max mem: 7228
# Test: Total time: 0:00:03 (0.0998 s / it)
# Averaged stats: model_time: 0.0109 (0.0111)  evaluator_time: 0.0187 (0.0260)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.335
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.521
# 2.5325777530670166
# Epoch: [93]  [ 0/22]  eta: 0:00:37  lr: 0.000300  time: 1.6898  data: 1.4030  max mem: 7234
# 2.843064546585083
# 2.4448728561401367
# 2.870184898376465
# 2.6265597343444824
# 3.196160316467285
# 3.389310598373413
# 2.4204540252685547
# 2.0958826541900635
# 2.9003992080688477
# 2.584933042526245
# 2.472055435180664
# 2.3768842220306396
# 2.4350171089172363
# 2.459294080734253
# 3.5423030853271484
# 2.4415712356567383
# 2.2596476078033447
# 3.1173691749572754
# 3.417494773864746
# 2.411012649536133
# Epoch: [93]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1460  data: 1.7523  max mem: 7234
# 2.7737693786621094
# Epoch: [93]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1514  data: 1.7490  max mem: 7234
# Epoch: [93] Total time: 0:00:46 (2.1344 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0116 (0.0116)  evaluator_time: 0.0155 (0.0155)  time: 0.0921  data: 0.0614  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0239)  time: 0.1024  data: 0.0573  max mem: 7234
# Test: Total time: 0:00:03 (0.0979 s / it)
# Averaged stats: model_time: 0.0110 (0.0111)  evaluator_time: 0.0170 (0.0239)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.509
# 2.569030523300171
# Epoch: [94]  [ 0/22]  eta: 0:00:46  lr: 0.000300  time: 2.1131  data: 1.6314  max mem: 7234
# 2.7493600845336914
# 2.477745294570923
# 3.0032942295074463
# 2.6279354095458984
# 3.1992950439453125
# 3.2873661518096924
# 2.438080310821533
# 3.278418779373169
# 2.403618335723877
# 2.7973642349243164
# 2.263920545578003
# 2.332826614379883
# 2.450327157974243
# 2.740901231765747
# 3.2848448753356934
# 2.9376864433288574
# 2.2189035415649414
# 2.393409252166748
# 2.3780014514923096
# 2.7024030685424805
# Epoch: [94]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1914  data: 1.8020  max mem: 7234
# 2.975403070449829
# Epoch: [94]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1861  data: 1.7971  max mem: 7234
# Epoch: [94] Total time: 0:00:48 (2.1870 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0119 (0.0119)  evaluator_time: 0.0157 (0.0157)  time: 0.0949  data: 0.0635  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0111)  evaluator_time: 0.0180 (0.0212)  time: 0.0961  data: 0.0568  max mem: 7234
# Test: Total time: 0:00:03 (0.0950 s / it)
# Averaged stats: model_time: 0.0109 (0.0111)  evaluator_time: 0.0180 (0.0212)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.513
# 2.701979160308838
# Epoch: [95]  [ 0/22]  eta: 0:00:46  lr: 0.000300  time: 2.0976  data: 1.6445  max mem: 7234
# 2.980989933013916
# 2.8209495544433594
# 2.828944683074951
# 2.592008113861084
# 2.386861801147461
# 1.9563748836517334
# 2.246460437774658
# 3.052309989929199
# 2.7110395431518555
# 2.4107046127319336
# 2.434072971343994
# 3.7376651763916016
# 2.8045806884765625
# 2.883876323699951
# 2.394820213317871
# 3.141188621520996
# 3.2998709678649902
# 2.882542133331299
# 2.685434341430664
# 2.7009363174438477
# Epoch: [95]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1643  data: 1.7666  max mem: 7234
# 2.8161799907684326
# Epoch: [95]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1794  data: 1.7838  max mem: 7234
# Epoch: [95] Total time: 0:00:47 (2.1802 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0151 (0.0151)  time: 0.0922  data: 0.0622  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0108 (0.0109)  evaluator_time: 0.0165 (0.0217)  time: 0.0970  data: 0.0564  max mem: 7234
# Test: Total time: 0:00:03 (0.0953 s / it)
# Averaged stats: model_time: 0.0108 (0.0109)  evaluator_time: 0.0165 (0.0217)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# 2.4612698554992676
# Epoch: [96]  [ 0/22]  eta: 0:00:42  lr: 0.000300  time: 1.9385  data: 1.5201  max mem: 7234
# 2.4834132194519043
# 2.629549503326416
# 2.9673171043395996
# 2.3513293266296387
# 2.7289493083953857
# 2.8478665351867676
# 2.4894537925720215
# 2.4611637592315674
# 2.1100668907165527
# 3.354891538619995
# 3.1376707553863525
# 2.86930513381958
# 3.1546497344970703
# 2.3039143085479736
# 2.3072001934051514
# 3.130262851715088
# 2.747274398803711
# 2.5042600631713867
# 2.57314395904541
# 2.320004463195801
# Epoch: [96]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1525  data: 1.7726  max mem: 7234
# 2.7370355129241943
# Epoch: [96]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1435  data: 1.7597  max mem: 7234
# Epoch: [96] Total time: 0:00:47 (2.1463 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0113 (0.0113)  evaluator_time: 0.0153 (0.0153)  time: 0.0922  data: 0.0621  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0112 (0.0111)  evaluator_time: 0.0172 (0.0207)  time: 0.0955  data: 0.0568  max mem: 7234
# Test: Total time: 0:00:03 (0.0948 s / it)
# Averaged stats: model_time: 0.0112 (0.0111)  evaluator_time: 0.0172 (0.0207)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.346
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.511
# 2.395580291748047
# Epoch: [97]  [ 0/22]  eta: 0:00:40  lr: 0.000300  time: 1.8476  data: 1.5401  max mem: 7234
# 2.6147494316101074
# 2.884056329727173
# 2.4617807865142822
# 2.8463120460510254
# 2.851248264312744
# 2.374218225479126
# 2.8168954849243164
# 2.4247379302978516
# 2.590061902999878
# 2.893540382385254
# 2.924060821533203
# 3.5079843997955322
# 2.4630160331726074
# 2.3220064640045166
# 2.70351505279541
# 2.190556049346924
# 2.471332311630249
# 2.7469213008880615
# 2.7895846366882324
# 3.0106518268585205
# Epoch: [97]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1132  data: 1.7262  max mem: 7234
# 2.7715907096862793
# Epoch: [97]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1021  data: 1.7182  max mem: 7234
# Epoch: [97] Total time: 0:00:46 (2.0958 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0157 (0.0157)  time: 0.0936  data: 0.0626  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0109 (0.0110)  evaluator_time: 0.0170 (0.0209)  time: 0.0948  data: 0.0561  max mem: 7234
# Test: Total time: 0:00:03 (0.0945 s / it)
# Averaged stats: model_time: 0.0109 (0.0110)  evaluator_time: 0.0170 (0.0209)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.518
# 2.353511333465576
# Epoch: [98]  [ 0/22]  eta: 0:00:38  lr: 0.000300  time: 1.7536  data: 1.4570  max mem: 7234
# 2.578549861907959
# 2.722609043121338
# 2.7190194129943848
# 2.992640733718872
# 2.8245182037353516
# 3.1151623725891113
# 2.92930269241333
# 2.3506321907043457
# 3.016263961791992
# 2.8377177715301514
# 2.2818961143493652
# 3.0040547847747803
# 3.4612224102020264
# 2.318873405456543
# 2.2373664379119873
# 3.118596315383911
# 2.2290701866149902
# 3.504833936691284
# 2.76839017868042
# 2.020244598388672
# Epoch: [98]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.0849  data: 1.7152  max mem: 7234
# 2.23441481590271
# Epoch: [98]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0825  data: 1.7140  max mem: 7234
# Epoch: [98] Total time: 0:00:45 (2.0882 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0151 (0.0151)  time: 0.0919  data: 0.0615  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0112)  evaluator_time: 0.0165 (0.0205)  time: 0.0945  data: 0.0562  max mem: 7234
# Test: Total time: 0:00:03 (0.0943 s / it)
# Averaged stats: model_time: 0.0111 (0.0112)  evaluator_time: 0.0165 (0.0205)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.520
# 2.771608352661133
# Epoch: [99]  [ 0/22]  eta: 0:00:45  lr: 0.000300  time: 2.0556  data: 1.7233  max mem: 7234
# 2.8570621013641357
# 3.02779221534729
# 2.1511762142181396
# 2.7744102478027344
# 2.7473549842834473
# 2.605417490005493
# 3.3820090293884277
# 2.6364331245422363
# 2.2479474544525146
# 2.8451664447784424
# 3.488515615463257
# 2.5512349605560303
# 3.1815991401672363
# 2.6506941318511963
# 2.6970369815826416
# 2.2426342964172363
# 2.8241078853607178
# 2.8777637481689453
# 2.574249744415283
# 2.3373351097106934
# Epoch: [99]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1442  data: 1.7468  max mem: 7234
# 2.5819344520568848
# Epoch: [99]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1122  data: 1.7121  max mem: 7234
# Epoch: [99] Total time: 0:00:47 (2.1435 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0117 (0.0117)  evaluator_time: 0.0150 (0.0150)  time: 0.0930  data: 0.0626  max mem: 7234
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0111 (0.0111)  evaluator_time: 0.0175 (0.0208)  time: 0.0952  data: 0.0562  max mem: 7234
# Test: Total time: 0:00:03 (0.0944 s / it)
# Averaged stats: model_time: 0.0111 (0.0111)  evaluator_time: 0.0175 (0.0208)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.217
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.519
# Training time 0:45:05

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_DenseNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.22446648879712305
