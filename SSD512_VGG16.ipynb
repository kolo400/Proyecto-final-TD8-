# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)
train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]


def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)



def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())

train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        img = read_image(path_base + '/Imagenes/' + item['image_filename'])
        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])


        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)
        if self.transform:
            img, target = self.transform(img, target)
        return img, target

train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))

print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import SSDFeatureExtractorResNet, ssd512_vgg16
model = ssd512_vgg16(pretrained=False)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16_features-amdegroot.pth" to /root/.cache/torch/hub/checkpoints/vgg16_features-amdegroot.pth
# 100%|██████████| 56.1M/56.1M [00:00<00:00, 324MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background


in_channels = [512, 1024, 512, 256, 256, 256 ,256]
num_anchors = [4, 6, 6, 6, 4, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)


        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()
        print(loss_value)

        optimizer.zero_grad()
        losses.backward()


        if loss_value>1000 or loss_value == np.nan:
          for name, param in model.named_parameters():
            if param.grad is not None:
                print(f"{name} grad max: {param.grad.max().item()}, grad min: {param.grad.min().item()}")

        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-18 14:05:29--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-18 14:05:29 (64.4 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-18 14:05:29--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-18 14:05:30 (96.7 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-18 14:05:30--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-18 14:05:30 (92.4 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-18 14:05:30--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-18 14:05:30 (82.1 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-18 14:05:31--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0s
#
# 2024-11-18 14:05:31 (143 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()#Solo se cambia la tasa cuando se alcanza uno de los milestones definidos
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# 44.353145599365234
# Epoch: [0]  [ 0/22]  eta: 0:07:27  lr: 0.000146  time: 20.3343  data: 16.9335  max mem: 5158
# 35.06880187988281
# 21.257986068725586
# 20.06468391418457
# 13.598235130310059
# 12.250038146972656
# 14.431861877441406
# 12.378029823303223
# 14.39593505859375
# 20.47702980041504
# 25.873992919921875
# 38.798091888427734
# 46.49089813232422
# 41.467403411865234
# 38.26050567626953
# 35.55735778808594
# 28.16193389892578
# 45.42140197753906
# 25.942665100097656
# 38.167110443115234
# 46.2960205078125
# Epoch: [0]  [20/22]  eta: 0:00:30  lr: 0.003000  time: 14.7414  data: 14.2043  max mem: 6137
# 36.86025619506836
# Epoch: [0]  [21/22]  eta: 0:00:14  lr: 0.003000  time: 14.6395  data: 14.1278  max mem: 6137
# Epoch: [0] Total time: 0:05:29 (14.9643 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.2508 (0.2508)  evaluator_time: 0.0298 (0.0298)  time: 0.3472  data: 0.0628  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0207)  evaluator_time: 0.0245 (0.0381)  time: 0.1141  data: 0.0592  max mem: 6137
# Test: Total time: 0:00:04 (0.1231 s / it)
# Averaged stats: model_time: 0.0148 (0.0207)  evaluator_time: 0.0245 (0.0381)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 78.22190856933594
# Epoch: [1]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1163  data: 1.6946  max mem: 6137
# 66.8428955078125
# 66.84488677978516
# 108.32132720947266
# 91.80287170410156
# 122.87308502197266
# 66.6559066772461
# 56.50204849243164
# 86.76622009277344
# 49.84220504760742
# 53.916263580322266
# 53.69565200805664
# 53.31896209716797
# 82.267822265625
# 69.07098388671875
# 75.7360610961914
# 76.66770935058594
# 125.90663146972656
# 93.12673950195312
# 100.95820617675781
# 113.67283630371094
# Epoch: [1]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.6198  data: 2.1335  max mem: 6137
# 111.25869750976562
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5917  data: 2.1147  max mem: 6137
# Epoch: [1] Total time: 0:00:56 (2.5757 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0303 (0.0303)  time: 0.1119  data: 0.0625  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0251 (0.0436)  time: 0.1213  data: 0.0581  max mem: 6137
# Test: Total time: 0:00:04 (0.1223 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0251 (0.0436)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 106.9976577758789
# Epoch: [2]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3367  data: 1.7940  max mem: 6137
# 104.20655822753906
# 98.74834442138672
# 92.29533386230469
# 102.09754943847656
# 56.42740249633789
# 92.58721923828125
# 55.54523849487305
# 67.89848327636719
# 108.51416015625
# 109.91239166259766
# 119.62210083007812
# 128.3354034423828
# 115.54558563232422
# 113.85907745361328
# 118.88445281982422
# 109.6789321899414
# 103.99213409423828
# 131.30812072753906
# 112.36064147949219
# 102.13827514648438
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4890  data: 1.9675  max mem: 6137
# 181.14170837402344
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4784  data: 1.9561  max mem: 6137
# Epoch: [2] Total time: 0:00:54 (2.4757 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0149 (0.0149)  evaluator_time: 0.0267 (0.0267)  time: 0.1097  data: 0.0642  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0145 (0.0146)  evaluator_time: 0.0194 (0.0368)  time: 0.1096  data: 0.0581  max mem: 6137
# Test: Total time: 0:00:04 (0.1156 s / it)
# Averaged stats: model_time: 0.0145 (0.0146)  evaluator_time: 0.0194 (0.0368)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 87.89116668701172
# Epoch: [3]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3417  data: 1.8858  max mem: 6137
# 94.110595703125
# 56.4322624206543
# 76.76166534423828
# 69.30180358886719
# 115.55937957763672
# 93.6401596069336
# 78.33027648925781
# 95.3702392578125
# 86.9056396484375
# 56.80951690673828
# 69.09599304199219
# 88.8770980834961
# 60.334041595458984
# 86.3473892211914
# 93.37322998046875
# 90.6048812866211
# 72.30215454101562
# 71.50053405761719
# 64.2377700805664
# 103.67537689208984
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3489  data: 1.8467  max mem: 6137
# 78.35530853271484
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3463  data: 1.8407  max mem: 6137
# Epoch: [3] Total time: 0:00:51 (2.3506 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0038 (0.0038)  time: 0.0852  data: 0.0628  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0145 (0.0145)  evaluator_time: 0.0048 (0.0044)  time: 0.0799  data: 0.0569  max mem: 6137
# Test: Total time: 0:00:03 (0.0824 s / it)
# Averaged stats: model_time: 0.0145 (0.0145)  evaluator_time: 0.0048 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 66.23946380615234
# Epoch: [4]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3302  data: 1.8985  max mem: 6137
# 57.757240295410156
# 57.92414855957031
# 53.25920104980469
# 91.7040786743164
# 55.13064193725586
# 78.1070556640625
# 84.99402618408203
# 82.4132080078125
# 77.61753845214844
# 84.30675506591797
# 82.12181091308594
# 82.17436218261719
# 97.18942260742188
# 64.71823120117188
# 71.06725311279297
# 56.2357063293457
# 49.2712516784668
# 76.68014526367188
# 54.64701461791992
# 32.05963897705078
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2875  data: 1.7938  max mem: 6137
# 49.01847457885742
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2833  data: 1.7923  max mem: 6137
# Epoch: [4] Total time: 0:00:50 (2.2966 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0037 (0.0037)  time: 0.0858  data: 0.0636  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0144)  evaluator_time: 0.0041 (0.0041)  time: 0.0793  data: 0.0568  max mem: 6137
# Test: Total time: 0:00:03 (0.0819 s / it)
# Averaged stats: model_time: 0.0144 (0.0144)  evaluator_time: 0.0041 (0.0041)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 70.2560043334961
# Epoch: [5]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4551  data: 1.9786  max mem: 6137
# 44.224544525146484
# 57.966617584228516
# 51.42502975463867
# 31.04451560974121
# 36.842185974121094
# 64.47631072998047
# 53.72123336791992
# 42.11749267578125
# 47.6815071105957
# 45.617130279541016
# 50.09730911254883
# 53.02849578857422
# 25.19147491455078
# 40.844810485839844
# 47.94435119628906
# 50.30231475830078
# 45.63426971435547
# 66.7711181640625
# 54.24388122558594
# 53.67156219482422
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4098  data: 1.9075  max mem: 6137
# 37.6722526550293
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4218  data: 1.9106  max mem: 6137
# Epoch: [5] Total time: 0:00:53 (2.4197 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0146 (0.0146)  evaluator_time: 0.0048 (0.0048)  time: 0.0867  data: 0.0635  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0145)  evaluator_time: 0.0040 (0.0054)  time: 0.0821  data: 0.0584  max mem: 6137
# Test: Total time: 0:00:03 (0.0844 s / it)
# Averaged stats: model_time: 0.0144 (0.0145)  evaluator_time: 0.0040 (0.0054)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 39.265159606933594
# Epoch: [6]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.9064  data: 1.4043  max mem: 6137
# 46.29131317138672
# 35.279361724853516
# 37.45344161987305
# 41.970909118652344
# 31.44908905029297
# 27.151653289794922
# 45.31671142578125
# 28.593170166015625
# 35.62716293334961
# 19.44477081298828
# 33.228309631347656
# 19.192405700683594
# 17.517343521118164
# 25.74954605102539
# 22.621257781982422
# 24.69775390625
# 18.535825729370117
# 23.864978790283203
# 23.085895538330078
# 23.256704330444336
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4637  data: 1.9563  max mem: 6137
# 14.455778121948242
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4415  data: 1.9368  max mem: 6137
# Epoch: [6] Total time: 0:00:53 (2.4259 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0147 (0.0147)  evaluator_time: 0.0353 (0.0353)  time: 0.1168  data: 0.0629  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0145 (0.0146)  evaluator_time: 0.0195 (0.0372)  time: 0.1103  data: 0.0581  max mem: 6137
# Test: Total time: 0:00:04 (0.1156 s / it)
# Averaged stats: model_time: 0.0145 (0.0146)  evaluator_time: 0.0195 (0.0372)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.014
# 22.788320541381836
# Epoch: [7]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3788  data: 1.8308  max mem: 6137
# 22.403818130493164
# 15.621787071228027
# 15.554177284240723
# 16.593055725097656
# 16.018064498901367
# 17.27701187133789
# 13.642629623413086
# 14.663946151733398
# 13.894768714904785
# 14.697388648986816
# 14.841134071350098
# 17.455524444580078
# 14.833450317382812
# 18.58682632446289
# 14.73803997039795
# 16.699840545654297
# 12.819541931152344
# 16.15734100341797
# 15.595541000366211
# 10.681693077087402
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2678  data: 1.7761  max mem: 6137
# 16.523290634155273
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2741  data: 1.7760  max mem: 6137
# Epoch: [7] Total time: 0:00:50 (2.2786 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0149 (0.0149)  evaluator_time: 0.0225 (0.0225)  time: 0.1039  data: 0.0626  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0146 (0.0146)  evaluator_time: 0.0240 (0.0365)  time: 0.1140  data: 0.0581  max mem: 6137
# Test: Total time: 0:00:04 (0.1148 s / it)
# Averaged stats: model_time: 0.0146 (0.0146)  evaluator_time: 0.0240 (0.0365)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# 9.280038833618164
# Epoch: [8]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1782  data: 1.6623  max mem: 6137
# 12.314346313476562
# 8.452920913696289
# 9.58470344543457
# 12.034832000732422
# 14.116477012634277
# 9.10400104522705
# 11.260941505432129
# 9.409293174743652
# 9.796284675598145
# 11.539713859558105
# 11.265751838684082
# 10.818260192871094
# 7.840628623962402
# 8.182873725891113
# 8.911094665527344
# 15.185441970825195
# 10.834991455078125
# 9.260720252990723
# 9.193709373474121
# 10.933136940002441
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3331  data: 1.8224  max mem: 6137
# 10.693236351013184
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3328  data: 1.8231  max mem: 6137
# Epoch: [8] Total time: 0:00:51 (2.3317 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0243 (0.0243)  time: 0.1059  data: 0.0627  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0147 (0.0148)  evaluator_time: 0.0191 (0.0363)  time: 0.1087  data: 0.0583  max mem: 6137
# Test: Total time: 0:00:04 (0.1150 s / it)
# Averaged stats: model_time: 0.0147 (0.0148)  evaluator_time: 0.0191 (0.0363)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# 6.616412162780762
# Epoch: [9]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9605  data: 1.5199  max mem: 6137
# 12.879220962524414
# 7.7296142578125
# 6.402456283569336
# 8.103118896484375
# 6.92193603515625
# 9.401079177856445
# 8.641288757324219
# 7.665807723999023
# 7.698487281799316
# 7.639960765838623
# 5.821500778198242
# 6.291716575622559
# 6.912847518920898
# 8.518717765808105
# 6.670762062072754
# 6.2199578285217285
# 8.256516456604004
# 6.904479026794434
# 7.754096031188965
# 6.505282402038574
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3279  data: 1.8266  max mem: 6137
# 6.374368667602539
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3023  data: 1.8100  max mem: 6137
# Epoch: [9] Total time: 0:00:50 (2.2994 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0356 (0.0356)  evaluator_time: 0.0252 (0.0252)  time: 0.1273  data: 0.0627  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0153)  evaluator_time: 0.0261 (0.0401)  time: 0.1137  data: 0.0572  max mem: 6137
# Test: Total time: 0:00:04 (0.1194 s / it)
# Averaged stats: model_time: 0.0148 (0.0153)  evaluator_time: 0.0261 (0.0401)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# 5.4185991287231445
# Epoch: [10]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3290  data: 1.8469  max mem: 6137
# 7.973727703094482
# 6.079337120056152
# 6.077237129211426
# 7.248115539550781
# 6.151418685913086
# 6.6308183670043945
# 7.64643669128418
# 6.556701183319092
# 5.995113372802734
# 7.3134965896606445
# 6.218517303466797
# 6.430782318115234
# 7.320615768432617
# 7.847607612609863
# 5.476180553436279
# 7.192056655883789
# 6.483814716339111
# 7.31651496887207
# 6.340275764465332
# 6.335516929626465
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3532  data: 1.8576  max mem: 6137
# 6.283103942871094
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3503  data: 1.8565  max mem: 6137
# Epoch: [10] Total time: 0:00:51 (2.3544 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0248 (0.0248)  time: 0.1064  data: 0.0624  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0268 (0.0401)  time: 0.1137  data: 0.0578  max mem: 6137
# Test: Total time: 0:00:04 (0.1190 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0268 (0.0401)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# 5.742346286773682
# Epoch: [11]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9702  data: 1.5355  max mem: 6137
# 6.490159511566162
# 5.610861778259277
# 6.104398727416992
# 6.982451915740967
# 5.776332378387451
# 6.8595147132873535
# 8.0965576171875
# 7.417728424072266
# 6.742669105529785
# 7.189046859741211
# 6.583017826080322
# 6.913450717926025
# 5.945478916168213
# 6.374124526977539
# 6.452299118041992
# 5.633872985839844
# 7.215642929077148
# 7.417302131652832
# 6.602074146270752
# 6.643510341644287
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3908  data: 1.8764  max mem: 6137
# 7.059091567993164
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3772  data: 1.8660  max mem: 6137
# Epoch: [11] Total time: 0:00:52 (2.3704 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0343 (0.0343)  time: 0.1160  data: 0.0628  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0202 (0.0394)  time: 0.1126  data: 0.0572  max mem: 6137
# Test: Total time: 0:00:04 (0.1182 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0202 (0.0394)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
# 7.307773590087891
# Epoch: [12]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2943  data: 1.8011  max mem: 6137
# 7.678462028503418
# 7.4996113777160645
# 7.55286979675293
# 7.447240829467773
# 7.915432929992676
# 6.507243633270264
# 5.861545562744141
# 6.825077056884766
# 6.916195392608643
# 6.202877044677734
# 6.558088779449463
# 5.909168720245361
# 6.3328704833984375
# 5.782439231872559
# 6.6277360916137695
# 6.812840461730957
# 5.646169662475586
# 5.446784973144531
# 5.8357625007629395
# 5.910633087158203
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3322  data: 1.8281  max mem: 6137
# 6.993595123291016
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3436  data: 1.8388  max mem: 6137
# Epoch: [12] Total time: 0:00:51 (2.3427 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0244 (0.0244)  time: 0.1064  data: 0.0628  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0147 (0.0148)  evaluator_time: 0.0261 (0.0388)  time: 0.1137  data: 0.0568  max mem: 6137
# Test: Total time: 0:00:04 (0.1172 s / it)
# Averaged stats: model_time: 0.0147 (0.0148)  evaluator_time: 0.0261 (0.0388)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
# 5.11505126953125
# Epoch: [13]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2554  data: 1.7483  max mem: 6137
# 6.13012170791626
# 6.912998676300049
# 5.921329975128174
# 6.559558868408203
# 6.179327011108398
# 6.20344352722168
# 5.791234970092773
# 6.5488200187683105
# 6.8241143226623535
# 5.968803405761719
# 6.121088981628418
# 7.002292633056641
# 5.215449333190918
# 5.992867469787598
# 6.707089424133301
# 6.415378093719482
# 6.627339839935303
# 6.422348976135254
# 6.8311357498168945
# 7.665422439575195
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3404  data: 1.8567  max mem: 6137
# 7.861260414123535
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3323  data: 1.8413  max mem: 6137
# Epoch: [13] Total time: 0:00:51 (2.3466 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0153 (0.0153)  evaluator_time: 0.0306 (0.0306)  time: 0.1132  data: 0.0633  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0150)  evaluator_time: 0.0261 (0.0400)  time: 0.1121  data: 0.0573  max mem: 6137
# Test: Total time: 0:00:04 (0.1185 s / it)
# Averaged stats: model_time: 0.0149 (0.0150)  evaluator_time: 0.0261 (0.0400)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.784416198730469
# Epoch: [14]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4139  data: 1.8825  max mem: 6137
# 6.1664533615112305
# 6.35858154296875
# 7.300313472747803
# 6.309261322021484
# 5.585262775421143
# 6.122979164123535
# 5.530435085296631
# 6.944782257080078
# 5.938787460327148
# 5.557162284851074
# 5.4102702140808105
# 5.898324012756348
# 5.4937896728515625
# 5.318753242492676
# 5.469015121459961
# 5.699082374572754
# 5.946238994598389
# 7.6853251457214355
# 5.66526985168457
# 5.568840026855469
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2779  data: 1.8016  max mem: 6137
# 6.740592956542969
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2746  data: 1.8007  max mem: 6137
# Epoch: [14] Total time: 0:00:50 (2.2939 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0259 (0.0259)  time: 0.1075  data: 0.0625  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0149)  evaluator_time: 0.0242 (0.0408)  time: 0.1128  data: 0.0571  max mem: 6137
# Test: Total time: 0:00:04 (0.1191 s / it)
# Averaged stats: model_time: 0.0149 (0.0149)  evaluator_time: 0.0242 (0.0408)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 6.272673606872559
# Epoch: [15]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3730  data: 1.8011  max mem: 6137
# 5.275930404663086
# 6.335579872131348
# 6.4857282638549805
# 6.908734321594238
# 6.762198448181152
# 5.683437824249268
# 6.035259246826172
# 5.731360912322998
# 6.407454967498779
# 5.753264904022217
# 6.624594211578369
# 5.923147678375244
# 7.2501912117004395
# 5.421607971191406
# 5.558472633361816
# 7.357479095458984
# 6.645463466644287
# 5.561793327331543
# 6.609356880187988
# 7.056107044219971
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3793  data: 1.8749  max mem: 6137
# 5.743002891540527
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3801  data: 1.8758  max mem: 6137
# Epoch: [15] Total time: 0:00:52 (2.3800 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0246 (0.0246)  time: 0.1062  data: 0.0626  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0149)  evaluator_time: 0.0268 (0.0392)  time: 0.1151  data: 0.0575  max mem: 6137
# Test: Total time: 0:00:04 (0.1179 s / it)
# Averaged stats: model_time: 0.0149 (0.0149)  evaluator_time: 0.0268 (0.0392)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 6.508899688720703
# Epoch: [16]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1916  data: 1.6909  max mem: 6137
# 7.120665550231934
# 5.8995842933654785
# 6.480688571929932
# 6.135112762451172
# 6.571547508239746
# 6.046856880187988
# 5.919580459594727
# 6.0308966636657715
# 6.603233814239502
# 5.99580192565918
# 5.099224090576172
# 6.000272750854492
# 5.652670860290527
# 7.558474540710449
# 6.530779838562012
# 5.9981770515441895
# 6.089583396911621
# 6.055999279022217
# 7.045395851135254
# 5.8974504470825195
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3714  data: 1.8579  max mem: 6137
# 6.24507999420166
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3856  data: 1.8607  max mem: 6137
# Epoch: [16] Total time: 0:00:52 (2.3767 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0265 (0.0265)  time: 0.1077  data: 0.0624  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0272 (0.0415)  time: 0.1131  data: 0.0569  max mem: 6137
# Test: Total time: 0:00:04 (0.1199 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0272 (0.0415)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# 5.875737190246582
# Epoch: [17]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2784  data: 1.7750  max mem: 6137
# 6.286922931671143
# 5.367819786071777
# 6.032082557678223
# 6.114133358001709
# 5.052529811859131
# 7.07196044921875
# 5.545897006988525
# 7.430331230163574
# 5.705590724945068
# 5.9016571044921875
# 5.681118488311768
# 5.926309585571289
# 5.411959171295166
# 5.761857032775879
# 5.9788970947265625
# 5.51612663269043
# 5.342225551605225
# 5.653611183166504
# 5.459245681762695
# 6.0408477783203125
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3274  data: 1.8289  max mem: 6137
# 5.458038806915283
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2997  data: 1.8064  max mem: 6137
# Epoch: [17] Total time: 0:00:51 (2.3226 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0260 (0.0260)  time: 0.1089  data: 0.0638  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0149)  evaluator_time: 0.0265 (0.0396)  time: 0.1141  data: 0.0568  max mem: 6137
# Test: Total time: 0:00:04 (0.1181 s / it)
# Averaged stats: model_time: 0.0149 (0.0149)  evaluator_time: 0.0265 (0.0396)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.439967155456543
# Epoch: [18]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4346  data: 1.7946  max mem: 6137
# 5.937136173248291
# 5.875802516937256
# 5.700787544250488
# 6.181890487670898
# 5.942597389221191
# 6.003819942474365
# 6.52431058883667
# 5.55657958984375
# 6.154740810394287
# 5.994813442230225
# 6.1318769454956055
# 5.580589294433594
# 5.480862140655518
# 5.853518009185791
# 5.624817848205566
# 7.693368911743164
# 5.8544487953186035
# 6.6561174392700195
# 6.2683820724487305
# 6.216203689575195
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4415  data: 1.9321  max mem: 6137
# 6.256406784057617
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4113  data: 1.9054  max mem: 6137
# Epoch: [18] Total time: 0:00:53 (2.4417 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0253 (0.0253)  time: 0.1066  data: 0.0624  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0149)  evaluator_time: 0.0252 (0.0423)  time: 0.1135  data: 0.0572  max mem: 6137
# Test: Total time: 0:00:04 (0.1210 s / it)
# Averaged stats: model_time: 0.0148 (0.0149)  evaluator_time: 0.0252 (0.0423)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 5.520571708679199
# Epoch: [19]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5775  data: 2.0584  max mem: 6137
# 6.26165246963501
# 5.984610557556152
# 5.751727104187012
# 6.299340724945068
# 5.193247318267822
# 6.169497489929199
# 5.844292640686035
# 5.828197956085205
# 6.525626182556152
# 5.7704267501831055
# 6.35679817199707
# 6.676798343658447
# 6.5018134117126465
# 6.407918930053711
# 5.751611709594727
# 5.655576229095459
# 6.67919921875
# 5.616147994995117
# 6.630511283874512
# 6.452092170715332
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4646  data: 1.9508  max mem: 6137
# 6.64332389831543
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4375  data: 1.9313  max mem: 6137
# Epoch: [19] Total time: 0:00:54 (2.4628 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0242 (0.0242)  time: 0.1060  data: 0.0629  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0260 (0.0403)  time: 0.1110  data: 0.0568  max mem: 6137
# Test: Total time: 0:00:04 (0.1181 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0260 (0.0403)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 5.83059024810791
# Epoch: [20]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2289  data: 1.7030  max mem: 6137
# 5.06036901473999
# 6.080214500427246
# 5.932751655578613
# 6.106652736663818
# 5.483017921447754
# 6.20515251159668
# 5.128364562988281
# 5.825980186462402
# 5.294088363647461
# 5.336139678955078
# 5.730422019958496
# 5.863959312438965
# 6.609062194824219
# 5.8407487869262695
# 5.64359712600708
# 5.525792598724365
# 5.6045918464660645
# 5.030941009521484
# 5.572612762451172
# 5.184144020080566
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3384  data: 1.8539  max mem: 6137
# 6.6001482009887695
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3242  data: 1.8411  max mem: 6137
# Epoch: [20] Total time: 0:00:51 (2.3365 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0265 (0.0265)  time: 0.1095  data: 0.0638  max mem: 6137
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0149)  evaluator_time: 0.0263 (0.0390)  time: 0.1137  data: 0.0573  max mem: 6137
# Test: Total time: 0:00:04 (0.1176 s / it)
# Averaged stats: model_time: 0.0148 (0.0149)  evaluator_time: 0.0263 (0.0390)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 5.56082820892334
# Epoch: [21]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3234  data: 1.8244  max mem: 6137
# 5.668210983276367
# 5.9543232917785645
# 5.3555827140808105
# 5.574116230010986
# 6.772191524505615
# 6.5687255859375
# 7.357174873352051
# 6.074991226196289
# 6.492661952972412
# 7.479450225830078
# 5.768834114074707
# 5.874961853027344
# 6.222649097442627
# 6.037319183349609
# 5.607596397399902
# 6.428934097290039
# 6.608087539672852
# 5.021860599517822
# 7.480781078338623
# 6.7725677490234375
# Epoch: [21]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5261  data: 1.9968  max mem: 6196
# 6.476972579956055
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4988  data: 1.9680  max mem: 6196
# Epoch: [21] Total time: 0:00:55 (2.5007 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0256 (0.0256)  time: 0.1086  data: 0.0641  max mem: 6196
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0148)  evaluator_time: 0.0255 (0.0403)  time: 0.1116  data: 0.0570  max mem: 6196
# Test: Total time: 0:00:04 (0.1186 s / it)
# Averaged stats: model_time: 0.0148 (0.0148)  evaluator_time: 0.0255 (0.0403)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.480748176574707
# Epoch: [22]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2373  data: 1.8219  max mem: 6196
# 5.583956241607666
# 7.003249168395996
# 5.779717922210693
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.013
# 5.444658279418945
# Epoch: [43]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4566  data: 2.0022  max mem: 6595
# 6.040299892425537
# 5.570103168487549
# 5.877202033996582
# 5.3645429611206055
# 5.424647808074951
# 5.730932235717773
# 5.260044097900391
# 5.342651844024658
# 5.676257133483887
# 6.0538482666015625
# 5.549254894256592
# 5.3463029861450195
# 4.849945068359375
# 5.738547325134277
# 5.839817523956299
# 5.051408767700195
# 5.427999496459961
# 5.7630720138549805
# 5.577915668487549
# 6.187954902648926
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4234  data: 1.9128  max mem: 6595
# 5.699158191680908
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4095  data: 1.8978  max mem: 6595
# Epoch: [43] Total time: 0:00:53 (2.4242 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0268 (0.0268)  time: 0.1087  data: 0.0628  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0150)  evaluator_time: 0.0271 (0.0399)  time: 0.1159  data: 0.0582  max mem: 6595
# Test: Total time: 0:00:04 (0.1189 s / it)
# Averaged stats: model_time: 0.0149 (0.0150)  evaluator_time: 0.0271 (0.0399)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# 6.060711860656738
# Epoch: [44]  [ 0/22]  eta: 0:01:04  lr: 0.003000  time: 2.9247  data: 2.3383  max mem: 6595
# 5.197402477264404
# 5.702573776245117
# 5.558758735656738
# 4.764441967010498
# 5.585690498352051
# 5.941637992858887
# 5.247198581695557
# 5.272563934326172
# 5.859642028808594
# 5.850702285766602
# 5.101804733276367
# 6.611208438873291
# 6.578554153442383
# 6.348650932312012
# 5.697973251342773
# 5.740996360778809
# 5.393138885498047
# 5.399621963500977
# 5.713877201080322
# 6.192238807678223
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4021  data: 1.8836  max mem: 6595
# 5.500716209411621
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3938  data: 1.8784  max mem: 6595
# Epoch: [44] Total time: 0:00:53 (2.4176 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0257 (0.0257)  time: 0.1070  data: 0.0624  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0149)  evaluator_time: 0.0263 (0.0416)  time: 0.1140  data: 0.0577  max mem: 6595
# Test: Total time: 0:00:04 (0.1200 s / it)
# Averaged stats: model_time: 0.0149 (0.0149)  evaluator_time: 0.0263 (0.0416)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 5.433708190917969
# Epoch: [45]  [ 0/22]  eta: 0:00:59  lr: 0.003000  time: 2.7003  data: 2.2376  max mem: 6595
# 4.988450050354004
# 6.397778511047363
# 5.594411849975586
# 5.683328151702881
# 5.924501419067383
# 5.300058841705322
# 5.448172569274902
# 5.303253173828125
# 5.857809066772461
# 5.762524604797363
# 5.5370330810546875
# 5.484746932983398
# 5.63746452331543
# 5.188027381896973
# 5.159655570983887
# 5.3879594802856445
# 5.371221542358398
# 5.779551982879639
# 5.769364356994629
# 5.901049613952637
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2864  data: 1.7993  max mem: 6595
# 5.871077537536621
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2565  data: 1.7692  max mem: 6595
# Epoch: [45] Total time: 0:00:50 (2.2912 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0266 (0.0266)  time: 0.1080  data: 0.0625  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0150)  evaluator_time: 0.0269 (0.0412)  time: 0.1142  data: 0.0579  max mem: 6595
# Test: Total time: 0:00:04 (0.1198 s / it)
# Averaged stats: model_time: 0.0149 (0.0150)  evaluator_time: 0.0269 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 5.8035430908203125
# Epoch: [46]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0867  data: 1.6832  max mem: 6595
# 5.560388565063477
# 5.102108001708984
# 5.353541374206543
# 5.842896461486816
# 5.334440231323242
# 6.630522727966309
# 5.336870193481445
# 6.524355411529541
# 5.133302688598633
# 5.839993476867676
# 5.824288368225098
# 5.583464622497559
# 5.515039443969727
# 5.411605358123779
# 5.762296676635742
# 5.59962272644043
# 5.33442497253418
# 5.426658630371094
# 5.638483047485352
# 6.691484451293945
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3927  data: 1.8913  max mem: 6595
# 5.12111234664917
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3768  data: 1.8789  max mem: 6595
# Epoch: [46] Total time: 0:00:52 (2.3718 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0153 (0.0153)  evaluator_time: 0.0269 (0.0269)  time: 0.1086  data: 0.0626  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0150 (0.0150)  evaluator_time: 0.0265 (0.0403)  time: 0.1169  data: 0.0580  max mem: 6595
# Test: Total time: 0:00:04 (0.1190 s / it)
# Averaged stats: model_time: 0.0150 (0.0150)  evaluator_time: 0.0265 (0.0403)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 5.04252815246582
# Epoch: [47]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9494  data: 1.5446  max mem: 6595
# 5.538929462432861
# 5.631181240081787
# 5.040088653564453
# 5.504169940948486
# 5.658821105957031
# 6.013113975524902
# 6.349587440490723
# 6.032567024230957
# 6.190858840942383
# 5.45017147064209
# 5.125605583190918
# 5.363529682159424
# 6.183906555175781
# 5.286300182342529
# 6.348573684692383
# 5.5565385818481445
# 5.883049011230469
# 5.648099899291992
# 5.592258453369141
# 5.187833786010742
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3790  data: 1.8689  max mem: 6595
# 5.327209949493408
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3618  data: 1.8471  max mem: 6595
# Epoch: [47] Total time: 0:00:51 (2.3506 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0267 (0.0267)  time: 0.1089  data: 0.0632  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0150)  evaluator_time: 0.0271 (0.0442)  time: 0.1221  data: 0.0584  max mem: 6595
# Test: Total time: 0:00:04 (0.1236 s / it)
# Averaged stats: model_time: 0.0149 (0.0150)  evaluator_time: 0.0271 (0.0442)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 5.901727199554443
# Epoch: [48]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2080  data: 1.7095  max mem: 6595
# 5.339354515075684
# 5.91086483001709
# 5.137343883514404
# 5.378522872924805
# 4.837571620941162
# 5.129838466644287
# 5.128934860229492
# 5.414191246032715
# 5.323488235473633
# 5.622385025024414
# 6.348970413208008
# 5.524559020996094
# 5.522579669952393
# 5.404231071472168
# 5.60376501083374
# 5.26331090927124
# 6.456640720367432
# 6.242612838745117
# 6.549421310424805
# 5.562065124511719
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3852  data: 1.8722  max mem: 6595
# 5.299195289611816
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3608  data: 1.8445  max mem: 6595
# Epoch: [48] Total time: 0:00:52 (2.3679 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0152 (0.0152)  evaluator_time: 0.0256 (0.0256)  time: 0.1071  data: 0.0625  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0151)  evaluator_time: 0.0262 (0.0392)  time: 0.1147  data: 0.0571  max mem: 6595
# Test: Total time: 0:00:04 (0.1179 s / it)
# Averaged stats: model_time: 0.0149 (0.0151)  evaluator_time: 0.0262 (0.0392)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.012
# 5.577636241912842
# Epoch: [49]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.9049  data: 1.4441  max mem: 6595
# 5.557921409606934
# 5.73299503326416
# 6.128903388977051
# 5.628413200378418
# 5.57015323638916
# 6.193548202514648
# 5.440917015075684
# 5.874451637268066
# 5.589924335479736
# 6.207396030426025
# 5.620203971862793
# 5.239436626434326
# 5.509755611419678
# 5.431560039520264
# 5.3005757331848145
# 5.259238243103027
# 5.398900985717773
# 5.928501129150391
# 5.157661437988281
# 5.0243239402771
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4061  data: 1.9115  max mem: 6595
# 5.317298889160156
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4136  data: 1.9176  max mem: 6595
# Epoch: [49] Total time: 0:00:52 (2.3794 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0336 (0.0336)  evaluator_time: 0.0259 (0.0259)  time: 0.1259  data: 0.0625  max mem: 6595
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0149 (0.0154)  evaluator_time: 0.0265 (0.0404)  time: 0.1149  data: 0.0571  max mem: 6595
# Test: Total time: 0:00:04 (0.1197 s / it)
# Averaged stats: model_time: 0.0149 (0.0154)  evaluator_time: 0.0265 (0.0404)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# Training time 0:54:51

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_VGG.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.00043070693444091814
