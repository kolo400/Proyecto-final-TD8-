# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]



def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)


def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())

train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)

train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        img = read_image(path_base + '/Imagenes/' + item['image_filename'])

        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)

        if self.transform:
            img, target = self.transform(img, target)

        return img, target


train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))

print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import ssd512_convnext

model = ssd512_convnext(name = "convnext_small")
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Small_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/convnext_small-0c510722.pth" to /root/.cache/torch/hub/checkpoints/convnext_small-0c510722.pth
# 100%|██████████| 192M/192M [00:01<00:00, 183MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background


in_channels = [96, 192, 384, 768, 512, 256,256,256]
num_anchors = [4, 6, 6, 6, 4, 4, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:

        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)


        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()


        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-18 18:51:48--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-18 18:51:48 (60.3 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-18 18:51:48--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-18 18:51:48 (61.6 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-18 18:51:48--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-18 18:51:48 (72.9 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-18 18:51:48--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-18 18:51:48 (84.0 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-18 18:51:48--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.001s
#
# 2024-11-18 18:51:49 (27.5 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# Epoch: [0]  [ 0/22]  eta: 0:05:11  lr: 0.000146  time: 14.1745  data: 9.9227  max mem: 10510
# Epoch: [0]  [20/22]  eta: 0:00:18  lr: 0.003000  time: 8.9815  data: 8.3539  max mem: 10989
# Epoch: [0]  [21/22]  eta: 0:00:09  lr: 0.003000  time: 8.8870  data: 8.2809  max mem: 10989
# Epoch: [0] Total time: 0:03:22 (9.2121 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:12  model_time: 0.2220 (0.2220)  evaluator_time: 0.0278 (0.0278)  time: 0.3165  data: 0.0629  max mem: 10989
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0231 (0.0286)  evaluator_time: 0.0190 (0.0360)  time: 0.1159  data: 0.0565  max mem: 10989
# Test: Total time: 0:00:05 (0.1271 s / it)
# Averaged stats: model_time: 0.0231 (0.0286)  evaluator_time: 0.0190 (0.0360)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
# Epoch: [1]  [ 0/22]  eta: 0:01:10  lr: 0.003000  time: 3.1819  data: 2.5787  max mem: 10989
# Epoch: [1]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5842  data: 1.9670  max mem: 10989
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5728  data: 1.9597  max mem: 10989
# Epoch: [1] Total time: 0:00:57 (2.6060 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0240 (0.0240)  evaluator_time: 0.0278 (0.0278)  time: 0.1180  data: 0.0624  max mem: 10989
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0229)  evaluator_time: 0.0208 (0.0359)  time: 0.1162  data: 0.0570  max mem: 10989
# Test: Total time: 0:00:04 (0.1215 s / it)
# Averaged stats: model_time: 0.0227 (0.0229)  evaluator_time: 0.0208 (0.0359)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.059
# Epoch: [2]  [ 0/22]  eta: 0:01:00  lr: 0.003000  time: 2.7697  data: 2.0500  max mem: 10989
# Epoch: [2]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5053  data: 1.8766  max mem: 11096
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5150  data: 1.8852  max mem: 11096
# Epoch: [2] Total time: 0:00:55 (2.5145 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0234 (0.0234)  evaluator_time: 0.0272 (0.0272)  time: 0.1161  data: 0.0618  max mem: 11096
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0234)  evaluator_time: 0.0253 (0.0346)  time: 0.1172  data: 0.0573  max mem: 11096
# Test: Total time: 0:00:04 (0.1209 s / it)
# Averaged stats: model_time: 0.0227 (0.0234)  evaluator_time: 0.0253 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.066
# Epoch: [3]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3467  data: 1.7015  max mem: 11096
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4314  data: 1.8201  max mem: 11096
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4261  data: 1.8195  max mem: 11096
# Epoch: [3] Total time: 0:00:53 (2.4227 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0231 (0.0231)  evaluator_time: 0.0258 (0.0258)  time: 0.1152  data: 0.0627  max mem: 11096
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0236)  evaluator_time: 0.0242 (0.0339)  time: 0.1164  data: 0.0561  max mem: 11096
# Test: Total time: 0:00:04 (0.1197 s / it)
# Averaged stats: model_time: 0.0228 (0.0236)  evaluator_time: 0.0242 (0.0339)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# Epoch: [4]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5538  data: 1.8922  max mem: 11096
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3591  data: 1.7395  max mem: 11096
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3446  data: 1.7270  max mem: 11096
# Epoch: [4] Total time: 0:00:51 (2.3616 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0234 (0.0234)  evaluator_time: 0.0210 (0.0210)  time: 0.1113  data: 0.0633  max mem: 11096
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0226 (0.0235)  evaluator_time: 0.0233 (0.0325)  time: 0.1141  data: 0.0563  max mem: 11096
# Test: Total time: 0:00:04 (0.1186 s / it)
# Averaged stats: model_time: 0.0226 (0.0235)  evaluator_time: 0.0233 (0.0325)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
# Epoch: [5]  [ 0/22]  eta: 0:00:55  lr: 0.003000  time: 2.5081  data: 1.8206  max mem: 11096
# Epoch: [5]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5150  data: 1.8766  max mem: 11096
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4796  data: 1.8465  max mem: 11096
# Epoch: [5] Total time: 0:00:55 (2.5003 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0241 (0.0241)  evaluator_time: 0.0218 (0.0218)  time: 0.1124  data: 0.0628  max mem: 11096
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0234)  evaluator_time: 0.0236 (0.0323)  time: 0.1156  data: 0.0561  max mem: 11096
# Test: Total time: 0:00:04 (0.1181 s / it)
# Averaged stats: model_time: 0.0227 (0.0234)  evaluator_time: 0.0236 (0.0323)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.083
# Epoch: [6]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2521  data: 1.7526  max mem: 11096
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4581  data: 1.8279  max mem: 11096
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4614  data: 1.8251  max mem: 11096
# Epoch: [6] Total time: 0:00:54 (2.4600 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0233 (0.0233)  evaluator_time: 0.0197 (0.0197)  time: 0.1100  data: 0.0635  max mem: 11096
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0231)  evaluator_time: 0.0221 (0.0339)  time: 0.1214  data: 0.0574  max mem: 11096
# Test: Total time: 0:00:04 (0.1200 s / it)
# Averaged stats: model_time: 0.0229 (0.0231)  evaluator_time: 0.0221 (0.0339)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.080
# Epoch: [7]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1767  data: 1.6095  max mem: 11096
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.5067  data: 1.8697  max mem: 11123
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4642  data: 1.8350  max mem: 11123
# Epoch: [7] Total time: 0:00:54 (2.4743 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0511 (0.0511)  evaluator_time: 0.0192 (0.0192)  time: 0.1354  data: 0.0615  max mem: 11123
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0225 (0.0237)  evaluator_time: 0.0224 (0.0294)  time: 0.1131  data: 0.0572  max mem: 11123
# Test: Total time: 0:00:04 (0.1159 s / it)
# Averaged stats: model_time: 0.0225 (0.0237)  evaluator_time: 0.0224 (0.0294)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.082
# Epoch: [8]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4523  data: 1.7953  max mem: 11123
# Epoch: [8]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5148  data: 1.8822  max mem: 11127
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4957  data: 1.8628  max mem: 11127
# Epoch: [8] Total time: 0:00:54 (2.4938 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0280 (0.0280)  evaluator_time: 0.0208 (0.0208)  time: 0.1145  data: 0.0620  max mem: 11127
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0235)  evaluator_time: 0.0220 (0.0299)  time: 0.1133  data: 0.0574  max mem: 11127
# Test: Total time: 0:00:04 (0.1165 s / it)
# Averaged stats: model_time: 0.0228 (0.0235)  evaluator_time: 0.0220 (0.0299)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.086
# Epoch: [9]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1920  data: 1.5946  max mem: 11127
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4068  data: 1.8055  max mem: 11127
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3987  data: 1.7927  max mem: 11127
# Epoch: [9] Total time: 0:00:52 (2.3896 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0236 (0.0236)  evaluator_time: 0.0181 (0.0181)  time: 0.1088  data: 0.0634  max mem: 11127
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0231)  evaluator_time: 0.0211 (0.0295)  time: 0.1135  data: 0.0572  max mem: 11127
# Test: Total time: 0:00:04 (0.1156 s / it)
# Averaged stats: model_time: 0.0228 (0.0231)  evaluator_time: 0.0211 (0.0295)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.100
# Epoch: [10]  [ 0/22]  eta: 0:01:02  lr: 0.003000  time: 2.8611  data: 2.1522  max mem: 11127
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4530  data: 1.8417  max mem: 11127
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4359  data: 1.8311  max mem: 11127
# Epoch: [10] Total time: 0:00:54 (2.4614 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0235 (0.0235)  evaluator_time: 0.0190 (0.0190)  time: 0.1087  data: 0.0625  max mem: 11127
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0237)  evaluator_time: 0.0218 (0.0308)  time: 0.1154  data: 0.0574  max mem: 11127
# Test: Total time: 0:00:04 (0.1177 s / it)
# Averaged stats: model_time: 0.0229 (0.0237)  evaluator_time: 0.0218 (0.0308)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.094
# Epoch: [11]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2273  data: 1.6498  max mem: 11127
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4745  data: 1.8298  max mem: 11470
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4751  data: 1.8242  max mem: 11470
# Epoch: [11] Total time: 0:00:54 (2.4648 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0238 (0.0238)  evaluator_time: 0.0198 (0.0198)  time: 0.1094  data: 0.0621  max mem: 11470
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0245)  evaluator_time: 0.0220 (0.0319)  time: 0.1144  data: 0.0563  max mem: 11470
# Test: Total time: 0:00:04 (0.1195 s / it)
# Averaged stats: model_time: 0.0227 (0.0245)  evaluator_time: 0.0220 (0.0319)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.100
# Epoch: [12]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.4033  data: 1.7876  max mem: 11470
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4263  data: 1.7997  max mem: 11470
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4161  data: 1.7962  max mem: 11470
# Epoch: [12] Total time: 0:00:53 (2.4245 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0234 (0.0234)  evaluator_time: 0.0191 (0.0191)  time: 0.1082  data: 0.0619  max mem: 11470
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0230)  evaluator_time: 0.0208 (0.0327)  time: 0.1185  data: 0.0562  max mem: 11470
# Test: Total time: 0:00:04 (0.1188 s / it)
# Averaged stats: model_time: 0.0227 (0.0230)  evaluator_time: 0.0208 (0.0327)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.107
# Epoch: [13]  [ 0/22]  eta: 0:00:59  lr: 0.003000  time: 2.7158  data: 2.1473  max mem: 11470
# Epoch: [13]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.4993  data: 1.8610  max mem: 11470
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4858  data: 1.8486  max mem: 11470
# Epoch: [13] Total time: 0:00:54 (2.4986 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0244 (0.0244)  evaluator_time: 0.0177 (0.0177)  time: 0.1092  data: 0.0633  max mem: 11470
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0232)  evaluator_time: 0.0223 (0.0291)  time: 0.1117  data: 0.0563  max mem: 11470
# Test: Total time: 0:00:04 (0.1152 s / it)
# Averaged stats: model_time: 0.0228 (0.0232)  evaluator_time: 0.0223 (0.0291)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.133
# Epoch: [14]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3732  data: 1.7196  max mem: 11470
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4397  data: 1.8307  max mem: 11470
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4382  data: 1.8328  max mem: 11470
# Epoch: [14] Total time: 0:00:53 (2.4352 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0230 (0.0230)  evaluator_time: 0.0180 (0.0180)  time: 0.1220  data: 0.0773  max mem: 11470
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0226 (0.0232)  evaluator_time: 0.0211 (0.0291)  time: 0.1118  data: 0.0565  max mem: 11470
# Test: Total time: 0:00:04 (0.1152 s / it)
# Averaged stats: model_time: 0.0226 (0.0232)  evaluator_time: 0.0211 (0.0291)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.137
# Epoch: [15]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4245  data: 1.8267  max mem: 11470
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4107  data: 1.7900  max mem: 11479
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4104  data: 1.7877  max mem: 11479
# Epoch: [15] Total time: 0:00:52 (2.4021 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0236 (0.0236)  evaluator_time: 0.0191 (0.0191)  time: 0.1080  data: 0.0616  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0231)  evaluator_time: 0.0208 (0.0296)  time: 0.1150  data: 0.0576  max mem: 11479
# Test: Total time: 0:00:04 (0.1158 s / it)
# Averaged stats: model_time: 0.0227 (0.0231)  evaluator_time: 0.0208 (0.0296)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.139
# Epoch: [16]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1379  data: 1.5318  max mem: 11479
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3682  data: 1.7677  max mem: 11479
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3801  data: 1.7721  max mem: 11479
# Epoch: [16] Total time: 0:00:52 (2.3686 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0233 (0.0233)  evaluator_time: 0.0173 (0.0173)  time: 0.1070  data: 0.0627  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0232)  evaluator_time: 0.0201 (0.0290)  time: 0.1158  data: 0.0586  max mem: 11479
# Test: Total time: 0:00:04 (0.1162 s / it)
# Averaged stats: model_time: 0.0229 (0.0232)  evaluator_time: 0.0201 (0.0290)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.151
# Epoch: [17]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3570  data: 1.7648  max mem: 11479
# Epoch: [17]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5537  data: 1.9154  max mem: 11479
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5485  data: 1.9068  max mem: 11479
# Epoch: [17] Total time: 0:00:56 (2.5470 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:06  model_time: 0.0660 (0.0660)  evaluator_time: 0.0190 (0.0190)  time: 0.1501  data: 0.0613  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0244)  evaluator_time: 0.0212 (0.0291)  time: 0.1119  data: 0.0561  max mem: 11479
# Test: Total time: 0:00:04 (0.1165 s / it)
# Averaged stats: model_time: 0.0227 (0.0244)  evaluator_time: 0.0212 (0.0291)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.149
# Epoch: [18]  [ 0/22]  eta: 0:01:02  lr: 0.003000  time: 2.8224  data: 2.1608  max mem: 11479
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4536  data: 1.8425  max mem: 11479
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4378  data: 1.8316  max mem: 11479
# Epoch: [18] Total time: 0:00:54 (2.4579 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0249 (0.0249)  evaluator_time: 0.0191 (0.0191)  time: 0.1104  data: 0.0627  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0228)  evaluator_time: 0.0222 (0.0304)  time: 0.1134  data: 0.0564  max mem: 11479
# Test: Total time: 0:00:04 (0.1163 s / it)
# Averaged stats: model_time: 0.0227 (0.0228)  evaluator_time: 0.0222 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.180
# Epoch: [19]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1372  data: 1.5700  max mem: 11479
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4902  data: 1.8741  max mem: 11479
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4788  data: 1.8668  max mem: 11479
# Epoch: [19] Total time: 0:00:54 (2.4744 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0239 (0.0239)  evaluator_time: 0.0203 (0.0203)  time: 0.1108  data: 0.0630  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0235)  evaluator_time: 0.0207 (0.0303)  time: 0.1136  data: 0.0562  max mem: 11479
# Test: Total time: 0:00:04 (0.1167 s / it)
# Averaged stats: model_time: 0.0228 (0.0235)  evaluator_time: 0.0207 (0.0303)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
# Epoch: [20]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1494  data: 1.5293  max mem: 11479
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4960  data: 1.8595  max mem: 11479
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4674  data: 1.8364  max mem: 11479
# Epoch: [20] Total time: 0:00:54 (2.4710 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0234 (0.0234)  evaluator_time: 0.0197 (0.0197)  time: 0.1082  data: 0.0614  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0231 (0.0232)  evaluator_time: 0.0205 (0.0301)  time: 0.1139  data: 0.0564  max mem: 11479
# Test: Total time: 0:00:04 (0.1159 s / it)
# Averaged stats: model_time: 0.0231 (0.0232)  evaluator_time: 0.0205 (0.0301)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.168
# Epoch: [21]  [ 0/22]  eta: 0:00:58  lr: 0.003000  time: 2.6567  data: 2.1099  max mem: 11479
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4194  data: 1.8267  max mem: 11479
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4140  data: 1.8226  max mem: 11479
# Epoch: [21] Total time: 0:00:53 (2.4325 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0242 (0.0242)  evaluator_time: 0.0204 (0.0204)  time: 0.1104  data: 0.0620  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0236)  evaluator_time: 0.0211 (0.0301)  time: 0.1134  data: 0.0563  max mem: 11479
# Test: Total time: 0:00:04 (0.1161 s / it)
# Averaged stats: model_time: 0.0229 (0.0236)  evaluator_time: 0.0211 (0.0301)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
# Epoch: [22]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5707  data: 1.9042  max mem: 11479
# Epoch: [22]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4778  data: 1.8613  max mem: 11479
# Epoch: [22]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4574  data: 1.8493  max mem: 11479
# Epoch: [22] Total time: 0:00:54 (2.4779 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0526 (0.0526)  evaluator_time: 0.0208 (0.0208)  time: 0.1394  data: 0.0623  max mem: 11479
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0238)  evaluator_time: 0.0208 (0.0306)  time: 0.1137  data: 0.0563  max mem: 11479
# Test: Total time: 0:00:04 (0.1169 s / it)
# Averaged stats: model_time: 0.0227 (0.0238)  evaluator_time: 0.0208 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.168
# Epoch: [23]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3693  data: 1.7835  max mem: 11479
# Epoch: [23]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4579  data: 1.8306  max mem: 11492
# Epoch: [23]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4649  data: 1.8275  max mem: 11492
# Epoch: [23] Total time: 0:00:54 (2.4560 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0238 (0.0238)  evaluator_time: 0.0209 (0.0209)  time: 0.1106  data: 0.0622  max mem: 11492
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0234)  evaluator_time: 0.0199 (0.0304)  time: 0.1134  data: 0.0562  max mem: 11492
# Test: Total time: 0:00:04 (0.1162 s / it)
# Averaged stats: model_time: 0.0227 (0.0234)  evaluator_time: 0.0199 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.179
# Epoch: [24]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2104  data: 1.6584  max mem: 11492
# Epoch: [24]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3595  data: 1.7504  max mem: 11492
# Epoch: [24]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3492  data: 1.7418  max mem: 11492
# Epoch: [24] Total time: 0:00:51 (2.3472 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0229 (0.0229)  evaluator_time: 0.0214 (0.0214)  time: 0.1090  data: 0.0611  max mem: 11492
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0231)  evaluator_time: 0.0202 (0.0297)  time: 0.1129  data: 0.0564  max mem: 11492
# Test: Total time: 0:00:04 (0.1152 s / it)
# Averaged stats: model_time: 0.0227 (0.0231)  evaluator_time: 0.0202 (0.0297)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.183
# Epoch: [25]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5841  data: 2.0253  max mem: 11492
# Epoch: [25]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4084  data: 1.7928  max mem: 11492
# Epoch: [25]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3797  data: 1.7692  max mem: 11492
# Epoch: [25] Total time: 0:00:52 (2.4090 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0232 (0.0232)  evaluator_time: 0.0216 (0.0216)  time: 0.1099  data: 0.0615  max mem: 11492
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0231 (0.0240)  evaluator_time: 0.0196 (0.0331)  time: 0.1148  data: 0.0572  max mem: 11492
# Test: Total time: 0:00:04 (0.1197 s / it)
# Averaged stats: model_time: 0.0231 (0.0240)  evaluator_time: 0.0196 (0.0331)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.178
# Epoch: [26]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4183  data: 1.7209  max mem: 11492
# Epoch: [26]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4044  data: 1.7950  max mem: 11492
# Epoch: [26]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3754  data: 1.7733  max mem: 11492
# Epoch: [26] Total time: 0:00:52 (2.3986 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0242 (0.0242)  evaluator_time: 0.0210 (0.0210)  time: 0.1114  data: 0.0626  max mem: 11492
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0233)  evaluator_time: 0.0206 (0.0297)  time: 0.1144  data: 0.0576  max mem: 11492
# Test: Total time: 0:00:04 (0.1160 s / it)
# Averaged stats: model_time: 0.0228 (0.0233)  evaluator_time: 0.0206 (0.0297)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
# ...
# Epoch: [41]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4678  data: 1.8598  max mem: 11797
# Epoch: [41]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4474  data: 1.8398  max mem: 11797
# Epoch: [41] Total time: 0:00:54 (2.4548 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0232 (0.0232)  evaluator_time: 0.0228 (0.0228)  time: 0.1110  data: 0.0613  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0233)  evaluator_time: 0.0196 (0.0280)  time: 0.1121  data: 0.0572  max mem: 11797
# Test: Total time: 0:00:04 (0.1142 s / it)
# Averaged stats: model_time: 0.0229 (0.0233)  evaluator_time: 0.0196 (0.0280)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.208
# Epoch: [42]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2407  data: 1.6569  max mem: 11797
# Epoch: [42]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4549  data: 1.8380  max mem: 11797
# Epoch: [42]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4368  data: 1.8138  max mem: 11797
# Epoch: [42] Total time: 0:00:53 (2.4430 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0232 (0.0232)  evaluator_time: 0.0231 (0.0231)  time: 0.1111  data: 0.0612  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0226 (0.0232)  evaluator_time: 0.0185 (0.0279)  time: 0.1099  data: 0.0561  max mem: 11797
# Test: Total time: 0:00:04 (0.1138 s / it)
# Averaged stats: model_time: 0.0226 (0.0232)  evaluator_time: 0.0185 (0.0279)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.219
# Epoch: [43]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4139  data: 1.8256  max mem: 11797
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4860  data: 1.8594  max mem: 11797
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4651  data: 1.8374  max mem: 11797
# Epoch: [43] Total time: 0:00:54 (2.4662 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0239 (0.0239)  evaluator_time: 0.0235 (0.0235)  time: 0.1132  data: 0.0620  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0239)  evaluator_time: 0.0184 (0.0324)  time: 0.1177  data: 0.0561  max mem: 11797
# Test: Total time: 0:00:04 (0.1194 s / it)
# Averaged stats: model_time: 0.0228 (0.0239)  evaluator_time: 0.0184 (0.0324)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.219
# Epoch: [44]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1745  data: 1.5140  max mem: 11797
# Epoch: [44]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5319  data: 1.8952  max mem: 11797
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5283  data: 1.8924  max mem: 11797
# Epoch: [44] Total time: 0:00:55 (2.5158 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0230 (0.0230)  evaluator_time: 0.0234 (0.0234)  time: 0.1115  data: 0.0616  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0229 (0.0233)  evaluator_time: 0.0180 (0.0279)  time: 0.1100  data: 0.0559  max mem: 11797
# Test: Total time: 0:00:04 (0.1141 s / it)
# Averaged stats: model_time: 0.0229 (0.0233)  evaluator_time: 0.0180 (0.0279)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.215
# Epoch: [45]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2081  data: 1.5635  max mem: 11797
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4092  data: 1.8012  max mem: 11797
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4151  data: 1.8014  max mem: 11797
# Epoch: [45] Total time: 0:00:52 (2.3976 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0234 (0.0234)  evaluator_time: 0.0242 (0.0242)  time: 0.1152  data: 0.0639  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0228 (0.0235)  evaluator_time: 0.0184 (0.0280)  time: 0.1108  data: 0.0563  max mem: 11797
# Test: Total time: 0:00:04 (0.1139 s / it)
# Averaged stats: model_time: 0.0228 (0.0235)  evaluator_time: 0.0184 (0.0280)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
# Epoch: [46]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3309  data: 1.7997  max mem: 11797
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4743  data: 1.8551  max mem: 11797
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4655  data: 1.8413  max mem: 11797
# Epoch: [46] Total time: 0:00:54 (2.4616 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0232 (0.0232)  evaluator_time: 0.0244 (0.0244)  time: 0.1134  data: 0.0623  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0230 (0.0237)  evaluator_time: 0.0182 (0.0281)  time: 0.1117  data: 0.0564  max mem: 11797
# Test: Total time: 0:00:04 (0.1143 s / it)
# Averaged stats: model_time: 0.0230 (0.0237)  evaluator_time: 0.0182 (0.0281)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.211
# Epoch: [47]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4509  data: 1.9328  max mem: 11797
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4767  data: 1.8539  max mem: 11797
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4583  data: 1.8267  max mem: 11797
# Epoch: [47] Total time: 0:00:54 (2.4669 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0285 (0.0285)  evaluator_time: 0.0242 (0.0242)  time: 0.1184  data: 0.0620  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0226 (0.0232)  evaluator_time: 0.0180 (0.0279)  time: 0.1099  data: 0.0560  max mem: 11797
# Test: Total time: 0:00:04 (0.1132 s / it)
# Averaged stats: model_time: 0.0226 (0.0232)  evaluator_time: 0.0180 (0.0279)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
# Epoch: [48]  [ 0/22]  eta: 0:01:05  lr: 0.003000  time: 2.9560  data: 2.1935  max mem: 11797
# Epoch: [48]  [20/22]  eta: 0:00:05  lr: 0.003000  time: 2.5057  data: 1.8932  max mem: 11797
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5263  data: 1.9041  max mem: 11797
# Epoch: [48] Total time: 0:00:55 (2.5404 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0231 (0.0231)  evaluator_time: 0.0249 (0.0249)  time: 0.1133  data: 0.0617  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0226 (0.0234)  evaluator_time: 0.0215 (0.0282)  time: 0.1113  data: 0.0565  max mem: 11797
# Test: Total time: 0:00:04 (0.1140 s / it)
# Averaged stats: model_time: 0.0226 (0.0234)  evaluator_time: 0.0215 (0.0282)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.216
# Epoch: [49]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1790  data: 1.6409  max mem: 11797
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.5024  data: 1.8903  max mem: 11797
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.5020  data: 1.8776  max mem: 11797
# Epoch: [49] Total time: 0:00:54 (2.4967 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0231 (0.0231)  evaluator_time: 0.0244 (0.0244)  time: 0.1130  data: 0.0618  max mem: 11797
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0227 (0.0236)  evaluator_time: 0.0185 (0.0276)  time: 0.1087  data: 0.0560  max mem: 11797
# Test: Total time: 0:00:04 (0.1132 s / it)
# Averaged stats: model_time: 0.0227 (0.0236)  evaluator_time: 0.0185 (0.0276)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.196
# Training time 0:53:38

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_ConvNext.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.04840599330174832
