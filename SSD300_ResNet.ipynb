# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]




def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)




def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())

train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        img = read_image(path_base + '/Imagenes/' + item['image_filename'])


        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])


        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])




        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)
        if self.transform:
            img, target = self.transform(img, target)

        return img, target



train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))


print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import ssd300_resnet50


model = ssd300_resnet50(pretrained=False)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 184MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1


in_channels = [2048, 512, 512, 256, 256]
num_anchors = [4, 6, 6, 6, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-17 15:16:51--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-17 15:16:51 (76.2 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-17 15:16:51--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-17 15:16:51 (107 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-17 15:16:51--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-17 15:16:51 (110 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-17 15:16:51--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-17 15:16:51 (89.0 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-17 15:16:51--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0s
#
# 2024-11-17 15:16:51 (144 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# Epoch: [0]  [ 0/22]  eta: 0:07:50  lr: 0.000146  time: 21.4035  data: 18.4663  max mem: 3827
# Epoch: [0]  [20/22]  eta: 0:00:30  lr: 0.003000  time: 15.1798  data: 14.8552  max mem: 4933
# Epoch: [0]  [21/22]  eta: 0:00:15  lr: 0.003000  time: 15.1319  data: 14.7999  max mem: 4933
# Epoch: [0] Total time: 0:05:40 (15.4803 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:12  model_time: 0.2194 (0.2194)  evaluator_time: 0.0257 (0.0257)  time: 0.3115  data: 0.0626  max mem: 4933
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0146 (0.0201)  evaluator_time: 0.0130 (0.0354)  time: 0.1083  data: 0.0588  max mem: 4933
# Test: Total time: 0:00:04 (0.1195 s / it)
# Averaged stats: model_time: 0.0146 (0.0201)  evaluator_time: 0.0130 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [1]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0029  data: 1.7726  max mem: 4933
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.4425  data: 2.1384  max mem: 4933
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.4539  data: 2.1535  max mem: 4933
# Epoch: [1] Total time: 0:00:53 (2.4356 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0149 (0.0149)  evaluator_time: 0.0248 (0.0248)  time: 0.1048  data: 0.0614  max mem: 4933
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0146)  evaluator_time: 0.0198 (0.0388)  time: 0.1064  data: 0.0563  max mem: 4933
# Test: Total time: 0:00:04 (0.1164 s / it)
# Averaged stats: model_time: 0.0144 (0.0146)  evaluator_time: 0.0198 (0.0388)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.042
# Epoch: [2]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.8094  data: 1.5962  max mem: 4933
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0852  data: 1.7715  max mem: 5076
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0546  data: 1.7477  max mem: 5076
# Epoch: [2] Total time: 0:00:45 (2.0747 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0153 (0.0153)  evaluator_time: 0.0273 (0.0273)  time: 0.1093  data: 0.0630  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0148 (0.0151)  evaluator_time: 0.0250 (0.0412)  time: 0.1175  data: 0.0574  max mem: 5076
# Test: Total time: 0:00:04 (0.1199 s / it)
# Averaged stats: model_time: 0.0148 (0.0151)  evaluator_time: 0.0250 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.116
# Epoch: [3]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7558  data: 1.4941  max mem: 5076
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1475  data: 1.8241  max mem: 5076
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1451  data: 1.8261  max mem: 5076
# Epoch: [3] Total time: 0:00:46 (2.1233 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0257 (0.0257)  time: 0.1073  data: 0.0629  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0144)  evaluator_time: 0.0195 (0.0394)  time: 0.1128  data: 0.0571  max mem: 5076
# Test: Total time: 0:00:04 (0.1168 s / it)
# Averaged stats: model_time: 0.0141 (0.0144)  evaluator_time: 0.0195 (0.0394)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.142
# Epoch: [4]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8914  data: 1.6212  max mem: 5076
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1097  data: 1.7767  max mem: 5076
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1134  data: 1.7792  max mem: 5076
# Epoch: [4] Total time: 0:00:46 (2.1078 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0146 (0.0146)  evaluator_time: 0.0242 (0.0242)  time: 0.1049  data: 0.0622  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0142)  evaluator_time: 0.0222 (0.0359)  time: 0.1066  data: 0.0563  max mem: 5076
# Test: Total time: 0:00:04 (0.1126 s / it)
# Averaged stats: model_time: 0.0140 (0.0142)  evaluator_time: 0.0222 (0.0359)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.130
# Epoch: [5]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1662  data: 1.8658  max mem: 5076
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0985  data: 1.7968  max mem: 5076
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0598  data: 1.7675  max mem: 5076
# Epoch: [5] Total time: 0:00:46 (2.0994 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0147 (0.0147)  evaluator_time: 0.0287 (0.0287)  time: 0.1098  data: 0.0628  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0143)  evaluator_time: 0.0247 (0.0412)  time: 0.1173  data: 0.0567  max mem: 5076
# Test: Total time: 0:00:04 (0.1182 s / it)
# Averaged stats: model_time: 0.0143 (0.0143)  evaluator_time: 0.0247 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.210
# Epoch: [6]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7710  data: 1.4723  max mem: 5076
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0822  data: 1.7643  max mem: 5076
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0659  data: 1.7478  max mem: 5076
# Epoch: [6] Total time: 0:00:45 (2.0593 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0290 (0.0290)  time: 0.1119  data: 0.0640  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0145)  evaluator_time: 0.0241 (0.0412)  time: 0.1185  data: 0.0574  max mem: 5076
# Test: Total time: 0:00:04 (0.1190 s / it)
# Averaged stats: model_time: 0.0142 (0.0145)  evaluator_time: 0.0241 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.226
# Epoch: [7]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8398  data: 1.5569  max mem: 5076
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1678  data: 1.8557  max mem: 5076
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1823  data: 1.8626  max mem: 5076
# Epoch: [7] Total time: 0:00:47 (2.1649 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0145 (0.0145)  evaluator_time: 0.0284 (0.0284)  time: 0.1085  data: 0.0619  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0143)  evaluator_time: 0.0241 (0.0397)  time: 0.1150  data: 0.0566  max mem: 5076
# Test: Total time: 0:00:04 (0.1170 s / it)
# Averaged stats: model_time: 0.0142 (0.0143)  evaluator_time: 0.0241 (0.0397)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.247
# Epoch: [8]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4200  data: 2.0724  max mem: 5076
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0247  data: 1.7249  max mem: 5076
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0317  data: 1.7329  max mem: 5076
# Epoch: [8] Total time: 0:00:45 (2.0594 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0144 (0.0144)  evaluator_time: 0.0275 (0.0275)  time: 0.1076  data: 0.0619  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0222 (0.0427)  time: 0.1220  data: 0.0568  max mem: 5076
# Test: Total time: 0:00:04 (0.1196 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0222 (0.0427)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.252
# Epoch: [9]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8916  data: 1.5488  max mem: 5076
# Epoch: [9]  [20/22]  eta: 0:00:03  lr: 0.003000  time: 1.9963  data: 1.7054  max mem: 5076
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0199  data: 1.7235  max mem: 5076
# Epoch: [9] Total time: 0:00:44 (2.0074 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0142 (0.0142)  evaluator_time: 0.0236 (0.0236)  time: 0.1047  data: 0.0632  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0145)  evaluator_time: 0.0240 (0.0404)  time: 0.1183  data: 0.0580  max mem: 5076
# Test: Total time: 0:00:04 (0.1185 s / it)
# Averaged stats: model_time: 0.0143 (0.0145)  evaluator_time: 0.0240 (0.0404)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
# Epoch: [10]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2082  data: 1.7109  max mem: 5076
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0566  data: 1.7585  max mem: 5076
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0960  data: 1.7921  max mem: 5076
# Epoch: [10] Total time: 0:00:45 (2.0894 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0146 (0.0146)  evaluator_time: 0.0235 (0.0235)  time: 0.1048  data: 0.0629  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0257 (0.0403)  time: 0.1180  data: 0.0576  max mem: 5076
# Test: Total time: 0:00:04 (0.1179 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0257 (0.0403)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
# Epoch: [11]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6587  data: 1.4041  max mem: 5076
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0297  data: 1.7117  max mem: 5076
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0146  data: 1.7055  max mem: 5076
# Epoch: [11] Total time: 0:00:44 (2.0168 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0143 (0.0143)  evaluator_time: 0.0242 (0.0242)  time: 0.1043  data: 0.0621  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0146)  evaluator_time: 0.0235 (0.0384)  time: 0.1159  data: 0.0580  max mem: 5076
# Test: Total time: 0:00:04 (0.1163 s / it)
# Averaged stats: model_time: 0.0144 (0.0146)  evaluator_time: 0.0235 (0.0384)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.304
# Epoch: [12]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9374  data: 1.6364  max mem: 5076
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1587  data: 1.8218  max mem: 5076
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1352  data: 1.8065  max mem: 5076
# Epoch: [12] Total time: 0:00:46 (2.1320 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0150 (0.0150)  evaluator_time: 0.0219 (0.0219)  time: 0.1035  data: 0.0628  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0145 (0.0145)  evaluator_time: 0.0270 (0.0385)  time: 0.1175  data: 0.0574  max mem: 5076
# Test: Total time: 0:00:04 (0.1165 s / it)
# Averaged stats: model_time: 0.0145 (0.0145)  evaluator_time: 0.0270 (0.0385)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.330
# Epoch: [13]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9730  data: 1.5966  max mem: 5076
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1664  data: 1.8363  max mem: 5076
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1770  data: 1.8460  max mem: 5076
# Epoch: [13] Total time: 0:00:47 (2.1655 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0146 (0.0146)  evaluator_time: 0.0242 (0.0242)  time: 0.1048  data: 0.0622  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0145)  evaluator_time: 0.0228 (0.0387)  time: 0.1142  data: 0.0562  max mem: 5076
# Test: Total time: 0:00:04 (0.1160 s / it)
# Averaged stats: model_time: 0.0142 (0.0145)  evaluator_time: 0.0228 (0.0387)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.301
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.350
# Epoch: [14]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8901  data: 1.5541  max mem: 5076
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0836  data: 1.7764  max mem: 5076
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0817  data: 1.7810  max mem: 5076
# Epoch: [14] Total time: 0:00:45 (2.0794 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0148 (0.0148)  evaluator_time: 0.0269 (0.0269)  time: 0.1071  data: 0.0617  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0233 (0.0368)  time: 0.1104  data: 0.0565  max mem: 5076
# Test: Total time: 0:00:04 (0.1142 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0233 (0.0368)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.290
# Epoch: [15]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8630  data: 1.5974  max mem: 5076
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0745  data: 1.7739  max mem: 5076
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0591  data: 1.7590  max mem: 5076
# Epoch: [15] Total time: 0:00:45 (2.0580 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0142 (0.0142)  evaluator_time: 0.0217 (0.0217)  time: 0.1028  data: 0.0633  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0144)  evaluator_time: 0.0288 (0.0380)  time: 0.1166  data: 0.0592  max mem: 5076
# Test: Total time: 0:00:04 (0.1169 s / it)
# Averaged stats: model_time: 0.0144 (0.0144)  evaluator_time: 0.0288 (0.0380)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.351
# Epoch: [16]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.6901  data: 1.4550  max mem: 5076
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0423  data: 1.7568  max mem: 5076
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0637  data: 1.7736  max mem: 5076
# Epoch: [16] Total time: 0:00:44 (2.0359 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0143 (0.0143)  evaluator_time: 0.0224 (0.0224)  time: 0.1044  data: 0.0639  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0145)  evaluator_time: 0.0238 (0.0399)  time: 0.1181  data: 0.0568  max mem: 5076
# Test: Total time: 0:00:04 (0.1180 s / it)
# Averaged stats: model_time: 0.0143 (0.0145)  evaluator_time: 0.0238 (0.0399)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.398
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.398
# Epoch: [17]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9692  data: 1.6310  max mem: 5076
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1029  data: 1.8064  max mem: 5076
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0961  data: 1.8015  max mem: 5076
# Epoch: [17] Total time: 0:00:45 (2.0889 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0147 (0.0147)  evaluator_time: 0.0241 (0.0241)  time: 0.1046  data: 0.0621  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0279 (0.0396)  time: 0.1164  data: 0.0566  max mem: 5076
# Test: Total time: 0:00:04 (0.1166 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0279 (0.0396)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.301
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.367
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.367
# Epoch: [18]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3791  data: 2.0480  max mem: 5076
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0500  data: 1.7501  max mem: 5076
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0417  data: 1.7432  max mem: 5076
# Epoch: [18] Total time: 0:00:45 (2.0589 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0147 (0.0147)  evaluator_time: 0.0212 (0.0212)  time: 0.1019  data: 0.0623  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0145)  evaluator_time: 0.0276 (0.0377)  time: 0.1146  data: 0.0577  max mem: 5076
# Test: Total time: 0:00:04 (0.1155 s / it)
# Averaged stats: model_time: 0.0144 (0.0145)  evaluator_time: 0.0276 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.350
# Epoch: [19]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1105  data: 1.8007  max mem: 5076
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0631  data: 1.7602  max mem: 5076
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0580  data: 1.7600  max mem: 5076
# Epoch: [19] Total time: 0:00:45 (2.0570 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0157 (0.0157)  evaluator_time: 0.0253 (0.0253)  time: 0.1085  data: 0.0637  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0145)  evaluator_time: 0.0229 (0.0377)  time: 0.1134  data: 0.0568  max mem: 5076
# Test: Total time: 0:00:04 (0.1150 s / it)
# Averaged stats: model_time: 0.0143 (0.0145)  evaluator_time: 0.0229 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.349
# Epoch: [20]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9812  data: 1.6078  max mem: 5076
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0644  data: 1.7684  max mem: 5076
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0741  data: 1.7771  max mem: 5076
# Epoch: [20] Total time: 0:00:45 (2.0697 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0148 (0.0148)  evaluator_time: 0.0257 (0.0257)  time: 0.1058  data: 0.0616  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0145)  evaluator_time: 0.0236 (0.0390)  time: 0.1158  data: 0.0563  max mem: 5076
# Test: Total time: 0:00:04 (0.1157 s / it)
# Averaged stats: model_time: 0.0142 (0.0145)  evaluator_time: 0.0236 (0.0390)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.413
# Epoch: [21]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9357  data: 1.5720  max mem: 5076
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1638  data: 1.8387  max mem: 5076
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1527  data: 1.8277  max mem: 5076
# Epoch: [21] Total time: 0:00:47 (2.1473 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0145 (0.0145)  evaluator_time: 0.0261 (0.0261)  time: 0.1060  data: 0.0616  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0142)  evaluator_time: 0.0233 (0.0391)  time: 0.1151  data: 0.0568  max mem: 5076
# Test: Total time: 0:00:04 (0.1159 s / it)
# Averaged stats: model_time: 0.0140 (0.0142)  evaluator_time: 0.0233 (0.0391)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.308
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.401
# Epoch: [22]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9977  data: 1.6633  max mem: 5076
# Epoch: [22]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1364  data: 1.8438  max mem: 5076
# Epoch: [22]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1079  data: 1.8141  max mem: 5076
# Epoch: [22] Total time: 0:00:46 (2.1142 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0146 (0.0146)  evaluator_time: 0.0184 (0.0184)  time: 0.0991  data: 0.0624  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0143)  evaluator_time: 0.0264 (0.0377)  time: 0.1147  data: 0.0576  max mem: 5076
# Test: Total time: 0:00:04 (0.1165 s / it)
# Averaged stats: model_time: 0.0140 (0.0143)  evaluator_time: 0.0264 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# Epoch: [23]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2345  data: 1.9260  max mem: 5076
# Epoch: [23]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1019  data: 1.8168  max mem: 5076
# Epoch: [23]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0878  data: 1.8063  max mem: 5076
# Epoch: [23] Total time: 0:00:46 (2.1023 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0142 (0.0142)  evaluator_time: 0.0240 (0.0240)  time: 0.1036  data: 0.0618  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0145)  evaluator_time: 0.0233 (0.0412)  time: 0.1213  data: 0.0574  max mem: 5076
# Test: Total time: 0:00:04 (0.1187 s / it)
# Averaged stats: model_time: 0.0143 (0.0145)  evaluator_time: 0.0233 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.410
# Epoch: [24]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.0939  data: 1.7997  max mem: 5076
# Epoch: [24]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1159  data: 1.8040  max mem: 5076
# Epoch: [24]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1048  data: 1.7995  max mem: 5076
# Epoch: [24] Total time: 0:00:46 (2.1191 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0149 (0.0149)  evaluator_time: 0.0167 (0.0167)  time: 0.0972  data: 0.0618  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0144)  evaluator_time: 0.0282 (0.0370)  time: 0.1150  data: 0.0578  max mem: 5076
# Test: Total time: 0:00:04 (0.1150 s / it)
# Averaged stats: model_time: 0.0140 (0.0144)  evaluator_time: 0.0282 (0.0370)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
# Epoch: [25]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7494  data: 1.4735  max mem: 5076
# Epoch: [25]  [20/22]  eta: 0:00:03  lr: 0.003000  time: 1.9941  data: 1.7222  max mem: 5076
# Epoch: [25]  [21/22]  eta: 0:00:01  lr: 0.003000  time: 1.9880  data: 1.7128  max mem: 5076
# Epoch: [25] Total time: 0:00:43 (1.9823 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0148 (0.0148)  evaluator_time: 0.0243 (0.0243)  time: 0.1053  data: 0.0624  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0231 (0.0373)  time: 0.1153  data: 0.0580  max mem: 5076
# Test: Total time: 0:00:04 (0.1152 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0231 (0.0373)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.397
# Epoch: [26]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1368  data: 1.7550  max mem: 5076
# Epoch: [26]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1053  data: 1.8046  max mem: 5076
# Epoch: [26]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1267  data: 1.8214  max mem: 5076
# Epoch: [26] Total time: 0:00:46 (2.1128 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0193 (0.0193)  time: 0.0989  data: 0.0613  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0230 (0.0372)  time: 0.1136  data: 0.0567  max mem: 5076
# Test: Total time: 0:00:04 (0.1145 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0230 (0.0372)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# ...
# Epoch: [41]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0784  data: 1.7735  max mem: 5076
# Epoch: [41]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0629  data: 1.7629  max mem: 5076
# Epoch: [41] Total time: 0:00:45 (2.0663 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0161 (0.0161)  evaluator_time: 0.0228 (0.0228)  time: 0.1056  data: 0.0629  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0145)  evaluator_time: 0.0215 (0.0335)  time: 0.1106  data: 0.0565  max mem: 5076
# Test: Total time: 0:00:04 (0.1112 s / it)
# Averaged stats: model_time: 0.0142 (0.0145)  evaluator_time: 0.0215 (0.0335)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.415
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.415
# Epoch: [42]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8327  data: 1.6302  max mem: 5076
# Epoch: [42]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1170  data: 1.8105  max mem: 5076
# Epoch: [42]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1042  data: 1.7957  max mem: 5076
# Epoch: [42] Total time: 0:00:46 (2.0982 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0145 (0.0145)  evaluator_time: 0.0167 (0.0167)  time: 0.0982  data: 0.0634  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0221 (0.0325)  time: 0.1122  data: 0.0571  max mem: 5076
# Test: Total time: 0:00:04 (0.1107 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0221 (0.0325)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# Epoch: [43]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3726  data: 1.9839  max mem: 5076
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1478  data: 1.8600  max mem: 5076
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1482  data: 1.8611  max mem: 5076
# Epoch: [43] Total time: 0:00:47 (2.1612 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0154 (0.0154)  evaluator_time: 0.0170 (0.0170)  time: 0.1192  data: 0.0830  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0146)  evaluator_time: 0.0231 (0.0346)  time: 0.1138  data: 0.0566  max mem: 5076
# Test: Total time: 0:00:04 (0.1123 s / it)
# Averaged stats: model_time: 0.0141 (0.0146)  evaluator_time: 0.0231 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.477
# Epoch: [44]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1561  data: 1.7628  max mem: 5076
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1695  data: 1.8609  max mem: 5076
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1760  data: 1.8642  max mem: 5076
# Epoch: [44] Total time: 0:00:47 (2.1715 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0144 (0.0144)  evaluator_time: 0.0222 (0.0222)  time: 0.1023  data: 0.0621  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0234 (0.0360)  time: 0.1128  data: 0.0565  max mem: 5076
# Test: Total time: 0:00:04 (0.1132 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0234 (0.0360)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.336
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.417
# Epoch: [45]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2132  data: 1.8573  max mem: 5076
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1759  data: 1.8664  max mem: 5076
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1708  data: 1.8594  max mem: 5076
# Epoch: [45] Total time: 0:00:47 (2.1749 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0151 (0.0151)  evaluator_time: 0.0249 (0.0249)  time: 0.1081  data: 0.0643  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0143)  evaluator_time: 0.0209 (0.0353)  time: 0.1167  data: 0.0577  max mem: 5076
# Test: Total time: 0:00:04 (0.1131 s / it)
# Averaged stats: model_time: 0.0140 (0.0143)  evaluator_time: 0.0209 (0.0353)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.413
# Epoch: [46]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9667  data: 1.6666  max mem: 5076
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1112  data: 1.7976  max mem: 5076
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1142  data: 1.7962  max mem: 5076
# Epoch: [46] Total time: 0:00:46 (2.1124 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0142 (0.0142)  evaluator_time: 0.0185 (0.0185)  time: 0.0986  data: 0.0623  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0217 (0.0323)  time: 0.1108  data: 0.0563  max mem: 5076
# Test: Total time: 0:00:04 (0.1090 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0217 (0.0323)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [47]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9266  data: 1.6277  max mem: 5076
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2265  data: 1.8969  max mem: 5076
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1991  data: 1.8778  max mem: 5076
# Epoch: [47] Total time: 0:00:48 (2.2009 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0155 (0.0155)  evaluator_time: 0.0152 (0.0152)  time: 0.0992  data: 0.0648  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0142)  evaluator_time: 0.0216 (0.0296)  time: 0.1089  data: 0.0578  max mem: 5076
# Test: Total time: 0:00:04 (0.1076 s / it)
# Averaged stats: model_time: 0.0141 (0.0142)  evaluator_time: 0.0216 (0.0296)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.431
# Epoch: [48]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.8077  data: 1.5372  max mem: 5076
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1601  data: 1.8469  max mem: 5076
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1599  data: 1.8577  max mem: 5076
# Epoch: [48] Total time: 0:00:47 (2.1549 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0144 (0.0144)  evaluator_time: 0.0117 (0.0117)  time: 0.0915  data: 0.0616  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0142)  evaluator_time: 0.0219 (0.0302)  time: 0.1103  data: 0.0566  max mem: 5076
# Test: Total time: 0:00:04 (0.1070 s / it)
# Averaged stats: model_time: 0.0142 (0.0142)  evaluator_time: 0.0219 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.468
# Epoch: [49]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9542  data: 1.6707  max mem: 5076
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1825  data: 1.8658  max mem: 5076
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1722  data: 1.8550  max mem: 5076
# Epoch: [49] Total time: 0:00:47 (2.1767 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0152 (0.0152)  time: 0.0964  data: 0.0626  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0146 (0.0147)  evaluator_time: 0.0208 (0.0314)  time: 0.1115  data: 0.0570  max mem: 5076
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0146 (0.0147)  evaluator_time: 0.0208 (0.0314)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.437
# Training time 0:49:56

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_ResNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.19843822226631133

# %%
start_time = time.time()


for epoch in range(50, 100):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Epoch: [50]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1369  data: 1.8288  max mem: 5076
# Epoch: [50]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1540  data: 1.8706  max mem: 5076
# Epoch: [50]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1315  data: 1.8486  max mem: 5076
# Epoch: [50] Total time: 0:00:47 (2.1429 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0143 (0.0143)  evaluator_time: 0.0180 (0.0180)  time: 0.0980  data: 0.0619  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0227 (0.0332)  time: 0.1133  data: 0.0579  max mem: 5076
# Test: Total time: 0:00:04 (0.1109 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0227 (0.0332)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.455
# Epoch: [51]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7568  data: 1.5199  max mem: 5076
# Epoch: [51]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1294  data: 1.8303  max mem: 5076
# Epoch: [51]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1180  data: 1.8205  max mem: 5076
# Epoch: [51] Total time: 0:00:46 (2.1012 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0158 (0.0158)  time: 0.0967  data: 0.0623  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0143)  evaluator_time: 0.0216 (0.0304)  time: 0.1111  data: 0.0577  max mem: 5076
# Test: Total time: 0:00:04 (0.1078 s / it)
# Averaged stats: model_time: 0.0142 (0.0143)  evaluator_time: 0.0216 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# Epoch: [52]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.4040  data: 2.0613  max mem: 5076
# Epoch: [52]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0998  data: 1.7921  max mem: 5076
# Epoch: [52]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1063  data: 1.7956  max mem: 5076
# Epoch: [52] Total time: 0:00:46 (2.1081 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0149 (0.0149)  evaluator_time: 0.0217 (0.0217)  time: 0.1030  data: 0.0626  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0144)  evaluator_time: 0.0210 (0.0335)  time: 0.1118  data: 0.0570  max mem: 5076
# Test: Total time: 0:00:04 (0.1118 s / it)
# Averaged stats: model_time: 0.0141 (0.0144)  evaluator_time: 0.0210 (0.0335)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [53]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9487  data: 1.6124  max mem: 5076
# Epoch: [53]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0117  data: 1.7319  max mem: 5076
# Epoch: [53]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 1.9991  data: 1.7196  max mem: 5076
# Epoch: [53] Total time: 0:00:44 (2.0144 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0143 (0.0143)  evaluator_time: 0.0216 (0.0216)  time: 0.1036  data: 0.0639  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0145)  evaluator_time: 0.0240 (0.0389)  time: 0.1172  data: 0.0602  max mem: 5076
# Test: Total time: 0:00:04 (0.1186 s / it)
# Averaged stats: model_time: 0.0142 (0.0145)  evaluator_time: 0.0240 (0.0389)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
# Epoch: [54]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7897  data: 1.5200  max mem: 5076
# Epoch: [54]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0587  data: 1.7673  max mem: 5076
# Epoch: [54]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0713  data: 1.7780  max mem: 5076
# Epoch: [54] Total time: 0:00:45 (2.0573 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0140 (0.0140)  evaluator_time: 0.0170 (0.0170)  time: 0.0963  data: 0.0617  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0139 (0.0142)  evaluator_time: 0.0239 (0.0300)  time: 0.1080  data: 0.0562  max mem: 5076
# Test: Total time: 0:00:04 (0.1070 s / it)
# Averaged stats: model_time: 0.0139 (0.0142)  evaluator_time: 0.0239 (0.0300)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
# Epoch: [55]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9166  data: 1.6045  max mem: 5076
# Epoch: [55]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0685  data: 1.7658  max mem: 5076
# Epoch: [55]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0671  data: 1.7652  max mem: 5076
# Epoch: [55] Total time: 0:00:45 (2.0636 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0147 (0.0147)  time: 0.0952  data: 0.0620  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0142)  evaluator_time: 0.0230 (0.0300)  time: 0.1097  data: 0.0565  max mem: 5076
# Test: Total time: 0:00:04 (0.1072 s / it)
# Averaged stats: model_time: 0.0143 (0.0142)  evaluator_time: 0.0230 (0.0300)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# Epoch: [56]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3760  data: 1.9935  max mem: 5076
# Epoch: [56]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0307  data: 1.7468  max mem: 5076
# Epoch: [56]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0051  data: 1.7233  max mem: 5076
# Epoch: [56] Total time: 0:00:44 (2.0357 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0149 (0.0149)  evaluator_time: 0.0249 (0.0249)  time: 0.1057  data: 0.0622  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0145)  evaluator_time: 0.0221 (0.0341)  time: 0.1139  data: 0.0579  max mem: 5076
# Test: Total time: 0:00:04 (0.1123 s / it)
# Averaged stats: model_time: 0.0143 (0.0145)  evaluator_time: 0.0221 (0.0341)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [57]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9098  data: 1.6451  max mem: 5076
# Epoch: [57]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0710  data: 1.7661  max mem: 5076
# Epoch: [57]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0520  data: 1.7557  max mem: 5076
# Epoch: [57] Total time: 0:00:45 (2.0634 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0145 (0.0145)  evaluator_time: 0.0165 (0.0165)  time: 0.0969  data: 0.0621  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0141)  evaluator_time: 0.0218 (0.0311)  time: 0.1094  data: 0.0565  max mem: 5076
# Test: Total time: 0:00:04 (0.1077 s / it)
# Averaged stats: model_time: 0.0140 (0.0141)  evaluator_time: 0.0218 (0.0311)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.424
# Epoch: [58]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9452  data: 1.5787  max mem: 5076
# Epoch: [58]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1517  data: 1.8322  max mem: 5076
# Epoch: [58]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1410  data: 1.8230  max mem: 5076
# Epoch: [58] Total time: 0:00:47 (2.1368 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0146 (0.0146)  evaluator_time: 0.0219 (0.0219)  time: 0.1019  data: 0.0617  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0144)  evaluator_time: 0.0223 (0.0347)  time: 0.1125  data: 0.0563  max mem: 5076
# Test: Total time: 0:00:04 (0.1116 s / it)
# Averaged stats: model_time: 0.0141 (0.0144)  evaluator_time: 0.0223 (0.0347)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.461
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.461
# Epoch: [59]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9402  data: 1.6324  max mem: 5076
# Epoch: [59]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0835  data: 1.7978  max mem: 5076
# Epoch: [59]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0744  data: 1.7904  max mem: 5076
# Epoch: [59] Total time: 0:00:45 (2.0792 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0162 (0.0162)  time: 0.0966  data: 0.0618  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0141)  evaluator_time: 0.0223 (0.0309)  time: 0.1086  data: 0.0572  max mem: 5076
# Test: Total time: 0:00:04 (0.1079 s / it)
# Averaged stats: model_time: 0.0140 (0.0141)  evaluator_time: 0.0223 (0.0309)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.421
# Epoch: [60]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8474  data: 1.5858  max mem: 5076
# Epoch: [60]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0127  data: 1.7328  max mem: 5076
# Epoch: [60]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0258  data: 1.7376  max mem: 5076
# Epoch: [60] Total time: 0:00:44 (2.0189 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0140 (0.0140)  evaluator_time: 0.0177 (0.0177)  time: 0.0978  data: 0.0624  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0224 (0.0318)  time: 0.1106  data: 0.0566  max mem: 5076
# Test: Total time: 0:00:04 (0.1090 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0224 (0.0318)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.244
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# Epoch: [61]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9448  data: 1.5641  max mem: 5076
# Epoch: [61]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1188  data: 1.8071  max mem: 5076
# Epoch: [61]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1311  data: 1.8196  max mem: 5076
# Epoch: [61] Total time: 0:00:46 (2.1243 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0160 (0.0160)  time: 0.0968  data: 0.0623  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0139 (0.0141)  evaluator_time: 0.0203 (0.0304)  time: 0.1064  data: 0.0562  max mem: 5076
# Test: Total time: 0:00:04 (0.1069 s / it)
# Averaged stats: model_time: 0.0139 (0.0141)  evaluator_time: 0.0203 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.368
# Epoch: [62]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.3065  data: 1.8540  max mem: 5076
# Epoch: [62]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0799  data: 1.7947  max mem: 5076
# Epoch: [62]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0555  data: 1.7714  max mem: 5076
# Epoch: [62] Total time: 0:00:46 (2.0930 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0146 (0.0146)  evaluator_time: 0.0187 (0.0187)  time: 0.0988  data: 0.0618  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0141)  evaluator_time: 0.0220 (0.0314)  time: 0.1088  data: 0.0567  max mem: 5076
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0140 (0.0141)  evaluator_time: 0.0220 (0.0314)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.431
# Epoch: [63]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2634  data: 1.8802  max mem: 5076
# Epoch: [63]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1281  data: 1.8185  max mem: 5076
# Epoch: [63]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1182  data: 1.8123  max mem: 5076
# Epoch: [63] Total time: 0:00:46 (2.1268 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0151 (0.0151)  evaluator_time: 0.0162 (0.0162)  time: 0.0994  data: 0.0642  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0150)  evaluator_time: 0.0248 (0.0324)  time: 0.1107  data: 0.0564  max mem: 5076
# Test: Total time: 0:00:04 (0.1105 s / it)
# Averaged stats: model_time: 0.0143 (0.0150)  evaluator_time: 0.0248 (0.0324)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.346
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# Epoch: [64]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9357  data: 1.5292  max mem: 5076
# Epoch: [64]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0216  data: 1.7312  max mem: 5076
# Epoch: [64]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0332  data: 1.7391  max mem: 5076
# Epoch: [64] Total time: 0:00:44 (2.0288 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0148 (0.0148)  time: 0.0957  data: 0.0624  max mem: 5076
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0244 (0.0367)  time: 0.1201  data: 0.0567  max mem: 5076
# Test: Total time: 0:00:04 (0.1139 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0244 (0.0367)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.445
# Epoch: [65]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7666  data: 1.4812  max mem: 5076
# Epoch: [65]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0954  data: 1.7951  max mem: 5152
# Epoch: [65]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0548  data: 1.7665  max mem: 5152
# Epoch: [65] Total time: 0:00:45 (2.0711 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0150 (0.0150)  evaluator_time: 0.0122 (0.0122)  time: 0.0933  data: 0.0623  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0146)  evaluator_time: 0.0228 (0.0276)  time: 0.1089  data: 0.0578  max mem: 5152
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0142 (0.0146)  evaluator_time: 0.0228 (0.0276)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.451
# Epoch: [66]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3649  data: 1.9885  max mem: 5152
# Epoch: [66]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1635  data: 1.8451  max mem: 5152
# Epoch: [66]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1636  data: 1.8453  max mem: 5152
# Epoch: [66] Total time: 0:00:47 (2.1756 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0146 (0.0146)  evaluator_time: 0.0124 (0.0124)  time: 0.0944  data: 0.0636  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0231 (0.0265)  time: 0.1069  data: 0.0574  max mem: 5152
# Test: Total time: 0:00:04 (0.1043 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0231 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.449
# Epoch: [67]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7105  data: 1.5304  max mem: 5152
# Epoch: [67]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1604  data: 1.8517  max mem: 5152
# Epoch: [67]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1738  data: 1.8651  max mem: 5152
# Epoch: [67] Total time: 0:00:47 (2.1516 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0140 (0.0140)  evaluator_time: 0.0165 (0.0165)  time: 0.0970  data: 0.0629  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0205 (0.0302)  time: 0.1128  data: 0.0601  max mem: 5152
# Test: Total time: 0:00:04 (0.1090 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0205 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.461
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.461
# Epoch: [68]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8963  data: 1.6122  max mem: 5152
# Epoch: [68]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1543  data: 1.8490  max mem: 5152
# Epoch: [68]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1492  data: 1.8413  max mem: 5152
# Epoch: [68] Total time: 0:00:47 (2.1490 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0150 (0.0150)  evaluator_time: 0.0150 (0.0150)  time: 0.0962  data: 0.0625  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0142)  evaluator_time: 0.0165 (0.0266)  time: 0.1051  data: 0.0579  max mem: 5152
# Test: Total time: 0:00:04 (0.1042 s / it)
# Averaged stats: model_time: 0.0142 (0.0142)  evaluator_time: 0.0165 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
# Epoch: [69]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0075  data: 1.6599  max mem: 5152
# Epoch: [69]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1156  data: 1.8086  max mem: 5152
# Epoch: [69]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1217  data: 1.8113  max mem: 5152
# Epoch: [69] Total time: 0:00:46 (2.1050 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0165 (0.0165)  evaluator_time: 0.0149 (0.0149)  time: 0.0985  data: 0.0634  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0227 (0.0313)  time: 0.1122  data: 0.0575  max mem: 5152
# Test: Total time: 0:00:04 (0.1090 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0227 (0.0313)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.460
# Epoch: [70]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0439  data: 1.7530  max mem: 5152
# Epoch: [70]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0593  data: 1.7635  max mem: 5152
# Epoch: [70]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0682  data: 1.7724  max mem: 5152
# Epoch: [70] Total time: 0:00:45 (2.0723 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0118 (0.0118)  time: 0.0935  data: 0.0631  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0209 (0.0285)  time: 0.1063  data: 0.0568  max mem: 5152
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0209 (0.0285)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.412
# Epoch: [71]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7930  data: 1.5078  max mem: 5152
# Epoch: [71]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1361  data: 1.8545  max mem: 5152
# Epoch: [71]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1039  data: 1.8252  max mem: 5152
# Epoch: [71] Total time: 0:00:46 (2.1046 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0156 (0.0156)  time: 0.0978  data: 0.0638  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0144)  evaluator_time: 0.0226 (0.0287)  time: 0.1081  data: 0.0570  max mem: 5152
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0143 (0.0144)  evaluator_time: 0.0226 (0.0287)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.451
# Epoch: [72]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0303  data: 1.6986  max mem: 5152
# Epoch: [72]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0855  data: 1.7945  max mem: 5152
# Epoch: [72]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0430  data: 1.7573  max mem: 5152
# Epoch: [72] Total time: 0:00:45 (2.0620 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0151 (0.0151)  time: 0.0960  data: 0.0626  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0215 (0.0261)  time: 0.1037  data: 0.0564  max mem: 5152
# Test: Total time: 0:00:04 (0.1035 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0215 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# Epoch: [73]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9578  data: 1.6920  max mem: 5152
# Epoch: [73]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1764  data: 1.8707  max mem: 5152
# Epoch: [73]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1803  data: 1.8779  max mem: 5152
# Epoch: [73] Total time: 0:00:47 (2.1764 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0160 (0.0160)  time: 0.0962  data: 0.0617  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0141)  evaluator_time: 0.0226 (0.0302)  time: 0.1081  data: 0.0563  max mem: 5152
# Test: Total time: 0:00:04 (0.1072 s / it)
# Averaged stats: model_time: 0.0141 (0.0141)  evaluator_time: 0.0226 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# Epoch: [74]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9133  data: 1.5949  max mem: 5152
# Epoch: [74]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1104  data: 1.8201  max mem: 5152
# Epoch: [74]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0850  data: 1.7943  max mem: 5152
# Epoch: [74] Total time: 0:00:46 (2.0910 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0157 (0.0157)  evaluator_time: 0.0136 (0.0136)  time: 0.0957  data: 0.0624  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0144)  evaluator_time: 0.0223 (0.0284)  time: 0.1071  data: 0.0570  max mem: 5152
# Test: Total time: 0:00:04 (0.1057 s / it)
# Averaged stats: model_time: 0.0141 (0.0144)  evaluator_time: 0.0223 (0.0284)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.442
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
# Epoch: [75]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0380  data: 1.7300  max mem: 5152
# Epoch: [75]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0860  data: 1.7900  max mem: 5152
# Epoch: [75]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0657  data: 1.7774  max mem: 5152
# Epoch: [75] Total time: 0:00:45 (2.0760 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0142 (0.0142)  evaluator_time: 0.0131 (0.0131)  time: 0.0942  data: 0.0632  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0147 (0.0145)  evaluator_time: 0.0185 (0.0286)  time: 0.1073  data: 0.0570  max mem: 5152
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0147 (0.0145)  evaluator_time: 0.0185 (0.0286)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
# Epoch: [76]  [ 0/22]  eta: 0:00:36  lr: 0.003000  time: 1.6422  data: 1.3410  max mem: 5152
# Epoch: [76]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1229  data: 1.7985  max mem: 5152
# Epoch: [76]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1347  data: 1.8131  max mem: 5152
# Epoch: [76] Total time: 0:00:46 (2.1099 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0145 (0.0145)  evaluator_time: 0.0159 (0.0159)  time: 0.0957  data: 0.0617  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0144)  evaluator_time: 0.0224 (0.0322)  time: 0.1134  data: 0.0564  max mem: 5152
# Test: Total time: 0:00:04 (0.1093 s / it)
# Averaged stats: model_time: 0.0141 (0.0144)  evaluator_time: 0.0224 (0.0322)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.404
# ...
# Epoch: [91]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1652  data: 1.8619  max mem: 5152
# Epoch: [91]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1839  data: 1.8709  max mem: 5152
# Epoch: [91] Total time: 0:00:47 (2.1590 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0148 (0.0148)  evaluator_time: 0.0119 (0.0119)  time: 0.0930  data: 0.0625  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0202 (0.0260)  time: 0.1039  data: 0.0569  max mem: 5152
# Test: Total time: 0:00:04 (0.1030 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0202 (0.0260)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.375
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.431
# Epoch: [92]  [ 0/22]  eta: 0:00:49  lr: 0.000300  time: 2.2498  data: 1.8925  max mem: 5152
# Epoch: [92]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.0748  data: 1.7824  max mem: 5152
# Epoch: [92]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0642  data: 1.7716  max mem: 5152
# Epoch: [92] Total time: 0:00:45 (2.0812 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0149 (0.0149)  evaluator_time: 0.0114 (0.0114)  time: 0.0929  data: 0.0628  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0142)  evaluator_time: 0.0168 (0.0258)  time: 0.1039  data: 0.0571  max mem: 5152
# Test: Total time: 0:00:04 (0.1034 s / it)
# Averaged stats: model_time: 0.0142 (0.0142)  evaluator_time: 0.0168 (0.0258)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [93]  [ 0/22]  eta: 0:00:40  lr: 0.000300  time: 1.8545  data: 1.5399  max mem: 5152
# Epoch: [93]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1111  data: 1.8312  max mem: 5152
# Epoch: [93]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1006  data: 1.8199  max mem: 5152
# Epoch: [93] Total time: 0:00:46 (2.0915 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0149 (0.0149)  evaluator_time: 0.0116 (0.0116)  time: 0.0926  data: 0.0625  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0145 (0.0147)  evaluator_time: 0.0176 (0.0260)  time: 0.1040  data: 0.0568  max mem: 5152
# Test: Total time: 0:00:04 (0.1036 s / it)
# Averaged stats: model_time: 0.0145 (0.0147)  evaluator_time: 0.0176 (0.0260)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [94]  [ 0/22]  eta: 0:00:43  lr: 0.000300  time: 1.9743  data: 1.7043  max mem: 5152
# Epoch: [94]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1851  data: 1.8744  max mem: 5152
# Epoch: [94]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1671  data: 1.8564  max mem: 5152
# Epoch: [94] Total time: 0:00:47 (2.1579 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0147 (0.0147)  evaluator_time: 0.0113 (0.0113)  time: 0.0920  data: 0.0623  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0143 (0.0143)  evaluator_time: 0.0168 (0.0261)  time: 0.1041  data: 0.0568  max mem: 5152
# Test: Total time: 0:00:04 (0.1031 s / it)
# Averaged stats: model_time: 0.0143 (0.0143)  evaluator_time: 0.0168 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
# Epoch: [95]  [ 0/22]  eta: 0:00:46  lr: 0.000300  time: 2.1275  data: 1.8972  max mem: 5152
# Epoch: [95]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1818  data: 1.8795  max mem: 5152
# Epoch: [95]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1738  data: 1.8674  max mem: 5152
# Epoch: [95] Total time: 0:00:47 (2.1649 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0163 (0.0163)  evaluator_time: 0.0116 (0.0116)  time: 0.0961  data: 0.0643  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0141 (0.0143)  evaluator_time: 0.0217 (0.0260)  time: 0.1037  data: 0.0565  max mem: 5152
# Test: Total time: 0:00:04 (0.1034 s / it)
# Averaged stats: model_time: 0.0141 (0.0143)  evaluator_time: 0.0217 (0.0260)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
# Epoch: [96]  [ 0/22]  eta: 0:00:49  lr: 0.000300  time: 2.2555  data: 1.8895  max mem: 5152
# Epoch: [96]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1391  data: 1.8410  max mem: 5152
# Epoch: [96]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1397  data: 1.8391  max mem: 5152
# Epoch: [96] Total time: 0:00:47 (2.1470 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0151 (0.0151)  evaluator_time: 0.0112 (0.0112)  time: 0.0918  data: 0.0618  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0144 (0.0144)  evaluator_time: 0.0216 (0.0262)  time: 0.1045  data: 0.0566  max mem: 5152
# Test: Total time: 0:00:04 (0.1033 s / it)
# Averaged stats: model_time: 0.0144 (0.0144)  evaluator_time: 0.0216 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
# Epoch: [97]  [ 0/22]  eta: 0:00:44  lr: 0.000300  time: 2.0379  data: 1.7032  max mem: 5152
# Epoch: [97]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1584  data: 1.8444  max mem: 5152
# Epoch: [97]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1393  data: 1.8270  max mem: 5152
# Epoch: [97] Total time: 0:00:47 (2.1415 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0156 (0.0156)  evaluator_time: 0.0115 (0.0115)  time: 0.0934  data: 0.0623  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0140 (0.0142)  evaluator_time: 0.0163 (0.0255)  time: 0.1028  data: 0.0566  max mem: 5152
# Test: Total time: 0:00:04 (0.1025 s / it)
# Averaged stats: model_time: 0.0140 (0.0142)  evaluator_time: 0.0163 (0.0255)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [98]  [ 0/22]  eta: 0:00:42  lr: 0.000300  time: 1.9444  data: 1.6557  max mem: 5152
# Epoch: [98]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1615  data: 1.8453  max mem: 5152
# Epoch: [98]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1579  data: 1.8390  max mem: 5152
# Epoch: [98] Total time: 0:00:47 (2.1584 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0144 (0.0144)  evaluator_time: 0.0116 (0.0116)  time: 0.0931  data: 0.0632  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0142 (0.0144)  evaluator_time: 0.0214 (0.0270)  time: 0.1047  data: 0.0565  max mem: 5152
# Test: Total time: 0:00:04 (0.1040 s / it)
# Averaged stats: model_time: 0.0142 (0.0144)  evaluator_time: 0.0214 (0.0270)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.441
# Epoch: [99]  [ 0/22]  eta: 0:00:39  lr: 0.000300  time: 1.8152  data: 1.5612  max mem: 5152
# Epoch: [99]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.0991  data: 1.8008  max mem: 5152
# Epoch: [99]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1128  data: 1.8075  max mem: 5152
# Epoch: [99] Total time: 0:00:46 (2.0918 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0151 (0.0151)  evaluator_time: 0.0114 (0.0114)  time: 0.0917  data: 0.0616  max mem: 5152
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0139 (0.0141)  evaluator_time: 0.0167 (0.0257)  time: 0.1027  data: 0.0561  max mem: 5152
# Test: Total time: 0:00:04 (0.1021 s / it)
# Averaged stats: model_time: 0.0139 (0.0141)  evaluator_time: 0.0167 (0.0257)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.375
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
# Training time 0:44:19

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_ResNet.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0a33bb81005> in <cell line: 2>()
#       1 print('El AP del mejor modelo siendo esre el que guardamos es:')
# ----> 2 print(best_ap)
#       3 torch.save({
#       4     'model_state_dict': best_model_weights,
#       5 }, path_base + "/pesos_modelos/SSD300_ResNet.pth" )
#
# NameError: name 'best_ap' is not defined
