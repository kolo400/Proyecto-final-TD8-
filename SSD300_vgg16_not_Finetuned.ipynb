# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()

classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]




def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)



# Agrupar las detecciones por imagen
def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }
        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())


train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        img = read_image(path_base + '/Imagenes/' + item['image_filename'])
        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])


        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])




        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)


        if self.transform:
            img, target = self.transform(img, target)
        return img, target



train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))


print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import  ssd300_vgg16

# Cargar el modelo SSD preentrenado
model = ssd300_vgg16(pretrained = False) #No esta pre entrenado --> si lo estara la backbone en Image Net.
model = model.to(device)  # Mueve el modelo a CUDA
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16_features-amdegroot.pth" to /root/.cache/torch/hub/checkpoints/vgg16_features-amdegroot.pth
# 100%|██████████| 56.1M/56.1M [00:00<00:00, 331MB/s]

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background
in_channels = [512, 1024, 512, 256, 256, 256]  # canales de las diferentes capas del feature map
num_anchors = [4, 6, 6, 6, 4, 4]  # número de default boxes por celda en cada feature map
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0: #Warm Up

        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()
        print(loss_value)
        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

"""
MetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.
Warmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.
"""
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-16 19:53:35--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-16 19:53:35 (83.7 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-16 19:53:35--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-16 19:53:36 (78.6 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-16 19:53:36--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-16 19:53:36 (96.9 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-16 19:53:36--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-16 19:53:36 (81.4 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-16 19:53:36--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0s
#
# 2024-11-16 19:53:37 (144 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()#Solo se cambia la tasa cuando se alcanza uno de los milestones definidos
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# 45.97407913208008
# Epoch: [0]  [ 0/22]  eta: 0:06:21  lr: 0.000146  time: 17.3372  data: 14.2933  max mem: 2975
# 37.277008056640625
# 19.986417770385742
# 15.452402114868164
# 10.619161605834961
# 12.63358211517334
# 12.299795150756836
# 11.684026718139648
# 35.765628814697266
# 17.89078140258789
# 19.90604019165039
# 20.79395866394043
# 21.278549194335938
# 25.839601516723633
# 18.348861694335938
# 22.905296325683594
# 23.096267700195312
# 20.996601104736328
# 20.865262985229492
# 51.59611129760742
# 85.96607208251953
# Epoch: [0]  [20/22]  eta: 0:00:28  lr: 0.003000  time: 14.3175  data: 14.0045  max mem: 3147
# 51.01362228393555
# Epoch: [0]  [21/22]  eta: 0:00:14  lr: 0.003000  time: 14.3317  data: 14.0175  max mem: 3147
# Epoch: [0] Total time: 0:05:17 (14.4208 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.2356 (0.2356)  evaluator_time: 0.0275 (0.0275)  time: 0.3304  data: 0.0632  max mem: 3147
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0093 (0.0151)  evaluator_time: 0.0153 (0.0369)  time: 0.1036  data: 0.0580  max mem: 3147
# Test: Total time: 0:00:04 (0.1153 s / it)
# Averaged stats: model_time: 0.0093 (0.0151)  evaluator_time: 0.0153 (0.0369)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 70.87510681152344
# Epoch: [1]  [ 0/22]  eta: 0:01:02  lr: 0.003000  time: 2.8468  data: 2.5294  max mem: 3147
# 87.869873046875
# 93.95613098144531
# 89.07982635498047
# 83.9161376953125
# 75.9791030883789
# 67.67582702636719
# 61.37914276123047
# 47.71147155761719
# 38.70643997192383
# 59.364967346191406
# 99.72140502929688
# 46.50294876098633
# 87.62828063964844
# 118.75723266601562
# 86.54666137695312
# 83.22901916503906
# 91.24832153320312
# 64.54603576660156
# 74.85235595703125
# 91.38257598876953
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3827  data: 2.0805  max mem: 3313
# 126.73321533203125
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3524  data: 2.0569  max mem: 3313
# Epoch: [1] Total time: 0:00:52 (2.3817 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0097 (0.0097)  evaluator_time: 0.0245 (0.0245)  time: 0.1004  data: 0.0626  max mem: 3313
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0095 (0.0098)  evaluator_time: 0.0259 (0.0402)  time: 0.1068  data: 0.0576  max mem: 3313
# Test: Total time: 0:00:04 (0.1145 s / it)
# Averaged stats: model_time: 0.0095 (0.0098)  evaluator_time: 0.0259 (0.0402)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# 83.44963073730469
# Epoch: [2]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1647  data: 1.8474  max mem: 3313
# 119.13785552978516
# 97.31146240234375
# 86.86695861816406
# 92.49970245361328
# 86.89968872070312
# 133.41329956054688
# 112.30302429199219
# 126.56520080566406
# 119.38684844970703
# 112.24728393554688
# 182.51806640625
# 139.80419921875
# 184.2559356689453
# 161.2047576904297
# 160.5038604736328
# 182.5325927734375
# 140.21688842773438
# 171.14779663085938
# 183.2469024658203
# 110.20339965820312
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1426  data: 1.8354  max mem: 3430
# 140.2216796875
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1511  data: 1.8431  max mem: 3430
# Epoch: [2] Total time: 0:00:47 (2.1498 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0087 (0.0087)  evaluator_time: 0.0011 (0.0011)  time: 0.0753  data: 0.0617  max mem: 3430
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0084 (0.0086)  evaluator_time: 0.0010 (0.0010)  time: 0.0694  data: 0.0561  max mem: 3430
# Test: Total time: 0:00:02 (0.0721 s / it)
# Averaged stats: model_time: 0.0084 (0.0086)  evaluator_time: 0.0010 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 114.30127716064453
# Epoch: [3]  [ 0/22]  eta: 0:00:35  lr: 0.003000  time: 1.6058  data: 1.4435  max mem: 3430
# 93.59867095947266
# 87.93905639648438
# 104.57727813720703
# 115.08181762695312
# 190.3375701904297
# 137.08175659179688
# 146.56187438964844
# 119.32250213623047
# 153.0481414794922
# 121.83329010009766
# 128.48626708984375
# 162.09527587890625
# 119.32150268554688
# 99.03245544433594
# 107.0028076171875
# 111.72098541259766
# 68.86724853515625
# 100.0259017944336
# 58.76543045043945
# 89.61676788330078
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2411  data: 1.9258  max mem: 3430
# 115.80223083496094
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1870  data: 1.8800  max mem: 3430
# Epoch: [3] Total time: 0:00:48 (2.2029 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0114 (0.0114)  evaluator_time: 0.0012 (0.0012)  time: 0.0801  data: 0.0636  max mem: 3430
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0086 (0.0123)  evaluator_time: 0.0010 (0.0010)  time: 0.0771  data: 0.0566  max mem: 3430
# Test: Total time: 0:00:03 (0.0767 s / it)
# Averaged stats: model_time: 0.0086 (0.0123)  evaluator_time: 0.0010 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 130.65362548828125
# Epoch: [4]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.6944  data: 1.4114  max mem: 3430
# 135.69842529296875
# 125.79193115234375
# 130.21144104003906
# 140.18104553222656
# 121.5036392211914
# 113.14112854003906
# 122.03646087646484
# 136.97299194335938
# 100.31523132324219
# 100.44277954101562
# 126.20558166503906
# 94.97681427001953
# 81.51559448242188
# 75.53279876708984
# 77.24434661865234
# 100.52304077148438
# 82.76602935791016
# 109.14685821533203
# 98.90536499023438
# 123.4410400390625
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1323  data: 1.8243  max mem: 3452
# 110.863037109375
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1303  data: 1.8239  max mem: 3452
# Epoch: [4] Total time: 0:00:46 (2.1049 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0088 (0.0088)  evaluator_time: 0.0014 (0.0014)  time: 0.0762  data: 0.0624  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0087 (0.0088)  evaluator_time: 0.0010 (0.0010)  time: 0.0707  data: 0.0571  max mem: 3452
# Test: Total time: 0:00:02 (0.0731 s / it)
# Averaged stats: model_time: 0.0087 (0.0088)  evaluator_time: 0.0010 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 126.95682525634766
# Epoch: [5]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0684  data: 1.7925  max mem: 3452
# 149.3163604736328
# 146.00042724609375
# 119.05772399902344
# 144.08657836914062
# 96.13763427734375
# 138.78704833984375
# 85.98640441894531
# 93.06607818603516
# 148.841796875
# 110.20679473876953
# 77.47125244140625
# 134.48092651367188
# 129.28346252441406
# 189.42477416992188
# 111.68634033203125
# 125.52274322509766
# 155.83189392089844
# 162.0128631591797
# 153.6105194091797
# 115.77445983886719
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2240  data: 1.8965  max mem: 3452
# 99.550537109375
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2086  data: 1.8856  max mem: 3452
# Epoch: [5] Total time: 0:00:48 (2.1963 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:02  model_time: 0.0087 (0.0087)  evaluator_time: 0.0013 (0.0013)  time: 0.0750  data: 0.0614  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0084 (0.0086)  evaluator_time: 0.0010 (0.0010)  time: 0.0694  data: 0.0562  max mem: 3452
# Test: Total time: 0:00:02 (0.0718 s / it)
# Averaged stats: model_time: 0.0084 (0.0086)  evaluator_time: 0.0010 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 103.87940216064453
# Epoch: [6]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9665  data: 1.6882  max mem: 3452
# 105.86474609375
# 88.02445983886719
# 67.5552978515625
# 81.78599548339844
# 55.53791046142578
# 112.75814819335938
# 100.46967315673828
# 73.40241241455078
# 60.64046859741211
# 78.547607421875
# 46.716163635253906
# 88.74837493896484
# 68.79869079589844
# 84.45791625976562
# 74.32206726074219
# 78.20124816894531
# 76.26542663574219
# 68.60163879394531
# 65.69146728515625
# 52.974056243896484
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0758  data: 1.7756  max mem: 3452
# 52.7711296081543
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0203  data: 1.7223  max mem: 3452
# Epoch: [6] Total time: 0:00:45 (2.0589 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0096 (0.0096)  evaluator_time: 0.0237 (0.0237)  time: 0.0991  data: 0.0621  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0093 (0.0095)  evaluator_time: 0.0130 (0.0341)  time: 0.0993  data: 0.0565  max mem: 3452
# Test: Total time: 0:00:04 (0.1061 s / it)
# Averaged stats: model_time: 0.0093 (0.0095)  evaluator_time: 0.0130 (0.0341)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 56.122920989990234
# Epoch: [7]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2013  data: 1.9478  max mem: 3452
# 62.978126525878906
# 58.5274772644043
# 47.00743865966797
# 55.606807708740234
# 60.38726806640625
# 70.63945770263672
# 56.93159866333008
# 52.502662658691406
# 50.771034240722656
# 44.47990798950195
# 46.109981536865234
# 32.66933059692383
# 26.92152976989746
# 36.106964111328125
# 49.117679595947266
# 22.663257598876953
# 34.44760513305664
# 36.407718658447266
# 27.71282386779785
# 53.931007385253906
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0835  data: 1.7786  max mem: 3452
# 48.68474197387695
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1002  data: 1.7858  max mem: 3452
# Epoch: [7] Total time: 0:00:46 (2.1010 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0096 (0.0096)  evaluator_time: 0.0243 (0.0243)  time: 0.0996  data: 0.0620  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0092 (0.0094)  evaluator_time: 0.0127 (0.0346)  time: 0.0992  data: 0.0564  max mem: 3452
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0092 (0.0094)  evaluator_time: 0.0127 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# 36.89280700683594
# Epoch: [8]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0541  data: 1.7067  max mem: 3452
# 47.827335357666016
# 38.94160079956055
# 37.000213623046875
# 41.2867431640625
# 42.250335693359375
# 38.16106033325195
# 47.589447021484375
# 29.563159942626953
# 35.72450256347656
# 30.105716705322266
# 37.24800109863281
# 26.419679641723633
# 32.98291015625
# 28.667835235595703
# 22.3699951171875
# 39.41133499145508
# 28.388961791992188
# 23.350976943969727
# 28.80499267578125
# 17.779869079589844
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0940  data: 1.8066  max mem: 3452
# 36.55784225463867
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1194  data: 1.8286  max mem: 3452
# Epoch: [8] Total time: 0:00:46 (2.1078 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0109 (0.0109)  evaluator_time: 0.0024 (0.0024)  time: 0.0790  data: 0.0618  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0094 (0.0099)  evaluator_time: 0.0058 (0.0093)  time: 0.0794  data: 0.0564  max mem: 3452
# Test: Total time: 0:00:03 (0.0815 s / it)
# Averaged stats: model_time: 0.0094 (0.0099)  evaluator_time: 0.0058 (0.0093)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# 21.843002319335938
# Epoch: [9]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1326  data: 1.7952  max mem: 3452
# 24.647293090820312
# 25.328548431396484
# 21.207246780395508
# 34.20924758911133
# 25.29557991027832
# 18.924224853515625
# 19.712121963500977
# 27.2960147857666
# 26.258930206298828
# 15.839168548583984
# 16.66114044189453
# 13.380430221557617
# 14.28504753112793
# 13.953060150146484
# 21.18956184387207
# 16.112369537353516
# 14.228995323181152
# 13.988056182861328
# 18.014474868774414
# 13.572399139404297
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1683  data: 1.8653  max mem: 3452
# 20.324264526367188
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1483  data: 1.8437  max mem: 3452
# Epoch: [9] Total time: 0:00:47 (2.1575 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0100 (0.0100)  evaluator_time: 0.0240 (0.0240)  time: 0.1000  data: 0.0623  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0097 (0.0098)  evaluator_time: 0.0126 (0.0344)  time: 0.0998  data: 0.0564  max mem: 3452
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0097 (0.0098)  evaluator_time: 0.0126 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 17.56682777404785
# Epoch: [10]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.3156  data: 2.0505  max mem: 3452
# 15.339916229248047
# 15.48515796661377
# 12.196282386779785
# 10.904430389404297
# 10.302456855773926
# 9.481429100036621
# 10.262967109680176
# 8.8203763961792
# 9.756105422973633
# 8.440861701965332
# 9.134060859680176
# 9.161666870117188
# 6.459117889404297
# 6.002658367156982
# 9.223146438598633
# 7.533022880554199
# 10.317276000976562
# 10.166496276855469
# 8.287857055664062
# 8.721131324768066
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0861  data: 1.7891  max mem: 3452
# 9.65667724609375
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0920  data: 1.7897  max mem: 3452
# Epoch: [10] Total time: 0:00:46 (2.1122 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0100 (0.0100)  evaluator_time: 0.0248 (0.0248)  time: 0.1011  data: 0.0625  max mem: 3452
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0097 (0.0100)  evaluator_time: 0.0131 (0.0345)  time: 0.1001  data: 0.0567  max mem: 3452
# Test: Total time: 0:00:04 (0.1073 s / it)
# Averaged stats: model_time: 0.0097 (0.0100)  evaluator_time: 0.0131 (0.0345)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 8.571378707885742
# Epoch: [11]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0370  data: 1.6044  max mem: 3452
# 9.333629608154297
# 7.59007453918457
# 10.083366394042969
# 9.910747528076172
# 10.567390441894531
# 8.39596176147461
# 9.566888809204102
# 8.473003387451172
# 9.389902114868164
# 9.929285049438477
# 6.625664710998535
# 7.0546464920043945
# 8.184809684753418
# 6.975505352020264
# 7.254585266113281
# 7.602231025695801
# 9.15882682800293
# 7.702554225921631
# 6.959163665771484
# 7.544980049133301
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2278  data: 1.9038  max mem: 3495
# 6.724052906036377
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2259  data: 1.9124  max mem: 3495
# Epoch: [11] Total time: 0:00:48 (2.2121 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0244 (0.0244)  time: 0.1008  data: 0.0624  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0102)  evaluator_time: 0.0127 (0.0344)  time: 0.0999  data: 0.0564  max mem: 3495
# Test: Total time: 0:00:04 (0.1070 s / it)
# Averaged stats: model_time: 0.0099 (0.0102)  evaluator_time: 0.0127 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 7.971797943115234
# Epoch: [12]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8751  data: 1.5533  max mem: 3495
# 8.99074935913086
# 6.6119184494018555
# 8.170743942260742
# 7.396274566650391
# 6.766390323638916
# 6.906917095184326
# 7.010318279266357
# 5.601502418518066
# 6.698336124420166
# 6.013102054595947
# 7.321629524230957
# 6.7444047927856445
# 7.450446128845215
# 6.628964424133301
# 8.110027313232422
# 7.924398899078369
# 7.386865615844727
# 7.2356414794921875
# 8.144354820251465
# 7.02487850189209
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2316  data: 1.9204  max mem: 3495
# 7.541015625
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1994  data: 1.8938  max mem: 3495
# Epoch: [12] Total time: 0:00:48 (2.2068 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0104 (0.0104)  evaluator_time: 0.0241 (0.0241)  time: 0.0999  data: 0.0617  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0102)  evaluator_time: 0.0127 (0.0346)  time: 0.1010  data: 0.0574  max mem: 3495
# Test: Total time: 0:00:04 (0.1079 s / it)
# Averaged stats: model_time: 0.0099 (0.0102)  evaluator_time: 0.0127 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 7.72882080078125
# Epoch: [13]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0571  data: 1.6988  max mem: 3495
# 7.851422309875488
# 5.71025276184082
# 7.53322696685791
# 6.765056610107422
# 6.166999816894531
# 6.3514556884765625
# 6.941396236419678
# 6.9196672439575195
# 6.280337333679199
# 5.921823024749756
# 6.723426818847656
# 5.811375617980957
# 6.558919906616211
# 5.331806659698486
# 6.442687511444092
# 6.936028957366943
# 7.2652668952941895
# 6.1336445808410645
# 6.223031997680664
# 6.800036907196045
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1360  data: 1.8326  max mem: 3495
# 6.905825614929199
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1121  data: 1.8170  max mem: 3495
# Epoch: [13] Total time: 0:00:47 (2.1401 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0103 (0.0103)  evaluator_time: 0.0240 (0.0240)  time: 0.0999  data: 0.0619  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0102)  evaluator_time: 0.0126 (0.0341)  time: 0.1001  data: 0.0571  max mem: 3495
# Test: Total time: 0:00:04 (0.1071 s / it)
# Averaged stats: model_time: 0.0099 (0.0102)  evaluator_time: 0.0126 (0.0341)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.395617961883545
# Epoch: [14]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0373  data: 1.7471  max mem: 3495
# 6.912432670593262
# 6.678401947021484
# 6.458293914794922
# 7.957479476928711
# 5.84584903717041
# 6.544334411621094
# 6.31840705871582
# 5.703827857971191
# 5.88803243637085
# 5.414182662963867
# 7.045008659362793
# 6.413384914398193
# 6.185218811035156
# 7.326046466827393
# 6.4815521240234375
# 6.256051063537598
# 7.089935302734375
# 6.8220109939575195
# 6.912220478057861
# 7.833757400512695
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1241  data: 1.8192  max mem: 3495
# 6.746343612670898
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1129  data: 1.8063  max mem: 3495
# Epoch: [14] Total time: 0:00:46 (2.1231 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0126 (0.0126)  evaluator_time: 0.0244 (0.0244)  time: 0.1044  data: 0.0635  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0101)  evaluator_time: 0.0126 (0.0343)  time: 0.1009  data: 0.0576  max mem: 3495
# Test: Total time: 0:00:04 (0.1077 s / it)
# Averaged stats: model_time: 0.0099 (0.0101)  evaluator_time: 0.0126 (0.0343)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.884395599365234
# Epoch: [15]  [ 0/22]  eta: 0:00:56  lr: 0.003000  time: 2.5623  data: 2.2044  max mem: 3495
# 6.7696027755737305
# 6.8437700271606445
# 6.728769302368164
# 6.128377437591553
# 7.577202796936035
# 7.451941967010498
# 6.05627965927124
# 6.643892288208008
# 5.938234329223633
# 6.112908840179443
# 6.035791397094727
# 6.730831623077393
# 7.146187782287598
# 6.733019828796387
# 6.460112571716309
# 6.957327365875244
# 6.4762468338012695
# 5.963827133178711
# 7.001800060272217
# 5.837963581085205
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0493  data: 1.7499  max mem: 3495
# 6.507968902587891
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0331  data: 1.7374  max mem: 3495
# Epoch: [15] Total time: 0:00:45 (2.0761 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0103 (0.0103)  evaluator_time: 0.0242 (0.0242)  time: 0.1003  data: 0.0620  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0103)  evaluator_time: 0.0129 (0.0345)  time: 0.1019  data: 0.0579  max mem: 3495
# Test: Total time: 0:00:04 (0.1081 s / it)
# Averaged stats: model_time: 0.0101 (0.0103)  evaluator_time: 0.0129 (0.0345)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 6.469390392303467
# Epoch: [16]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1726  data: 1.8416  max mem: 3495
# 5.377037048339844
# 7.714951515197754
# 7.3500213623046875
# 6.00602388381958
# 6.553689002990723
# 9.070806503295898
# 6.355044841766357
# 7.092201232910156
# 7.3575897216796875
# 6.388335227966309
# 5.888947010040283
# 7.078815937042236
# 5.763491630554199
# 7.7886199951171875
# 7.007861137390137
# 7.615164756774902
# 6.573493003845215
# 6.44157600402832
# 6.64117431640625
# 6.691275119781494
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1675  data: 1.8676  max mem: 3495
# 7.64883279800415
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2035  data: 1.8870  max mem: 3495
# Epoch: [16] Total time: 0:00:48 (2.1915 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0103 (0.0103)  evaluator_time: 0.0250 (0.0250)  time: 0.1007  data: 0.0617  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0098 (0.0099)  evaluator_time: 0.0137 (0.0352)  time: 0.1008  data: 0.0567  max mem: 3495
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0098 (0.0099)  evaluator_time: 0.0137 (0.0352)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 7.131320953369141
# Epoch: [17]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0433  data: 1.8039  max mem: 3495
# 7.597696781158447
# 7.038658142089844
# 6.308715343475342
# 5.855942249298096
# 5.818864822387695
# 7.516902923583984
# 6.878116607666016
# 6.54018497467041
# 7.238492012023926
# 7.62237548828125
# 7.235999584197998
# 6.794966697692871
# 6.9841766357421875
# 6.8382368087768555
# 7.776268005371094
# 6.873956680297852
# 6.418703079223633
# 6.392582893371582
# 7.0694403648376465
# 5.601188659667969
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1226  data: 1.8158  max mem: 3495
# 5.932950973510742
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1093  data: 1.8064  max mem: 3495
# Epoch: [17] Total time: 0:00:46 (2.1175 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0258 (0.0258)  evaluator_time: 0.0248 (0.0248)  time: 0.1160  data: 0.0618  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0106)  evaluator_time: 0.0152 (0.0346)  time: 0.1012  data: 0.0569  max mem: 3495
# Test: Total time: 0:00:04 (0.1084 s / it)
# Averaged stats: model_time: 0.0102 (0.0106)  evaluator_time: 0.0152 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 5.7589826583862305
# Epoch: [18]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3202  data: 2.0576  max mem: 3495
# 5.860260963439941
# 5.891712665557861
# 5.583967685699463
# 6.218405723571777
# 5.570949554443359
# 5.692326545715332
# 6.251830101013184
# 6.232121467590332
# 6.330792427062988
# 5.788010120391846
# 5.970829963684082
# 5.864246368408203
# 6.480428218841553
# 6.613736152648926
# 5.99065637588501
# 5.337808609008789
# 6.26386833190918
# 5.646086692810059
# 5.987102508544922
# 6.525944232940674
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1995  data: 1.8960  max mem: 3495
# 5.852087020874023
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1868  data: 1.8841  max mem: 3495
# Epoch: [18] Total time: 0:00:48 (2.1995 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0240 (0.0240)  time: 0.1007  data: 0.0626  max mem: 3495
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0102 (0.0102)  evaluator_time: 0.0135 (0.0344)  time: 0.1002  data: 0.0566  max mem: 3495
# Test: Total time: 0:00:04 (0.1078 s / it)
# Averaged stats: model_time: 0.0102 (0.0102)  evaluator_time: 0.0135 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 6.656641006469727
# Epoch: [19]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8700  data: 1.6336  max mem: 3495
# 6.14036750793457
# 7.130545139312744
# 6.389392852783203
# 5.952980041503906
# 6.952371120452881
# 6.405396461486816
# 8.819499969482422
# 6.375879287719727
# 6.343901634216309
# 6.701568603515625
# 6.497452735900879
# 6.610163688659668
# 7.531682968139648
# 6.636141777038574
# 6.407908916473389
# 7.41329288482666
# 6.658659934997559
# 6.263619422912598
# 6.1880950927734375
# 6.64640474319458
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1958  data: 1.8772  max mem: 3577
# 6.539779186248779
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1643  data: 1.8567  max mem: 3577
# Epoch: [19] Total time: 0:00:47 (2.1709 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0242 (0.0242)  time: 0.1013  data: 0.0629  max mem: 3577
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0137 (0.0349)  time: 0.1011  data: 0.0567  max mem: 3577
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0137 (0.0349)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
# 6.097567081451416
# Epoch: [20]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7843  data: 1.5422  max mem: 3577
# 6.137249946594238
# 6.135034561157227
# 5.878008842468262
# 7.560375213623047
# 5.734992027282715
# 6.662858009338379
# 6.008292198181152
# 6.25956916809082
# 7.350105285644531
# 5.837925910949707
# 6.821073532104492
# 5.93228816986084
# 6.179682731628418
# 5.615663528442383
# 6.312790870666504
# 5.873000144958496
# 5.836864948272705
# 5.880070209503174
# 6.913196086883545
# 5.506748676300049
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1593  data: 1.8528  max mem: 3766
# 7.577818870544434
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1459  data: 1.8344  max mem: 3766
# Epoch: [20] Total time: 0:00:47 (2.1454 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0105 (0.0105)  evaluator_time: 0.0241 (0.0241)  time: 0.1006  data: 0.0623  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0099 (0.0102)  evaluator_time: 0.0128 (0.0344)  time: 0.1002  data: 0.0565  max mem: 3766
# Test: Total time: 0:00:04 (0.1076 s / it)
# Averaged stats: model_time: 0.0099 (0.0102)  evaluator_time: 0.0128 (0.0344)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 6.375391006469727
# Epoch: [21]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8852  data: 1.6150  max mem: 3766
# 5.766297340393066
# 5.72804069519043
# 6.41363525390625
# 6.204359531402588
# 6.12654447555542
# 6.910950660705566
# 6.985630035400391
# 6.0488409996032715
# 6.140508651733398
# 5.815679550170898
# 6.212757587432861
# 6.933011054992676
# 6.558204174041748
# 6.149532318115234
# 6.303529739379883
# 6.6547017097473145
# 6.331686973571777
# 6.30534553527832
# 8.680294036865234
# 6.19725227355957
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2125  data: 1.8961  max mem: 3766
# 5.740653038024902
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2317  data: 1.9155  max mem: 3766
# Epoch: [21] Total time: 0:00:48 (2.2156 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0241 (0.0241)  time: 0.1012  data: 0.0626  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0132 (0.0384)  time: 0.1010  data: 0.0565  max mem: 3766
# Test: Total time: 0:00:04 (0.1112 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0132 (0.0384)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.55084228515625
# Epoch: [22]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.8156  data: 1.5605  max mem: 3766
# 5.797491550445557
# 6.023491859436035
# 6.331295967102051
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 5.576305866241455
# Epoch: [43]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7792  data: 1.5645  max mem: 3766
# 5.296671390533447
# 6.6637163162231445
# 6.279748916625977
# 6.142381191253662
# 5.773427486419678
# 6.22273588180542
# 5.182518482208252
# 5.61795711517334
# 5.5950727462768555
# 6.726884841918945
# 6.4318742752075195
# 6.853111267089844
# 5.98499059677124
# 5.79251766204834
# 5.436604022979736
# 5.754762649536133
# 5.103412628173828
# 6.431674003601074
# 6.122863292694092
# 6.826167106628418
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2199  data: 1.8998  max mem: 3766
# 5.774367332458496
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1596  data: 1.8440  max mem: 3766
# Epoch: [43] Total time: 0:00:47 (2.1652 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0103 (0.0103)  evaluator_time: 0.0243 (0.0243)  time: 0.1004  data: 0.0622  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0104)  evaluator_time: 0.0133 (0.0345)  time: 0.1017  data: 0.0578  max mem: 3766
# Test: Total time: 0:00:04 (0.1081 s / it)
# Averaged stats: model_time: 0.0100 (0.0104)  evaluator_time: 0.0133 (0.0345)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# 5.7165093421936035
# Epoch: [44]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8207  data: 1.6065  max mem: 3766
# 5.996814250946045
# 6.506734848022461
# 6.057937145233154
# 5.828914642333984
# 5.899519443511963
# 5.535472393035889
# 5.21528434753418
# 5.914754867553711
# 5.851922035217285
# 6.181899547576904
# 5.77415132522583
# 5.00794792175293
# 7.176723480224609
# 5.934778213500977
# 5.732062339782715
# 5.442890167236328
# 6.051778793334961
# 5.810050010681152
# 6.771411418914795
# 5.290561676025391
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1583  data: 1.8483  max mem: 3766
# 5.755149841308594
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1803  data: 1.8736  max mem: 3766
# Epoch: [44] Total time: 0:00:47 (2.1598 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0237 (0.0237)  time: 0.1010  data: 0.0632  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0098 (0.0100)  evaluator_time: 0.0127 (0.0342)  time: 0.1003  data: 0.0569  max mem: 3766
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0098 (0.0100)  evaluator_time: 0.0127 (0.0342)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# 5.736764430999756
# Epoch: [45]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8370  data: 1.5487  max mem: 3766
# 5.496415615081787
# 5.686602592468262
# 5.633707046508789
# 8.31733512878418
# 5.984930992126465
# 5.788537502288818
# 5.297165870666504
# 5.534933090209961
# 6.081521987915039
# 5.5784454345703125
# 6.385005950927734
# 5.613361358642578
# 6.422957897186279
# 5.956668853759766
# 6.95810604095459
# 6.644020080566406
# 5.398653984069824
# 7.191768646240234
# 6.338383197784424
# 5.83303689956665
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2286  data: 1.9099  max mem: 3766
# 5.767849922180176
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2143  data: 1.8930  max mem: 3766
# Epoch: [45] Total time: 0:00:48 (2.2053 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:09  model_time: 0.0106 (0.0106)  evaluator_time: 0.0249 (0.0249)  time: 0.2346  data: 0.1953  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0101 (0.0104)  evaluator_time: 0.0163 (0.0354)  time: 0.1025  data: 0.0569  max mem: 3766
# Test: Total time: 0:00:04 (0.1122 s / it)
# Averaged stats: model_time: 0.0101 (0.0104)  evaluator_time: 0.0163 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 5.832644939422607
# Epoch: [46]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7514  data: 1.5350  max mem: 3766
# 5.90703010559082
# 5.782405853271484
# 6.2452898025512695
# 5.990602493286133
# 6.091732501983643
# 5.814545154571533
# 5.997652053833008
# 6.9305572509765625
# 6.549783706665039
# 6.235198974609375
# 5.25348424911499
# 5.543205261230469
# 5.6337666511535645
# 6.126667022705078
# 6.304504871368408
# 6.09153938293457
# 5.936221122741699
# 5.831887245178223
# 5.535744667053223
# 6.832594871520996
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1321  data: 1.8188  max mem: 3766
# 6.319720268249512
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1343  data: 1.8182  max mem: 3766
# Epoch: [46] Total time: 0:00:46 (2.1321 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0106 (0.0106)  evaluator_time: 0.0259 (0.0259)  time: 0.1020  data: 0.0619  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0098 (0.0102)  evaluator_time: 0.0181 (0.0357)  time: 0.1015  data: 0.0565  max mem: 3766
# Test: Total time: 0:00:04 (0.1086 s / it)
# Averaged stats: model_time: 0.0098 (0.0102)  evaluator_time: 0.0181 (0.0357)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
# 5.401318550109863
# Epoch: [47]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8650  data: 1.6200  max mem: 3766
# 6.131196975708008
# 5.75354528427124
# 5.782034873962402
# 5.8101911544799805
# 7.645595073699951
# 6.629683494567871
# 6.403233528137207
# 6.752474784851074
# 5.8468732833862305
# 5.809065341949463
# 5.919378280639648
# 6.053903579711914
# 5.654272079467773
# 6.007534027099609
# 5.649946689605713
# 5.78645658493042
# 5.750367164611816
# 6.113801956176758
# 5.860135078430176
# 6.038100242614746
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1770  data: 1.8754  max mem: 3766
# 5.9877424240112305
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1651  data: 1.8642  max mem: 3766
# Epoch: [47] Total time: 0:00:47 (2.1582 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0104 (0.0104)  evaluator_time: 0.0254 (0.0254)  time: 0.1009  data: 0.0616  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0102)  evaluator_time: 0.0188 (0.0355)  time: 0.1031  data: 0.0574  max mem: 3766
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0100 (0.0102)  evaluator_time: 0.0188 (0.0355)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
# 6.4653167724609375
# Epoch: [48]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2493  data: 1.8589  max mem: 3766
# 5.722404479980469
# 6.005144119262695
# 5.7861409187316895
# 5.982302188873291
# 6.105808258056641
# 6.420687675476074
# 8.120838165283203
# 6.130558490753174
# 6.5029616355896
# 5.812593460083008
# 5.203176498413086
# 6.071367263793945
# 6.319179058074951
# 6.5027875900268555
# 8.192899703979492
# 7.399546146392822
# 6.800566673278809
# 5.541790008544922
# 6.832324981689453
# 6.95922327041626
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1852  data: 1.8527  max mem: 3766
# 5.377159118652344
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1762  data: 1.8487  max mem: 3766
# Epoch: [48] Total time: 0:00:48 (2.1826 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:06  model_time: 0.0106 (0.0106)  evaluator_time: 0.0755 (0.0755)  time: 0.1521  data: 0.0623  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0103)  evaluator_time: 0.0129 (0.0355)  time: 0.0999  data: 0.0565  max mem: 3766
# Test: Total time: 0:00:04 (0.1089 s / it)
# Averaged stats: model_time: 0.0100 (0.0103)  evaluator_time: 0.0129 (0.0355)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# 6.391102313995361
# Epoch: [49]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1233  data: 1.7908  max mem: 3766
# 5.81912899017334
# 6.3199052810668945
# 5.97886848449707
# 5.680555820465088
# 5.786995887756348
# 6.760265350341797
# 6.0259199142456055
# 6.027339935302734
# 6.566604137420654
# 6.34772253036499
# 5.5164666175842285
# 5.419417381286621
# 5.627418518066406
# 5.6631364822387695
# 6.326852798461914
# 5.753389358520508
# 6.073012351989746
# 8.297426223754883
# 7.872034072875977
# 5.843273639678955
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1753  data: 1.8560  max mem: 3766
# 5.64802360534668
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1645  data: 1.8452  max mem: 3766
# Epoch: [49] Total time: 0:00:47 (2.1778 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0102 (0.0102)  evaluator_time: 0.0240 (0.0240)  time: 0.0991  data: 0.0613  max mem: 3766
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0100 (0.0101)  evaluator_time: 0.0125 (0.0342)  time: 0.0994  data: 0.0561  max mem: 3766
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0100 (0.0101)  evaluator_time: 0.0125 (0.0342)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# Training time 0:49:51

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD_Original_not_Finetuned.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.00024610736659442205

# %%
start_time = time.time()

# Continuar el entrenamiento por otras 50 épocas
for epoch in range(50, 100):  # Cambiar el rango para empezar en la época 50
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()  # El scheduler seguirá ajustando la tasa en las épocas definidas
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
