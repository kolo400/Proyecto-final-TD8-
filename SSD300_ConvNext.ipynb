# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)


train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]


def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)



def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())


train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)


for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1


for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1


class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        img = read_image(path_base + '/Imagenes/' + item['image_filename'])
        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])


        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)


        if self.transform:
            img, target = self.transform(img, target)
        return img, target


train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))


print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import ssd300_convnext


model = ssd300_convnext(name = "convnext_small")
model = model.to(device)

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background

in_channels = [96, 192, 384, 768, 512, 256,256]
num_anchors = [4, 6, 6, 6, 4, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-18 15:56:46--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-18 15:56:47 (87.7 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-18 15:56:47--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-18 15:56:47 (96.2 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-18 15:56:47--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-18 15:56:47 (89.9 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-18 15:56:47--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-18 15:56:47 (67.4 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-18 15:56:47--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.002s
#
# 2024-11-18 15:56:47 (14.6 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# Epoch: [0]  [ 0/22]  eta: 0:04:51  lr: 0.000146  time: 13.2717  data: 10.0450  max mem: 4334
# Epoch: [0]  [20/22]  eta: 0:00:17  lr: 0.003000  time: 8.4399  data: 8.0783  max mem: 4981
# Epoch: [0]  [21/22]  eta: 0:00:08  lr: 0.003000  time: 8.3802  data: 8.0219  max mem: 4981
# Epoch: [0] Total time: 0:03:10 (8.6591 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:11  model_time: 0.1933 (0.1933)  evaluator_time: 0.0257 (0.0257)  time: 0.2852  data: 0.0625  max mem: 4981
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0208 (0.0250)  evaluator_time: 0.0170 (0.0354)  time: 0.1134  data: 0.0573  max mem: 4981
# Test: Total time: 0:00:04 (0.1237 s / it)
# Averaged stats: model_time: 0.0208 (0.0250)  evaluator_time: 0.0170 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.053
# Epoch: [1]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1971  data: 1.8806  max mem: 4981
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3068  data: 1.9417  max mem: 5303
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2880  data: 1.9246  max mem: 5303
# Epoch: [1] Total time: 0:00:50 (2.3047 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0208 (0.0208)  evaluator_time: 0.0265 (0.0265)  time: 0.1136  data: 0.0625  max mem: 5303
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0206 (0.0204)  evaluator_time: 0.0177 (0.0402)  time: 0.1148  data: 0.0571  max mem: 5303
# Test: Total time: 0:00:04 (0.1238 s / it)
# Averaged stats: model_time: 0.0206 (0.0204)  evaluator_time: 0.0177 (0.0402)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.068
# Epoch: [2]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7952  data: 1.4594  max mem: 5303
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2095  data: 1.8618  max mem: 5321
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1646  data: 1.8245  max mem: 5321
# Epoch: [2] Total time: 0:00:47 (2.1739 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0204 (0.0204)  evaluator_time: 0.0256 (0.0256)  time: 0.1126  data: 0.0629  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0204)  evaluator_time: 0.0242 (0.0366)  time: 0.1163  data: 0.0576  max mem: 5321
# Test: Total time: 0:00:04 (0.1204 s / it)
# Averaged stats: model_time: 0.0201 (0.0204)  evaluator_time: 0.0242 (0.0366)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.086
# Epoch: [3]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0245  data: 1.5447  max mem: 5321
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1150  data: 1.7452  max mem: 5321
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1301  data: 1.7605  max mem: 5321
# Epoch: [3] Total time: 0:00:46 (2.1295 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0272 (0.0272)  time: 0.1132  data: 0.0622  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0202)  evaluator_time: 0.0238 (0.0355)  time: 0.1158  data: 0.0579  max mem: 5321
# Test: Total time: 0:00:04 (0.1191 s / it)
# Averaged stats: model_time: 0.0200 (0.0202)  evaluator_time: 0.0238 (0.0355)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.096
# Epoch: [4]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8632  data: 1.5005  max mem: 5321
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1094  data: 1.7390  max mem: 5321
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1032  data: 1.7314  max mem: 5321
# Epoch: [4] Total time: 0:00:46 (2.0994 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0272 (0.0272)  time: 0.1133  data: 0.0622  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0204 (0.0206)  evaluator_time: 0.0253 (0.0354)  time: 0.1185  data: 0.0593  max mem: 5321
# Test: Total time: 0:00:04 (0.1201 s / it)
# Averaged stats: model_time: 0.0204 (0.0206)  evaluator_time: 0.0253 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.101
# Epoch: [5]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7550  data: 1.5082  max mem: 5321
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1127  data: 1.7689  max mem: 5321
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1021  data: 1.7591  max mem: 5321
# Epoch: [5] Total time: 0:00:46 (2.0956 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0260 (0.0260)  time: 0.1140  data: 0.0636  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0207)  evaluator_time: 0.0233 (0.0343)  time: 0.1161  data: 0.0577  max mem: 5321
# Test: Total time: 0:00:04 (0.1184 s / it)
# Averaged stats: model_time: 0.0203 (0.0207)  evaluator_time: 0.0233 (0.0343)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.133
# Epoch: [6]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9610  data: 1.5317  max mem: 5321
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2040  data: 1.8318  max mem: 5321
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1775  data: 1.8117  max mem: 5321
# Epoch: [6] Total time: 0:00:48 (2.1844 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0203 (0.0203)  evaluator_time: 0.0265 (0.0265)  time: 0.1123  data: 0.0619  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0205)  evaluator_time: 0.0235 (0.0345)  time: 0.1152  data: 0.0566  max mem: 5321
# Test: Total time: 0:00:04 (0.1181 s / it)
# Averaged stats: model_time: 0.0203 (0.0205)  evaluator_time: 0.0235 (0.0345)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.131
# Epoch: [7]  [ 0/22]  eta: 0:00:59  lr: 0.003000  time: 2.6910  data: 2.3024  max mem: 5321
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1219  data: 1.7955  max mem: 5321
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1176  data: 1.7922  max mem: 5321
# Epoch: [7] Total time: 0:00:47 (2.1551 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0217 (0.0217)  evaluator_time: 0.0270 (0.0270)  time: 0.1162  data: 0.0632  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0204)  evaluator_time: 0.0229 (0.0370)  time: 0.1135  data: 0.0571  max mem: 5321
# Test: Total time: 0:00:04 (0.1214 s / it)
# Averaged stats: model_time: 0.0202 (0.0204)  evaluator_time: 0.0229 (0.0370)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.143
# Epoch: [8]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7373  data: 1.4252  max mem: 5321
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1401  data: 1.8022  max mem: 5321
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1404  data: 1.8039  max mem: 5321
# Epoch: [8] Total time: 0:00:46 (2.1288 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0266 (0.0266)  time: 0.1125  data: 0.0619  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0205 (0.0205)  evaluator_time: 0.0234 (0.0338)  time: 0.1143  data: 0.0566  max mem: 5321
# Test: Total time: 0:00:04 (0.1174 s / it)
# Averaged stats: model_time: 0.0205 (0.0205)  evaluator_time: 0.0234 (0.0338)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.164
# Epoch: [9]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0677  data: 1.6999  max mem: 5321
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1179  data: 1.7865  max mem: 5321
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1030  data: 1.7698  max mem: 5321
# Epoch: [9] Total time: 0:00:46 (2.1259 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0208 (0.0208)  evaluator_time: 0.0254 (0.0254)  time: 0.1121  data: 0.0621  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0206)  evaluator_time: 0.0213 (0.0333)  time: 0.1151  data: 0.0572  max mem: 5321
# Test: Total time: 0:00:04 (0.1178 s / it)
# Averaged stats: model_time: 0.0201 (0.0206)  evaluator_time: 0.0213 (0.0333)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.168
# Epoch: [10]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8477  data: 1.5127  max mem: 5321
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0568  data: 1.7013  max mem: 5321
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0415  data: 1.6929  max mem: 5321
# Epoch: [10] Total time: 0:00:44 (2.0444 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0211 (0.0211)  evaluator_time: 0.0266 (0.0266)  time: 0.1151  data: 0.0635  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0204)  evaluator_time: 0.0216 (0.0332)  time: 0.1152  data: 0.0568  max mem: 5321
# Test: Total time: 0:00:04 (0.1171 s / it)
# Averaged stats: model_time: 0.0201 (0.0204)  evaluator_time: 0.0216 (0.0332)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.169
# Epoch: [11]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8417  data: 1.5326  max mem: 5321
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1266  data: 1.7587  max mem: 5321
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0976  data: 1.7311  max mem: 5321
# Epoch: [11] Total time: 0:00:46 (2.1072 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0203 (0.0203)  evaluator_time: 0.0276 (0.0276)  time: 0.1160  data: 0.0644  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0204)  evaluator_time: 0.0213 (0.0329)  time: 0.1148  data: 0.0569  max mem: 5321
# Test: Total time: 0:00:04 (0.1163 s / it)
# Averaged stats: model_time: 0.0202 (0.0204)  evaluator_time: 0.0213 (0.0329)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.172
# Epoch: [12]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1427  data: 1.7501  max mem: 5321
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1392  data: 1.7676  max mem: 5321
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1184  data: 1.7531  max mem: 5321
# Epoch: [12] Total time: 0:00:46 (2.1305 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0203 (0.0203)  evaluator_time: 0.0274 (0.0274)  time: 0.1144  data: 0.0630  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0205 (0.0208)  evaluator_time: 0.0222 (0.0329)  time: 0.1162  data: 0.0574  max mem: 5321
# Test: Total time: 0:00:04 (0.1170 s / it)
# Averaged stats: model_time: 0.0205 (0.0208)  evaluator_time: 0.0222 (0.0329)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.170
# Epoch: [13]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7720  data: 1.4949  max mem: 5321
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2392  data: 1.9036  max mem: 5321
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2235  data: 1.8871  max mem: 5321
# Epoch: [13] Total time: 0:00:48 (2.2110 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0206 (0.0206)  evaluator_time: 0.0265 (0.0265)  time: 0.1139  data: 0.0629  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0203)  evaluator_time: 0.0217 (0.0361)  time: 0.1130  data: 0.0565  max mem: 5321
# Test: Total time: 0:00:04 (0.1190 s / it)
# Averaged stats: model_time: 0.0200 (0.0203)  evaluator_time: 0.0217 (0.0361)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
# Epoch: [14]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9946  data: 1.6068  max mem: 5321
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1751  data: 1.8239  max mem: 5321
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1377  data: 1.7950  max mem: 5321
# Epoch: [14] Total time: 0:00:47 (2.1635 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0230 (0.0230)  evaluator_time: 0.0254 (0.0254)  time: 0.1158  data: 0.0637  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0205 (0.0206)  evaluator_time: 0.0215 (0.0324)  time: 0.1145  data: 0.0580  max mem: 5321
# Test: Total time: 0:00:04 (0.1168 s / it)
# Averaged stats: model_time: 0.0205 (0.0206)  evaluator_time: 0.0215 (0.0324)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.186
# Epoch: [15]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7515  data: 1.4397  max mem: 5321
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0511  data: 1.7180  max mem: 5321
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0464  data: 1.7095  max mem: 5321
# Epoch: [15] Total time: 0:00:44 (2.0302 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0220 (0.0220)  evaluator_time: 0.0265 (0.0265)  time: 0.1175  data: 0.0648  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0204)  evaluator_time: 0.0214 (0.0317)  time: 0.1123  data: 0.0569  max mem: 5321
# Test: Total time: 0:00:04 (0.1153 s / it)
# Averaged stats: model_time: 0.0202 (0.0204)  evaluator_time: 0.0214 (0.0317)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.177
# Epoch: [16]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8524  data: 1.5588  max mem: 5321
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0895  data: 1.7379  max mem: 5321
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0833  data: 1.7249  max mem: 5321
# Epoch: [16] Total time: 0:00:45 (2.0844 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0270 (0.0270)  time: 0.1131  data: 0.0623  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0203)  evaluator_time: 0.0210 (0.0316)  time: 0.1121  data: 0.0568  max mem: 5321
# Test: Total time: 0:00:04 (0.1147 s / it)
# Averaged stats: model_time: 0.0200 (0.0203)  evaluator_time: 0.0210 (0.0316)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.187
# Epoch: [17]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1669  data: 1.6621  max mem: 5321
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1732  data: 1.8214  max mem: 5321
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1414  data: 1.7926  max mem: 5321
# Epoch: [17] Total time: 0:00:47 (2.1675 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0261 (0.0261)  time: 0.1123  data: 0.0622  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0205)  evaluator_time: 0.0217 (0.0315)  time: 0.1126  data: 0.0570  max mem: 5321
# Test: Total time: 0:00:04 (0.1151 s / it)
# Averaged stats: model_time: 0.0203 (0.0205)  evaluator_time: 0.0217 (0.0315)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.194
# Epoch: [18]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0101  data: 1.6619  max mem: 5321
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1224  data: 1.7878  max mem: 5321
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1036  data: 1.7674  max mem: 5321
# Epoch: [18] Total time: 0:00:46 (2.1194 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0206 (0.0206)  evaluator_time: 0.0244 (0.0244)  time: 0.1126  data: 0.0637  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0206)  evaluator_time: 0.0204 (0.0306)  time: 0.1120  data: 0.0569  max mem: 5321
# Test: Total time: 0:00:04 (0.1147 s / it)
# Averaged stats: model_time: 0.0202 (0.0206)  evaluator_time: 0.0204 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
# Epoch: [19]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1841  data: 1.7857  max mem: 5321
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2271  data: 1.8703  max mem: 5321
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2168  data: 1.8598  max mem: 5321
# Epoch: [19] Total time: 0:00:49 (2.2277 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0208 (0.0208)  evaluator_time: 0.0259 (0.0259)  time: 0.1129  data: 0.0623  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0207)  evaluator_time: 0.0241 (0.0350)  time: 0.1213  data: 0.0580  max mem: 5321
# Test: Total time: 0:00:04 (0.1193 s / it)
# Averaged stats: model_time: 0.0203 (0.0207)  evaluator_time: 0.0241 (0.0350)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
# Epoch: [20]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9128  data: 1.5976  max mem: 5321
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2871  data: 1.9156  max mem: 5321
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2740  data: 1.9086  max mem: 5321
# Epoch: [20] Total time: 0:00:49 (2.2689 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0210 (0.0210)  evaluator_time: 0.0251 (0.0251)  time: 0.1134  data: 0.0634  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0205)  evaluator_time: 0.0215 (0.0313)  time: 0.1133  data: 0.0580  max mem: 5321
# Test: Total time: 0:00:04 (0.1155 s / it)
# Averaged stats: model_time: 0.0202 (0.0205)  evaluator_time: 0.0215 (0.0313)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
# Epoch: [21]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4142  data: 1.9235  max mem: 5321
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1153  data: 1.7764  max mem: 5321
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1126  data: 1.7753  max mem: 5321
# Epoch: [21] Total time: 0:00:47 (2.1425 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0210 (0.0210)  evaluator_time: 0.0254 (0.0254)  time: 0.1124  data: 0.0622  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0203)  evaluator_time: 0.0208 (0.0310)  time: 0.1124  data: 0.0578  max mem: 5321
# Test: Total time: 0:00:04 (0.1148 s / it)
# Averaged stats: model_time: 0.0202 (0.0203)  evaluator_time: 0.0208 (0.0310)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
# Epoch: [22]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1780  data: 1.7522  max mem: 5321
# Epoch: [22]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1710  data: 1.8024  max mem: 5321
# Epoch: [22]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1885  data: 1.8189  max mem: 5321
# Epoch: [22] Total time: 0:00:47 (2.1816 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0259 (0.0259)  time: 0.1141  data: 0.0638  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0205 (0.0205)  evaluator_time: 0.0205 (0.0304)  time: 0.1117  data: 0.0580  max mem: 5321
# Test: Total time: 0:00:04 (0.1145 s / it)
# Averaged stats: model_time: 0.0205 (0.0205)  evaluator_time: 0.0205 (0.0304)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
# Epoch: [23]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7166  data: 1.3726  max mem: 5321
# Epoch: [23]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2811  data: 1.9226  max mem: 5321
# Epoch: [23]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2526  data: 1.8920  max mem: 5321
# Epoch: [23] Total time: 0:00:49 (2.2531 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0201 (0.0201)  evaluator_time: 0.0246 (0.0246)  time: 0.1122  data: 0.0637  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0204)  evaluator_time: 0.0202 (0.0306)  time: 0.1124  data: 0.0579  max mem: 5321
# Test: Total time: 0:00:04 (0.1148 s / it)
# Averaged stats: model_time: 0.0203 (0.0204)  evaluator_time: 0.0202 (0.0306)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
# Epoch: [24]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9938  data: 1.6184  max mem: 5321
# Epoch: [24]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1281  data: 1.7840  max mem: 5321
# Epoch: [24]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1369  data: 1.7938  max mem: 5321
# Epoch: [24] Total time: 0:00:47 (2.1390 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0239 (0.0239)  time: 0.1097  data: 0.0617  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0201)  evaluator_time: 0.0205 (0.0303)  time: 0.1104  data: 0.0564  max mem: 5321
# Test: Total time: 0:00:04 (0.1135 s / it)
# Averaged stats: model_time: 0.0200 (0.0201)  evaluator_time: 0.0205 (0.0303)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
# Epoch: [25]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0385  data: 1.6595  max mem: 5321
# Epoch: [25]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1046  data: 1.7745  max mem: 5321
# Epoch: [25]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0663  data: 1.7428  max mem: 5321
# Epoch: [25] Total time: 0:00:46 (2.0921 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0204 (0.0204)  evaluator_time: 0.0251 (0.0251)  time: 0.1109  data: 0.0618  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0221)  evaluator_time: 0.0212 (0.0338)  time: 0.1210  data: 0.0570  max mem: 5321
# Test: Total time: 0:00:04 (0.1190 s / it)
# Averaged stats: model_time: 0.0201 (0.0221)  evaluator_time: 0.0212 (0.0338)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
# Epoch: [26]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0294  data: 1.6003  max mem: 5321
# Epoch: [26]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1179  data: 1.7791  max mem: 5321
# Epoch: [26]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1227  data: 1.7824  max mem: 5321
# Epoch: [26] Total time: 0:00:46 (2.1099 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0228 (0.0228)  evaluator_time: 0.0249 (0.0249)  time: 0.1147  data: 0.0631  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0201)  evaluator_time: 0.0207 (0.0303)  time: 0.1113  data: 0.0576  max mem: 5321
# Test: Total time: 0:00:04 (0.1143 s / it)
# Averaged stats: model_time: 0.0200 (0.0201)  evaluator_time: 0.0207 (0.0303)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
# ...
# Epoch: [41]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1013  data: 1.7667  max mem: 5321
# Epoch: [41]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0898  data: 1.7547  max mem: 5321
# Epoch: [41] Total time: 0:00:46 (2.0987 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0203 (0.0203)  evaluator_time: 0.0240 (0.0240)  time: 0.1104  data: 0.0623  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0202)  evaluator_time: 0.0197 (0.0283)  time: 0.1087  data: 0.0568  max mem: 5321
# Test: Total time: 0:00:04 (0.1115 s / it)
# Averaged stats: model_time: 0.0202 (0.0202)  evaluator_time: 0.0197 (0.0283)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.245
# Epoch: [42]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9460  data: 1.5753  max mem: 5321
# Epoch: [42]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1537  data: 1.7964  max mem: 5321
# Epoch: [42]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1551  data: 1.7949  max mem: 5321
# Epoch: [42] Total time: 0:00:47 (2.1503 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0237 (0.0237)  evaluator_time: 0.0244 (0.0244)  time: 0.1348  data: 0.0829  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0199 (0.0203)  evaluator_time: 0.0196 (0.0284)  time: 0.1084  data: 0.0565  max mem: 5321
# Test: Total time: 0:00:04 (0.1120 s / it)
# Averaged stats: model_time: 0.0199 (0.0203)  evaluator_time: 0.0196 (0.0284)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.251
# Epoch: [43]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9147  data: 1.5294  max mem: 5321
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0988  data: 1.7742  max mem: 5321
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0878  data: 1.7722  max mem: 5321
# Epoch: [43] Total time: 0:00:45 (2.0885 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0239 (0.0239)  time: 0.1108  data: 0.0627  max mem: 5321
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0207)  evaluator_time: 0.0203 (0.0290)  time: 0.1088  data: 0.0566  max mem: 5321
# Test: Total time: 0:00:04 (0.1125 s / it)
# Averaged stats: model_time: 0.0201 (0.0207)  evaluator_time: 0.0203 (0.0290)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.249
# Epoch: [44]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8812  data: 1.5336  max mem: 5321
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0569  data: 1.7395  max mem: 5321
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0960  data: 1.7645  max mem: 5373
# Epoch: [44] Total time: 0:00:45 (2.0864 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0201 (0.0201)  evaluator_time: 0.0235 (0.0235)  time: 0.1091  data: 0.0619  max mem: 5373
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0204)  evaluator_time: 0.0203 (0.0284)  time: 0.1084  data: 0.0563  max mem: 5373
# Test: Total time: 0:00:04 (0.1114 s / it)
# Averaged stats: model_time: 0.0201 (0.0204)  evaluator_time: 0.0203 (0.0284)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.250
# Epoch: [45]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9390  data: 1.5850  max mem: 5373
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1240  data: 1.7822  max mem: 5373
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1128  data: 1.7726  max mem: 5373
# Epoch: [45] Total time: 0:00:46 (2.1170 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0238 (0.0238)  time: 0.1096  data: 0.0617  max mem: 5373
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0202)  evaluator_time: 0.0201 (0.0282)  time: 0.1087  data: 0.0567  max mem: 5373
# Test: Total time: 0:00:04 (0.1109 s / it)
# Averaged stats: model_time: 0.0201 (0.0202)  evaluator_time: 0.0201 (0.0282)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.249
# Epoch: [46]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0019  data: 1.7251  max mem: 5373
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0970  data: 1.7675  max mem: 5373
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0751  data: 1.7484  max mem: 5373
# Epoch: [46] Total time: 0:00:45 (2.0831 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0206 (0.0206)  evaluator_time: 0.0239 (0.0239)  time: 0.1117  data: 0.0635  max mem: 5373
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0202)  evaluator_time: 0.0211 (0.0283)  time: 0.1091  data: 0.0570  max mem: 5373
# Test: Total time: 0:00:04 (0.1114 s / it)
# Averaged stats: model_time: 0.0200 (0.0202)  evaluator_time: 0.0211 (0.0283)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.240
# Epoch: [47]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9406  data: 1.6028  max mem: 5373
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0836  data: 1.7475  max mem: 5373
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0803  data: 1.7519  max mem: 5373
# Epoch: [47] Total time: 0:00:45 (2.0793 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0212 (0.0212)  evaluator_time: 0.0236 (0.0236)  time: 0.1117  data: 0.0631  max mem: 5373
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0203)  evaluator_time: 0.0206 (0.0282)  time: 0.1084  data: 0.0567  max mem: 5373
# Test: Total time: 0:00:04 (0.1116 s / it)
# Averaged stats: model_time: 0.0200 (0.0203)  evaluator_time: 0.0206 (0.0282)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.246
# Epoch: [48]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9288  data: 1.5634  max mem: 5373
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1024  data: 1.7611  max mem: 5389
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0541  data: 1.7206  max mem: 5389
# Epoch: [48] Total time: 0:00:46 (2.0909 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0206 (0.0206)  evaluator_time: 0.0252 (0.0252)  time: 0.1115  data: 0.0620  max mem: 5389
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0202 (0.0204)  evaluator_time: 0.0203 (0.0284)  time: 0.1087  data: 0.0567  max mem: 5389
# Test: Total time: 0:00:04 (0.1114 s / it)
# Averaged stats: model_time: 0.0202 (0.0204)  evaluator_time: 0.0203 (0.0284)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.260
# Epoch: [49]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2348  data: 1.8820  max mem: 5389
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1633  data: 1.7989  max mem: 5750
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1669  data: 1.8002  max mem: 5750
# Epoch: [49] Total time: 0:00:47 (2.1636 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0200 (0.0200)  evaluator_time: 0.0230 (0.0230)  time: 0.1090  data: 0.0622  max mem: 5750
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0201 (0.0203)  evaluator_time: 0.0204 (0.0320)  time: 0.1158  data: 0.0563  max mem: 5750
# Test: Total time: 0:00:04 (0.1159 s / it)
# Averaged stats: model_time: 0.0201 (0.0203)  evaluator_time: 0.0204 (0.0320)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.106
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.256
# Training time 0:47:50

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_ConvNext.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.06692030952341901

# %%
start_time = time.time()


for epoch in range(50, 100):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Epoch: [50]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1020  data: 1.7753  max mem: 2889
# Epoch: [50]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1698  data: 1.8244  max mem: 2889
# Epoch: [50]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1700  data: 1.8269  max mem: 2889
# Epoch: [50] Total time: 0:00:47 (2.1531 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0200 (0.0200)  evaluator_time: 0.0246 (0.0246)  time: 0.1099  data: 0.0617  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0199)  evaluator_time: 0.0196 (0.0280)  time: 0.1101  data: 0.0574  max mem: 2889
# Test: Total time: 0:00:04 (0.1108 s / it)
# Averaged stats: model_time: 0.0200 (0.0199)  evaluator_time: 0.0196 (0.0280)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.337
# Epoch: [51]  [ 0/22]  eta: 0:00:41  lr: 0.003000  time: 1.8733  data: 1.5958  max mem: 2889
# Epoch: [51]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1141  data: 1.7572  max mem: 2889
# Epoch: [51]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1085  data: 1.7493  max mem: 2889
# Epoch: [51] Total time: 0:00:46 (2.1104 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0214 (0.0214)  evaluator_time: 0.0258 (0.0258)  time: 0.1137  data: 0.0628  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0201)  evaluator_time: 0.0223 (0.0291)  time: 0.1121  data: 0.0570  max mem: 2889
# Test: Total time: 0:00:04 (0.1127 s / it)
# Averaged stats: model_time: 0.0200 (0.0201)  evaluator_time: 0.0223 (0.0291)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.353
# Epoch: [52]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7664  data: 1.3835  max mem: 2889
# Epoch: [52]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0918  data: 1.7397  max mem: 2889
# Epoch: [52]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0941  data: 1.7444  max mem: 2889
# Epoch: [52] Total time: 0:00:45 (2.0817 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0201 (0.0201)  evaluator_time: 0.0239 (0.0239)  time: 0.1093  data: 0.0616  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0198 (0.0200)  evaluator_time: 0.0198 (0.0271)  time: 0.1092  data: 0.0566  max mem: 2889
# Test: Total time: 0:00:04 (0.1101 s / it)
# Averaged stats: model_time: 0.0198 (0.0200)  evaluator_time: 0.0198 (0.0271)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.357
# Epoch: [53]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9976  data: 1.6665  max mem: 2889
# Epoch: [53]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1587  data: 1.8178  max mem: 2889
# Epoch: [53]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1736  data: 1.8272  max mem: 2889
# Epoch: [53] Total time: 0:00:47 (2.1589 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0241 (0.0241)  time: 0.1097  data: 0.0617  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0195 (0.0197)  evaluator_time: 0.0197 (0.0266)  time: 0.1077  data: 0.0561  max mem: 2889
# Test: Total time: 0:00:04 (0.1088 s / it)
# Averaged stats: model_time: 0.0195 (0.0197)  evaluator_time: 0.0197 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.345
# Epoch: [54]  [ 0/22]  eta: 0:00:57  lr: 0.003000  time: 2.6006  data: 2.2687  max mem: 2889
# Epoch: [54]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1799  data: 1.8361  max mem: 2889
# Epoch: [54]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1741  data: 1.8281  max mem: 2889
# Epoch: [54] Total time: 0:00:48 (2.1888 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0196 (0.0196)  evaluator_time: 0.0252 (0.0252)  time: 0.1110  data: 0.0627  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0193 (0.0196)  evaluator_time: 0.0211 (0.0269)  time: 0.1105  data: 0.0592  max mem: 2889
# Test: Total time: 0:00:04 (0.1111 s / it)
# Averaged stats: model_time: 0.0193 (0.0196)  evaluator_time: 0.0211 (0.0269)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.317
# Epoch: [55]  [ 0/22]  eta: 0:00:37  lr: 0.003000  time: 1.7030  data: 1.4201  max mem: 2889
# Epoch: [55]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0966  data: 1.7607  max mem: 2889
# Epoch: [55]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1120  data: 1.7699  max mem: 2889
# Epoch: [55] Total time: 0:00:46 (2.0922 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0193 (0.0193)  evaluator_time: 0.0237 (0.0237)  time: 0.1090  data: 0.0624  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0196 (0.0196)  evaluator_time: 0.0199 (0.0267)  time: 0.1080  data: 0.0564  max mem: 2889
# Test: Total time: 0:00:04 (0.1087 s / it)
# Averaged stats: model_time: 0.0196 (0.0196)  evaluator_time: 0.0199 (0.0267)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.342
# Epoch: [56]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9440  data: 1.6249  max mem: 2889
# Epoch: [56]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1673  data: 1.8138  max mem: 2889
# Epoch: [56]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1367  data: 1.7855  max mem: 2889
# Epoch: [56] Total time: 0:00:47 (2.1488 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0263 (0.0263)  time: 0.1117  data: 0.0615  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0197 (0.0197)  evaluator_time: 0.0196 (0.0276)  time: 0.1100  data: 0.0565  max mem: 2889
# Test: Total time: 0:00:04 (0.1096 s / it)
# Averaged stats: model_time: 0.0197 (0.0197)  evaluator_time: 0.0196 (0.0276)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.359
# Epoch: [57]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0426  data: 1.6597  max mem: 2889
# Epoch: [57]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1349  data: 1.7854  max mem: 2889
# Epoch: [57]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1373  data: 1.7871  max mem: 2889
# Epoch: [57] Total time: 0:00:47 (2.1473 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0265 (0.0265)  time: 0.1118  data: 0.0614  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0199 (0.0200)  evaluator_time: 0.0195 (0.0269)  time: 0.1089  data: 0.0566  max mem: 2889
# Test: Total time: 0:00:04 (0.1092 s / it)
# Averaged stats: model_time: 0.0199 (0.0200)  evaluator_time: 0.0195 (0.0269)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.345
# Epoch: [58]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2675  data: 1.7615  max mem: 2889
# Epoch: [58]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2194  data: 1.8417  max mem: 2889
# Epoch: [58]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2261  data: 1.8489  max mem: 2889
# Epoch: [58] Total time: 0:00:48 (2.2145 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0196 (0.0196)  evaluator_time: 0.0245 (0.0245)  time: 0.1094  data: 0.0617  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0198 (0.0198)  evaluator_time: 0.0201 (0.0294)  time: 0.1073  data: 0.0566  max mem: 2889
# Test: Total time: 0:00:04 (0.1118 s / it)
# Averaged stats: model_time: 0.0198 (0.0198)  evaluator_time: 0.0201 (0.0294)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.343
# Epoch: [59]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1472  data: 1.7722  max mem: 2889
# Epoch: [59]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1901  data: 1.8197  max mem: 2889
# Epoch: [59]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1793  data: 1.8081  max mem: 2889
# Epoch: [59] Total time: 0:00:48 (2.1891 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0198 (0.0198)  evaluator_time: 0.0246 (0.0246)  time: 0.1091  data: 0.0610  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0196 (0.0197)  evaluator_time: 0.0191 (0.0273)  time: 0.1093  data: 0.0565  max mem: 2889
# Test: Total time: 0:00:04 (0.1092 s / it)
# Averaged stats: model_time: 0.0196 (0.0197)  evaluator_time: 0.0191 (0.0273)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.368
# Epoch: [60]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9833  data: 1.6422  max mem: 2889
# Epoch: [60]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1111  data: 1.7601  max mem: 2889
# Epoch: [60]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1121  data: 1.7584  max mem: 2889
# Epoch: [60] Total time: 0:00:46 (2.1065 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0199 (0.0199)  evaluator_time: 0.0233 (0.0233)  time: 0.1083  data: 0.0615  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0196 (0.0197)  evaluator_time: 0.0196 (0.0269)  time: 0.1091  data: 0.0564  max mem: 2889
# Test: Total time: 0:00:04 (0.1088 s / it)
# Averaged stats: model_time: 0.0196 (0.0197)  evaluator_time: 0.0196 (0.0269)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.358
# Epoch: [61]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4620  data: 1.9400  max mem: 2889
# Epoch: [61]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1785  data: 1.8235  max mem: 2889
# Epoch: [61]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1602  data: 1.8078  max mem: 2889
# Epoch: [61] Total time: 0:00:48 (2.1865 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0204 (0.0204)  evaluator_time: 0.0231 (0.0231)  time: 0.1090  data: 0.0617  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0196 (0.0197)  evaluator_time: 0.0190 (0.0266)  time: 0.1086  data: 0.0570  max mem: 2889
# Test: Total time: 0:00:04 (0.1088 s / it)
# Averaged stats: model_time: 0.0196 (0.0197)  evaluator_time: 0.0190 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.354
# Epoch: [62]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0816  data: 1.5579  max mem: 2889
# Epoch: [62]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2088  data: 1.8630  max mem: 2889
# Epoch: [62]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2083  data: 1.8596  max mem: 2889
# Epoch: [62] Total time: 0:00:48 (2.1874 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0212 (0.0212)  evaluator_time: 0.0242 (0.0242)  time: 0.1110  data: 0.0619  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0195 (0.0197)  evaluator_time: 0.0196 (0.0266)  time: 0.1093  data: 0.0579  max mem: 2889
# Test: Total time: 0:00:04 (0.1094 s / it)
# Averaged stats: model_time: 0.0195 (0.0197)  evaluator_time: 0.0196 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.351
# Epoch: [63]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4307  data: 2.1190  max mem: 2889
# Epoch: [63]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0628  data: 1.7254  max mem: 2889
# Epoch: [63]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0429  data: 1.7091  max mem: 2889
# Epoch: [63] Total time: 0:00:45 (2.0690 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0197 (0.0197)  evaluator_time: 0.0251 (0.0251)  time: 0.1098  data: 0.0613  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0203 (0.0203)  evaluator_time: 0.0201 (0.0273)  time: 0.1117  data: 0.0583  max mem: 2889
# Test: Total time: 0:00:04 (0.1111 s / it)
# Averaged stats: model_time: 0.0203 (0.0203)  evaluator_time: 0.0201 (0.0273)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.369
# Epoch: [64]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8620  data: 1.5397  max mem: 2889
# Epoch: [64]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1433  data: 1.8008  max mem: 2889
# Epoch: [64]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1175  data: 1.7782  max mem: 2889
# Epoch: [64] Total time: 0:00:46 (2.1245 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0229 (0.0229)  time: 0.1101  data: 0.0631  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0198 (0.0198)  evaluator_time: 0.0192 (0.0265)  time: 0.1095  data: 0.0579  max mem: 2889
# Test: Total time: 0:00:04 (0.1099 s / it)
# Averaged stats: model_time: 0.0198 (0.0198)  evaluator_time: 0.0192 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.358
# Epoch: [65]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9980  data: 1.6396  max mem: 2889
# Epoch: [65]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2292  data: 1.8763  max mem: 2889
# Epoch: [65]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2085  data: 1.8583  max mem: 2889
# Epoch: [65] Total time: 0:00:48 (2.1981 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0201 (0.0201)  evaluator_time: 0.0253 (0.0253)  time: 0.1115  data: 0.0624  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0200 (0.0202)  evaluator_time: 0.0200 (0.0310)  time: 0.1107  data: 0.0568  max mem: 2889
# Test: Total time: 0:00:04 (0.1142 s / it)
# Averaged stats: model_time: 0.0200 (0.0202)  evaluator_time: 0.0200 (0.0310)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.378
# Epoch: [66]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1408  data: 1.7416  max mem: 2889
# Epoch: [66]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2026  data: 1.8450  max mem: 2889
# Epoch: [66]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2219  data: 1.8661  max mem: 2889
# Epoch: [66] Total time: 0:00:48 (2.2254 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0201 (0.0201)  evaluator_time: 0.0245 (0.0245)  time: 0.1098  data: 0.0615  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0195 (0.0197)  evaluator_time: 0.0191 (0.0264)  time: 0.1076  data: 0.0561  max mem: 2889
# Test: Total time: 0:00:04 (0.1087 s / it)
# Averaged stats: model_time: 0.0195 (0.0197)  evaluator_time: 0.0191 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.353
# Epoch: [67]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1841  data: 1.8330  max mem: 2889
# Epoch: [67]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2333  data: 1.8900  max mem: 2889
# Epoch: [67]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2428  data: 1.8961  max mem: 2889
# Epoch: [67] Total time: 0:00:49 (2.2348 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0205 (0.0205)  evaluator_time: 0.0236 (0.0236)  time: 0.1097  data: 0.0619  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0199 (0.0200)  evaluator_time: 0.0201 (0.0265)  time: 0.1085  data: 0.0566  max mem: 2889
# Test: Total time: 0:00:04 (0.1099 s / it)
# Averaged stats: model_time: 0.0199 (0.0200)  evaluator_time: 0.0201 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.141
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.356
# Epoch: [68]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0511  data: 1.6792  max mem: 2889
# Epoch: [68]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2100  data: 1.8648  max mem: 2889
# Epoch: [68]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2178  data: 1.8690  max mem: 2889
# Epoch: [68] Total time: 0:00:48 (2.2069 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0202 (0.0202)  evaluator_time: 0.0230 (0.0230)  time: 0.1084  data: 0.0615  max mem: 2889
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0196 (0.0199)  evaluator_time: 0.0197 (0.0263)  time: 0.1076  data: 0.0564  max mem: 2889
# Test: Total time: 0:00:04 (0.1084 s / it)
# Averaged stats: model_time: 0.0196 (0.0199)  evaluator_time: 0.0197 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.362
# Epoch: [69]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4329  data: 1.9950  max mem: 2889
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d5bf73ea672b> in <cell line: 4>()
#       3 # Continuar el entrenamiento por otras 50 épocas
#       4 for epoch in range(50, 100):  # Cambiar el rango para empezar en la época 50
# ----> 5     train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
#       6     lr_scheduler.step()  # El scheduler seguirá ajustando la tasa en las épocas definidas
#       7     ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
#
# <ipython-input-8-9dffbf636685> in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      22         #Lista de diccionarios, y cada diccionario en esa lista contiene los targets (objetivos) correspondientes a una imagen
#      23         #específica en el dataset.
# ---> 24         loss_dict = model(images, targets) #Si el modelo esta entrenandose devuelve la loss
#      25         #with torch.cuda.amp.autocast():
#      26         #  loss_dict = model(images, targets)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /content/drive/MyDrive/Academico/TD8 personal /ssd.py in forward(self, images, targets)
#     353
#     354         # create the set of anchors
# --> 355         anchors = self.anchor_generator(images, features)
#     356
#     357         losses = {}
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/anchor_utils.py in forward(self, image_list, feature_maps)
#     252         dtype, device = feature_maps[0].dtype, feature_maps[0].device
#     253         default_boxes = self._grid_default_boxes(grid_sizes, image_size, dtype=dtype)
# --> 254         default_boxes = default_boxes.to(device)
#     255
#     256         dboxes = []
#
# KeyboardInterrupt:

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD300_ConvNext.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.11780624083251919
