# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt
import sys
import pandas as pd
from collections import defaultdict
import json
import random
from torch.utils.data import Dataset
import numpy as np
import torchvision.models.detection as detection
from torch.utils.data import DataLoader
import torch.utils
import torch
from PIL import Image as read_image
from torchvision.io import read_image
from torchvision.transforms import v2
from transforms import RandomPhotometricDistort, RandomZoomOut, RandomIoUCrop, RandomHorizontalFlip,RandomVerticalFlip ,ToTensor, Compose
from torchvision.transforms.functional import convert_image_dtype

# %%
drive.mount('/content/drive')
path_base = '/content/drive/MyDrive/Academico/TD8 personal '
sys.path.append(path_base)
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
train_file = path_base + '/classificationDownload (1)/train.csv'
test_file = path_base + '/classificationDownload (1)/test.csv'
classification_file = path_base + '/classificationDownload (1)/classifications.csv'

train_images = pd.read_csv(train_file)['image_filename'].tolist()
test_images = pd.read_csv(test_file)['image_filename'].tolist()


classification_data = pd.read_csv(classification_file)

train_data = classification_data[classification_data['image_filename'].isin(train_images)]
test_data = classification_data[classification_data['image_filename'].isin(test_images)]




def get_transform(train=True):
    transforms = []
    if train:
        transforms.append(RandomPhotometricDistort())
        transforms.append(RandomZoomOut(fill=list((207., 202., 205.))))
        transforms.append(RandomHorizontalFlip(p=0.5))
        transforms.append(RandomVerticalFlip(p=0.5))

    transforms.append(v2.ToDtype(torch.float, scale=True))
    return Compose(transforms)


def group_detections(data):
    grouped_data = {}
    for _, row in data.iterrows():
        image_name = row['image_filename']
        if image_name not in grouped_data:
            grouped_data[image_name] = {
                'image_filename': image_name,
                'image_id': row['image_id'],
                'image_doi': row['image_doi'],
                'classifications': []
            }

        grouped_data[image_name]['classifications'].append({
            'nucleus_x': row['nucleus_x'],
            'nucleus_y': row['nucleus_y'],
            'bethesda_system': row['bethesda_system'],
            'cell_id': row['cell_id']
        })
    return list(grouped_data.values())


train_data_grouped = group_detections(train_data)
test_data_grouped = group_detections(test_data)


train_counts = defaultdict(int)
test_counts = defaultdict(int)

for item in train_data_grouped:
    for classification in item['classifications']:
        train_counts[classification['bethesda_system']] += 1

for item in test_data_grouped:
    for classification in item['classifications']:
        test_counts[classification['bethesda_system']] += 1

class PAPDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        self.label_map = {
            "SCC": 1,
            "HSIL": 2,
            "LSIL": 3,
            "ASC-H": 4,
            "ASC-US": 5,
            "Negative for intraepithelial lesion": 6
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        img = read_image(path_base + '/Imagenes/' + item['image_filename'])

        image_doi = item['image_doi']
        image_id = item['image_id']
        boxes = []
        labels = []
        for classification in item['classifications']:
            nucleus_x = classification['nucleus_x']
            nucleus_y = classification['nucleus_y']
            x_min = nucleus_x - 50
            y_min = nucleus_y - 50
            x_max = nucleus_x + 50
            y_max = nucleus_y + 50
            boxes.append([x_min, y_min, x_max, y_max])
            labels.append(self.label_map[classification['bethesda_system']])


        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {
            "boxes": boxes,
            "labels": labels,
            "area": area,
            "image_id": image_id
        }

        num_objs = boxes.shape[0]
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)

        if self.transform:
            img, target = self.transform(img, target)
        return img, target



train_dataset = PAPDataset(train_data_grouped, transform=get_transform(train=True))
test_dataset = PAPDataset(test_data_grouped, transform=get_transform(train=False))


print("Training Counts:", dict(train_counts))
print("Test Counts:", dict(test_counts))
print(f"Training Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
# Out:
# Training Counts: {'SCC': 145, 'Negative for intraepithelial lesion': 6043, 'LSIL': 1221, 'HSIL': 1588, 'ASC-H': 808, 'ASC-US': 550}
# Test Counts: {'ASC-H': 117, 'Negative for intraepithelial lesion': 736, 'ASC-US': 56, 'LSIL': 139, 'SCC': 16, 'HSIL': 115}
# Training Dataset Size: 360
# Test Dataset Size: 40

# %%
from ssd import SSDFeatureExtractorResNet_Upgraded, ssd512_resnet50_Upgraded
model = ssd512_resnet50_Upgraded(pretrained = False, load = True)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /content/drive/MyDrive/Academico/TD8 personal /ssd.py:1837: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/content/drive/MyDrive/Academico/TD8 personal ' + '/pesos_modelos/Resnet50_SipakMed') #Cargo los pesos de Resnet 50 pre entrenado en SipakMed

# %%
from ssd import SSDClassificationHead, SSDRegressionHead
num_classes = 6+1  # Ejemplo con 6  clases + 1 clase background


in_channels = [8192, 3584, 3584, 3328, 256, 256]
num_anchors = [4, 6, 6, 6, 4, 4]
model.head.classification_head = SSDClassificationHead(in_channels, num_anchors, num_classes)

# %%
def collate_fn(batch):
    return tuple(zip(*batch))



batch_size = 16

train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_batch_sampler = train_batch_sampler = torch.utils.data.BatchSampler(
            train_sampler, batch_size, drop_last=True)


data_loader = torch.utils.data.DataLoader(
        train_dataset, batch_sampler=train_batch_sampler,
        collate_fn=collate_fn)


data_loader_test = torch.utils.data.DataLoader(
        test_dataset, batch_size=1,
        sampler=test_sampler,
        collate_fn=collate_fn)

# %%
import math
from utils import MetricLogger, warmup_lr_scheduler, SmoothedValue
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if not isinstance(v, int) else v for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()
        print(loss_value)

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            break

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger
# Out:
# '\nMetricLogger te ayuda a monitorear métricas a lo largo del entrenamiento.\nWarmup Learning Rate Scheduler te permite empezar el entrenamiento de manera más suave ajustando gradualmente la tasa de aprendizaje durante las primeras iteraciones para evitar inestabilidad.\n'

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !pip install -U pycocotools
# Out:
# --2024-11-19 18:00:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-11-19 18:00:17 (61.2 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2024-11-19 18:00:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2024-11-19 18:00:17 (101 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2024-11-19 18:00:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2024-11-19 18:00:17 (107 MB/s) - ‘coco_utils.py’ saved [8397/8397]
#
# --2024-11-19 18:00:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2024-11-19 18:00:18 (101 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2024-11-19 18:00:18--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.002s
#
# 2024-11-19 18:00:18 (12.5 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from torchvision.datasets import VOCDetection
from torchvision.transforms import Compose, ToTensor, RandomHorizontalFlip, Normalize
from engine import evaluate
import time
import datetime


params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr = 0.003, momentum=0.9, weight_decay = 0.0005)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80,110], gamma=0.1)
model.to(device)
best_ap = 0.0

print("Start training")
start_time = time.time()
for epoch in range(50):
  train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
  lr_scheduler.step()
  ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
  if ap > best_ap:
    best_ap = ap
    best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# Start training
# 25.11927032470703
# Epoch: [0]  [ 0/22]  eta: 0:03:45  lr: 0.000146  time: 10.2313  data: 6.6201  max mem: 11273
# 26.41074562072754
# 22.71268653869629
# 18.994705200195312
# 13.703094482421875
# 16.671476364135742
# 14.634176254272461
# 11.086359024047852
# 10.561686515808105
# 10.792121887207031
# 9.97930908203125
# 8.419669151306152
# 8.797271728515625
# 8.854043960571289
# 9.148704528808594
# 8.926671028137207
# 8.093688011169434
# 7.526572227478027
# 8.723756790161133
# 7.850994110107422
# 7.521486282348633
# Epoch: [0]  [20/22]  eta: 0:00:12  lr: 0.003000  time: 6.1743  data: 5.8091  max mem: 12463
# 8.218050003051758
# Epoch: [0]  [21/22]  eta: 0:00:06  lr: 0.003000  time: 6.0990  data: 5.7386  max mem: 12463
# Epoch: [0] Total time: 0:02:19 (6.3192 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:16  model_time: 0.3129 (0.3129)  evaluator_time: 0.0303 (0.0303)  time: 0.4096  data: 0.0627  max mem: 12463
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0242)  evaluator_time: 0.0192 (0.0377)  time: 0.1147  data: 0.0585  max mem: 12463
# Test: Total time: 0:00:05 (0.1254 s / it)
# Averaged stats: model_time: 0.0166 (0.0242)  evaluator_time: 0.0192 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.046
# 8.184814453125
# Epoch: [1]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3277  data: 1.9084  max mem: 12463
# 6.229785919189453
# 6.600788116455078
# 6.448779106140137
# 6.526622295379639
# 6.009245872497559
# 5.486630439758301
# 5.653990268707275
# 6.327110290527344
# 6.107280254364014
# 5.561275482177734
# 6.113076686859131
# 5.076103210449219
# 5.918334007263184
# 5.576675891876221
# 5.584211349487305
# 5.2928900718688965
# 5.034699440002441
# 4.9701151847839355
# 5.099125862121582
# 4.784603118896484
# Epoch: [1]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2639  data: 1.9308  max mem: 12463
# 4.7665252685546875
# Epoch: [1]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2535  data: 1.9217  max mem: 12463
# Epoch: [1] Total time: 0:00:49 (2.2660 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0432 (0.0432)  evaluator_time: 0.0302 (0.0302)  time: 0.1376  data: 0.0606  max mem: 12463
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0174)  evaluator_time: 0.0236 (0.0412)  time: 0.1162  data: 0.0574  max mem: 12463
# Test: Total time: 0:00:04 (0.1213 s / it)
# Averaged stats: model_time: 0.0165 (0.0174)  evaluator_time: 0.0236 (0.0412)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.237
# 4.995905876159668
# Epoch: [2]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2894  data: 1.8972  max mem: 12463
# 4.642168045043945
# 4.241235256195068
# 4.419519424438477
# 4.726846218109131
# 4.231203556060791
# 4.7046732902526855
# 4.950325965881348
# 4.497280120849609
# 3.895493507385254
# 4.498860836029053
# 4.485996246337891
# 5.163661956787109
# 4.019710540771484
# 4.283294677734375
# 4.364956378936768
# 4.571017742156982
# 4.374750137329102
# 4.123625755310059
# 3.8786089420318604
# 3.776479721069336
# Epoch: [2]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2064  data: 1.8632  max mem: 12463
# 4.06016206741333
# Epoch: [2]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1774  data: 1.8343  max mem: 12463
# Epoch: [2] Total time: 0:00:48 (2.2087 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0276 (0.0276)  time: 0.1100  data: 0.0615  max mem: 12463
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0167)  evaluator_time: 0.0235 (0.0331)  time: 0.1108  data: 0.0567  max mem: 12463
# Test: Total time: 0:00:04 (0.1130 s / it)
# Averaged stats: model_time: 0.0166 (0.0167)  evaluator_time: 0.0235 (0.0331)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.174
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
# 4.206302165985107
# Epoch: [3]  [ 0/22]  eta: 0:00:39  lr: 0.003000  time: 1.7901  data: 1.4907  max mem: 12463
# 3.81935977935791
# 4.488150596618652
# 4.543430805206299
# 3.5719480514526367
# 4.137856483459473
# 4.151246547698975
# 3.8512563705444336
# 3.421693801879883
# 3.3573756217956543
# 3.3784916400909424
# 4.362697601318359
# 4.677232265472412
# 3.503174304962158
# 4.065973281860352
# 4.663276672363281
# 4.196365833282471
# 4.733584403991699
# 3.9021494388580322
# 3.99597430229187
# 3.7766168117523193
# Epoch: [3]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1440  data: 1.7738  max mem: 12753
# 3.8367645740509033
# Epoch: [3]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1302  data: 1.7618  max mem: 12753
# Epoch: [3] Total time: 0:00:46 (2.1262 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0182 (0.0182)  evaluator_time: 0.0282 (0.0282)  time: 0.1127  data: 0.0625  max mem: 12753
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0169)  evaluator_time: 0.0226 (0.0341)  time: 0.1112  data: 0.0569  max mem: 12753
# Test: Total time: 0:00:04 (0.1145 s / it)
# Averaged stats: model_time: 0.0167 (0.0169)  evaluator_time: 0.0226 (0.0341)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.341
# 3.6035256385803223
# Epoch: [4]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3641  data: 1.9641  max mem: 12753
# 3.739410400390625
# 4.176570892333984
# 3.472078800201416
# 3.3724122047424316
# 3.9729671478271484
# 4.282492637634277
# 4.011638641357422
# 3.362701177597046
# 3.8951797485351562
# 3.703627824783325
# 4.461546897888184
# 3.875865936279297
# 3.691624164581299
# 3.4344656467437744
# 4.5879740715026855
# 4.059443473815918
# 3.513789653778076
# 3.626178026199341
# 3.2624902725219727
# 4.424014091491699
# Epoch: [4]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0792  data: 1.7396  max mem: 12753
# 3.7118053436279297
# Epoch: [4]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0756  data: 1.7328  max mem: 12753
# Epoch: [4] Total time: 0:00:46 (2.0984 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0176 (0.0176)  evaluator_time: 0.0269 (0.0269)  time: 0.1108  data: 0.0625  max mem: 12753
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0168)  evaluator_time: 0.0220 (0.0354)  time: 0.1134  data: 0.0563  max mem: 12753
# Test: Total time: 0:00:04 (0.1154 s / it)
# Averaged stats: model_time: 0.0166 (0.0168)  evaluator_time: 0.0220 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.358
# 3.3964731693267822
# Epoch: [5]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1583  data: 1.8852  max mem: 12753
# 3.3496625423431396
# 3.8757288455963135
# 3.504336357116699
# 3.6238136291503906
# 4.256033897399902
# 2.812499761581421
# 3.595705986022949
# 3.3822505474090576
# 3.7264440059661865
# 3.9017348289489746
# 3.276139736175537
# 3.318692684173584
# 3.767458200454712
# 3.6998050212860107
# 3.5459864139556885
# 3.545459032058716
# 3.964888095855713
# 3.6530981063842773
# 4.040321350097656
# 3.6788859367370605
# Epoch: [5]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0635  data: 1.7656  max mem: 12753
# 3.3759989738464355
# Epoch: [5]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0546  data: 1.7515  max mem: 12753
# Epoch: [5] Total time: 0:00:45 (2.0652 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0171 (0.0171)  evaluator_time: 0.0221 (0.0221)  time: 0.1041  data: 0.0613  max mem: 12753
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0168)  evaluator_time: 0.0216 (0.0354)  time: 0.1151  data: 0.0565  max mem: 12753
# Test: Total time: 0:00:04 (0.1158 s / it)
# Averaged stats: model_time: 0.0164 (0.0168)  evaluator_time: 0.0216 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.313
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.386
# 3.5642857551574707
# Epoch: [6]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9734  data: 1.6451  max mem: 12753
# 3.1224286556243896
# 3.3071532249450684
# 3.3580753803253174
# 3.221457004547119
# 3.9667506217956543
# 3.3613617420196533
# 2.780766487121582
# 3.9121484756469727
# 3.5764269828796387
# 3.53202223777771
# 3.3469197750091553
# 4.072273254394531
# 3.087334394454956
# 3.358999490737915
# 3.0974373817443848
# 3.3084287643432617
# 3.737426996231079
# 3.616349220275879
# 3.5468759536743164
# 3.0108821392059326
# Epoch: [6]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1093  data: 1.7653  max mem: 12753
# 3.950836181640625
# Epoch: [6]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1116  data: 1.7654  max mem: 12753
# Epoch: [6] Total time: 0:00:46 (2.1061 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0168 (0.0168)  evaluator_time: 0.0250 (0.0250)  time: 0.1070  data: 0.0614  max mem: 12753
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0164)  evaluator_time: 0.0235 (0.0326)  time: 0.1103  data: 0.0559  max mem: 12753
# Test: Total time: 0:00:04 (0.1109 s / it)
# Averaged stats: model_time: 0.0162 (0.0164)  evaluator_time: 0.0235 (0.0326)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.380
# 3.3538870811462402
# Epoch: [7]  [ 0/22]  eta: 0:01:04  lr: 0.003000  time: 2.9331  data: 2.5074  max mem: 12753
# 2.9023337364196777
# 3.600264549255371
# 3.3208324909210205
# 3.3487749099731445
# 3.428143262863159
# 3.2267794609069824
# 3.3969566822052
# 3.8020002841949463
# 3.450164318084717
# 4.056891441345215
# 3.9010462760925293
# 3.5639429092407227
# 3.4720020294189453
# 3.831026077270508
# 2.902618408203125
# 3.4756839275360107
# 2.96466064453125
# 3.8547329902648926
# 3.5230236053466797
# 3.586820125579834
# Epoch: [7]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2613  data: 1.8914  max mem: 12753
# 2.9363410472869873
# Epoch: [7]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2529  data: 1.8875  max mem: 12753
# Epoch: [7] Total time: 0:00:50 (2.2938 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0288 (0.0288)  time: 0.1124  data: 0.0626  max mem: 12753
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0167)  evaluator_time: 0.0233 (0.0364)  time: 0.1130  data: 0.0569  max mem: 12753
# Test: Total time: 0:00:04 (0.1161 s / it)
# Averaged stats: model_time: 0.0163 (0.0167)  evaluator_time: 0.0233 (0.0364)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.350
# 3.1021921634674072
# Epoch: [8]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3310  data: 1.9504  max mem: 12753
# 3.3774309158325195
# 3.2733612060546875
# 3.1322710514068604
# 3.180265426635742
# 3.5783867835998535
# 4.660130023956299
# 3.5517141819000244
# 3.2317569255828857
# 3.1195664405822754
# 3.420760154724121
# 3.0664262771606445
# 3.3163504600524902
# 3.2420358657836914
# 3.4308061599731445
# 2.8149216175079346
# 3.1771507263183594
# 2.640488624572754
# 3.1797432899475098
# 4.152601718902588
# 3.6419880390167236
# Epoch: [8]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1244  data: 1.7817  max mem: 12885
# 2.938784122467041
# Epoch: [8]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1075  data: 1.7591  max mem: 12885
# Epoch: [8] Total time: 0:00:46 (2.1309 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0170 (0.0170)  evaluator_time: 0.0223 (0.0223)  time: 0.1041  data: 0.0612  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0241 (0.0383)  time: 0.1203  data: 0.0560  max mem: 12885
# Test: Total time: 0:00:04 (0.1170 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0241 (0.0383)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
# 3.26381778717041
# Epoch: [9]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.4051  data: 2.0272  max mem: 12885
# 3.443202495574951
# 2.641594886779785
# 2.8505029678344727
# 2.8988113403320312
# 2.848243474960327
# 3.2133126258850098
# 3.2369582653045654
# 3.096315383911133
# 2.8763387203216553
# 2.9096827507019043
# 3.665313720703125
# 2.3382062911987305
# 3.395981788635254
# 3.8637704849243164
# 3.299480438232422
# 3.2981481552124023
# 3.255624532699585
# 4.3456807136535645
# 3.614508867263794
# 3.39507794380188
# Epoch: [9]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1319  data: 1.7692  max mem: 12885
# 2.8584492206573486
# Epoch: [9]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1007  data: 1.7463  max mem: 12885
# Epoch: [9] Total time: 0:00:46 (2.1340 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0178 (0.0178)  evaluator_time: 0.0270 (0.0270)  time: 0.1111  data: 0.0624  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0170)  evaluator_time: 0.0218 (0.0352)  time: 0.1133  data: 0.0579  max mem: 12885
# Test: Total time: 0:00:04 (0.1158 s / it)
# Averaged stats: model_time: 0.0168 (0.0170)  evaluator_time: 0.0218 (0.0352)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
# 3.162827968597412
# Epoch: [10]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0908  data: 1.6657  max mem: 12885
# 3.608802080154419
# 2.888129472732544
# 3.5849905014038086
# 3.4102373123168945
# 2.964352607727051
# 3.069274425506592
# 2.8118624687194824
# 4.1419172286987305
# 3.189359426498413
# 3.1549878120422363
# 3.309457302093506
# 3.2464194297790527
# 3.607717990875244
# 3.320556640625
# 3.1558284759521484
# 3.264935255050659
# 3.4291069507598877
# 3.0586442947387695
# 2.871303081512451
# 3.017106771469116
# Epoch: [10]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1187  data: 1.7854  max mem: 12885
# 2.9569873809814453
# Epoch: [10]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1279  data: 1.7982  max mem: 12885
# Epoch: [10] Total time: 0:00:46 (2.1250 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0174 (0.0174)  evaluator_time: 0.0270 (0.0270)  time: 0.1097  data: 0.0615  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0168)  evaluator_time: 0.0218 (0.0352)  time: 0.1145  data: 0.0578  max mem: 12885
# Test: Total time: 0:00:04 (0.1154 s / it)
# Averaged stats: model_time: 0.0166 (0.0168)  evaluator_time: 0.0218 (0.0352)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.405
# 2.9452874660491943
# Epoch: [11]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.2012  data: 1.9116  max mem: 12885
# 3.308076858520508
# 2.82560658454895
# 3.13287353515625
# 2.6416704654693604
# 4.308532238006592
# 3.4128804206848145
# 2.6719534397125244
# 4.321110248565674
# 3.243657112121582
# 2.943549633026123
# 3.202763795852661
# 2.9259285926818848
# 3.6849827766418457
# 2.9937198162078857
# 3.3324077129364014
# 2.8546414375305176
# 2.89323091506958
# 3.0425004959106445
# 3.1744132041931152
# 2.6075029373168945
# Epoch: [11]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1227  data: 1.7674  max mem: 12885
# 3.073570728302002
# Epoch: [11]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0807  data: 1.7317  max mem: 12885
# Epoch: [11] Total time: 0:00:46 (2.1185 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0236 (0.0236)  time: 0.1059  data: 0.0613  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0168)  evaluator_time: 0.0234 (0.0351)  time: 0.1157  data: 0.0582  max mem: 12885
# Test: Total time: 0:00:04 (0.1150 s / it)
# Averaged stats: model_time: 0.0167 (0.0168)  evaluator_time: 0.0234 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
# 3.0670149326324463
# Epoch: [12]  [ 0/22]  eta: 0:00:40  lr: 0.003000  time: 1.8532  data: 1.5532  max mem: 12885
# 3.089055061340332
# 3.077956438064575
# 2.507416248321533
# 4.097172737121582
# 2.3889832496643066
# 2.628422260284424
# 3.7987382411956787
# 3.4210474491119385
# 2.5903894901275635
# 3.062579393386841
# 3.864222526550293
# 2.9925789833068848
# 2.5130696296691895
# 3.290757179260254
# 3.044753074645996
# 3.3087522983551025
# 3.452190399169922
# 2.749818801879883
# 3.054399251937866
# 2.6492629051208496
# Epoch: [12]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0715  data: 1.7370  max mem: 12885
# 2.6866555213928223
# Epoch: [12]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0582  data: 1.7241  max mem: 12885
# Epoch: [12] Total time: 0:00:45 (2.0573 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0288 (0.0288)  time: 0.1127  data: 0.0628  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0170)  evaluator_time: 0.0220 (0.0349)  time: 0.1139  data: 0.0566  max mem: 12885
# Test: Total time: 0:00:04 (0.1155 s / it)
# Averaged stats: model_time: 0.0166 (0.0170)  evaluator_time: 0.0220 (0.0349)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.471
# 2.5912535190582275
# Epoch: [13]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4598  data: 2.1528  max mem: 12885
# 2.6802244186401367
# 2.9009928703308105
# 2.5631799697875977
# 3.867138385772705
# 2.655507802963257
# 2.9884626865386963
# 3.8417789936065674
# 3.3566596508026123
# 3.075862407684326
# 3.4752862453460693
# 2.644909381866455
# 3.130594253540039
# 2.374316692352295
# 4.026074409484863
# 2.7426934242248535
# 2.7607297897338867
# 2.849480390548706
# 3.150743007659912
# 3.342689037322998
# 3.324378490447998
# Epoch: [13]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1339  data: 1.7950  max mem: 12885
# 3.60516095161438
# Epoch: [13]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1489  data: 1.8071  max mem: 12885
# Epoch: [13] Total time: 0:00:47 (2.1610 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0171 (0.0171)  evaluator_time: 0.0213 (0.0213)  time: 0.1029  data: 0.0609  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0223 (0.0342)  time: 0.1144  data: 0.0563  max mem: 12885
# Test: Total time: 0:00:04 (0.1135 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0223 (0.0342)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
# 3.3373830318450928
# Epoch: [14]  [ 0/22]  eta: 0:00:59  lr: 0.003000  time: 2.7092  data: 2.2958  max mem: 12885
# 2.716236114501953
# 2.981168746948242
# 3.199629783630371
# 3.2175819873809814
# 2.951176166534424
# 3.1932904720306396
# 3.0228443145751953
# 3.1799910068511963
# 2.648984909057617
# 2.565911293029785
# 2.5725033283233643
# 2.6803832054138184
# 3.282928705215454
# 2.8774681091308594
# 2.7386040687561035
# 3.721491575241089
# 3.3517701625823975
# 2.6824920177459717
# 2.7890241146087646
# 2.924254894256592
# Epoch: [14]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1989  data: 1.8373  max mem: 12885
# 3.4394161701202393
# Epoch: [14]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2022  data: 1.8389  max mem: 12885
# Epoch: [14] Total time: 0:00:48 (2.2251 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0178 (0.0178)  evaluator_time: 0.0215 (0.0215)  time: 0.1057  data: 0.0627  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0169)  evaluator_time: 0.0195 (0.0310)  time: 0.1130  data: 0.0591  max mem: 12885
# Test: Total time: 0:00:04 (0.1123 s / it)
# Averaged stats: model_time: 0.0163 (0.0169)  evaluator_time: 0.0195 (0.0310)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.463
# 2.7034122943878174
# Epoch: [15]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4625  data: 2.0608  max mem: 12885
# 2.374019145965576
# 2.7956619262695312
# 2.6049070358276367
# 2.678101062774658
# 2.4565601348876953
# 2.6559853553771973
# 2.65871524810791
# 3.2571096420288086
# 2.470430850982666
# 2.6779112815856934
# 2.8292574882507324
# 3.5505588054656982
# 2.7170753479003906
# 2.796376943588257
# 3.384392023086548
# 2.646796703338623
# 3.2913758754730225
# 3.0767476558685303
# 2.8488543033599854
# 3.388725757598877
# Epoch: [15]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2431  data: 1.8919  max mem: 12885
# 3.402510643005371
# Epoch: [15]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2372  data: 1.8839  max mem: 12885
# Epoch: [15] Total time: 0:00:49 (2.2389 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0168 (0.0168)  evaluator_time: 0.0205 (0.0205)  time: 0.1201  data: 0.0792  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0210 (0.0330)  time: 0.1125  data: 0.0565  max mem: 12885
# Test: Total time: 0:00:04 (0.1126 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0210 (0.0330)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# 2.731951951980591
# Epoch: [16]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2378  data: 1.9725  max mem: 12885
# 3.294498920440674
# 2.4829885959625244
# 2.635993480682373
# 2.832024574279785
# 2.4145781993865967
# 2.791837215423584
# 2.7947826385498047
# 2.960057258605957
# 3.012737512588501
# 2.521310806274414
# 3.2531282901763916
# 2.7484750747680664
# 3.055172920227051
# 2.8720669746398926
# 3.009650468826294
# 2.310713529586792
# 2.974541187286377
# 2.6365649700164795
# 2.528036594390869
# 3.833578586578369
# Epoch: [16]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1740  data: 1.8234  max mem: 12885
# 3.0184807777404785
# Epoch: [16]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1658  data: 1.8175  max mem: 12885
# Epoch: [16] Total time: 0:00:47 (2.1814 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0427 (0.0427)  evaluator_time: 0.0282 (0.0282)  time: 0.1364  data: 0.0618  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0173)  evaluator_time: 0.0236 (0.0351)  time: 0.1131  data: 0.0564  max mem: 12885
# Test: Total time: 0:00:04 (0.1147 s / it)
# Averaged stats: model_time: 0.0166 (0.0173)  evaluator_time: 0.0236 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.412
# 2.8052186965942383
# Epoch: [17]  [ 0/22]  eta: 0:00:55  lr: 0.003000  time: 2.5034  data: 2.0513  max mem: 12885
# 2.780726671218872
# 3.233729124069214
# 3.3619537353515625
# 3.2865524291992188
# 2.884485960006714
# 3.083125591278076
# 2.611389636993408
# 2.5297176837921143
# 3.0407021045684814
# 2.751445770263672
# 2.6040685176849365
# 2.752056837081909
# 2.9526329040527344
# 2.297919988632202
# 2.8546040058135986
# 2.6175098419189453
# 3.126649856567383
# 2.5972697734832764
# 2.902982234954834
# 3.059109687805176
# Epoch: [17]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2716  data: 1.9151  max mem: 12885
# 2.763554334640503
# Epoch: [17]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2546  data: 1.8992  max mem: 12885
# Epoch: [17] Total time: 0:00:50 (2.2786 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0174 (0.0174)  evaluator_time: 0.0209 (0.0209)  time: 0.1036  data: 0.0616  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0169)  evaluator_time: 0.0246 (0.0354)  time: 0.1206  data: 0.0579  max mem: 12885
# Test: Total time: 0:00:04 (0.1157 s / it)
# Averaged stats: model_time: 0.0168 (0.0169)  evaluator_time: 0.0246 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# 2.37943434715271
# Epoch: [18]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0076  data: 1.6700  max mem: 12885
# 3.0428900718688965
# 2.4772841930389404
# 2.514145851135254
# 2.9934468269348145
# 3.438455820083618
# 2.949467420578003
# 2.7053184509277344
# 2.8480498790740967
# 3.1280617713928223
# 3.2179040908813477
# 3.1864073276519775
# 3.105529308319092
# 3.2968029975891113
# 3.0398435592651367
# 3.4015886783599854
# 3.0616743564605713
# 2.831810474395752
# 3.8870768547058105
# 3.514965534210205
# 2.483241081237793
# Epoch: [18]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1867  data: 1.8314  max mem: 12885
# 3.308687210083008
# Epoch: [18]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2097  data: 1.8532  max mem: 12885
# Epoch: [18] Total time: 0:00:48 (2.2115 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0212 (0.0212)  time: 0.1046  data: 0.0623  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0168)  evaluator_time: 0.0250 (0.0323)  time: 0.1121  data: 0.0570  max mem: 12885
# Test: Total time: 0:00:04 (0.1120 s / it)
# Averaged stats: model_time: 0.0164 (0.0168)  evaluator_time: 0.0250 (0.0323)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# 3.583266496658325
# Epoch: [19]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3531  data: 1.8804  max mem: 12885
# 2.853450059890747
# 2.6387438774108887
# 2.7930102348327637
# 2.685879707336426
# 2.6443653106689453
# 3.068512439727783
# 2.7046453952789307
# 2.452077627182007
# 2.9087729454040527
# 2.3269197940826416
# 2.9236838817596436
# 2.984131097793579
# 2.836451530456543
# 2.8162460327148438
# 2.5047287940979004
# 3.4215095043182373
# 2.228590965270996
# 3.093602180480957
# 3.106959342956543
# 2.8722639083862305
# Epoch: [19]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2308  data: 1.8652  max mem: 12885
# 3.4759607315063477
# Epoch: [19]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2199  data: 1.8545  max mem: 12885
# Epoch: [19] Total time: 0:00:49 (2.2412 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0171 (0.0171)  evaluator_time: 0.0198 (0.0198)  time: 0.1027  data: 0.0620  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0169 (0.0171)  evaluator_time: 0.0252 (0.0342)  time: 0.1153  data: 0.0570  max mem: 12885
# Test: Total time: 0:00:04 (0.1144 s / it)
# Averaged stats: model_time: 0.0169 (0.0171)  evaluator_time: 0.0252 (0.0342)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# 2.8731675148010254
# Epoch: [20]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4096  data: 2.0628  max mem: 12885
# 2.7791848182678223
# 2.443268060684204
# 3.5228333473205566
# 2.685429096221924
# 2.3346920013427734
# 2.6528916358947754
# 2.9499688148498535
# 2.7772161960601807
# 2.8646178245544434
# 2.401071786880493
# 3.7323427200317383
# 3.286123752593994
# 2.777020215988159
# 3.017709732055664
# 2.9485063552856445
# 2.513533353805542
# 2.5064516067504883
# 3.121717929840088
# 2.6319916248321533
# 2.6460137367248535
# Epoch: [20]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2806  data: 1.9066  max mem: 12885
# 2.8679933547973633
# Epoch: [20]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2648  data: 1.8908  max mem: 12885
# Epoch: [20] Total time: 0:00:50 (2.2774 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0226 (0.0226)  time: 0.1051  data: 0.0615  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0168)  evaluator_time: 0.0199 (0.0315)  time: 0.1106  data: 0.0566  max mem: 12885
# Test: Total time: 0:00:04 (0.1110 s / it)
# Averaged stats: model_time: 0.0167 (0.0168)  evaluator_time: 0.0199 (0.0315)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.516
# 3.588122606277466
# Epoch: [21]  [ 0/22]  eta: 0:00:53  lr: 0.003000  time: 2.4292  data: 2.0420  max mem: 12885
# 2.83425235748291
# 3.2416529655456543
# 2.493330717086792
# 2.372072696685791
# 2.384164333343506
# 2.822232484817505
# 3.513307571411133
# 2.5680127143859863
# 2.696929454803467
# 2.3249406814575195
# 2.4454588890075684
# 2.617551565170288
# 2.8859896659851074
# 2.5819406509399414
# 3.6099131107330322
# 3.1199162006378174
# 3.511753559112549
# 2.604893684387207
# 2.8445651531219482
# 3.0387940406799316
# Epoch: [21]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.3317  data: 1.9671  max mem: 12885
# 2.6909053325653076
# Epoch: [21]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.3510  data: 1.9838  max mem: 12885
# Epoch: [21] Total time: 0:00:51 (2.3407 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0177 (0.0177)  evaluator_time: 0.0189 (0.0189)  time: 0.1019  data: 0.0616  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0167)  evaluator_time: 0.0230 (0.0339)  time: 0.1148  data: 0.0566  max mem: 12885
# Test: Total time: 0:00:04 (0.1133 s / it)
# Averaged stats: model_time: 0.0165 (0.0167)  evaluator_time: 0.0230 (0.0339)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
# 1.8900344371795654
# Epoch: [43]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1143  data: 1.7438  max mem: 12885
# 2.358613967895508
# 1.8149815797805786
# 2.2220866680145264
# 2.50557541847229
# 2.9269416332244873
# 3.2882790565490723
# 2.1615633964538574
# 1.8009850978851318
# 2.514528274536133
# 2.1561288833618164
# 2.6801624298095703
# 2.2231497764587402
# 2.7257494926452637
# 2.991171360015869
# 3.037086009979248
# 2.511692762374878
# 2.367069721221924
# 2.31870174407959
# 2.273777961730957
# 2.409282922744751
# Epoch: [43]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1383  data: 1.7996  max mem: 12885
# 2.366103410720825
# Epoch: [43]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1312  data: 1.7925  max mem: 12885
# Epoch: [43] Total time: 0:00:46 (2.1325 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0180 (0.0180)  evaluator_time: 0.0211 (0.0211)  time: 0.1049  data: 0.0621  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0171 (0.0169)  evaluator_time: 0.0243 (0.0318)  time: 0.1131  data: 0.0571  max mem: 12885
# Test: Total time: 0:00:04 (0.1116 s / it)
# Averaged stats: model_time: 0.0171 (0.0169)  evaluator_time: 0.0243 (0.0318)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
# 2.2639222145080566
# Epoch: [44]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0845  data: 1.7602  max mem: 12885
# 2.3311212062835693
# 2.238330364227295
# 2.893071174621582
# 2.122684955596924
# 2.6588706970214844
# 2.6214990615844727
# 2.2154381275177
# 2.119770050048828
# 2.036891460418701
# 1.756394863128662
# 2.143188953399658
# 1.9808872938156128
# 2.9228920936584473
# 2.421583890914917
# 2.7974014282226562
# 2.353724956512451
# 1.8831932544708252
# 2.666374683380127
# 2.56376576423645
# 2.3174915313720703
# Epoch: [44]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2072  data: 1.8579  max mem: 12885
# 2.204116106033325
# Epoch: [44]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2093  data: 1.8642  max mem: 12885
# Epoch: [44] Total time: 0:00:48 (2.2019 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0170 (0.0170)  evaluator_time: 0.0227 (0.0227)  time: 0.1050  data: 0.0616  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0169)  evaluator_time: 0.0179 (0.0302)  time: 0.1101  data: 0.0569  max mem: 12885
# Test: Total time: 0:00:04 (0.1096 s / it)
# Averaged stats: model_time: 0.0163 (0.0169)  evaluator_time: 0.0179 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.450
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
# 2.1787168979644775
# Epoch: [45]  [ 0/22]  eta: 0:00:58  lr: 0.003000  time: 2.6788  data: 2.2270  max mem: 12885
# 2.2371833324432373
# 2.1424245834350586
# 1.8254669904708862
# 2.0411174297332764
# 3.018862724304199
# 1.750718593597412
# 2.3654391765594482
# 2.800114393234253
# 2.845078945159912
# 2.0578038692474365
# 2.3088107109069824
# 2.995224952697754
# 2.304072380065918
# 2.9129679203033447
# 2.594405174255371
# 2.5237324237823486
# 2.9973528385162354
# 2.5344913005828857
# 2.4931368827819824
# 2.489508628845215
# Epoch: [45]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1007  data: 1.7591  max mem: 12885
# 2.1510109901428223
# Epoch: [45]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0831  data: 1.7347  max mem: 12885
# Epoch: [45] Total time: 0:00:46 (2.1245 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0169 (0.0169)  evaluator_time: 0.0180 (0.0180)  time: 0.1000  data: 0.0614  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0164)  evaluator_time: 0.0197 (0.0290)  time: 0.1088  data: 0.0567  max mem: 12885
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0163 (0.0164)  evaluator_time: 0.0197 (0.0290)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.434
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.541
# 2.4309792518615723
# Epoch: [46]  [ 0/22]  eta: 0:01:00  lr: 0.003000  time: 2.7583  data: 2.3106  max mem: 12885
# 2.5578198432922363
# 2.0936214923858643
# 2.4632060527801514
# 2.2862603664398193
# 2.512826919555664
# 2.297976493835449
# 2.344341278076172
# 2.2390079498291016
# 1.9281694889068604
# 2.2846832275390625
# 1.7192978858947754
# 2.636554479598999
# 2.196424961090088
# 2.328763246536255
# 2.262601852416992
# 2.8796122074127197
# 2.362639904022217
# 2.363466739654541
# 2.416506290435791
# 2.4957454204559326
# Epoch: [46]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1273  data: 1.7832  max mem: 12885
# 3.1312241554260254
# Epoch: [46]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1258  data: 1.7792  max mem: 12885
# Epoch: [46] Total time: 0:00:47 (2.1687 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0166 (0.0166)  evaluator_time: 0.0204 (0.0204)  time: 0.1032  data: 0.0625  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0168)  evaluator_time: 0.0213 (0.0298)  time: 0.1132  data: 0.0589  max mem: 12885
# Test: Total time: 0:00:04 (0.1103 s / it)
# Averaged stats: model_time: 0.0167 (0.0168)  evaluator_time: 0.0213 (0.0298)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.442
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.572
# 2.464324951171875
# Epoch: [47]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1828  data: 1.8986  max mem: 12885
# 2.7651939392089844
# 2.582515239715576
# 2.9314749240875244
# 2.7025680541992188
# 2.156116008758545
# 2.6614348888397217
# 1.909692406654358
# 2.4864501953125
# 2.4437808990478516
# 2.536768674850464
# 1.99601411819458
# 2.367680072784424
# 1.9895901679992676
# 2.298201560974121
# 2.2638347148895264
# 2.206408977508545
# 2.5049540996551514
# 2.1980490684509277
# 2.717905044555664
# 2.915992021560669
# Epoch: [47]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2006  data: 1.8572  max mem: 12885
# 1.9104161262512207
# Epoch: [47]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1840  data: 1.8427  max mem: 12885
# Epoch: [47] Total time: 0:00:48 (2.1883 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0166 (0.0166)  evaluator_time: 0.0280 (0.0280)  time: 0.1111  data: 0.0628  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0161 (0.0163)  evaluator_time: 0.0200 (0.0350)  time: 0.1135  data: 0.0563  max mem: 12885
# Test: Total time: 0:00:04 (0.1136 s / it)
# Averaged stats: model_time: 0.0161 (0.0163)  evaluator_time: 0.0200 (0.0350)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.529
# 2.5862293243408203
# Epoch: [48]  [ 0/22]  eta: 0:00:55  lr: 0.003000  time: 2.5345  data: 2.1777  max mem: 12885
# 2.0500333309173584
# 2.076155662536621
# 2.7142844200134277
# 2.4913814067840576
# 2.4170658588409424
# 2.4470503330230713
# 1.9683655500411987
# 2.112957239151001
# 2.2854208946228027
# 2.5340700149536133
# 2.2290241718292236
# 2.265505790710449
# 2.896414041519165
# 1.8909913301467896
# 2.324460506439209
# 2.822402238845825
# 2.365776300430298
# 2.2654078006744385
# 2.2115259170532227
# 2.2904164791107178
# Epoch: [48]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1625  data: 1.8142  max mem: 12885
# 2.5049729347229004
# Epoch: [48]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1493  data: 1.8038  max mem: 12885
# Epoch: [48] Total time: 0:00:47 (2.1776 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0171 (0.0171)  evaluator_time: 0.0165 (0.0165)  time: 0.1011  data: 0.0636  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0166)  evaluator_time: 0.0232 (0.0300)  time: 0.1091  data: 0.0559  max mem: 12885
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0163 (0.0166)  evaluator_time: 0.0232 (0.0300)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.581
# 2.4315176010131836
# Epoch: [49]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9751  data: 1.7579  max mem: 12885
# 2.2145986557006836
# 2.8224265575408936
# 1.9783376455307007
# 2.2148382663726807
# 2.3967599868774414
# 2.0938427448272705
# 2.1254563331604004
# 2.3157711029052734
# 1.9567581415176392
# 1.944989562034607
# 2.4103968143463135
# 2.58022403717041
# 2.8955373764038086
# 2.5577614307403564
# 2.2978155612945557
# 2.6674952507019043
# 2.0790133476257324
# 1.99802565574646
# 2.407670736312866
# 2.349564790725708
# Epoch: [49]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0930  data: 1.7553  max mem: 12885
# 2.623197317123413
# Epoch: [49]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0943  data: 1.7537  max mem: 12885
# Epoch: [49] Total time: 0:00:46 (2.0984 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0173 (0.0173)  evaluator_time: 0.0240 (0.0240)  time: 0.1060  data: 0.0611  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0167)  evaluator_time: 0.0221 (0.0382)  time: 0.1132  data: 0.0575  max mem: 12885
# Test: Total time: 0:00:04 (0.1177 s / it)
# Averaged stats: model_time: 0.0166 (0.0167)  evaluator_time: 0.0221 (0.0382)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.522
# Training time 0:47:42

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_ResNet_upgraded_finetuned.pth" )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.2680958707813942

# %%
start_time = time.time()


for epoch in range(50, 100):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# 2.295315742492676
# Epoch: [50]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3637  data: 2.0405  max mem: 12885
# 2.447047233581543
# 2.1442601680755615
# 2.8514864444732666
# 2.0185482501983643
# 2.2891268730163574
# 2.7347404956817627
# 2.1174933910369873
# 2.2802228927612305
# 2.542239189147949
# 2.097573757171631
# 2.104536533355713
# 2.873229742050171
# 2.5813021659851074
# 2.1490588188171387
# 2.6637954711914062
# 2.2578253746032715
# 2.1996803283691406
# 2.472625732421875
# 2.072277069091797
# 1.928715705871582
# Epoch: [50]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1893  data: 1.8573  max mem: 12885
# 2.287635564804077
# Epoch: [50]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1504  data: 1.8218  max mem: 12885
# Epoch: [50] Total time: 0:00:48 (2.2072 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0170 (0.0170)  evaluator_time: 0.0200 (0.0200)  time: 0.1021  data: 0.0615  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0165)  evaluator_time: 0.0192 (0.0295)  time: 0.1104  data: 0.0580  max mem: 12885
# Test: Total time: 0:00:04 (0.1093 s / it)
# Averaged stats: model_time: 0.0165 (0.0165)  evaluator_time: 0.0192 (0.0295)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.429
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.273
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
# 2.097977638244629
# Epoch: [51]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9563  data: 1.6184  max mem: 12885
# 2.376438617706299
# 2.4642252922058105
# 2.436723232269287
# 2.3794960975646973
# 2.6927011013031006
# 2.982036590576172
# 2.2261834144592285
# 2.3852250576019287
# 2.313101053237915
# 2.3735833168029785
# 1.957587480545044
# 2.0287961959838867
# 2.118187189102173
# 2.2353711128234863
# 2.2306742668151855
# 2.2424163818359375
# 2.5947816371917725
# 1.8873907327651978
# 2.2641589641571045
# 2.02416729927063
# Epoch: [51]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1335  data: 1.7626  max mem: 12885
# 2.2142558097839355
# Epoch: [51]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1511  data: 1.7838  max mem: 12885
# Epoch: [51] Total time: 0:00:47 (2.1391 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0170 (0.0170)  evaluator_time: 0.0188 (0.0188)  time: 0.1009  data: 0.0615  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0164)  evaluator_time: 0.0228 (0.0293)  time: 0.1097  data: 0.0563  max mem: 12885
# Test: Total time: 0:00:04 (0.1088 s / it)
# Averaged stats: model_time: 0.0163 (0.0164)  evaluator_time: 0.0228 (0.0293)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.453
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.584
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.584
# 2.231334924697876
# Epoch: [52]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1673  data: 1.8625  max mem: 12885
# 2.087254047393799
# 2.1489148139953613
# 2.25417160987854
# 2.042060375213623
# 2.8338327407836914
# 2.2771055698394775
# 2.317948818206787
# 2.6479082107543945
# 2.3256428241729736
# 2.9803779125213623
# 2.1166534423828125
# 2.096652030944824
# 2.1106815338134766
# 2.3356223106384277
# 2.5713372230529785
# 2.4185221195220947
# 1.9184632301330566
# 2.185448408126831
# 2.8581504821777344
# 2.0815868377685547
# Epoch: [52]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1676  data: 1.8346  max mem: 12885
# 1.8361971378326416
# Epoch: [52]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1738  data: 1.8412  max mem: 12885
# Epoch: [52] Total time: 0:00:47 (2.1683 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0190 (0.0190)  evaluator_time: 0.0163 (0.0163)  time: 0.1010  data: 0.0618  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0167)  evaluator_time: 0.0227 (0.0299)  time: 0.1103  data: 0.0564  max mem: 12885
# Test: Total time: 0:00:04 (0.1092 s / it)
# Averaged stats: model_time: 0.0165 (0.0167)  evaluator_time: 0.0227 (0.0299)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
# 1.8577113151550293
# Epoch: [53]  [ 0/22]  eta: 0:00:51  lr: 0.003000  time: 2.3487  data: 2.0026  max mem: 12885
# 2.1473536491394043
# 2.2223072052001953
# 2.188386917114258
# 2.48777437210083
# 2.324873924255371
# 2.7848944664001465
# 2.2900426387786865
# 2.215869426727295
# 2.579651355743408
# 2.334364652633667
# 2.177299976348877
# 2.558114528656006
# 2.9502341747283936
# 2.2069339752197266
# 2.0948917865753174
# 2.5144193172454834
# 2.1557443141937256
# 1.9481582641601562
# 2.0190651416778564
# 2.0789103507995605
# Epoch: [53]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2677  data: 1.9106  max mem: 12885
# 2.1011271476745605
# Epoch: [53]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2807  data: 1.9166  max mem: 12885
# Epoch: [53] Total time: 0:00:49 (2.2708 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0172 (0.0172)  evaluator_time: 0.0221 (0.0221)  time: 0.1048  data: 0.0619  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0166)  evaluator_time: 0.0192 (0.0289)  time: 0.1078  data: 0.0561  max mem: 12885
# Test: Total time: 0:00:04 (0.1084 s / it)
# Averaged stats: model_time: 0.0162 (0.0166)  evaluator_time: 0.0192 (0.0289)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.537
# 2.5212507247924805
# Epoch: [54]  [ 0/22]  eta: 0:00:44  lr: 0.003000  time: 2.0076  data: 1.7227  max mem: 12885
# 1.9146491289138794
# 2.0597431659698486
# 1.9310988187789917
# 1.963069200515747
# 3.027233123779297
# 3.1093497276306152
# 2.5091185569763184
# 2.2040395736694336
# 2.354576587677002
# 2.316105365753174
# 2.2556252479553223
# 2.8562231063842773
# 2.342801570892334
# 2.2360970973968506
# 2.3213491439819336
# 2.3420491218566895
# 1.8176121711730957
# 2.1891095638275146
# 2.0995049476623535
# 2.3281877040863037
# Epoch: [54]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1746  data: 1.8267  max mem: 12885
# 1.7407151460647583
# Epoch: [54]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1625  data: 1.8113  max mem: 12885
# Epoch: [54] Total time: 0:00:47 (2.1622 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0164 (0.0164)  time: 0.0984  data: 0.0614  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0168)  evaluator_time: 0.0196 (0.0297)  time: 0.1110  data: 0.0566  max mem: 12885
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0167 (0.0168)  evaluator_time: 0.0196 (0.0297)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.446
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.569
# 2.0707945823669434
# Epoch: [55]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1154  data: 1.7750  max mem: 12885
# 2.0270769596099854
# 2.1746761798858643
# 2.350515365600586
# 2.2745351791381836
# 2.791682243347168
# 2.1273837089538574
# 2.1873130798339844
# 1.6750843524932861
# 2.187375068664551
# 2.6197996139526367
# 1.903673529624939
# 2.1532790660858154
# 2.5902798175811768
# 2.4169862270355225
# 2.005767822265625
# 2.1773486137390137
# 2.238246202468872
# 2.663677215576172
# 2.025169610977173
# 2.1422672271728516
# Epoch: [55]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2465  data: 1.8894  max mem: 12885
# 2.155877113342285
# Epoch: [55]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2539  data: 1.8965  max mem: 12885
# Epoch: [55] Total time: 0:00:49 (2.2466 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0188 (0.0188)  evaluator_time: 0.0144 (0.0144)  time: 0.0989  data: 0.0617  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0166)  evaluator_time: 0.0207 (0.0294)  time: 0.1096  data: 0.0560  max mem: 12885
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0163 (0.0166)  evaluator_time: 0.0207 (0.0294)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
# 2.257443904876709
# Epoch: [56]  [ 0/22]  eta: 0:00:43  lr: 0.003000  time: 1.9682  data: 1.7139  max mem: 12885
# 2.301445484161377
# 2.3355424404144287
# 1.7916243076324463
# 2.2078254222869873
# 2.0070204734802246
# 2.168921947479248
# 2.269648790359497
# 2.598480224609375
# 2.4113218784332275
# 2.084601402282715
# 2.2679946422576904
# 2.0796477794647217
# 2.362781286239624
# 2.5329384803771973
# 2.3412280082702637
# 2.7877445220947266
# 1.9642325639724731
# 2.0962512493133545
# 1.8275537490844727
# 1.9746018648147583
# Epoch: [56]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1621  data: 1.8046  max mem: 12885
# 2.3681640625
# Epoch: [56]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1465  data: 1.7857  max mem: 12885
# Epoch: [56] Total time: 0:00:47 (2.1570 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0166 (0.0166)  evaluator_time: 0.0152 (0.0152)  time: 0.0972  data: 0.0617  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0170 (0.0170)  evaluator_time: 0.0175 (0.0259)  time: 0.1064  data: 0.0572  max mem: 12885
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0170 (0.0170)  evaluator_time: 0.0175 (0.0259)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.472
# 2.5263402462005615
# Epoch: [57]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1961  data: 1.8611  max mem: 12885
# 2.039760112762451
# 2.590165376663208
# 2.7780704498291016
# 2.147610902786255
# 2.0475423336029053
# 1.8566491603851318
# 2.404207468032837
# 1.9400278329849243
# 2.814211845397949
# 2.0225346088409424
# 2.3826346397399902
# 2.3519558906555176
# 2.9842183589935303
# 2.820312023162842
# 2.246316432952881
# 2.3648524284362793
# 2.3620803356170654
# 2.9500322341918945
# 2.8185455799102783
# 1.7989150285720825
# Epoch: [57]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1113  data: 1.7722  max mem: 12885
# 2.048434257507324
# Epoch: [57]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1144  data: 1.7796  max mem: 12885
# Epoch: [57] Total time: 0:00:46 (2.1247 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0182 (0.0182)  evaluator_time: 0.0251 (0.0251)  time: 0.1079  data: 0.0610  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0167)  evaluator_time: 0.0216 (0.0336)  time: 0.1131  data: 0.0563  max mem: 12885
# Test: Total time: 0:00:04 (0.1125 s / it)
# Averaged stats: model_time: 0.0166 (0.0167)  evaluator_time: 0.0216 (0.0336)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.413
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 2.8740031719207764
# Epoch: [58]  [ 0/22]  eta: 0:00:50  lr: 0.003000  time: 2.2833  data: 1.8995  max mem: 12885
# 2.3584108352661133
# 3.163123607635498
# 2.043243885040283
# 2.05572509765625
# 2.577432632446289
# 2.6403722763061523
# 2.2492642402648926
# 2.7535488605499268
# 2.672576665878296
# 1.9283018112182617
# 2.308736801147461
# 2.04050350189209
# 2.6054575443267822
# 2.6757352352142334
# 2.5677404403686523
# 2.198080062866211
# 2.2730753421783447
# 2.0099070072174072
# 2.307873249053955
# 2.692716360092163
# Epoch: [58]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2377  data: 1.8714  max mem: 12885
# 2.3791213035583496
# Epoch: [58]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2208  data: 1.8584  max mem: 12885
# Epoch: [58] Total time: 0:00:49 (2.2276 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0171 (0.0171)  evaluator_time: 0.0197 (0.0197)  time: 0.1026  data: 0.0620  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0166)  evaluator_time: 0.0191 (0.0310)  time: 0.1110  data: 0.0565  max mem: 12885
# Test: Total time: 0:00:04 (0.1099 s / it)
# Averaged stats: model_time: 0.0164 (0.0166)  evaluator_time: 0.0191 (0.0310)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.546
# 2.5619120597839355
# Epoch: [59]  [ 0/22]  eta: 0:00:57  lr: 0.003000  time: 2.6129  data: 2.2406  max mem: 12885
# 2.1584107875823975
# 2.070756435394287
# 2.1563355922698975
# 2.792229175567627
# 2.022890090942383
# 2.1850545406341553
# 2.4125113487243652
# 2.215104103088379
# 2.0955822467803955
# 2.8634157180786133
# 2.6654748916625977
# 1.6759165525436401
# 2.297422409057617
# 1.8761203289031982
# 2.2767295837402344
# 2.4068450927734375
# 2.376744270324707
# 2.5102624893188477
# 1.765742301940918
# 2.053368091583252
# Epoch: [59]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1560  data: 1.8070  max mem: 12885
# 2.0904884338378906
# Epoch: [59]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1285  data: 1.7824  max mem: 12885
# Epoch: [59] Total time: 0:00:47 (2.1669 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0201 (0.0201)  evaluator_time: 0.0138 (0.0138)  time: 0.0987  data: 0.0613  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0164)  evaluator_time: 0.0216 (0.0274)  time: 0.1077  data: 0.0562  max mem: 12885
# Test: Total time: 0:00:04 (0.1060 s / it)
# Averaged stats: model_time: 0.0162 (0.0164)  evaluator_time: 0.0216 (0.0274)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.435
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.566
# 1.8582303524017334
# Epoch: [60]  [ 0/22]  eta: 0:00:38  lr: 0.003000  time: 1.7439  data: 1.5461  max mem: 12885
# 2.1609861850738525
# 2.3126232624053955
# 2.7296862602233887
# 2.421961784362793
# 1.9443480968475342
# 2.4986066818237305
# 2.0726819038391113
# 2.325453996658325
# 2.314892053604126
# 2.2548534870147705
# 2.306281805038452
# 2.4138600826263428
# 2.600459098815918
# 2.1020755767822266
# 2.4021058082580566
# 1.8984005451202393
# 2.698391914367676
# 2.2007296085357666
# 2.007141590118408
# 2.5651257038116455
# Epoch: [60]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2059  data: 1.8458  max mem: 12885
# 2.066338539123535
# Epoch: [60]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2138  data: 1.8538  max mem: 12885
# Epoch: [60] Total time: 0:00:47 (2.1781 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0172 (0.0172)  evaluator_time: 0.0158 (0.0158)  time: 0.0982  data: 0.0615  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0169 (0.0314)  time: 0.1083  data: 0.0560  max mem: 12885
# Test: Total time: 0:00:04 (0.1102 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0169 (0.0314)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 2.3981242179870605
# Epoch: [61]  [ 0/22]  eta: 0:01:00  lr: 0.003000  time: 2.7284  data: 2.3006  max mem: 12885
# 2.02390193939209
# 1.9377444982528687
# 2.707979917526245
# 2.653329849243164
# 1.794358730316162
# 2.2230632305145264
# 2.2073919773101807
# 2.3352839946746826
# 2.075690269470215
# 2.261604070663452
# 2.3038089275360107
# 2.269151210784912
# 2.26145339012146
# 2.511615753173828
# 2.0297508239746094
# 2.5624470710754395
# 2.1601929664611816
# 2.308051109313965
# 2.948284149169922
# 2.4897313117980957
# Epoch: [61]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1942  data: 1.8537  max mem: 12885
# 2.2821669578552246
# Epoch: [61]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1823  data: 1.8491  max mem: 12885
# Epoch: [61] Total time: 0:00:48 (2.2161 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0168 (0.0168)  evaluator_time: 0.0136 (0.0136)  time: 0.0963  data: 0.0622  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0165)  evaluator_time: 0.0238 (0.0299)  time: 0.1122  data: 0.0574  max mem: 12885
# Test: Total time: 0:00:04 (0.1092 s / it)
# Averaged stats: model_time: 0.0167 (0.0165)  evaluator_time: 0.0238 (0.0299)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.585
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.585
# 2.470949649810791
# Epoch: [62]  [ 0/22]  eta: 0:00:45  lr: 0.003000  time: 2.0456  data: 1.6866  max mem: 12885
# 2.0904781818389893
# 1.8345518112182617
# 1.8099995851516724
# 2.811776638031006
# 2.2364513874053955
# 2.2300117015838623
# 2.232785224914551
# 2.215505838394165
# 2.244978427886963
# 2.4398350715637207
# 1.95241379737854
# 2.1264545917510986
# 2.4112496376037598
# 1.7336000204086304
# 2.5857491493225098
# 2.7167325019836426
# 2.0748579502105713
# 2.4321653842926025
# 2.162628173828125
# 2.153583288192749
# Epoch: [62]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1984  data: 1.8477  max mem: 12885
# 2.397488832473755
# Epoch: [62]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1690  data: 1.8201  max mem: 12885
# Epoch: [62] Total time: 0:00:47 (2.1746 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0174 (0.0174)  evaluator_time: 0.0160 (0.0160)  time: 0.1007  data: 0.0637  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0230 (0.0291)  time: 0.1110  data: 0.0570  max mem: 12885
# Test: Total time: 0:00:04 (0.1082 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0230 (0.0291)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.429
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.579
# 2.0044684410095215
# Epoch: [63]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3926  data: 2.1092  max mem: 12885
# 2.368215799331665
# 2.26802921295166
# 2.5913519859313965
# 2.2887368202209473
# 2.2764530181884766
# 2.3827571868896484
# 2.1262853145599365
# 2.6377975940704346
# 1.63580322265625
# 2.226530075073242
# 1.8688734769821167
# 1.9638667106628418
# 2.0269603729248047
# 1.9057097434997559
# 1.9419689178466797
# 1.8494709730148315
# 2.1049888134002686
# 2.0141656398773193
# 1.966614007949829
# 2.464874505996704
# Epoch: [63]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.0862  data: 1.7614  max mem: 12885
# 2.2688612937927246
# Epoch: [63]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.0779  data: 1.7542  max mem: 12885
# Epoch: [63] Total time: 0:00:46 (2.1019 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0159 (0.0159)  time: 0.0986  data: 0.0621  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0170)  evaluator_time: 0.0193 (0.0281)  time: 0.1109  data: 0.0584  max mem: 12885
# Test: Total time: 0:00:04 (0.1088 s / it)
# Averaged stats: model_time: 0.0168 (0.0170)  evaluator_time: 0.0193 (0.0281)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.528
# 2.3327205181121826
# Epoch: [64]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4699  data: 2.0188  max mem: 12885
# 2.543407678604126
# 2.171433448791504
# 2.3719935417175293
# 1.9535040855407715
# 1.8877674341201782
# 2.00980281829834
# 2.6428029537200928
# 1.914588212966919
# 2.6607542037963867
# 2.4710049629211426
# 2.597710132598877
# 2.0016305446624756
# 2.6443872451782227
# 2.608936071395874
# 2.6820545196533203
# 2.3204193115234375
# 2.2661566734313965
# 2.2943437099456787
# 2.362182855606079
# 2.5569779872894287
# Epoch: [64]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2562  data: 1.8933  max mem: 12885
# 2.0462117195129395
# Epoch: [64]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2631  data: 1.9011  max mem: 12885
# Epoch: [64] Total time: 0:00:50 (2.2739 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0192 (0.0192)  evaluator_time: 0.0201 (0.0201)  time: 0.1056  data: 0.0624  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0160 (0.0165)  evaluator_time: 0.0217 (0.0295)  time: 0.1083  data: 0.0562  max mem: 12885
# Test: Total time: 0:00:04 (0.1090 s / it)
# Averaged stats: model_time: 0.0160 (0.0165)  evaluator_time: 0.0217 (0.0295)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
# 2.9438061714172363
# Epoch: [65]  [ 0/22]  eta: 0:00:54  lr: 0.003000  time: 2.4749  data: 1.9434  max mem: 12885
# 2.6345529556274414
# 1.7510684728622437
# 2.5944900512695312
# 2.7473387718200684
# 2.501166820526123
# 2.559985876083374
# 2.3638086318969727
# 2.5417320728302
# 2.04500150680542
# 2.183608293533325
# 2.345454216003418
# 2.400480270385742
# 2.0771801471710205
# 2.436393976211548
# 2.3758597373962402
# 2.130486488342285
# 2.2571868896484375
# 2.201683759689331
# 1.5936682224273682
# 2.5120575428009033
# Epoch: [65]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2075  data: 1.8402  max mem: 12885
# 2.414656400680542
# Epoch: [65]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1914  data: 1.8233  max mem: 12885
# Epoch: [65] Total time: 0:00:48 (2.2156 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0178 (0.0178)  evaluator_time: 0.0213 (0.0213)  time: 0.1080  data: 0.0649  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0170)  evaluator_time: 0.0215 (0.0328)  time: 0.1138  data: 0.0568  max mem: 12885
# Test: Total time: 0:00:04 (0.1134 s / it)
# Averaged stats: model_time: 0.0166 (0.0170)  evaluator_time: 0.0215 (0.0328)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
# 2.363346815109253
# Epoch: [66]  [ 0/22]  eta: 0:00:46  lr: 0.003000  time: 2.1037  data: 1.7159  max mem: 12885
# 2.1046135425567627
# 1.7042142152786255
# 2.432624340057373
# 1.9065885543823242
# 1.9780659675598145
# 2.2301297187805176
# 2.0356035232543945
# 2.2046875953674316
# 1.715700626373291
# 2.6416542530059814
# 2.2876076698303223
# 2.00998592376709
# 2.7912755012512207
# 2.2700352668762207
# 2.3646039962768555
# 2.051344156265259
# 1.9756313562393188
# 2.0972023010253906
# 2.101151704788208
# 2.4560515880584717
# Epoch: [66]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1400  data: 1.7943  max mem: 12885
# 1.9413447380065918
# Epoch: [66]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1397  data: 1.7889  max mem: 12885
# Epoch: [66] Total time: 0:00:47 (2.1457 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0164 (0.0164)  evaluator_time: 0.0147 (0.0147)  time: 0.0957  data: 0.0609  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0164)  evaluator_time: 0.0209 (0.0277)  time: 0.1085  data: 0.0561  max mem: 12885
# Test: Total time: 0:00:04 (0.1065 s / it)
# Averaged stats: model_time: 0.0164 (0.0164)  evaluator_time: 0.0209 (0.0277)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.560
# 2.145224094390869
# Epoch: [67]  [ 0/22]  eta: 0:00:52  lr: 0.003000  time: 2.3902  data: 2.0162  max mem: 12885
# 2.34771728515625
# 1.7989635467529297
# 2.542332410812378
# 2.0400166511535645
# 2.6095519065856934
# 1.7768619060516357
# 1.7512062788009644
# 1.8017812967300415
# 1.5826083421707153
# 2.540590524673462
# 2.4038753509521484
# 1.9875967502593994
# 2.0884268283843994
# 1.8758265972137451
# 1.9178495407104492
# 1.9661109447479248
# 2.1261777877807617
# 2.6680736541748047
# 2.3317453861236572
# 2.130362033843994
# Epoch: [67]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1594  data: 1.8056  max mem: 12885
# 2.2129342555999756
# Epoch: [67]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1434  data: 1.7936  max mem: 12885
# Epoch: [67] Total time: 0:00:47 (2.1664 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0147 (0.0147)  time: 0.0967  data: 0.0614  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0170)  evaluator_time: 0.0215 (0.0284)  time: 0.1110  data: 0.0568  max mem: 12885
# Test: Total time: 0:00:04 (0.1087 s / it)
# Averaged stats: model_time: 0.0166 (0.0170)  evaluator_time: 0.0215 (0.0284)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.595
# 2.14471435546875
# Epoch: [68]  [ 0/22]  eta: 0:00:48  lr: 0.003000  time: 2.1876  data: 1.9196  max mem: 12885
# 2.169456958770752
# 2.1025843620300293
# 1.956960916519165
# 2.0582199096679688
# 2.166642904281616
# 2.730112314224243
# 2.0366315841674805
# 1.7094508409500122
# 1.9705595970153809
# 2.2005105018615723
# 2.496171236038208
# 2.3607676029205322
# 1.7853854894638062
# 2.0142853260040283
# 1.7342472076416016
# 2.200805187225342
# 2.88928484916687
# 1.9735205173492432
# 1.947351336479187
# 2.199117660522461
# Epoch: [68]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.1509  data: 1.8041  max mem: 12885
# 2.6932077407836914
# Epoch: [68]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.1423  data: 1.7964  max mem: 12885
# Epoch: [68] Total time: 0:00:47 (2.1587 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0131 (0.0131)  time: 0.0952  data: 0.0614  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0164)  evaluator_time: 0.0230 (0.0288)  time: 0.1098  data: 0.0561  max mem: 12885
# Test: Total time: 0:00:04 (0.1073 s / it)
# Averaged stats: model_time: 0.0163 (0.0164)  evaluator_time: 0.0230 (0.0288)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.575
# 2.2210264205932617
# Epoch: [69]  [ 0/22]  eta: 0:00:42  lr: 0.003000  time: 1.9541  data: 1.6058  max mem: 12885
# 2.1718060970306396
# 1.9859559535980225
# 2.381948947906494
# 2.007812261581421
# 2.0487120151519775
# 1.9006167650222778
# 2.71384596824646
# 2.149177312850952
# 2.1492295265197754
# 2.5020370483398438
# 2.1834609508514404
# 1.8961842060089111
# 2.559566020965576
# 1.8537118434906006
# 2.598773717880249
# 2.063587188720703
# 2.1933088302612305
# 2.340632438659668
# 2.796967029571533
# 2.917470932006836
# Epoch: [69]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2805  data: 1.9142  max mem: 12885
# 2.0530142784118652
# Epoch: [69]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2733  data: 1.9066  max mem: 12885
# Epoch: [69] Total time: 0:00:49 (2.2607 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0163 (0.0163)  time: 0.0981  data: 0.0611  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0167)  evaluator_time: 0.0209 (0.0287)  time: 0.1098  data: 0.0565  max mem: 12885
# Test: Total time: 0:00:04 (0.1084 s / it)
# Averaged stats: model_time: 0.0167 (0.0167)  evaluator_time: 0.0209 (0.0287)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.791398048400879
# Epoch: [70]  [ 0/22]  eta: 0:00:47  lr: 0.003000  time: 2.1601  data: 1.8120  max mem: 12885
# 1.780641794204712
# 2.2726900577545166
# 2.1624953746795654
# 2.523092269897461
# 1.8497278690338135
# 2.378204345703125
# 2.4233860969543457
# 2.383962631225586
# 2.097015857696533
# 2.721224784851074
# 2.208317756652832
# 2.2694787979125977
# 2.204732656478882
# 2.605238437652588
# 1.7734147310256958
# 1.9694969654083252
# 2.102029800415039
# 2.5905396938323975
# 2.5723679065704346
# 1.856199026107788
# Epoch: [70]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2278  data: 1.8468  max mem: 12885
# 2.4009714126586914
# Epoch: [70]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2038  data: 1.8284  max mem: 12885
# Epoch: [70] Total time: 0:00:49 (2.2286 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0172 (0.0172)  evaluator_time: 0.0129 (0.0129)  time: 0.0960  data: 0.0621  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0169 (0.0170)  evaluator_time: 0.0232 (0.0297)  time: 0.1121  data: 0.0569  max mem: 12885
# Test: Total time: 0:00:04 (0.1098 s / it)
# Averaged stats: model_time: 0.0169 (0.0170)  evaluator_time: 0.0232 (0.0297)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# 2.0919058322906494
# Epoch: [71]  [ 0/22]  eta: 0:00:49  lr: 0.003000  time: 2.2329  data: 1.8664  max mem: 12885
# 1.8892204761505127
# 2.439612627029419
# 2.1443262100219727
# 2.098649501800537
# 1.8963682651519775
# 2.650620937347412
# 2.1907119750976562
# 1.8926624059677124
# 2.213778495788574
# 2.2140884399414062
# 2.70061993598938
# 2.4153189659118652
# 1.5305098295211792
# 1.911972165107727
# 2.3924505710601807
# 2.4983677864074707
# 2.129330635070801
# 2.093203544616699
# 2.053424835205078
# 2.3490686416625977
# Epoch: [71]  [20/22]  eta: 0:00:04  lr: 0.003000  time: 2.2314  data: 1.8946  max mem: 12885
# 2.1016411781311035
# Epoch: [71]  [21/22]  eta: 0:00:02  lr: 0.003000  time: 2.2182  data: 1.8737  max mem: 12885
# Epoch: [71] Total time: 0:00:49 (2.2307 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0180 (0.0180)  evaluator_time: 0.0154 (0.0154)  time: 0.0992  data: 0.0620  max mem: 12885
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0164)  evaluator_time: 0.0232 (0.0294)  time: 0.1096  data: 0.0560  max mem: 12885
# Test: Total time: 0:00:04 (0.1080 s / it)
# Averaged stats: model_time: 0.0162 (0.0164)  evaluator_time: 0.0232 (0.0294)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.564
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.552
# 2.192656993865967
# Epoch: [93]  [ 0/22]  eta: 0:00:50  lr: 0.000300  time: 2.2857  data: 1.8794  max mem: 12892
# 1.839093565940857
# 1.9791173934936523
# 1.9814441204071045
# 1.7852606773376465
# 1.630616307258606
# 1.737326741218567
# 1.9362001419067383
# 1.8057820796966553
# 1.592763900756836
# 2.218536138534546
# 2.0882086753845215
# 1.9534037113189697
# 1.4540083408355713
# 1.8993453979492188
# 1.8963899612426758
# 1.4690626859664917
# 1.8454750776290894
# 1.7024015188217163
# 2.533090829849243
# 1.7380943298339844
# Epoch: [93]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1418  data: 1.7792  max mem: 12892
# 1.9764291048049927
# Epoch: [93]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1113  data: 1.7500  max mem: 12892
# Epoch: [93] Total time: 0:00:47 (2.1413 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0172 (0.0172)  evaluator_time: 0.0139 (0.0139)  time: 0.0971  data: 0.0624  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0166)  evaluator_time: 0.0171 (0.0271)  time: 0.1078  data: 0.0563  max mem: 12892
# Test: Total time: 0:00:04 (0.1068 s / it)
# Averaged stats: model_time: 0.0163 (0.0166)  evaluator_time: 0.0171 (0.0271)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
# 2.2074594497680664
# Epoch: [94]  [ 0/22]  eta: 0:00:47  lr: 0.000300  time: 2.1771  data: 1.7305  max mem: 12892
# 1.5334646701812744
# 1.7594457864761353
# 2.0018348693847656
# 2.0447936058044434
# 1.7238140106201172
# 2.115518569946289
# 1.5928823947906494
# 1.5044025182724
# 1.7610809803009033
# 1.607185959815979
# 1.9681758880615234
# 1.5806961059570312
# 2.1750717163085938
# 1.8237361907958984
# 2.076313018798828
# 2.1045360565185547
# 1.4019566774368286
# 1.6828234195709229
# 1.6202164888381958
# 2.1713907718658447
# Epoch: [94]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1554  data: 1.8188  max mem: 12892
# 1.6534243822097778
# Epoch: [94]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1653  data: 1.8273  max mem: 12892
# Epoch: [94] Total time: 0:00:47 (2.1671 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0189 (0.0189)  evaluator_time: 0.0130 (0.0130)  time: 0.0976  data: 0.0618  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0164)  evaluator_time: 0.0171 (0.0265)  time: 0.1069  data: 0.0561  max mem: 12892
# Test: Total time: 0:00:04 (0.1049 s / it)
# Averaged stats: model_time: 0.0163 (0.0164)  evaluator_time: 0.0171 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
# 2.050488233566284
# Epoch: [95]  [ 0/22]  eta: 0:00:46  lr: 0.000300  time: 2.1031  data: 1.7726  max mem: 12892
# 1.8903069496154785
# 1.7684170007705688
# 1.8517370223999023
# 1.862669825553894
# 1.670097827911377
# 1.4763693809509277
# 1.7624726295471191
# 1.5420105457305908
# 1.8773932456970215
# 1.744227647781372
# 1.6590698957443237
# 1.6332900524139404
# 2.003232479095459
# 1.721124291419983
# 1.986467719078064
# 1.7699918746948242
# 1.6943070888519287
# 1.9627394676208496
# 1.9739453792572021
# 1.8322012424468994
# Epoch: [95]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1813  data: 1.8303  max mem: 12892
# 1.7609460353851318
# Epoch: [95]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1559  data: 1.8067  max mem: 12892
# Epoch: [95] Total time: 0:00:48 (2.1842 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0176 (0.0176)  evaluator_time: 0.0139 (0.0139)  time: 0.0985  data: 0.0633  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0167)  evaluator_time: 0.0168 (0.0302)  time: 0.1072  data: 0.0565  max mem: 12892
# Test: Total time: 0:00:04 (0.1099 s / it)
# Averaged stats: model_time: 0.0163 (0.0167)  evaluator_time: 0.0168 (0.0302)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.304
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
# 1.569603443145752
# Epoch: [96]  [ 0/22]  eta: 0:00:52  lr: 0.000300  time: 2.3785  data: 1.9274  max mem: 12892
# 1.5514707565307617
# 2.0373828411102295
# 1.8197252750396729
# 1.7904586791992188
# 1.5577260255813599
# 2.1107192039489746
# 2.112067222595215
# 2.381747007369995
# 1.658084511756897
# 1.5912219285964966
# 1.9298022985458374
# 2.060068368911743
# 1.871870517730713
# 1.9428730010986328
# 1.797410249710083
# 1.7664117813110352
# 1.8423620462417603
# 1.854088544845581
# 2.236053466796875
# 2.4909563064575195
# Epoch: [96]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1887  data: 1.8247  max mem: 12892
# 1.824750542640686
# Epoch: [96]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1843  data: 1.8187  max mem: 12892
# Epoch: [96] Total time: 0:00:48 (2.2010 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0131 (0.0131)  time: 0.0961  data: 0.0624  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0165)  evaluator_time: 0.0164 (0.0266)  time: 0.1076  data: 0.0565  max mem: 12892
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0165 (0.0165)  evaluator_time: 0.0164 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
# 2.2339165210723877
# Epoch: [97]  [ 0/22]  eta: 0:00:46  lr: 0.000300  time: 2.0922  data: 1.6895  max mem: 12892
# 1.798021674156189
# 2.1986522674560547
# 1.6217095851898193
# 1.7581125497817993
# 2.259676218032837
# 1.6977307796478271
# 2.0167653560638428
# 1.8731837272644043
# 1.7700915336608887
# 2.32381272315979
# 1.8557186126708984
# 1.6921499967575073
# 1.7150206565856934
# 2.14622163772583
# 1.924602746963501
# 2.4439783096313477
# 1.6154522895812988
# 1.6565310955047607
# 1.4606513977050781
# 1.6097691059112549
# Epoch: [97]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.2871  data: 1.9190  max mem: 12892
# 1.875745415687561
# Epoch: [97]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.2770  data: 1.9084  max mem: 12892
# Epoch: [97] Total time: 0:00:50 (2.2807 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0179 (0.0179)  evaluator_time: 0.0135 (0.0135)  time: 0.0974  data: 0.0621  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0158 (0.0265)  time: 0.1071  data: 0.0562  max mem: 12892
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0158 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# 2.0733776092529297
# Epoch: [98]  [ 0/22]  eta: 0:00:51  lr: 0.000300  time: 2.3598  data: 1.9404  max mem: 12892
# 2.1713650226593018
# 1.9845407009124756
# 1.8277015686035156
# 1.411539077758789
# 1.9477896690368652
# 2.0743536949157715
# 1.766106367111206
# 1.6809470653533936
# 1.679633617401123
# 1.7906662225723267
# 1.792137861251831
# 2.066667318344116
# 1.5228451490402222
# 1.801116943359375
# 1.8055293560028076
# 2.2291011810302734
# 1.7630888223648071
# 1.9848014116287231
# 2.0767977237701416
# 1.7373085021972656
# Epoch: [98]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1610  data: 1.8045  max mem: 12892
# 1.5561248064041138
# Epoch: [98]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1328  data: 1.7857  max mem: 12892
# Epoch: [98] Total time: 0:00:47 (2.1615 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0173 (0.0173)  evaluator_time: 0.0140 (0.0140)  time: 0.0972  data: 0.0621  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0168)  evaluator_time: 0.0166 (0.0265)  time: 0.1079  data: 0.0564  max mem: 12892
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0166 (0.0168)  evaluator_time: 0.0166 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.559
# 1.630443811416626
# Epoch: [99]  [ 0/22]  eta: 0:00:52  lr: 0.000300  time: 2.3996  data: 2.0824  max mem: 12892
# 1.9451112747192383
# 1.5281003713607788
# 1.771681308746338
# 1.9339544773101807
# 2.1720571517944336
# 2.4944357872009277
# 1.7493925094604492
# 1.7825939655303955
# 2.0743041038513184
# 1.7421238422393799
# 1.724027156829834
# 1.8452181816101074
# 1.6966359615325928
# 1.7252243757247925
# 1.9271149635314941
# 2.118349313735962
# 2.08272647857666
# 1.5856364965438843
# 1.790400505065918
# 2.1430506706237793
# Epoch: [99]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1217  data: 1.7809  max mem: 12892
# 1.5889816284179688
# Epoch: [99]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1266  data: 1.7796  max mem: 12892
# Epoch: [99] Total time: 0:00:46 (2.1353 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0134 (0.0134)  time: 0.0960  data: 0.0618  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0166)  evaluator_time: 0.0187 (0.0270)  time: 0.1093  data: 0.0580  max mem: 12892
# Test: Total time: 0:00:04 (0.1072 s / it)
# Averaged stats: model_time: 0.0162 (0.0166)  evaluator_time: 0.0187 (0.0270)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
# Training time 0:45:56

# %%
print('El AP del mejor modelo siendo esre el que guardamos es:')
print(best_ap)
torch.save({
    'model_state_dict': best_model_weights,
}, path_base + "/pesos_modelos/SSD512_ResNet_upgraded_finetuned.pth"   )
# Out:
# El AP del mejor modelo siendo esre el que guardamos es:
# 0.29881452517346024

# %%
start_time = time.time()


for epoch in range(100, 120):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# 1.9080226421356201
# Epoch: [100]  [ 0/22]  eta: 0:00:52  lr: 0.000300  time: 2.3722  data: 2.0531  max mem: 12892
# 1.554222583770752
# 1.818747878074646
# 1.7284327745437622
# 1.759906530380249
# 1.6784331798553467
# 1.7957497835159302
# 1.8905892372131348
# 1.3840364217758179
# 1.746946930885315
# 1.6150803565979004
# 2.00706148147583
# 1.7305346727371216
# 1.5604149103164673
# 1.998816967010498
# 1.8235204219818115
# 2.0636861324310303
# 1.9379171133041382
# 1.7314600944519043
# 1.7827610969543457
# 2.5643861293792725
# Epoch: [100]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1744  data: 1.8105  max mem: 12892
# 1.7729945182800293
# Epoch: [100]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1719  data: 1.8079  max mem: 12892
# Epoch: [100] Total time: 0:00:47 (2.1814 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0173 (0.0173)  evaluator_time: 0.0128 (0.0128)  time: 0.0946  data: 0.0609  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0163)  evaluator_time: 0.0174 (0.0262)  time: 0.1078  data: 0.0572  max mem: 12892
# Test: Total time: 0:00:04 (0.1051 s / it)
# Averaged stats: model_time: 0.0162 (0.0163)  evaluator_time: 0.0174 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# 1.9126498699188232
# Epoch: [101]  [ 0/22]  eta: 0:00:51  lr: 0.000300  time: 2.3215  data: 1.9298  max mem: 12892
# 1.7069015502929688
# 2.060980796813965
# 1.6990089416503906
# 1.958531379699707
# 1.9387202262878418
# 2.2488505840301514
# 1.927760362625122
# 1.799307942390442
# 1.5907174348831177
# 1.771938681602478
# 1.8115031719207764
# 2.403456211090088
# 1.8490612506866455
# 1.7170758247375488
# 1.8716048002243042
# 1.708699107170105
# 1.617408037185669
# 1.9668608903884888
# 2.3370747566223145
# 1.4715648889541626
# Epoch: [101]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1670  data: 1.8333  max mem: 12892
# 2.1388511657714844
# Epoch: [101]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1411  data: 1.8098  max mem: 12892
# Epoch: [101] Total time: 0:00:47 (2.1702 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0134 (0.0134)  time: 0.0961  data: 0.0618  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0167)  evaluator_time: 0.0182 (0.0270)  time: 0.1100  data: 0.0584  max mem: 12892
# Test: Total time: 0:00:04 (0.1075 s / it)
# Averaged stats: model_time: 0.0164 (0.0167)  evaluator_time: 0.0182 (0.0270)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
# 1.911698579788208
# Epoch: [102]  [ 0/22]  eta: 0:00:47  lr: 0.000300  time: 2.1764  data: 1.8358  max mem: 12892
# 1.8432148694992065
# 1.7208747863769531
# 2.121361017227173
# 2.217613697052002
# 1.8484210968017578
# 1.6019232273101807
# 1.82027006149292
# 1.5373138189315796
# 1.9760408401489258
# 2.164137840270996
# 1.819990873336792
# 2.0398669242858887
# 1.5172840356826782
# 1.6730506420135498
# 1.9419327974319458
# 1.9678423404693604
# 2.439936637878418
# 1.5297595262527466
# 2.541685104370117
# 1.6760427951812744
# Epoch: [102]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1836  data: 1.8480  max mem: 12892
# 1.4027793407440186
# Epoch: [102]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1889  data: 1.8555  max mem: 12892
# Epoch: [102] Total time: 0:00:48 (2.1963 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0127 (0.0127)  time: 0.0957  data: 0.0623  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0165)  evaluator_time: 0.0169 (0.0262)  time: 0.1068  data: 0.0563  max mem: 12892
# Test: Total time: 0:00:04 (0.1056 s / it)
# Averaged stats: model_time: 0.0162 (0.0165)  evaluator_time: 0.0169 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 1.7508318424224854
# Epoch: [103]  [ 0/22]  eta: 0:00:49  lr: 0.000300  time: 2.2617  data: 1.8447  max mem: 12892
# 1.7031421661376953
# 2.0026791095733643
# 1.9849228858947754
# 1.6686311960220337
# 1.774153470993042
# 1.7471411228179932
# 1.722767949104309
# 2.1701254844665527
# 1.4227741956710815
# 1.761136531829834
# 2.3555800914764404
# 1.9277620315551758
# 1.813096046447754
# 1.8270868062973022
# 1.6281095743179321
# 1.9038591384887695
# 1.566867470741272
# 1.8012899160385132
# 1.5351166725158691
# 2.2080695629119873
# Epoch: [103]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1594  data: 1.8124  max mem: 12892
# 1.7066233158111572
# Epoch: [103]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1214  data: 1.7736  max mem: 12892
# Epoch: [103] Total time: 0:00:47 (2.1486 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0167 (0.0167)  evaluator_time: 0.0130 (0.0130)  time: 0.0951  data: 0.0617  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0177 (0.0267)  time: 0.1087  data: 0.0572  max mem: 12892
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0177 (0.0267)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.561
# 1.9157074689865112
# Epoch: [104]  [ 0/22]  eta: 0:00:44  lr: 0.000300  time: 2.0389  data: 1.6392  max mem: 12892
# 2.6256747245788574
# 1.7862701416015625
# 1.8883265256881714
# 1.537524700164795
# 1.5509763956069946
# 1.9191739559173584
# 1.6772544384002686
# 1.6413687467575073
# 2.07886004447937
# 1.792445421218872
# 1.9222891330718994
# 1.9306235313415527
# 1.8045426607131958
# 1.736900806427002
# 1.5123913288116455
# 2.2021985054016113
# 2.0422964096069336
# 1.9629549980163574
# 1.6218265295028687
# 1.8375731706619263
# Epoch: [104]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1749  data: 1.8445  max mem: 12892
# 1.5552647113800049
# Epoch: [104]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1337  data: 1.8131  max mem: 12892
# Epoch: [104] Total time: 0:00:47 (2.1633 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0165 (0.0165)  evaluator_time: 0.0131 (0.0131)  time: 0.1125  data: 0.0793  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0167)  evaluator_time: 0.0161 (0.0261)  time: 0.1081  data: 0.0575  max mem: 12892
# Test: Total time: 0:00:04 (0.1066 s / it)
# Averaged stats: model_time: 0.0164 (0.0167)  evaluator_time: 0.0161 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.301
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
# 1.775871753692627
# Epoch: [105]  [ 0/22]  eta: 0:00:51  lr: 0.000300  time: 2.3372  data: 1.9417  max mem: 12892
# 1.7347267866134644
# 1.664243459701538
# 2.026486873626709
# 1.6918420791625977
# 1.3387095928192139
# 1.6370809078216553
# 1.778299331665039
# 1.8269284963607788
# 1.848960280418396
# 2.0929152965545654
# 1.9753763675689697
# 1.8381565809249878
# 2.2641665935516357
# 1.839462161064148
# 2.6356887817382812
# 2.198376417160034
# 1.6806753873825073
# 1.86624014377594
# 2.214510679244995
# 1.637223720550537
# Epoch: [105]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.0928  data: 1.7635  max mem: 12892
# 1.755001425743103
# Epoch: [105]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.0847  data: 1.7569  max mem: 12892
# Epoch: [105] Total time: 0:00:46 (2.1058 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0132 (0.0132)  time: 0.0955  data: 0.0616  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0167)  evaluator_time: 0.0179 (0.0263)  time: 0.1078  data: 0.0566  max mem: 12892
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0167 (0.0167)  evaluator_time: 0.0179 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 2.046982526779175
# Epoch: [106]  [ 0/22]  eta: 0:00:48  lr: 0.000300  time: 2.2047  data: 1.8681  max mem: 12892
# 1.8010892868041992
# 1.6437469720840454
# 2.4667699337005615
# 1.7011802196502686
# 1.6120326519012451
# 1.6684927940368652
# 2.0738792419433594
# 1.7900646924972534
# 1.7044930458068848
# 1.8322726488113403
# 1.5849405527114868
# 1.7398663759231567
# 1.5804212093353271
# 1.8545001745224
# 1.8253602981567383
# 2.1919186115264893
# 1.5620256662368774
# 2.2793068885803223
# 2.045752763748169
# 3.0197532176971436
# Epoch: [106]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.2100  data: 1.8438  max mem: 12892
# 1.6838879585266113
# Epoch: [106]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.2149  data: 1.8424  max mem: 12892
# Epoch: [106] Total time: 0:00:48 (2.2137 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0211 (0.0211)  evaluator_time: 0.0149 (0.0149)  time: 0.1060  data: 0.0661  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0161 (0.0165)  evaluator_time: 0.0169 (0.0265)  time: 0.1067  data: 0.0560  max mem: 12892
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0161 (0.0165)  evaluator_time: 0.0169 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.562
# 1.8405888080596924
# Epoch: [107]  [ 0/22]  eta: 0:00:44  lr: 0.000300  time: 2.0385  data: 1.7942  max mem: 12892
# 1.8761345148086548
# 2.2612714767456055
# 1.8192126750946045
# 1.7820978164672852
# 1.576301097869873
# 2.082387924194336
# 1.4535423517227173
# 1.9462159872055054
# 1.957808494567871
# 1.8073360919952393
# 1.6003739833831787
# 1.904099941253662
# 1.7337112426757812
# 2.7964460849761963
# 1.6923905611038208
# 1.6118788719177246
# 1.4442942142486572
# 1.986051082611084
# 1.8894696235656738
# 1.9510772228240967
# Epoch: [107]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1589  data: 1.8217  max mem: 12892
# 1.9406070709228516
# Epoch: [107]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1798  data: 1.8334  max mem: 12892
# Epoch: [107] Total time: 0:00:47 (2.1804 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0400 (0.0400)  evaluator_time: 0.0130 (0.0130)  time: 0.1190  data: 0.0624  max mem: 12892
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0170)  evaluator_time: 0.0175 (0.0298)  time: 0.1143  data: 0.0566  max mem: 12892
# Test: Total time: 0:00:04 (0.1093 s / it)
# Averaged stats: model_time: 0.0164 (0.0170)  evaluator_time: 0.0175 (0.0298)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# 1.9942963123321533
# Epoch: [108]  [ 0/22]  eta: 0:00:58  lr: 0.000300  time: 2.6366  data: 2.0750  max mem: 12895
# 1.5348361730575562
# 1.8520687818527222
# 1.3307559490203857
# 1.7163113355636597
# 2.2589809894561768
# 1.6410741806030273
# 1.828648567199707
# 1.6327788829803467
# 1.7349350452423096
# 1.5290613174438477
# 2.020747184753418
# 1.3853609561920166
# 1.763528823852539
# 1.7802503108978271
# 2.0024280548095703
# 1.6824796199798584
# 1.7445422410964966
# 1.8280246257781982
# 2.3490309715270996
# 1.9475023746490479
# Epoch: [108]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.1451  data: 1.8177  max mem: 12999
# 1.8200325965881348
# Epoch: [108]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1338  data: 1.8000  max mem: 12999
# Epoch: [108] Total time: 0:00:47 (2.1565 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0168 (0.0168)  evaluator_time: 0.0130 (0.0130)  time: 0.1077  data: 0.0742  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0167)  evaluator_time: 0.0192 (0.0266)  time: 0.1079  data: 0.0566  max mem: 12999
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0165 (0.0167)  evaluator_time: 0.0192 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.563
# 1.7979471683502197
# Epoch: [109]  [ 0/22]  eta: 0:00:51  lr: 0.000300  time: 2.3348  data: 2.0171  max mem: 12999
# 1.889851689338684
# 2.1216838359832764
# 1.9084547758102417
# 1.5572118759155273
# 1.844754695892334
# 1.6869704723358154
# 1.4703969955444336
# 1.9350858926773071
# 1.9781544208526611
# 2.007119655609131
# 1.708970069885254
# 1.6042201519012451
# 1.7539416551589966
# 1.7293810844421387
# 1.7271404266357422
# 1.884141445159912
# 2.0079545974731445
# 1.753263235092163
# 1.7866095304489136
# 2.1948890686035156
# Epoch: [109]  [20/22]  eta: 0:00:04  lr: 0.000300  time: 2.2049  data: 1.8595  max mem: 12999
# 1.653507113456726
# Epoch: [109]  [21/22]  eta: 0:00:02  lr: 0.000300  time: 2.1828  data: 1.8472  max mem: 12999
# Epoch: [109] Total time: 0:00:48 (2.2068 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0456 (0.0456)  evaluator_time: 0.0123 (0.0123)  time: 0.1232  data: 0.0617  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0173)  evaluator_time: 0.0162 (0.0263)  time: 0.1067  data: 0.0561  max mem: 12999
# Test: Total time: 0:00:04 (0.1058 s / it)
# Averaged stats: model_time: 0.0162 (0.0173)  evaluator_time: 0.0162 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 1.933034062385559
# Epoch: [110]  [ 0/22]  eta: 0:00:43  lr: 0.000030  time: 1.9576  data: 1.6651  max mem: 12999
# 1.7418253421783447
# 1.7471778392791748
# 2.046452283859253
# 1.4590539932250977
# 2.084810495376587
# 2.1772232055664062
# 1.4790797233581543
# 1.761222004890442
# 1.687466025352478
# 1.662666916847229
# 1.6505649089813232
# 2.1586532592773438
# 1.5749956369400024
# 1.6997648477554321
# 2.04018497467041
# 1.69499933719635
# 1.9339213371276855
# 1.8637752532958984
# 1.499125599861145
# 1.756413221359253
# Epoch: [110]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1970  data: 1.8458  max mem: 12999
# 2.0060720443725586
# Epoch: [110]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1860  data: 1.8269  max mem: 12999
# Epoch: [110] Total time: 0:00:48 (2.1899 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0607 (0.0607)  evaluator_time: 0.0133 (0.0133)  time: 0.1411  data: 0.0632  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0177)  evaluator_time: 0.0186 (0.0265)  time: 0.1084  data: 0.0576  max mem: 12999
# Test: Total time: 0:00:04 (0.1072 s / it)
# Averaged stats: model_time: 0.0164 (0.0177)  evaluator_time: 0.0186 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.552
# 1.5038988590240479
# Epoch: [111]  [ 0/22]  eta: 0:00:47  lr: 0.000030  time: 2.1634  data: 1.8335  max mem: 12999
# 2.317030429840088
# 1.5953094959259033
# 1.6278603076934814
# 1.3087080717086792
# 1.9680449962615967
# 2.2148473262786865
# 1.7465763092041016
# 1.9363720417022705
# 1.7910873889923096
# 1.7194299697875977
# 1.724478006362915
# 1.747788906097412
# 1.445296287536621
# 1.7886731624603271
# 1.7872066497802734
# 1.6490484476089478
# 1.790264368057251
# 1.6588712930679321
# 1.7381832599639893
# 1.6551131010055542
# Epoch: [111]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1810  data: 1.8202  max mem: 12999
# 1.6473697423934937
# Epoch: [111]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1666  data: 1.8114  max mem: 12999
# Epoch: [111] Total time: 0:00:47 (2.1745 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0133 (0.0133)  time: 0.0956  data: 0.0615  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0166)  evaluator_time: 0.0158 (0.0263)  time: 0.1084  data: 0.0574  max mem: 12999
# Test: Total time: 0:00:04 (0.1056 s / it)
# Averaged stats: model_time: 0.0165 (0.0166)  evaluator_time: 0.0158 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 2.0834763050079346
# Epoch: [112]  [ 0/22]  eta: 0:00:43  lr: 0.000030  time: 1.9650  data: 1.5670  max mem: 12999
# 1.5588045120239258
# 1.7070562839508057
# 1.7419755458831787
# 1.6682438850402832
# 1.7718794345855713
# 1.5949699878692627
# 2.0626792907714844
# 2.4189207553863525
# 2.492889881134033
# 1.6350035667419434
# 1.7454100847244263
# 1.8918612003326416
# 1.5602842569351196
# 2.0694704055786133
# 1.3463178873062134
# 1.9396545886993408
# 1.5338892936706543
# 2.0658817291259766
# 1.371347427368164
# 1.427004337310791
# Epoch: [112]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1187  data: 1.7888  max mem: 12999
# 1.858946442604065
# Epoch: [112]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1297  data: 1.7933  max mem: 12999
# Epoch: [112] Total time: 0:00:46 (2.1159 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0614 (0.0614)  evaluator_time: 0.0131 (0.0131)  time: 0.1403  data: 0.0618  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0169 (0.0183)  evaluator_time: 0.0190 (0.0267)  time: 0.1116  data: 0.0585  max mem: 12999
# Test: Total time: 0:00:04 (0.1086 s / it)
# Averaged stats: model_time: 0.0169 (0.0183)  evaluator_time: 0.0190 (0.0267)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 1.923017978668213
# Epoch: [113]  [ 0/22]  eta: 0:00:56  lr: 0.000030  time: 2.5660  data: 2.1498  max mem: 12999
# 1.6909255981445312
# 1.9536395072937012
# 1.8551744222640991
# 1.681476354598999
# 2.141768455505371
# 1.5863866806030273
# 2.0829694271087646
# 1.6909637451171875
# 2.2166924476623535
# 1.8409732580184937
# 1.9155871868133545
# 2.223642349243164
# 1.6145849227905273
# 1.542816400527954
# 1.7778761386871338
# 1.7840774059295654
# 1.6511951684951782
# 1.641739010810852
# 2.2028160095214844
# 1.9047493934631348
# Epoch: [113]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1882  data: 1.8483  max mem: 12999
# 2.133849620819092
# Epoch: [113]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2157  data: 1.8707  max mem: 12999
# Epoch: [113] Total time: 0:00:49 (2.2403 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0130 (0.0130)  time: 0.0942  data: 0.0607  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0177)  evaluator_time: 0.0164 (0.0262)  time: 0.1096  data: 0.0562  max mem: 12999
# Test: Total time: 0:00:04 (0.1065 s / it)
# Averaged stats: model_time: 0.0165 (0.0177)  evaluator_time: 0.0164 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 1.7340272665023804
# Epoch: [114]  [ 0/22]  eta: 0:00:50  lr: 0.000030  time: 2.3066  data: 1.9709  max mem: 12999
# 1.9624319076538086
# 1.3960620164871216
# 1.8335517644882202
# 1.7463726997375488
# 1.6452746391296387
# 2.432525873184204
# 1.87150239944458
# 1.8303074836730957
# 1.6442606449127197
# 2.2646522521972656
# 1.504089593887329
# 1.8585076332092285
# 2.133014678955078
# 1.7338252067565918
# 1.8436553478240967
# 1.6829936504364014
# 1.6280769109725952
# 1.5940148830413818
# 1.7327594757080078
# 2.1732091903686523
# Epoch: [114]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.3323  data: 1.9717  max mem: 12999
# 1.573565125465393
# Epoch: [114]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.3009  data: 1.9371  max mem: 12999
# Epoch: [114] Total time: 0:00:51 (2.3222 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0168 (0.0168)  evaluator_time: 0.0131 (0.0131)  time: 0.0962  data: 0.0626  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0167)  evaluator_time: 0.0167 (0.0261)  time: 0.1075  data: 0.0567  max mem: 12999
# Test: Total time: 0:00:04 (0.1060 s / it)
# Averaged stats: model_time: 0.0164 (0.0167)  evaluator_time: 0.0167 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 1.66265070438385
# Epoch: [115]  [ 0/22]  eta: 0:00:47  lr: 0.000030  time: 2.1452  data: 1.7282  max mem: 12999
# 1.6845784187316895
# 1.818732738494873
# 1.5576790571212769
# 1.7490124702453613
# 1.5130739212036133
# 1.649916410446167
# 1.7736278772354126
# 1.920053482055664
# 1.9528648853302002
# 1.2560720443725586
# 1.6223320960998535
# 2.0182008743286133
# 1.8877769708633423
# 1.8027541637420654
# 1.5950469970703125
# 2.4081718921661377
# 1.873232364654541
# 1.8963778018951416
# 1.8114579916000366
# 1.864426851272583
# Epoch: [115]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2102  data: 1.8877  max mem: 12999
# 1.7001354694366455
# Epoch: [115]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2002  data: 1.8746  max mem: 12999
# Epoch: [115] Total time: 0:00:48 (2.1971 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0393 (0.0393)  evaluator_time: 0.0135 (0.0135)  time: 0.1180  data: 0.0615  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0174)  evaluator_time: 0.0159 (0.0260)  time: 0.1074  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0167 (0.0174)  evaluator_time: 0.0159 (0.0260)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
# 1.445649266242981
# Epoch: [116]  [ 0/22]  eta: 0:00:40  lr: 0.000030  time: 1.8582  data: 1.6266  max mem: 12999
# 1.8775856494903564
# 2.1707940101623535
# 2.2520270347595215
# 1.604461908340454
# 1.654552698135376
# 2.261758804321289
# 1.7318365573883057
# 1.8954001665115356
# 1.5103317499160767
# 2.1023659706115723
# 1.7576823234558105
# 2.0526864528656006
# 1.8011668920516968
# 1.6016343832015991
# 1.68471360206604
# 2.332547903060913
# 1.7727488279342651
# 1.916312575340271
# 1.8168480396270752
# 2.1686830520629883
# Epoch: [116]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2475  data: 1.8992  max mem: 12999
# 1.8698736429214478
# Epoch: [116]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2443  data: 1.8910  max mem: 12999
# Epoch: [116] Total time: 0:00:48 (2.2226 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0144 (0.0144)  time: 0.0978  data: 0.0625  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0168)  evaluator_time: 0.0164 (0.0266)  time: 0.1086  data: 0.0568  max mem: 12999
# Test: Total time: 0:00:04 (0.1069 s / it)
# Averaged stats: model_time: 0.0168 (0.0168)  evaluator_time: 0.0164 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.705871820449829
# Epoch: [117]  [ 0/22]  eta: 0:00:47  lr: 0.000030  time: 2.1789  data: 1.8639  max mem: 12999
# 1.542091965675354
# 1.492255449295044
# 1.6350752115249634
# 2.125671148300171
# 1.7604477405548096
# 1.5206892490386963
# 1.7132693529129028
# 1.5365709066390991
# 1.774550199508667
# 1.787398338317871
# 2.0316109657287598
# 1.875223159790039
# 1.648277997970581
# 2.510403871536255
# 1.9390673637390137
# 2.1218535900115967
# 1.7073233127593994
# 2.098051071166992
# 2.78769850730896
# 1.8204044103622437
# Epoch: [117]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2203  data: 1.8675  max mem: 12999
# 1.7361681461334229
# Epoch: [117]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2091  data: 1.8624  max mem: 12999
# Epoch: [117] Total time: 0:00:48 (2.2153 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0176 (0.0176)  evaluator_time: 0.0127 (0.0127)  time: 0.1173  data: 0.0833  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0166)  evaluator_time: 0.0164 (0.0263)  time: 0.1072  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1060 s / it)
# Averaged stats: model_time: 0.0164 (0.0166)  evaluator_time: 0.0164 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# 2.028378486633301
# Epoch: [118]  [ 0/22]  eta: 0:00:55  lr: 0.000030  time: 2.5188  data: 2.1626  max mem: 12999
# 1.5237988233566284
# 1.6100194454193115
# 1.9879809617996216
# 1.3771735429763794
# 1.5349059104919434
# 1.5950052738189697
# 1.7271900177001953
# 1.734706997871399
# 1.61905837059021
# 1.776885747909546
# 1.987175464630127
# 1.3540940284729004
# 1.7623858451843262
# 2.0467662811279297
# 2.2434468269348145
# 1.7742931842803955
# 1.7812743186950684
# 1.6256239414215088
# 2.006654977798462
# 1.8700662851333618
# Epoch: [118]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1878  data: 1.8452  max mem: 12999
# 1.913871169090271
# Epoch: [118]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1648  data: 1.8260  max mem: 12999
# Epoch: [118] Total time: 0:00:48 (2.1902 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0186 (0.0186)  evaluator_time: 0.0133 (0.0133)  time: 0.1010  data: 0.0652  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0168)  evaluator_time: 0.0160 (0.0262)  time: 0.1078  data: 0.0565  max mem: 12999
# Test: Total time: 0:00:04 (0.1056 s / it)
# Averaged stats: model_time: 0.0166 (0.0168)  evaluator_time: 0.0160 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 2.036879777908325
# Epoch: [119]  [ 0/22]  eta: 0:00:54  lr: 0.000030  time: 2.4866  data: 2.1509  max mem: 12999
# 2.1667613983154297
# 1.5946401357650757
# 1.811169981956482
# 1.6162017583847046
# 1.8703012466430664
# 1.7297430038452148
# 1.5639994144439697
# 2.135159730911255
# 1.7657580375671387
# 1.4797362089157104
# 1.9920241832733154
# 1.464446783065796
# 1.7836098670959473
# 1.887198805809021
# 1.9030613899230957
# 1.7525274753570557
# 1.8544584512710571
# 1.6466641426086426
# 2.5165655612945557
# 1.5992934703826904
# Epoch: [119]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2950  data: 1.9276  max mem: 12999
# 1.9877692461013794
# Epoch: [119]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2655  data: 1.9023  max mem: 12999
# Epoch: [119] Total time: 0:00:50 (2.2978 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:05  model_time: 0.0577 (0.0577)  evaluator_time: 0.0130 (0.0130)  time: 0.1364  data: 0.0620  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0177)  evaluator_time: 0.0159 (0.0263)  time: 0.1074  data: 0.0564  max mem: 12999
# Test: Total time: 0:00:04 (0.1063 s / it)
# Averaged stats: model_time: 0.0164 (0.0177)  evaluator_time: 0.0159 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# Training time 0:18:21

# %%
start_time = time.time()

for epoch in range(120, 150):
    train_one_epoch(model, optimizer, data_loader, device, epoch, 20)
    lr_scheduler.step()
    ap = evaluate(model, data_loader_test, device=device).coco_eval["bbox"].stats[0]
    if ap > best_ap:
      best_ap = ap
      best_model_weights = model.state_dict()

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# 1.8815008401870728
# Epoch: [120]  [ 0/22]  eta: 0:00:52  lr: 0.000030  time: 2.3955  data: 2.1442  max mem: 12999
# 1.765442132949829
# 1.4625215530395508
# 2.1458537578582764
# 2.3577799797058105
# 1.645620584487915
# 1.9083654880523682
# 1.7686976194381714
# 1.7786095142364502
# 1.8517048358917236
# 2.361187696456909
# 1.5881495475769043
# 1.993222713470459
# 1.6873246431350708
# 1.5787760019302368
# 1.9499197006225586
# 1.8770813941955566
# 1.7296322584152222
# 2.80816650390625
# 2.0396387577056885
# 1.620174765586853
# Epoch: [120]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2184  data: 1.8572  max mem: 12999
# 1.5713119506835938
# Epoch: [120]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2092  data: 1.8490  max mem: 12999
# Epoch: [120] Total time: 0:00:48 (2.2231 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0128 (0.0128)  time: 0.0968  data: 0.0632  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0165)  evaluator_time: 0.0230 (0.0299)  time: 0.1151  data: 0.0575  max mem: 12999
# Test: Total time: 0:00:04 (0.1098 s / it)
# Averaged stats: model_time: 0.0164 (0.0165)  evaluator_time: 0.0230 (0.0299)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 1.6649835109710693
# Epoch: [121]  [ 0/22]  eta: 0:00:48  lr: 0.000030  time: 2.2130  data: 1.8638  max mem: 12999
# 1.871873378753662
# 1.7000128030776978
# 1.8380746841430664
# 1.9498000144958496
# 1.6555689573287964
# 2.498953342437744
# 2.0899112224578857
# 1.5777647495269775
# 1.5873279571533203
# 1.6880792379379272
# 1.827620029449463
# 1.5986146926879883
# 1.6633304357528687
# 2.067695379257202
# 1.35561203956604
# 1.619520664215088
# 1.5706262588500977
# 2.090179681777954
# 1.8045620918273926
# 1.4182345867156982
# Epoch: [121]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2098  data: 1.8581  max mem: 12999
# 2.1837716102600098
# Epoch: [121]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1825  data: 1.8338  max mem: 12999
# Epoch: [121] Total time: 0:00:48 (2.2000 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0274 (0.0274)  evaluator_time: 0.0128 (0.0128)  time: 0.1054  data: 0.0615  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0171)  evaluator_time: 0.0169 (0.0264)  time: 0.1087  data: 0.0570  max mem: 12999
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0168 (0.0171)  evaluator_time: 0.0169 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.546
# 1.9099528789520264
# Epoch: [122]  [ 0/22]  eta: 0:00:49  lr: 0.000030  time: 2.2356  data: 1.9016  max mem: 12999
# 1.984511137008667
# 1.920607566833496
# 2.2390732765197754
# 1.8120701313018799
# 1.8847839832305908
# 1.9279489517211914
# 1.7668513059616089
# 1.7235333919525146
# 1.5804758071899414
# 1.9915657043457031
# 1.3456389904022217
# 1.4618372917175293
# 1.761582612991333
# 1.6334110498428345
# 1.986598253250122
# 1.414023756980896
# 1.7692997455596924
# 1.6716349124908447
# 1.7030975818634033
# 1.8395650386810303
# Epoch: [122]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1531  data: 1.8235  max mem: 12999
# 1.697410225868225
# Epoch: [122]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1324  data: 1.8095  max mem: 12999
# Epoch: [122] Total time: 0:00:47 (2.1456 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0181 (0.0181)  evaluator_time: 0.0130 (0.0130)  time: 0.0964  data: 0.0617  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0166)  evaluator_time: 0.0179 (0.0265)  time: 0.1082  data: 0.0571  max mem: 12999
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0163 (0.0166)  evaluator_time: 0.0179 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.545
# 1.6762070655822754
# Epoch: [123]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1083  data: 1.7203  max mem: 12999
# 1.8025455474853516
# 1.7832434177398682
# 1.383744716644287
# 1.7205839157104492
# 1.4939695596694946
# 1.7378803491592407
# 2.1311888694763184
# 1.8690577745437622
# 2.2119243144989014
# 1.685760498046875
# 1.8545444011688232
# 1.5243942737579346
# 1.976574182510376
# 1.970813512802124
# 1.508122444152832
# 1.58162522315979
# 1.9992350339889526
# 1.7414785623550415
# 1.9811158180236816
# 1.9492279291152954
# Epoch: [123]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1714  data: 1.8224  max mem: 12999
# 1.7111701965332031
# Epoch: [123]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1517  data: 1.8108  max mem: 12999
# Epoch: [123] Total time: 0:00:47 (2.1567 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0172 (0.0172)  evaluator_time: 0.0127 (0.0127)  time: 0.0957  data: 0.0621  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0168 (0.0170)  evaluator_time: 0.0161 (0.0265)  time: 0.1099  data: 0.0583  max mem: 12999
# Test: Total time: 0:00:04 (0.1074 s / it)
# Averaged stats: model_time: 0.0168 (0.0170)  evaluator_time: 0.0161 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# 1.4539133310317993
# Epoch: [124]  [ 0/22]  eta: 0:00:52  lr: 0.000030  time: 2.3800  data: 1.9921  max mem: 12999
# 1.9683053493499756
# 1.760986089706421
# 1.6236412525177002
# 1.940934181213379
# 2.040661573410034
# 1.6733227968215942
# 1.729582667350769
# 1.7764945030212402
# 2.1204545497894287
# 1.7346949577331543
# 1.9312341213226318
# 1.9446704387664795
# 1.752213716506958
# 1.7226219177246094
# 1.913055181503296
# 1.9209831953048706
# 1.6203476190567017
# 1.4879454374313354
# 1.9534382820129395
# 1.581438660621643
# Epoch: [124]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2284  data: 1.8766  max mem: 12999
# 2.4107537269592285
# Epoch: [124]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2268  data: 1.8794  max mem: 12999
# Epoch: [124] Total time: 0:00:49 (2.2374 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0174 (0.0174)  evaluator_time: 0.0128 (0.0128)  time: 0.0978  data: 0.0638  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0167)  evaluator_time: 0.0157 (0.0262)  time: 0.1092  data: 0.0582  max mem: 12999
# Test: Total time: 0:00:04 (0.1065 s / it)
# Averaged stats: model_time: 0.0164 (0.0167)  evaluator_time: 0.0157 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.9129211902618408
# Epoch: [125]  [ 0/22]  eta: 0:00:52  lr: 0.000030  time: 2.3687  data: 1.9682  max mem: 12999
# 2.0752112865448
# 1.815779209136963
# 1.655487060546875
# 1.853790044784546
# 1.8774464130401611
# 1.992521047592163
# 2.198909282684326
# 1.440435528755188
# 2.2490344047546387
# 1.7614742517471313
# 1.6416125297546387
# 1.6663084030151367
# 1.5357319116592407
# 1.7108113765716553
# 1.462522268295288
# 2.347841739654541
# 1.9668184518814087
# 1.555098533630371
# 1.6804468631744385
# 1.7183765172958374
# Epoch: [125]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1947  data: 1.8343  max mem: 12999
# 2.1640875339508057
# Epoch: [125]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1977  data: 1.8357  max mem: 12999
# Epoch: [125] Total time: 0:00:48 (2.2036 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0129 (0.0129)  time: 0.0953  data: 0.0616  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0164)  evaluator_time: 0.0168 (0.0265)  time: 0.1073  data: 0.0562  max mem: 12999
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0163 (0.0164)  evaluator_time: 0.0168 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# 1.6746478080749512
# Epoch: [126]  [ 0/22]  eta: 0:00:59  lr: 0.000030  time: 2.7032  data: 2.2980  max mem: 12999
# 1.6016430854797363
# 1.8866360187530518
# 2.087164878845215
# 1.7661038637161255
# 1.759626865386963
# 1.645861029624939
# 1.380344033241272
# 1.6131964921951294
# 1.5698825120925903
# 1.883804440498352
# 1.6498637199401855
# 1.901766300201416
# 1.9725158214569092
# 1.5637187957763672
# 1.584273099899292
# 1.6593979597091675
# 2.1086578369140625
# 1.9437215328216553
# 1.5208768844604492
# 1.8491837978363037
# Epoch: [126]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1978  data: 1.8583  max mem: 12999
# 1.915001630783081
# Epoch: [126]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1931  data: 1.8517  max mem: 12999
# Epoch: [126] Total time: 0:00:48 (2.2140 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0123 (0.0123)  time: 0.0955  data: 0.0625  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0164)  evaluator_time: 0.0162 (0.0262)  time: 0.1071  data: 0.0566  max mem: 12999
# Test: Total time: 0:00:04 (0.1053 s / it)
# Averaged stats: model_time: 0.0162 (0.0164)  evaluator_time: 0.0162 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.3970298767089844
# Epoch: [127]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1288  data: 1.7972  max mem: 12999
# 2.1390023231506348
# 2.0784881114959717
# 2.0589122772216797
# 1.5023481845855713
# 1.6722164154052734
# 1.8171656131744385
# 1.5529972314834595
# 1.724452257156372
# 1.5444549322128296
# 1.7677481174468994
# 1.9058241844177246
# 2.1002254486083984
# 1.551591157913208
# 1.9252548217773438
# 1.8688695430755615
# 1.5010907649993896
# 1.6926915645599365
# 1.6332889795303345
# 1.942368984222412
# 2.211057424545288
# Epoch: [127]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1146  data: 1.7967  max mem: 12999
# 1.9276045560836792
# Epoch: [127]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.0984  data: 1.7819  max mem: 12999
# Epoch: [127] Total time: 0:00:46 (2.1105 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0127 (0.0127)  time: 0.0943  data: 0.0611  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0164)  evaluator_time: 0.0164 (0.0262)  time: 0.1076  data: 0.0565  max mem: 12999
# Test: Total time: 0:00:04 (0.1049 s / it)
# Averaged stats: model_time: 0.0165 (0.0164)  evaluator_time: 0.0164 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
# 2.1315579414367676
# Epoch: [128]  [ 0/22]  eta: 0:00:57  lr: 0.000030  time: 2.6363  data: 2.2965  max mem: 12999
# 2.195624351501465
# 1.8700175285339355
# 1.593636155128479
# 1.622397780418396
# 2.145179271697998
# 1.6537293195724487
# 1.780821442604065
# 1.4905648231506348
# 1.4527391195297241
# 1.6098390817642212
# 2.1561734676361084
# 1.9767576456069946
# 1.9798541069030762
# 1.1928621530532837
# 1.9343827962875366
# 1.498489499092102
# 1.6907243728637695
# 1.8013861179351807
# 1.630340576171875
# 1.615082025527954
# Epoch: [128]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1069  data: 1.7769  max mem: 12999
# 1.6626209020614624
# Epoch: [128]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1084  data: 1.7754  max mem: 12999
# Epoch: [128] Total time: 0:00:46 (2.1339 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0180 (0.0180)  evaluator_time: 0.0124 (0.0124)  time: 0.0954  data: 0.0611  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0169 (0.0167)  evaluator_time: 0.0170 (0.0264)  time: 0.1095  data: 0.0578  max mem: 12999
# Test: Total time: 0:00:04 (0.1064 s / it)
# Averaged stats: model_time: 0.0169 (0.0167)  evaluator_time: 0.0170 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# 2.2197487354278564
# Epoch: [129]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1052  data: 1.7836  max mem: 12999
# 2.305440902709961
# 1.8222827911376953
# 1.6874489784240723
# 1.4845890998840332
# 1.8633575439453125
# 1.8157782554626465
# 1.8767896890640259
# 1.9739322662353516
# 1.2707710266113281
# 1.6558588743209839
# 1.3580836057662964
# 1.9019854068756104
# 1.4795048236846924
# 1.901698350906372
# 1.8896238803863525
# 1.466353416442871
# 1.8627773523330688
# 1.7339175939559937
# 1.9102017879486084
# 1.8265581130981445
# Epoch: [129]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1596  data: 1.8264  max mem: 12999
# 2.1210200786590576
# Epoch: [129]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1666  data: 1.8349  max mem: 12999
# Epoch: [129] Total time: 0:00:47 (2.1734 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0175 (0.0175)  evaluator_time: 0.0130 (0.0130)  time: 0.0960  data: 0.0617  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0167)  evaluator_time: 0.0169 (0.0264)  time: 0.1073  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0164 (0.0167)  evaluator_time: 0.0169 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
# 1.5973447561264038
# Epoch: [130]  [ 0/22]  eta: 0:00:44  lr: 0.000030  time: 2.0227  data: 1.6046  max mem: 12999
# 1.988732099533081
# 2.086503744125366
# 1.9975354671478271
# 1.798777461051941
# 1.6390855312347412
# 1.7042431831359863
# 1.6162009239196777
# 2.0827648639678955
# 1.529009222984314
# 1.7419849634170532
# 1.9484632015228271
# 1.7211153507232666
# 1.8482670783996582
# 2.3259310722351074
# 2.702303409576416
# 1.853432059288025
# 2.177567958831787
# 1.5982286930084229
# 1.7094537019729614
# 1.732479214668274
# Epoch: [130]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2777  data: 1.9066  max mem: 12999
# 1.7040128707885742
# Epoch: [130]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2604  data: 1.8921  max mem: 12999
# Epoch: [130] Total time: 0:00:49 (2.2653 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0130 (0.0130)  time: 0.0960  data: 0.0622  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0165)  evaluator_time: 0.0179 (0.0265)  time: 0.1072  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1056 s / it)
# Averaged stats: model_time: 0.0164 (0.0165)  evaluator_time: 0.0179 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.563
# 1.8872982263565063
# Epoch: [131]  [ 0/22]  eta: 0:00:49  lr: 0.000030  time: 2.2355  data: 1.8599  max mem: 12999
# 1.542456030845642
# 1.4966206550598145
# 1.6250579357147217
# 1.9727296829223633
# 2.1891531944274902
# 1.842930555343628
# 1.9074831008911133
# 1.7037019729614258
# 1.464847207069397
# 1.7131961584091187
# 1.7935150861740112
# 2.2695839405059814
# 1.7248376607894897
# 1.9580717086791992
# 2.205913543701172
# 1.5915250778198242
# 2.183290958404541
# 2.0290420055389404
# 1.8749847412109375
# 1.6132330894470215
# Epoch: [131]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.3332  data: 1.9701  max mem: 12999
# 1.511038064956665
# Epoch: [131]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2961  data: 1.9383  max mem: 12999
# Epoch: [131] Total time: 0:00:50 (2.3090 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0189 (0.0189)  evaluator_time: 0.0124 (0.0124)  time: 0.0978  data: 0.0628  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0170)  evaluator_time: 0.0163 (0.0261)  time: 0.1078  data: 0.0567  max mem: 12999
# Test: Total time: 0:00:04 (0.1057 s / it)
# Averaged stats: model_time: 0.0167 (0.0170)  evaluator_time: 0.0163 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.5479495525360107
# Epoch: [132]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.0958  data: 1.8572  max mem: 12999
# 2.1936633586883545
# 1.7993415594100952
# 1.8456016778945923
# 1.6469205617904663
# 1.6953456401824951
# 2.248661994934082
# 1.9092447757720947
# 1.5410188436508179
# 1.7361282110214233
# 1.599560022354126
# 1.7114083766937256
# 1.7320141792297363
# 1.6365166902542114
# 2.0442821979522705
# 1.5823521614074707
# 1.4877656698226929
# 1.8084790706634521
# 1.5101642608642578
# 2.2970938682556152
# 1.6819193363189697
# Epoch: [132]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1174  data: 1.7942  max mem: 12999
# 2.1705238819122314
# Epoch: [132]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.0933  data: 1.7755  max mem: 12999
# Epoch: [132] Total time: 0:00:46 (2.1115 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0192 (0.0192)  evaluator_time: 0.0140 (0.0140)  time: 0.0998  data: 0.0628  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0167)  evaluator_time: 0.0160 (0.0264)  time: 0.1071  data: 0.0565  max mem: 12999
# Test: Total time: 0:00:04 (0.1061 s / it)
# Averaged stats: model_time: 0.0163 (0.0167)  evaluator_time: 0.0160 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.550
# 1.7948474884033203
# Epoch: [133]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1290  data: 1.7637  max mem: 12999
# 1.5283775329589844
# 1.607271432876587
# 1.9646036624908447
# 1.8153438568115234
# 2.1056432723999023
# 2.207643747329712
# 2.07051682472229
# 2.2990994453430176
# 1.521462082862854
# 1.6453033685684204
# 1.5897470712661743
# 2.235161542892456
# 2.084533214569092
# 1.6178829669952393
# 1.5446398258209229
# 2.2470028400421143
# 1.8589396476745605
# 1.645240068435669
# 1.6572574377059937
# 1.6322762966156006
# Epoch: [133]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2429  data: 1.8778  max mem: 12999
# 1.7617145776748657
# Epoch: [133]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2408  data: 1.8726  max mem: 12999
# Epoch: [133] Total time: 0:00:48 (2.2271 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0359 (0.0359)  evaluator_time: 0.0132 (0.0132)  time: 0.1152  data: 0.0621  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0170)  evaluator_time: 0.0227 (0.0296)  time: 0.1150  data: 0.0573  max mem: 12999
# Test: Total time: 0:00:04 (0.1091 s / it)
# Averaged stats: model_time: 0.0165 (0.0170)  evaluator_time: 0.0227 (0.0296)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.550
# 1.9386223554611206
# Epoch: [134]  [ 0/22]  eta: 0:00:57  lr: 0.000030  time: 2.6340  data: 2.1854  max mem: 12999
# 2.468966007232666
# 1.8845367431640625
# 1.61465585231781
# 1.7432856559753418
# 2.0308775901794434
# 1.607079029083252
# 1.8178308010101318
# 2.1493113040924072
# 2.011744976043701
# 1.7333970069885254
# 1.8121421337127686
# 2.0156867504119873
# 1.4818974733352661
# 1.6545082330703735
# 1.6238373517990112
# 1.7497117519378662
# 1.8218756914138794
# 1.645003080368042
# 1.8059089183807373
# 1.3213200569152832
# Epoch: [134]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1970  data: 1.8299  max mem: 12999
# 1.8760732412338257
# Epoch: [134]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1760  data: 1.8099  max mem: 12999
# Epoch: [134] Total time: 0:00:48 (2.2138 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0170 (0.0170)  evaluator_time: 0.0125 (0.0125)  time: 0.0956  data: 0.0624  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0163)  evaluator_time: 0.0170 (0.0263)  time: 0.1081  data: 0.0574  max mem: 12999
# Test: Total time: 0:00:04 (0.1052 s / it)
# Averaged stats: model_time: 0.0162 (0.0163)  evaluator_time: 0.0170 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.563
# 1.5307087898254395
# Epoch: [135]  [ 0/22]  eta: 0:00:39  lr: 0.000030  time: 1.7944  data: 1.4568  max mem: 12999
# 1.7213314771652222
# 1.6563024520874023
# 1.8755488395690918
# 2.1173627376556396
# 1.789578914642334
# 1.6365095376968384
# 1.4632596969604492
# 1.891587734222412
# 1.647387981414795
# 1.6514594554901123
# 1.4366375207901
# 1.764366626739502
# 1.8695006370544434
# 1.6674535274505615
# 1.890298843383789
# 1.8659452199935913
# 2.1753711700439453
# 1.6508930921554565
# 1.8057403564453125
# 1.7959351539611816
# Epoch: [135]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2428  data: 1.8790  max mem: 12999
# 1.4947742223739624
# Epoch: [135]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2236  data: 1.8650  max mem: 12999
# Epoch: [135] Total time: 0:00:48 (2.2202 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0124 (0.0124)  time: 0.0946  data: 0.0616  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0165)  evaluator_time: 0.0165 (0.0264)  time: 0.1079  data: 0.0571  max mem: 12999
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0162 (0.0165)  evaluator_time: 0.0165 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# 1.5102531909942627
# Epoch: [136]  [ 0/22]  eta: 0:01:00  lr: 0.000030  time: 2.7333  data: 2.3406  max mem: 12999
# 1.663443684577942
# 1.7428452968597412
# 1.8764395713806152
# 2.1962952613830566
# 1.56982421875
# 1.8067723512649536
# 1.6953643560409546
# 1.915390968322754
# 1.7885475158691406
# 1.4407979249954224
# 2.517730236053467
# 1.952744960784912
# 1.8904576301574707
# 1.5053783655166626
# 2.227675437927246
# 1.98838210105896
# 2.556694507598877
# 1.88725745677948
# 1.715775489807129
# 1.828039288520813
# Epoch: [136]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1966  data: 1.8504  max mem: 12999
# 1.5872678756713867
# Epoch: [136]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1765  data: 1.8239  max mem: 12999
# Epoch: [136] Total time: 0:00:48 (2.2090 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0172 (0.0172)  evaluator_time: 0.0126 (0.0126)  time: 0.0962  data: 0.0627  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0166)  evaluator_time: 0.0170 (0.0263)  time: 0.1087  data: 0.0577  max mem: 12999
# Test: Total time: 0:00:04 (0.1062 s / it)
# Averaged stats: model_time: 0.0164 (0.0166)  evaluator_time: 0.0170 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
# 1.7820380926132202
# Epoch: [137]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1320  data: 1.8965  max mem: 12999
# 1.9997626543045044
# 1.581937551498413
# 1.4825669527053833
# 1.8291394710540771
# 1.8615264892578125
# 1.6681984663009644
# 1.793381690979004
# 1.9473681449890137
# 1.7886995077133179
# 2.0434489250183105
# 2.0108532905578613
# 1.7340739965438843
# 2.1595282554626465
# 1.8206889629364014
# 1.6670572757720947
# 2.002610206604004
# 1.808932900428772
# 1.624286413192749
# 2.010591983795166
# 1.6388510465621948
# Epoch: [137]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1855  data: 1.8443  max mem: 12999
# 1.5785505771636963
# Epoch: [137]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1514  data: 1.8111  max mem: 12999
# Epoch: [137] Total time: 0:00:47 (2.1783 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0178 (0.0178)  evaluator_time: 0.0122 (0.0122)  time: 0.0971  data: 0.0633  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0168)  evaluator_time: 0.0161 (0.0266)  time: 0.1078  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1062 s / it)
# Averaged stats: model_time: 0.0167 (0.0168)  evaluator_time: 0.0161 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.550
# 1.815441608428955
# Epoch: [138]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1245  data: 1.7739  max mem: 12999
# 1.9047054052352905
# 1.6210802793502808
# 2.0399088859558105
# 1.681751012802124
# 2.2995166778564453
# 1.6092894077301025
# 1.672450065612793
# 1.6228607892990112
# 1.6198982000350952
# 1.5375232696533203
# 1.6133980751037598
# 1.643411636352539
# 1.6275372505187988
# 2.1710922718048096
# 1.7965943813323975
# 1.4159406423568726
# 1.6441608667373657
# 1.9381563663482666
# 2.3996527194976807
# 1.626298189163208
# Epoch: [138]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2242  data: 1.8673  max mem: 12999
# 1.5910570621490479
# Epoch: [138]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2019  data: 1.8454  max mem: 12999
# Epoch: [138] Total time: 0:00:48 (2.2168 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0188 (0.0188)  evaluator_time: 0.0123 (0.0123)  time: 0.0988  data: 0.0637  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0169 (0.0168)  evaluator_time: 0.0163 (0.0266)  time: 0.1086  data: 0.0566  max mem: 12999
# Test: Total time: 0:00:04 (0.1067 s / it)
# Averaged stats: model_time: 0.0169 (0.0168)  evaluator_time: 0.0163 (0.0266)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# 1.5982978343963623
# Epoch: [139]  [ 0/22]  eta: 0:00:50  lr: 0.000030  time: 2.2878  data: 1.8215  max mem: 12999
# 1.806125521659851
# 1.9169044494628906
# 1.7342537641525269
# 1.7991526126861572
# 2.0189664363861084
# 2.058540105819702
# 2.0260767936706543
# 2.2103352546691895
# 1.6587481498718262
# 1.7712225914001465
# 1.8565709590911865
# 2.138092041015625
# 2.431473731994629
# 1.717517614364624
# 1.6813393831253052
# 1.734877586364746
# 1.889702320098877
# 1.5649514198303223
# 1.8104698657989502
# 1.7995376586914062
# Epoch: [139]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1392  data: 1.7834  max mem: 12999
# 1.7951704263687134
# Epoch: [139]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1204  data: 1.7637  max mem: 12999
# Epoch: [139] Total time: 0:00:47 (2.1381 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0167 (0.0167)  evaluator_time: 0.0126 (0.0126)  time: 0.0943  data: 0.0612  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0165)  evaluator_time: 0.0166 (0.0262)  time: 0.1070  data: 0.0564  max mem: 12999
# Test: Total time: 0:00:04 (0.1055 s / it)
# Averaged stats: model_time: 0.0163 (0.0165)  evaluator_time: 0.0166 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.563
# 1.5428078174591064
# Epoch: [140]  [ 0/22]  eta: 0:00:53  lr: 0.000030  time: 2.4238  data: 2.0651  max mem: 12999
# 1.760979413986206
# 1.8677756786346436
# 1.5836331844329834
# 1.7434332370758057
# 1.364986777305603
# 1.8849308490753174
# 1.9969656467437744
# 1.50384521484375
# 1.727450966835022
# 1.9523500204086304
# 1.9792028665542603
# 1.7272742986679077
# 1.9818780422210693
# 2.229132652282715
# 1.5099003314971924
# 1.4946950674057007
# 1.7783994674682617
# 1.5400384664535522
# 1.7513718605041504
# 1.6598187685012817
# Epoch: [140]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2048  data: 1.8564  max mem: 12999
# 1.5605322122573853
# Epoch: [140]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2019  data: 1.8530  max mem: 12999
# Epoch: [140] Total time: 0:00:48 (2.2149 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0177 (0.0177)  evaluator_time: 0.0127 (0.0127)  time: 0.0995  data: 0.0654  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0167)  evaluator_time: 0.0160 (0.0265)  time: 0.1071  data: 0.0560  max mem: 12999
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0165 (0.0167)  evaluator_time: 0.0160 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# 1.5396158695220947
# Epoch: [141]  [ 0/22]  eta: 0:00:49  lr: 0.000030  time: 2.2520  data: 1.9373  max mem: 12999
# 1.6652283668518066
# 1.697428822517395
# 2.07879638671875
# 1.586708903312683
# 2.0762789249420166
# 1.7622121572494507
# 2.164823055267334
# 1.7053903341293335
# 1.81520414352417
# 1.4020466804504395
# 1.9899780750274658
# 1.9002928733825684
# 1.7265751361846924
# 1.6071109771728516
# 1.881045937538147
# 1.512843370437622
# 1.8379383087158203
# 1.6598832607269287
# 1.2718896865844727
# 1.9658219814300537
# Epoch: [141]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1045  data: 1.7557  max mem: 12999
# 1.7293469905853271
# Epoch: [141]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1066  data: 1.7543  max mem: 12999
# Epoch: [141] Total time: 0:00:46 (2.1241 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0399 (0.0399)  evaluator_time: 0.0130 (0.0130)  time: 0.1205  data: 0.0639  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0173)  evaluator_time: 0.0163 (0.0261)  time: 0.1073  data: 0.0563  max mem: 12999
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0165 (0.0173)  evaluator_time: 0.0163 (0.0261)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 1.5789868831634521
# Epoch: [143]  [ 0/22]  eta: 0:00:45  lr: 0.000030  time: 2.0718  data: 1.6502  max mem: 12999
# 2.042055368423462
# 1.8509364128112793
# 1.7485392093658447
# 1.6755322217941284
# 1.8931050300598145
# 1.6226167678833008
# 1.6897380352020264
# 1.479813814163208
# 2.2049546241760254
# 1.7328639030456543
# 1.8635485172271729
# 1.6642450094223022
# 1.8209936618804932
# 1.776108741760254
# 1.3714752197265625
# 1.8450919389724731
# 2.017951011657715
# 1.8444042205810547
# 1.7632648944854736
# 1.9625062942504883
# Epoch: [143]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.0637  data: 1.7425  max mem: 12999
# 1.8496031761169434
# Epoch: [143]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.0488  data: 1.7291  max mem: 12999
# Epoch: [143] Total time: 0:00:45 (2.0512 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0174 (0.0174)  evaluator_time: 0.0126 (0.0126)  time: 0.0967  data: 0.0630  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0165 (0.0167)  evaluator_time: 0.0163 (0.0264)  time: 0.1078  data: 0.0567  max mem: 12999
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0165 (0.0167)  evaluator_time: 0.0163 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# 1.5605978965759277
# Epoch: [144]  [ 0/22]  eta: 0:00:40  lr: 0.000030  time: 1.8308  data: 1.5184  max mem: 12999
# 1.407486081123352
# 1.8235399723052979
# 1.8120415210723877
# 1.7881689071655273
# 1.749699354171753
# 1.7398788928985596
# 1.627494215965271
# 2.0578689575195312
# 1.8700964450836182
# 2.0548324584960938
# 1.7107452154159546
# 1.8018710613250732
# 1.5592410564422607
# 1.809443712234497
# 1.7192628383636475
# 1.6216356754302979
# 1.8992313146591187
# 1.7013049125671387
# 1.9334195852279663
# 1.9790096282958984
# Epoch: [144]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.0583  data: 1.7269  max mem: 12999
# 1.7920539379119873
# Epoch: [144]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.0704  data: 1.7358  max mem: 12999
# Epoch: [144] Total time: 0:00:45 (2.0641 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:04  model_time: 0.0329 (0.0329)  evaluator_time: 0.0124 (0.0124)  time: 0.1127  data: 0.0636  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0171)  evaluator_time: 0.0159 (0.0263)  time: 0.1075  data: 0.0565  max mem: 12999
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0162 (0.0171)  evaluator_time: 0.0159 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
# 2.008674144744873
# Epoch: [145]  [ 0/22]  eta: 0:00:49  lr: 0.000030  time: 2.2468  data: 1.8608  max mem: 12999
# 2.1541197299957275
# 2.286895275115967
# 1.7550718784332275
# 2.0786097049713135
# 1.7135030031204224
# 1.8942655324935913
# 1.828111171722412
# 1.8242818117141724
# 1.798508882522583
# 1.7792086601257324
# 1.5541391372680664
# 1.5939297676086426
# 1.6345951557159424
# 2.3991074562072754
# 1.8467047214508057
# 1.4133340120315552
# 1.5581398010253906
# 1.7754836082458496
# 2.5469038486480713
# 1.714452862739563
# Epoch: [145]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2009  data: 1.8548  max mem: 12999
# 2.484819173812866
# Epoch: [145]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1893  data: 1.8419  max mem: 12999
# Epoch: [145] Total time: 0:00:48 (2.2032 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0173 (0.0173)  evaluator_time: 0.0127 (0.0127)  time: 0.0955  data: 0.0618  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0163 (0.0200)  evaluator_time: 0.0170 (0.0265)  time: 0.1144  data: 0.0567  max mem: 12999
# Test: Total time: 0:00:04 (0.1092 s / it)
# Averaged stats: model_time: 0.0163 (0.0200)  evaluator_time: 0.0170 (0.0265)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
# 1.5283019542694092
# Epoch: [146]  [ 0/22]  eta: 0:00:48  lr: 0.000030  time: 2.2096  data: 1.8776  max mem: 12999
# 1.5520933866500854
# 1.4722130298614502
# 1.7832274436950684
# 2.017139196395874
# 1.903699517250061
# 2.194481611251831
# 1.6261305809020996
# 1.5017681121826172
# 2.058216094970703
# 1.4952057600021362
# 1.7944016456604004
# 1.8846471309661865
# 1.6708526611328125
# 1.4702019691467285
# 1.4688923358917236
# 2.170862913131714
# 1.9036145210266113
# 2.4031805992126465
# 1.7590991258621216
# 1.7574572563171387
# Epoch: [146]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1295  data: 1.7759  max mem: 12999
# 1.5905348062515259
# Epoch: [146]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1288  data: 1.7751  max mem: 12999
# Epoch: [146] Total time: 0:00:46 (2.1342 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0175 (0.0175)  evaluator_time: 0.0136 (0.0136)  time: 0.0962  data: 0.0615  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0164 (0.0166)  evaluator_time: 0.0163 (0.0263)  time: 0.1087  data: 0.0576  max mem: 12999
# Test: Total time: 0:00:04 (0.1059 s / it)
# Averaged stats: model_time: 0.0164 (0.0166)  evaluator_time: 0.0163 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# 1.7125800848007202
# Epoch: [147]  [ 0/22]  eta: 0:00:46  lr: 0.000030  time: 2.1267  data: 1.8596  max mem: 12999
# 1.7595645189285278
# 1.820050597190857
# 1.6098990440368652
# 1.482621669769287
# 1.8605561256408691
# 2.302192211151123
# 2.022822618484497
# 1.5936517715454102
# 2.2875125408172607
# 1.7563917636871338
# 1.821617841720581
# 1.667483925819397
# 2.009363889694214
# 1.5006779432296753
# 1.6608480215072632
# 1.6105451583862305
# 1.807347297668457
# 2.072345495223999
# 1.7441719770431519
# 2.5802199840545654
# Epoch: [147]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.2724  data: 1.8963  max mem: 12999
# 1.9796571731567383
# Epoch: [147]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.2634  data: 1.8860  max mem: 12999
# Epoch: [147] Total time: 0:00:49 (2.2524 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0165 (0.0165)  evaluator_time: 0.0123 (0.0123)  time: 0.0939  data: 0.0614  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0167 (0.0178)  evaluator_time: 0.0179 (0.0264)  time: 0.1119  data: 0.0581  max mem: 12999
# Test: Total time: 0:00:04 (0.1074 s / it)
# Averaged stats: model_time: 0.0167 (0.0178)  evaluator_time: 0.0179 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# 1.6137641668319702
# Epoch: [148]  [ 0/22]  eta: 0:00:43  lr: 0.000030  time: 1.9836  data: 1.6947  max mem: 12999
# 2.1087629795074463
# 1.6241036653518677
# 1.6857404708862305
# 2.083682060241699
# 1.7816030979156494
# 1.6137166023254395
# 1.921575903892517
# 2.269700288772583
# 1.3924938440322876
# 1.8135037422180176
# 1.453488826751709
# 1.682681918144226
# 1.6295984983444214
# 1.7595956325531006
# 1.6963216066360474
# 1.691845178604126
# 2.069875478744507
# 1.725285291671753
# 1.585811972618103
# 2.0064446926116943
# Epoch: [148]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.0767  data: 1.7496  max mem: 12999
# 1.844957947731018
# Epoch: [148]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.0874  data: 1.7607  max mem: 12999
# Epoch: [148] Total time: 0:00:45 (2.0824 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0169 (0.0169)  evaluator_time: 0.0124 (0.0124)  time: 0.0958  data: 0.0628  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0162 (0.0164)  evaluator_time: 0.0158 (0.0262)  time: 0.1078  data: 0.0572  max mem: 12999
# Test: Total time: 0:00:04 (0.1054 s / it)
# Averaged stats: model_time: 0.0162 (0.0164)  evaluator_time: 0.0158 (0.0262)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.552
# 1.6069296598434448
# Epoch: [149]  [ 0/22]  eta: 0:00:47  lr: 0.000030  time: 2.1392  data: 1.8071  max mem: 12999
# 1.6090396642684937
# 1.8368511199951172
# 1.756708025932312
# 1.5844335556030273
# 1.827757716178894
# 1.8226933479309082
# 1.5286911725997925
# 1.568928837776184
# 1.662649393081665
# 1.8961738348007202
# 1.6657190322875977
# 1.6584982872009277
# 2.12724232673645
# 1.8963871002197266
# 1.7061519622802734
# 1.8397598266601562
# 1.905696153640747
# 1.7501475811004639
# 1.633155345916748
# 1.5739144086837769
# Epoch: [149]  [20/22]  eta: 0:00:04  lr: 0.000030  time: 2.1541  data: 1.8138  max mem: 12999
# 2.1515591144561768
# Epoch: [149]  [21/22]  eta: 0:00:02  lr: 0.000030  time: 2.1630  data: 1.8230  max mem: 12999
# Epoch: [149] Total time: 0:00:47 (2.1637 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:03  model_time: 0.0171 (0.0171)  evaluator_time: 0.0126 (0.0126)  time: 0.0954  data: 0.0621  max mem: 12999
# Test:  [39/40]  eta: 0:00:00  model_time: 0.0166 (0.0178)  evaluator_time: 0.0160 (0.0263)  time: 0.1084  data: 0.0573  max mem: 12999
# Test: Total time: 0:00:04 (0.1069 s / it)
# Averaged stats: model_time: 0.0166 (0.0178)  evaluator_time: 0.0160 (0.0263)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# Training time 0:27:20
